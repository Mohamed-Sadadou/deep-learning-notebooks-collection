# %% [markdown]
# # Fine Tunning T5 small model pour generer les aspects et opinions a partir de text

# %%
# !pip install datasets transformers SentencePiece accelerate rouge

# %% [markdown]
# imports

# %%
from datasets import load_dataset , Dataset
import pandas as pd
import torch
from torch.utils.data import DataLoader
from transformers import (
    T5ForConditionalGeneration,
    T5Tokenizer,
    AdamW,
    Trainer,
    TrainingArguments,
    AutoTokenizer,
    AutoModelForCausalLM,
    GenerationConfig,
    DataCollatorForSeq2Seq
    )
import json
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk import word_tokenize, pos_tag
from sklearn.model_selection import train_test_split
import ast
import numpy as np
from rouge import Rouge
import re
from nltk.tokenize import sent_tokenize
from textblob import TextBlob
import ast

# %% [markdown]
# # NLTK Downloading

# %%
nltk.download('punkt')
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# # load the datasets

# %%
df = pd.read_csv('/content/drive/MyDrive/Master 2/absa_df_extracted.csv')

total_size = len(df)
adjusted_total_size = total_size - (total_size % 1000)

train_ratio = 0.85
val_test_ratio = 0.15
val_ratio_of_val_test = 0.5

train_size = int(adjusted_total_size * train_ratio)
val_test_size = adjusted_total_size - train_size
val_size = int(val_test_size * val_ratio_of_val_test)
test_size = val_test_size - val_size

train_df = df.sample(n=train_size, random_state=42).reset_index(drop=True)
remaining_df = df.drop(train_df.index).reset_index(drop=True)
val_df = remaining_df.sample(n=val_size, random_state=42).reset_index(drop=True)
test_df = remaining_df.drop(val_df.index).reset_index(drop=True)

print(f"Taille totale ajustée: {adjusted_total_size}")
print(f"Taille de l'ensemble d'entraînement: {len(train_df)}")
print(f"Taille de l'ensemble de validation: {len(val_df)}")
print(f"Taille de l'ensemble de test: {len(test_df)}")
# Out:
# Taille totale ajustée: 28000
# Taille de l'ensemble d'entraînement: 23800
# Taille de l'ensemble de validation: 2100
# Taille de l'ensemble de test: 2885

# %% [markdown]
# ### sauvegarde pour chargement ulterieur

# %%
train_df.to_csv('/content/drive/MyDrive/Master 2/absa_train_df.csv', index=False)
val_df.to_csv('/content/drive/MyDrive/Master 2/absa_val_df.csv', index=False)
test_df.to_csv('/content/drive/MyDrive/Master 2/absa_test_df.csv', index=False)

# %% [markdown]
# ### Chargement

# %%
train_df= pd.read_csv('/content/drive/MyDrive/Master 2/absa_train_df.csv')
val_df= pd.read_csv('/content/drive/MyDrive/Master 2/absa_val_df.csv')
test_df= pd.read_csv('/content/drive/MyDrive/Master 2/absa_test_df.csv')

# %%
print(f"Taille de l'ensemble d'entraînement: {len(train_df)}")
print(f"Taille de l'ensemble de validation: {len(val_df)}")
print(f"Taille de l'ensemble de test: {len(test_df)}")
# Out:
# Taille de l'ensemble d'entraînement: 23800
# Taille de l'ensemble de validation: 2100
# Taille de l'ensemble de test: 2885

# %% [markdown]
# # Definition des fonction de formatage des données

# %%
def clean_elements(elements):
    cleaned_elements = []
    for element in elements:
        cleaned_element = re.sub(r'[^\w\s]', '', element)
        cleaned_elements.append(cleaned_element.strip())
    return cleaned_elements
def format_data(text, main_aspect, extracted_aspects, global_polarity, extracted_opinions):
    extracted_aspects_list = ast.literal_eval(extracted_aspects)
    extracted_opinions_list = ast.literal_eval(extracted_opinions)
    extracted_aspects_list = clean_elements(extracted_aspects_list)
    extracted_opinions_list = clean_elements(extracted_opinions_list)
    if not pd.isna(main_aspect) and main_aspect not in extracted_aspects_list:
        cleaned_main_aspect = re.sub(r'[^\w\s]', '', main_aspect)
        extracted_aspects_list.append(cleaned_main_aspect)
    extracted_aspects_list = list(set(extracted_aspects_list))
    extracted_opinions_list = list(set(extracted_opinions_list))
    if not extracted_opinions_list:
        extracted_opinions_list = ['neutral']
    extracted_aspects_str = ', '.join(extracted_aspects_list)
    extracted_opinions_str = ', '.join(extracted_opinions_list)
    input_text = f"review: {text}"
    target_text = f"main aspect: {main_aspect} extracted aspects: {extracted_aspects_str} extracted opinions: {extracted_opinions_str} global polarity: {global_polarity}  </s>"

    return input_text, target_text

def prepare_data(df, tokenizer):
    dataset = []
    for _, row in df.iterrows():
        input_text, target_text = format_data(row['text'], row['aspect'], row['extracted_aspects'], row['aspect_polarity'],row["extracted_opinions"])
        input_encoding = tokenizer(
            input_text,
            padding="max_length",
            truncation=True,
            max_length=150,
            return_tensors="pt"
        )
        target_encoding = tokenizer(
            target_text,
            padding="max_length",
            truncation=True,
            max_length=150,
            return_tensors="pt"
        )

        dataset.append({
            "input_ids": input_encoding.input_ids.squeeze(),
            "attention_mask": input_encoding.attention_mask.squeeze(),
            "labels": target_encoding.input_ids.squeeze()
        })

    return dataset

# %%
for _, row in train_df.iterrows():
        input_text, target_text = format_data(row['text'], row['aspect'], row['extracted_aspects'], row['aspect_polarity'], row['extracted_opinions'])
        print(target_text)
        break
# Out:
# main aspect: games extracted aspects: music, facebook, pictures, games, email, daughter extracted opinions: neutral global polarity: neutral  </s>

# %% [markdown]
# # Chargement du model T5 small pre entrainé

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# # Verification de la longeur de token

# %%
max_len_input = 0
max_len_target = 0

for _, row in train_df.iterrows():
    input_text, target_text = format_data(row['text'], row['aspect'], row['extracted_aspects'], row['aspect_polarity'], row['extracted_opinions'])
    input_tokens = tokenizer.tokenize(input_text)
    target_tokens = tokenizer.tokenize(target_text)
    max_len_input = max(max_len_input, len(input_tokens))
    max_len_target = max(max_len_target, len(target_tokens))

print(f"Nombre maximal de tokens pour input_text: {max_len_input}")
print(f"Nombre maximal de tokens pour target_text: {max_len_target}")
# Out:
# Nombre maximal de tokens pour input_text: 139
# Nombre maximal de tokens pour target_text: 103

# %% [markdown]
# #Lancement du fine tunning du model

# %%
train_dataset = prepare_data(train_df, tokenizer)
val_dataset = prepare_data(val_df, tokenizer)

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=40,
    per_device_train_batch_size=54,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    evaluation_strategy="epoch"
)
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator
)
trainer.train()

model.save_pretrained('/content/drive/MyDrive/Master 2/absa_t5_model_150L__')
tokenizer.save_pretrained('/content/drive/MyDrive/Master 2/absa_t5_model_150L__')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:303: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
#     <div>
#
#       <progress value='17640' max='17640' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [17640/17640 5:37:28, Epoch 40/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.394571</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.206300</td>
#       <td>0.296317</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.305300</td>
#       <td>0.257554</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.259100</td>
#       <td>0.232443</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.236700</td>
#       <td>0.212427</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.220800</td>
#       <td>0.194648</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.204900</td>
#       <td>0.180328</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.195000</td>
#       <td>0.168681</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.195000</td>
#       <td>0.156940</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.186000</td>
#       <td>0.147863</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.176500</td>
#       <td>0.139344</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.169500</td>
#       <td>0.132776</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.163700</td>
#       <td>0.125216</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.157300</td>
#       <td>0.119375</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.152000</td>
#       <td>0.113077</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.147800</td>
#       <td>0.108925</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.147800</td>
#       <td>0.104303</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.143300</td>
#       <td>0.100445</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.139400</td>
#       <td>0.097195</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.136600</td>
#       <td>0.093299</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.132900</td>
#       <td>0.090367</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.129500</td>
#       <td>0.087837</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.128000</td>
#       <td>0.085282</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.125200</td>
#       <td>0.083380</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.122900</td>
#       <td>0.080571</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.122900</td>
#       <td>0.078992</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.121500</td>
#       <td>0.077252</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.118900</td>
#       <td>0.075767</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.117500</td>
#       <td>0.074414</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.116100</td>
#       <td>0.073511</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.115200</td>
#       <td>0.072401</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.113300</td>
#       <td>0.071683</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.113300</td>
#       <td>0.070605</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.113300</td>
#       <td>0.069742</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.112000</td>
#       <td>0.069195</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.111500</td>
#       <td>0.068698</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.109800</td>
#       <td>0.068263</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.110300</td>
#       <td>0.068171</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.109600</td>
#       <td>0.067950</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.109800</td>
#       <td>0.067968</td>
#     </tr>
#   </tbody>
# </table><p>
# ('/content/drive/MyDrive/Master 2/absa_t5_model_150L_/tokenizer_config.json',
#  '/content/drive/MyDrive/Master 2/absa_t5_model_150L_/special_tokens_map.json',
#  '/content/drive/MyDrive/Master 2/absa_t5_model_150L_/spiece.model',
#  '/content/drive/MyDrive/Master 2/absa_t5_model_150L_/added_tokens.json')

# %% [markdown]
# # Chargement du model fine tuné

# %%
model_path = '/content/drive/MyDrive/Master 2/my_t5_model_150L_'
tokenizer = T5Tokenizer.from_pretrained(model_path)
model = T5ForConditionalGeneration.from_pretrained(model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# # Generation des predictions pour calcul de la performances

# %%
test_dataset = prepare_data(test_df, tokenizer)
def test_model(model, tokenizer, test_dataset, max_length=150):
    model.eval()
    predictions = []
    i = 0
    for batch in test_dataset:
        if(i%700==0):print( "itteration n° ",i)
        i+=1
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        if input_ids.ndim == 1:
            input_ids = input_ids.unsqueeze(0)
        if attention_mask.ndim == 1:
            attention_mask = attention_mask.unsqueeze(0)
        outputs = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=max_length)
        prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
        predictions.append(prediction)
    return predictions
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
test_predictions = test_model(model, tokenizer, test_dataset, max_length=150)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:303: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# itteration n°  0
# itteration n°  700
# itteration n°  1400
# itteration n°  2100
# itteration n°  2800

# %% [markdown]
# # Sauvegarde des predictions pour utilisations ulterieurs

# %%
file_path = '/content/drive/MyDrive/Master 2/test_predictions.csv'

# %%
df_predictions = pd.DataFrame({'predictions': test_predictions})
df_predictions.to_csv(file_path, index=False)

# %%
df_loaded = pd.read_csv(file_path)
test_predictions  = df_loaded['predictions'].tolist()

# %%
print((test_predictions[0]))
# Out:
# main aspect: hotel extracted aspects: importance, beauty, staff, area, nights, kindness, site, management, night extracted opinions: importance, beauty, kindness, suffering, bad global polarity: negative

# %% [markdown]
# # Associations des valeurs de generation et valeurs du dataset

# %%
truths=[]
predictions=[]
for i, (prediction, row) in enumerate(zip(test_predictions, test_df.iterrows())):
    actual_label = row[1]
    input_text, target_text = format_data(row[1]['text'], row[1]['aspect'], row[1]['extracted_aspects'], row[1]['aspect_polarity'], row[1]['extracted_opinions'])
    truths.append(target_text[:-5])
    predictions.append(prediction)
    print(f"Test Example {i + 1}:")
    print(f"Prediction   : {prediction}")
    print(f"Ground truth : {target_text[:-5]}")
    print("-" * 50)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Test Example 1636:
# Prediction   : main aspect: hotel extracted aspects: business, hall, hotel extracted opinions: fantastic global polarity: positive
# Ground truth : main aspect: transportation extracted aspects: business, transportation, hall, hotel extracted opinions: fantastic global polarity: neutral
# --------------------------------------------------
# Test Example 1637:
# Prediction   : main aspect: rooms extracted aspects: level, lot, rooms, food, bugs extracted opinions: desired, good global polarity: negative
# Ground truth : main aspect: rooms extracted aspects: level, lot, rooms, food, bugs extracted opinions: desired, good global polarity: negative
# --------------------------------------------------
# Test Example 1638:
# Prediction   : main aspect: hotel extracted aspects: entrance, navigator, thing, taxi, hotel extracted opinions: bad global polarity: negative
# Ground truth : main aspect: hotelservices extracted aspects: entrance, taxi, thing, navigator, hotelservices, hotel extracted opinions: bad global polarity: positive
# --------------------------------------------------
# Test Example 1639:
# Prediction   : main aspect: facilities extracted aspects: facilities, checkin extracted opinions: good global polarity: positive
# Ground truth : main aspect: hotelservices extracted aspects: checkout, checkin, hotelservices extracted opinions: good global polarity: neutral
# --------------------------------------------------
# Test Example 1640:
# Prediction   : main aspect: hotel extracted aspects: club, park, beach, restaurant, stars, aqua, hotel extracted opinions: clean, pleasant, enjoy, beautiful global polarity: positive
# Ground truth : main aspect: restaurant extracted aspects: club, park, stars, restaurant, beach, hotel, aqua extracted opinions: clean, relaxing, pleasant, enjoy, beautiful global polarity: positive
# --------------------------------------------------
# Test Example 1641:
# Prediction   : main aspect: hotel extracted aspects: hilton, recreation, visit, service, family, golf, time, hotels, courses, hotel extracted opinions: wonderful, excellent, beautiful, worth, great global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: hilton, recreation, golf, visit, service, family, time, hotels, courses, worth, hotel extracted opinions: excellent, wonderful, beautiful, worth, great global polarity: positive
# --------------------------------------------------
# Test Example 1642:
# Prediction   : main aspect: hotel extracted aspects: i, staff, nights, hotel, end extracted opinions: helpful, friendly, good global polarity: positive
# Ground truth : main aspect: staff extracted aspects: i, staff, nights, hotel, end extracted opinions: helpful, friendly, good global polarity: positive
# --------------------------------------------------
# Test Example 1643:
# Prediction   : main aspect: room extracted aspects: parties, holidays, room extracted opinions: parties, holidays, fine global polarity: neutral
# Ground truth : main aspect: reception extracted aspects: reception, parties, holidays, room extracted opinions: parties, holidays, fine global polarity: neutral
# --------------------------------------------------
# Test Example 1644:
# Prediction   : main aspect: hotel extracted aspects: drinks, pool, views, rooms, submarine, atmosphere, sea, hotel extracted opinions: recommend, excellent, well global polarity: positive
# Ground truth : main aspect: parking extracted aspects: , drinks, pool, views, rooms, submarine, parking, atmosphere, sea, hotel extracted opinions: recommend, excellent, well global polarity: neutral
# --------------------------------------------------
# Test Example 1645:
# Prediction   : main aspect: room extracted aspects: breakfast, room, level, people, inconvenience, cleanliness extracted opinions: inconvenience, no, good, great global polarity: positive
# Ground truth : main aspect: staff extracted aspects: breakfast, room, staff, level, people, inconvenience, cleanliness extracted opinions: inconvenience, no, good, great global polarity: neutral
# --------------------------------------------------
# Test Example 1646:
# Prediction   : main aspect: television extracted aspects: tv, breakfast, reception, service, screen, rooms, television, selection extracted opinions: nice, clean, no global polarity: neutral
# Ground truth : main aspect: location extracted aspects: tv, breakfast, reception, service, screen, rooms, location, selection extracted opinions: nice, clean, no global polarity: neutral
# --------------------------------------------------
# Test Example 1647:
# Prediction   : main aspect: receptionists extracted aspects: saudi, reception, staff, course, receptionists, people, thanks extracted opinions: pleased, strange, thanks, respectable global polarity: positive
# Ground truth : main aspect: accommodation extracted aspects: saudi, reception, staff, course, accommodation, people, thanks extracted opinions: pleased, strange, thanks, respectable global polarity: positive
# --------------------------------------------------
# Test Example 1648:
# Prediction   : main aspect: room extracted aspects: room, season, leak, bathtub, roof, space, peak extracted opinions: leak, limited global polarity: negative
# Ground truth : main aspect: bathroom extracted aspects: room, season, bathtub, bathroom, roof, peak, space, leak extracted opinions: leak, limited global polarity: negative
# --------------------------------------------------
# Test Example 1649:
# Prediction   : main aspect: bathroom extracted aspects: door, shower, wires, bathroom, beware extracted opinions: poor, desperately global polarity: negative
# Ground truth : main aspect: bathroom extracted aspects: door, shower, wires, bathroom, beware extracted opinions: poor, torn, desperately global polarity: negative
# --------------------------------------------------
# Test Example 1650:
# Prediction   : main aspect: pool extracted aspects: pool, superpremium, service, relief, dementia, drink, way, meals, everything, chance, places, food, nightclubs, hotel extracted opinions: chance, relief global polarity: positive
# Ground truth : main aspect: food extracted aspects: pool, service, superpremium, relief, dementia, drink, way, meals, food, everything, chance, places, nightclubs, hotel extracted opinions: chance, relief global polarity: positive
# --------------------------------------------------
# Test Example 1651:
# Prediction   : main aspect: hotel extracted aspects:, traveler, staff, t, hotel extracted opinions: honest, fine, trust global polarity: negative
# Ground truth : main aspect: internet extracted aspects: , internet, traveler, staff, t, hotel extracted opinions: honest, fine, trust global polarity: neutral
# --------------------------------------------------
# Test Example 1652:
# Prediction   : main aspect: hotel extracted aspects: work, i, staff, kind, accommodation, machine, food, suites, bangkok, hotel extracted opinions: favorite, excellent, kind, good global polarity: positive
# Ground truth : main aspect: food extracted aspects: work, i, staff, kind, accommodation, machine, food, suites, bangkok, hotel extracted opinions: favorite, excellent, kind, good global polarity: positive
# --------------------------------------------------
# Test Example 1653:
# Prediction   : main aspect: hotel extracted aspects: room, level, air, conditioning, rooms, hotel extracted opinions: clean, bad global polarity: negative
# Ground truth : main aspect: cleanliness extracted aspects: room, level, air, conditioning, rooms, cleanliness, hotel extracted opinions: clean, bad global polarity: negative
# --------------------------------------------------
# Test Example 1654:
# Prediction   : main aspect: rooms extracted aspects: online, rooms, bother, lobby extracted opinions: recommend, no, good, bother global polarity: neutral
# Ground truth : main aspect: rooms extracted aspects: online, rooms, lobby, bother extracted opinions: recommend, no, good, bother, lobby global polarity: neutral
# --------------------------------------------------
# Test Example 1655:
# Prediction   : main aspect: food extracted aspects: trip, vista, food, middle, bar, sea, honesty, taste, hotel extracted opinions: honesty, comfortable, pleasant, beautiful, sweet global polarity: positive
# Ground truth : main aspect: sea extracted aspects: trip, vista, food, middle, bar, sea, honesty, taste, hotel extracted opinions: honesty, comfortable, pleasant, beautiful, sweet global polarity: positive
# --------------------------------------------------
# Test Example 1656:
# Prediction   : main aspect: hotel extracted aspects: internet, hurghada, i, club, resort, name, one, hotel extracted opinions: no global polarity: negative
# Ground truth : main aspect: internet extracted aspects: internet, hurghada, name, i, club, resort, online, hotel extracted opinions: no global polarity: negative
# --------------------------------------------------
# Test Example 1657:
# Prediction   : main aspect: rooms extracted aspects: room, water, rooms, time, obligations, bottles extracted opinions: obligations global polarity: negative
# Ground truth : main aspect: room extracted aspects: room, water, rooms, time, obligations, bottles extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 1658:
# Prediction   : main aspect: meals extracted aspects: options, breakfast, meals, inmate extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: receptionists extracted aspects: options, receptionists, breakfast, inmate extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Test Example 1659:
# Prediction   : main aspect: facilities extracted aspects: facilities, room extracted opinions: clean global polarity: positive
# Ground truth : main aspect: bathroom extracted aspects: facilities, bathroom, room extracted opinions: clean global polarity: neutral
# --------------------------------------------------
# Test Example 1660:
# Prediction   : main aspect: location extracted aspects:, i, service, location, price extracted opinions: like global polarity: negative
# Ground truth : main aspect: service extracted aspects: i, service, location, t, price extracted opinions: like global polarity: negative
# --------------------------------------------------
# Test Example 1661:
# Prediction   : main aspect: hotel extracted aspects: hello, staff, trip, nights, heart, meeting, city, tower, kingdom, business, hotel extracted opinions: friendly, landmark, well global polarity: positive
# Ground truth : main aspect: pool extracted aspects: hello, pool, staff, trip, heart, nights, landmark, meeting, city, tower, business, kingdom, hotel extracted opinions: friendly, landmark, well global polarity: neutral
# --------------------------------------------------
# Test Example 1662:
# Prediction   : main aspect: hotel extracted aspects: service, pools, rooms, ages, stars, food, children, sea, wonder, hotel extracted opinions: excellent, charming, safe, good, great global polarity: neutral
# Ground truth : main aspect: hotel extracted aspects: service, pools, ages, rooms, stars, food, children, sea, wonder, hotel extracted opinions: excellent, charming, safe, good, great global polarity: positive
# --------------------------------------------------
# Test Example 1663:
# Prediction   : main aspect: service extracted aspects: cups, service, food, beverage extracted opinions: bad, good global polarity: neutral
# Ground truth : main aspect: wifi extracted aspects: wifi, cups, service, plastic, food, beverage extracted opinions: bad, good global polarity: neutral
# --------------------------------------------------
# Test Example 1664:
# Prediction   : main aspect: reception extracted aspects: room, reception, service, staff, restaurant, exception extracted opinions: excellent global polarity: positive
# Ground truth : main aspect: receptionists extracted aspects: room, reception, staff, service, receptionists, restaurant, exception extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# Test Example 1665:
# Prediction   : main aspect: service extracted aspects: restaurant, swimming, quality, hotel, food, reefs, disadvantage, effort, buildings, terms, pools, size, rooms, beach, space, furniture, sea, shelf, management extracted opinions: good, giving, unprofessional, disadvantage, gain global polarity: negative
# Ground truth : main aspect: service extracted aspects: restaurant, swimming, quality, hotel, food, reefs, disadvantage, effort, buildings, terms, pools, size, rooms, beach, ie, space, sea, shelf, service, furniture, management extracted opinions: good, giving, unprofessional, disadvantage, gain global polarity: negative
# --------------------------------------------------
# Test Example 1666:
# Prediction   : main aspect: hotel extracted aspects: access, i, prophet, hotels, mosque, hotel extracted opinions: wonderful, beautiful, easy global polarity: positive
# Ground truth : main aspect: tourism extracted aspects: tourism, access, i, prophet, hotels, mosque, hotel extracted opinions: wonderful, beautiful, easy global polarity: positive
# --------------------------------------------------
# Test Example 1667:
# Prediction   : main aspect: hotel extracted aspects: anyone, experimenter, expert, hotel extracted opinions: recommend global polarity: negative
# Ground truth : main aspect: hotel extracted aspects: anyone, i, hotel, experimenter, expert, end extracted opinions: recommend global polarity: negative
# --------------------------------------------------
# Test Example 1668:
# Prediction   : main aspect: hotel extracted aspects: meters, place, side, beach, jewel, sea, value, hotel extracted opinions: value, beautiful global polarity: positive
# Ground truth : main aspect: place extracted aspects: sea, meters, place, side, jewel, beach, value, hotel extracted opinions: value, beautiful, jewel global polarity: positive
# --------------------------------------------------
# Test Example 1669:
# Prediction   : main aspect: facilities extracted aspects: anyone, paphos, facilities, basilica, gardens extracted opinions: failed, comfortable, good global polarity: neutral
# Ground truth : main aspect: meals extracted aspects: anyone, paphos, meals, basilica, gardens extracted opinions: failed, comfortable, good global polarity: neutral
# --------------------------------------------------
# Test Example 1670:
# Prediction   : main aspect: hotel extracted aspects: region, dahab, restaurant, beds, bathrooms, places, experiences, hotel extracted opinions: clean, excellent, bad, good, best global polarity: neutral
# Ground truth : main aspect: bathroom extracted aspects: region, dahab, restaurant, beds, bathrooms, bathroom, hotels, places, experiences, price, hotel extracted opinions: clean, excellent, bad, good, best global polarity: neutral
# --------------------------------------------------
# Test Example 1671:
# Prediction   : main aspect: treatment extracted aspects: reception, service, level, colleagues, treatment, hotels extracted opinions: recommend, good, well global polarity: positive
# Ground truth : main aspect: hotelservices extracted aspects: reception, service, level, colleagues, treatment, hotels, hotelservices extracted opinions: recommend, good, well global polarity: positive
# --------------------------------------------------
# Test Example 1672:
# Prediction   : main aspect: hotel extracted aspects: cable, connections, room, stay, staff, bath, refrigerator, area, rooms, villa, center, tidy, city, bathroom, everything, rosa, hotel extracted opinions: nice, recommend, worth, good global polarity: neutral
# Ground truth : main aspect: hotel extracted aspects: cable, connections, room, stay, staff, bath, refrigerator, area, rooms, villa, center, tidy, city, bathroom, everything, rosa, hotel extracted opinions: nice, recommend, worth, good global polarity: neutral
# --------------------------------------------------
# Test Example 1673:
# Prediction   : main aspect: service extracted aspects: service, rooms, staff extracted opinions: poor, unfriendly global polarity: negative
# Ground truth : main aspect: rooms extracted aspects: service, rooms, staff extracted opinions: poor, unfriendly global polarity: negative
# --------------------------------------------------
# Test Example 1674:
# Prediction   : main aspect: pool extracted aspects: al, manager, pool, problem, staff, fang, beach, salem, time, swimming, abaza, guest extracted opinions: problem, important, solving, great global polarity: positive
# Ground truth : main aspect: employees extracted aspects: al, pool, staff, managers, mahmoud, problem, fang, employees, beach, salem, time, swimming, office, guest extracted opinions: problem, important, solving, great global polarity: positive
# --------------------------------------------------
# Test Example 1675:
# Prediction   : main aspect: pool extracted aspects:, need, pool, work, air, conditioning, mini, fridge, children, swimming, advance, cleaning, t extracted opinions: complain, sure, dire, well, dirty global polarity: negative
# Ground truth : main aspect: tourism extracted aspects: , tourism, need, pool, i, work, air, conditioning, mini, fridge, children, swim, advance, swimming, cleaning, t extracted opinions: complain, sure, dire, well, dirty global polarity: negative
# --------------------------------------------------
# Test Example 1676:
# Prediction   : main aspect: television extracted aspects: tv, room, channels, sofas, television, plasma extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: amenities extracted aspects: tv, room, channels, sofas, amenities, plasma extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Test Example 1677:
# Prediction   : main aspect: furniture extracted aspects: carpets, floor, entry, procedure, moment, furniture, time, everything, surprise, executive extracted opinions: frustrating, bad, surprise global polarity: negative
# Ground truth : main aspect: tourism extracted aspects: tourism, carpets, floor, entry, procedure, moment, furniture, executive, time, everything, surprise extracted opinions: frustrating, bad, surprise global polarity: positive
# --------------------------------------------------
# Test Example 1678:
# Prediction   : main aspect: rooms extracted aspects: tv, markets, air, forms, conditioning, rooms, channels, insulation, exception, furniture, beds, everything, children, cleanliness, location, price, hotel extracted opinions: care, no, good, best, hope global polarity: neutral
# Ground truth : main aspect: room extracted aspects: location, tv, markets, room, air, forms, rooms, channels, insulation, exception, furniture, beds, everything, children, cleanliness, price, hotel extracted opinions: care, no, good, best, hope global polarity: neutral
# --------------------------------------------------
# Test Example 1679:
# Prediction   : main aspect: hotel extracted aspects: spot, i, brother, god, daham, narrator, hotel extracted opinions: wonderful, god global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: spot, narrator, i, god, brother, daham, hotel extracted opinions: wonderful, god global polarity: positive
# --------------------------------------------------
# Test Example 1680:
# Prediction   : main aspect: staff extracted aspects: breakfast, dining, staff, tips, sightseeing extracted opinions: nice, friendly, want, great global polarity: positive
# Ground truth : main aspect: staff extracted aspects: tips, breakfast, dining, staff extracted opinions: nice, friendly, want, help, great global polarity: positive
# --------------------------------------------------
# Test Example 1681:
# Prediction   : main aspect: food extracted aspects: drinks, music, place, visit, del, people, carmen, food, karns extracted opinions: good, perfect, definitely, relax, worth, great global polarity: positive
# Ground truth : main aspect: staff extracted aspects: drinks, music, place, visit, del, staff, karns, people, food, carmen extracted opinions: good, perfect, definitely, relax, worth, great global polarity: neutral
# --------------------------------------------------
# Test Example 1682:
# Prediction   : main aspect: location extracted aspects: location, i, price, hotel extracted opinions: excellent, good global polarity: positive
# Ground truth : main aspect: location extracted aspects: hotel, location, i, price extracted opinions: excellent, good global polarity: positive
# --------------------------------------------------
# Test Example 1683:
# Prediction   : main aspect: buffet extracted aspects: breakfast, bathtub, buffet, faucet, afterwards, quality extracted opinions: no global polarity: negative
# Ground truth : main aspect: buffet extracted aspects: breakfast, shower, bathtub, faucet, buffet, afterwards extracted opinions: no global polarity: negative
# --------------------------------------------------
# Test Example 1684:
# Prediction   : main aspect: prices extracted aspects: prices, road, tastes, beach, food, minutes, price extracted opinions: good global polarity: neutral
# Ground truth : main aspect: views extracted aspects: views, road, tastes, beach, food, minutes, price extracted opinions: good global polarity: neutral
# --------------------------------------------------
# Test Example 1685:
# Prediction   : main aspect: hotel extracted aspects: stays, hotel extracted opinions: recommended global polarity: negative
# Ground truth : main aspect: hotel extracted aspects: stays, hotel extracted opinions: recommended global polarity: negative
# --------------------------------------------------
# Test Example 1686:
# Prediction   : main aspect: hotel extracted aspects: families, services, spa, presence, mall, rotana, hotel, families, restaurants, facilities, cafes, housing, pharmacies, options, experience, ghurair, rotana, hotel extracted opinions: best global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: families, services, options, spa, experience, hotel, family, mall, presence, pool, rotana, hotels, cafes, shops, ghurair, i, restaurants, pharmacies, facilities, housing, dubai extracted opinions: best global polarity: positive
# --------------------------------------------------
# Test Example 1687:
# Prediction   : main aspect: location extracted aspects: weather, center, city, minutes, location extracted opinions: clean, bad, good global polarity: neutral
# Ground truth : main aspect: location extracted aspects: weather, center, city, minutes, location extracted opinions: clean, bad, good global polarity: positive
# --------------------------------------------------
# Test Example 1688:
# Prediction   : main aspect: hotel extracted aspects: windows, anything,, anything, t, hotel, i, service, air, conditioning, weather, food, nights, reception, noise, system, conference extracted opinions: good, great global polarity: neutral
# Ground truth : main aspect: conditioning extracted aspects: , windows, anything, system, t, hotel, sleep, weather, couldn, something, food, night, reception, air, conditioning, heating, noise, i, service, nights, conference extracted opinions: good, great global polarity: neutral
# --------------------------------------------------
# Test Example 1689:
# Prediction   : main aspect: rooms extracted aspects: cleaner, receptionists, rooms, time, request extracted opinions: cleaner global polarity: negative
# Ground truth : main aspect: cleanliness extracted aspects: receptionists, rooms, time, cleanliness, cleaner extracted opinions: cleaner global polarity: positive
# --------------------------------------------------
# Test Example 1690:
# Prediction   : main aspect: restaurant extracted aspects: restaurant, barbecue extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: restaurant extracted aspects: restaurant, barbecue extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 1691:
# Prediction   : main aspect: bar extracted aspects: bar, cocktail, worker extracted opinions: neutral global polarity: positive
# Ground truth : main aspect: food extracted aspects: bar, food, cocktail, worker extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Test Example 1692:
# Prediction   : main aspect: hotel extracted aspects: diameter, pressure, plane, jain, suhoor, restaurant, blocks, landing, quality, ramadan, hotel extracted opinions: leave, pressure global polarity: negative
# Ground truth : main aspect: hotel extracted aspects: diameter, pressure, blocks, landing, ramadan, suhoor, restaurant, jain, plane, quality, hotel extracted opinions: leave, pressure, fallen, blocks global polarity: negative
# --------------------------------------------------
# Test Example 1693:
# Prediction   : main aspect: hotel extracted aspects: friend, ache, dinner, stomach, hotel extracted opinions: friend global polarity: negative
# Ground truth : main aspect: meals extracted aspects: ache, friend, meals, dinner, stomach, hotel extracted opinions: ache, friend global polarity: negative
# --------------------------------------------------
# Test Example 1694:
# Prediction   : main aspect: hotel extracted aspects: manager, shower, repellent, i, air, works, rooms, bedspreads, tub, hotel extracted opinions: dirty, no, great, worst global polarity: negative
# Ground truth : main aspect: bathroom extracted aspects: manager, shower, repellent, i, air, works, rooms, bedspreads, bathroom, tub, hotel extracted opinions: dirty, no, great, worst global polarity: negative
# --------------------------------------------------
# Test Example 1695:
# Prediction   : main aspect: hotel extracted aspects: comfort, comment, reception, i, sides, someone, one, hotel extracted opinions: comfort, thank, like, no, good global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: comfort, comment, reception, i, sides, someone, hotel extracted opinions: comfort, thank, like, no, good global polarity: positive
# --------------------------------------------------
# Test Example 1696:
# Prediction   : main aspect: internet extracted aspects: tv, internet, phone, soap, room, toilet extracted opinions: no global polarity: negative
# Ground truth : main aspect: room extracted aspects: tv, internet, phone, soap, room, toilet extracted opinions: no global polarity: negative
# --------------------------------------------------
# Test Example 1697:
# Prediction   : main aspect: hotel extracted aspects: entertainment, life, terms, services, kind, resort, night, lot, luxury, things, meals, joy, city, space, car, hotel extracted opinions: entertainment, kind, leave, boring, bad, good, joy, excites global polarity: negative
# Ground truth : main aspect: food extracted aspects: entertainment, life, terms, services, kind, resort, night, lot, luxury, things, meals, joy, food, city, space, car, hotel extracted opinions: entertainment, kind, leave, boring, bad, good, joy, excites global polarity: negative
# --------------------------------------------------
# Test Example 1698:
# Prediction   : main aspect: rooms extracted aspects:, tea, bit, beds, rooms, shortbread, cookies, places, selection extracted opinions: nice, comfortable, good global polarity: positive
# Ground truth : main aspect: bedding extracted aspects: , tea, bed, bit, rooms, shortbread, cookies, places, bedding, selection extracted opinions: nice, comfortable, good global polarity: positive
# --------------------------------------------------
# Test Example 1699:
# Prediction   : main aspect: hotel extracted aspects: year, agra, jaipur, delhi, hotels, times, hotel extracted opinions: love global polarity: positive
# Ground truth : main aspect: prices extracted aspects: prices, agra, year, jaipur, ahmedabad, hotels, delhi, times, hotel extracted opinions: love global polarity: positive
# --------------------------------------------------
# Test Example 1700:
# Prediction   : main aspect: bedding extracted aspects: bed, room, cover, notes, sofa, rest, chairs, floors, stains, cleanliness, smell, hotel extracted opinions: bad, good global polarity: negative
# Ground truth : main aspect: internet extracted aspects: internet, bed, room, cover, notes, sofa, rest, floors, chairs, cleanliness, stains, smell, hotel extracted opinions: bad, good global polarity: neutral
# --------------------------------------------------
# Test Example 1701:
# Prediction   : main aspect: reception extracted aspects: room, reception, service, staff, restaurant, exception extracted opinions: excellent global polarity: positive
# Ground truth : main aspect: restaurant extracted aspects: room, reception, staff, service, restaurant, exception extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# Test Example 1702:
# Prediction   : main aspect: food extracted aspects: breakfast, i, menu, family, drink, restaurant, hotel, share, food, poor, amounts, value, downstairs extracted opinions: recommend, poor, share, value, great global polarity: negative
# Ground truth : main aspect: restaurant extracted aspects: breakfast, i, menu, family, drink, restaurant, hotel, food, share, amounts, value, downstairs extracted opinions: recommend, poor, share, value, great global polarity: negative
# --------------------------------------------------
# Test Example 1703:
# Prediction   : main aspect: food extracted aspects: options, food, variety extracted opinions: no, limited global polarity: negative
# Ground truth : main aspect: food extracted aspects: options, food, variety extracted opinions: no, limited global polarity: negative
# --------------------------------------------------
# Test Example 1704:
# Prediction   : main aspect: service extracted aspects: heights, service, food, thing, everything, worker, official, bliss, nothing extracted opinions: wonderful, smiling, bliss global polarity: positive
# Ground truth : main aspect: facilities extracted aspects: service, heights, food, facilities, everything, thing, worker, official, bliss, nothing extracted opinions: wonderful, smiling, bliss global polarity: positive
# --------------------------------------------------
# Test Example 1705:
# Prediction   : main aspect: reception extracted aspects: manager, reception, selfrehabilitation, hotel extracted opinions: neutral global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: manager, reception, i, selfrehabilitation, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Test Example 1706:
# Prediction   : main aspect: amenities extracted aspects: number, drinks,, anyone, room, water, stars, furniture, amenities, vacation, bar, time, insects, cleanliness extracted opinions: number, recommend, pleasant, bad, worn, perfect, worth global polarity: negative
# Ground truth : main aspect: room extracted aspects: number, drinks, , anyone, room, i, water, stars, furniture, time, vacation, bar, cleanliness, insects extracted opinions: number, recommend, pleasant, bad, worn, perfect, worth global polarity: negative
# --------------------------------------------------
# Test Example 1707:
# Prediction   : main aspect: food extracted aspects: problem, restaurants, food, block, meals, panache, hotel extracted opinions: problem, block, no global polarity: negative
# Ground truth : main aspect: television extracted aspects: problem, restaurants, meals, food, block, television, panache, hotel extracted opinions: problem, block, no global polarity: neutral
# --------------------------------------------------
# Test Example 1708:
# Prediction   : main aspect: meals extracted aspects: breakfast, service, rooms, meals, beds, bar extracted opinions: excellent global polarity: neutral
# Ground truth : main aspect: fitness extracted aspects: breakfast, service, fitness, rooms, beds, bar extracted opinions: excellent global polarity: neutral
# --------------------------------------------------
# Test Example 1709:
# Prediction   : main aspect: hotel extracted aspects: windows, anything,, anything, t, hotel, i, service, air, conditioning, weather, food, nights, reception, noise, system, conference extracted opinions: good, great global polarity: neutral
# Ground truth : main aspect: television extracted aspects: , windows, anything, system, t, hotel, sleep, weather, couldn, something, food, television, night, reception, air, heating, noise, i, service, nights, conference extracted opinions: good, great global polarity: neutral
# --------------------------------------------------
# Test Example 1710:
# Prediction   : main aspect: service extracted aspects: hkon, i, service, level, food, time, cancn, sokhna, cleanliness, hotel extracted opinions: excellent, enjoy, good, sure, nice, definitely global polarity: positive
# Ground truth : main aspect: service extracted aspects: hkon, i, service, level, food, time, cancn, sokhna, hotel extracted opinions: excellent, enjoy, good, nice, sure, definitely global polarity: neutral
# --------------------------------------------------
# Test Example 1711:
# Prediction   : main aspect: service extracted aspects: bit, services, money, service, trip, food, business, choice, dubai, hotel extracted opinions: good, great global polarity: positive
# Ground truth : main aspect: service extracted aspects: bit, services, money, service, trip, food, business, choice, dubai, hotel extracted opinions: good, great global polarity: neutral
# --------------------------------------------------
# Test Example 1712:
# Prediction   : main aspect: rooms extracted aspects: everything, rooms, dishes, cabinet extracted opinions: weak, bad global polarity: negative
# Ground truth : main aspect: amenities extracted aspects: rooms, amenities, everything, dishes, cabinet extracted opinions: bad, weak global polarity: negative
# --------------------------------------------------
# Test Example 1713:
# Prediction   : main aspect: conditioning extracted aspects: window, month, air, conditioning, degrees, conditioner extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: conditioning extracted aspects: window, month, air, conditioning, degrees, conditioner, paris extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 1714:
# Prediction   : main aspect: food extracted aspects: room, service, options, food, plenty extracted opinions: great global polarity: positive
# Ground truth : main aspect: food extracted aspects: room, service, options, food, plenty extracted opinions: great global polarity: positive
# --------------------------------------------------
# Test Example 1715:
# Prediction   : main aspect: amenities extracted aspects: socket, socket, gates, problem, room, minimization, service, toilets, foam, dispenser, toilets, amenities, foam, finishing, rooms, tandoor, cost, dispenser, problems, soap, peak extracted opinions: annoying, problems, problem, no, good, fit, best, beautiful global polarity: neutral
# Ground truth : main aspect: rooms extracted aspects: toilets, socket, gates, problem, minimization, bathroom, shampoo, soap, problems, room, rooms, peak, dispenser, liquid, service, tandoor, cost, foam, finishing extracted opinions: annoying, problems, problem, no, good, fit, best, beautiful global polarity: neutral
# --------------------------------------------------
# Test Example 1716:
# Prediction   : main aspect: hotel extracted aspects: account, service, level, gentlemen, accommodation, problem, development, improvement, items, cleanliness, hotel extracted opinions: wonderful, comfortable, responsible, problem, improvement, please global polarity: positive
# Ground truth : main aspect: service extracted aspects: evaluation, account, service, level, gentlemen, accommodation, problem, development, improvement, please, items, cleanliness, hotel extracted opinions: comfortable, responsible, problem, wonderful, improvement, please global polarity: positive
# --------------------------------------------------
# Test Example 1717:
# Prediction   : main aspect: service extracted aspects: decoration, i, service, trip, area, rooms, building, facilities, remarks, business, hotel extracted opinions: good, well global polarity: negative
# Ground truth : main aspect: staff extracted aspects: decoration, i, service, trip, staff, area, rooms, building, facilities, remarks, business, hotel extracted opinions: good, well global polarity: neutral
# --------------------------------------------------
# Test Example 1718:
# Prediction   : main aspect: staff extracted aspects: deficits, members, staff, lot, speaking, attitude, friendliness extracted opinions: hard, helpful, friendliness, positive, well, best, great global polarity: positive
# Ground truth : main aspect: accommodation extracted aspects: deficits, members, staff, accommodation, lot, speaking, attitude, friendliness extracted opinions: hard, helpful, friendliness, positive, well, best, great global polarity: positive
# --------------------------------------------------
# Test Example 1719:
# Prediction   : main aspect: hotel extracted aspects: subway, attractions, station, trips, facilities, business, base, tourist extracted opinions: attractions, good, great global polarity: positive
# Ground truth : main aspect: meals extracted aspects: subway, meals, hill, hotel, attractions, facilities, station, trips, business, base, tourist extracted opinions: attractions, good, great global polarity: neutral
# --------------------------------------------------
# Test Example 1720:
# Prediction   : main aspect: rooms extracted aspects: traveler, i, service, rooms, cleanliness, hotel extracted opinions: recommend, bad, terrible global polarity: negative
# Ground truth : main aspect: service extracted aspects: traveler, i, service, rooms, cleanliness, hotel extracted opinions: recommend, bad, terrible global polarity: negative
# --------------------------------------------------
# Test Example 1721:
# Prediction   : main aspect: bathroom extracted aspects: shower, period, stars, fact, frankly, room, i, service, back, mistake, god, salads, mattress, bathroom, smell, sweets, sea, time, types, smell, hotel extracted opinions: mistake, broken, god, no, bad, sweets, sweet, shocked global polarity: negative
# Ground truth : main aspect: bedding extracted aspects: mattress, period, stars, fact, bathroom, smell, hotel, shower, frankly, need, god, sweet, room, mistake, sweets, sea, bedding, bed, salads, i, service, time, types extracted opinions: mistake, broken, god, no, bad, sweets, sweet, shocked global polarity: negative
# --------------------------------------------------
# Test Example 1722:
# Prediction   : main aspect: furniture extracted aspects: furniture, building extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: furniture extracted aspects: building, furniture extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 1723:
# Prediction   : main aspect: hotel extracted aspects: procedures, trips, business, hotel extracted opinions: special, no, fine global polarity: positive
# Ground truth : main aspect: food extracted aspects: food, procedures, trips, business, hotel extracted opinions: special, no, fine global polarity: neutral
# --------------------------------------------------
# Test Example 1724:
# Prediction   : main aspect: hotel extracted aspects: while, anything, hopes, i, staff, impression, rooms, restaurant, display, sound, time, pyramids, location, hotel extracted opinions: hopes, impression, helpful, good, wrong, acceptable global polarity: neutral
# Ground truth : main aspect: staff extracted aspects: while, nothing, anything, hopes, i, staff, impression, rooms, restaurant, display, sound, time, pyramids, location, hotel extracted opinions: hopes, impression, helpful, good, wrong, acceptable global polarity: neutral
# --------------------------------------------------
# Test Example 1725:
# Prediction   : main aspect: hotelservices extracted aspects: manager, anything, phone, room, service, cell, workers, hotelservices extracted opinions: stolen, unfortunately global polarity: negative
# Ground truth : main aspect: hotelservices extracted aspects: manager, phone, anything, room, service, cell, workers, hotelservices extracted opinions: stolen, unfortunately global polarity: negative
# --------------------------------------------------
# Test Example 1726:
# Prediction   : main aspect: room extracted aspects: questions, forever, room, son, reception, service, sewers, people, clothes, hold, motel, smell extracted opinions: like, avoiding, bad, upset, accidentally global polarity: negative
# Ground truth : main aspect: reception extracted aspects: questions, forever, room, son, service, reception, sewers, people, clothes, hold, motel, smell extracted opinions: avoiding, like, bad, upset, accidentally global polarity: negative
# --------------------------------------------------
# Test Example 1727:
# Prediction   : main aspect: hotel extracted aspects: city, location, hotel extracted opinions: neutral global polarity: positive
# Ground truth : main aspect: food extracted aspects: food, location, city, hotel extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Test Example 1728:
# Prediction   : main aspect: rooms extracted aspects: size, rooms, street, facade, rest, hotels, grill, price extracted opinions: no, good global polarity: neutral
# Ground truth : main aspect: pool extracted aspects: pool, facade, size, rooms, street, hotel, rest, grill, hotels, price extracted opinions: no, good global polarity: neutral
# --------------------------------------------------
# Test Example 1729:
# Prediction   : main aspect: meals extracted aspects: breakfast, fine, meals extracted opinions: better, fine global polarity: positive
# Ground truth : main aspect: fitness extracted aspects: breakfast, fitness, fine extracted opinions: better, fine global polarity: neutral
# --------------------------------------------------
# Test Example 1730:
# Prediction   : main aspect: rooms extracted aspects: drinks, entertainment, rooms, clubs, floors extracted opinions: entertainment global polarity: positive
# Ground truth : main aspect: facilities extracted aspects: drinks, entertainment, rooms, clubs, facilities, floors extracted opinions: entertainment global polarity: positive
# --------------------------------------------------
# Test Example 1731:
# Prediction   : main aspect: staff extracted aspects: holiday, days, room, reception, money, anyone, honeymoon, resort, view, mountains, minutes, hotel, time, taba, sea, home extracted opinions: holiday, recommend, like, no, friendly, magnificent, welcoming, best, enjoyed, wonderful global polarity: positive
# Ground truth : main aspect: employees extracted aspects: holiday, days, money, reception, staff, honeymoon, resort, room, view, mountains, anyone, employees, minutes, hotel, time, taba, sea, home extracted opinions: holiday, recommend, like, no, welcoming, magnificent, friendly, wonderful, best, enjoyed global polarity: positive
# --------------------------------------------------
# Test Example 1732:
# Prediction   : main aspect: hotel extracted aspects: breakfast, disaster, room, i, place, box, toilet, rooms, kitchen, cockroaches, bathroom, ejection, hotel extracted opinions: disaster, dirty global polarity: negative
# Ground truth : main aspect: bathroom extracted aspects: room, place, i, disaster, toilet, box, rooms, kitchen, cockroaches, bathroom, ejection, hotel extracted opinions: disaster, dirty global polarity: negative
# --------------------------------------------------
# Test Example 1733:
# Prediction   : main aspect: rooms extracted aspects: design, pool, floor, rooms, hotel extracted opinions: comfortable, good, great global polarity: neutral
# Ground truth : main aspect: internet extracted aspects: design, internet, pool, floor, rooms, hotel extracted opinions: comfortable, good, great global polarity: neutral
# --------------------------------------------------
# Test Example 1734:
# Prediction   : main aspect: location extracted aspects: views, service, location extracted opinions: wonderful, beautiful, bad, unfortunately global polarity: positive
# Ground truth : main aspect: views extracted aspects: location, views, service extracted opinions: wonderful, beautiful, bad, unfortunately global polarity: positive
# --------------------------------------------------
# Test Example 1735:
# Prediction   : main aspect: cleanliness extracted aspects: cleanliness extracted opinions: worst global polarity: negative
# Ground truth : main aspect: cleanliness extracted aspects: cleanliness extracted opinions: worst global polarity: negative
# --------------------------------------------------
# Test Example 1736:
# Prediction   : main aspect: rooms extracted aspects: problems, stay, prophet, service, rooms, mosque, hotel extracted opinions: magnificent, clean, problems, no global polarity: positive
# Ground truth : main aspect: rooms extracted aspects: problems, stay, prophet, service, rooms, mosque, hotel extracted opinions: magnificent, clean, problems, no global polarity: positive
# --------------------------------------------------
# Test Example 1737:
# Prediction   : main aspect: fitness extracted aspects: pool, stay, gym, fitness, bike, facilities, dammam, treadmill, hotel extracted opinions: recommend, comfortable, no, want global polarity: negative
# Ground truth : main aspect: fitness extracted aspects: pool, bike, stay, fitness, gym, facilities, dammam, treadmill, hotel extracted opinions: recommend, comfortable, no, want global polarity: negative
# --------------------------------------------------
# Test Example 1738:
# Prediction   : main aspect: management extracted aspects: support, staff, response, management extracted opinions: support global polarity: positive
# Ground truth : main aspect: staff extracted aspects: support, staff, response, management extracted opinions: support global polarity: negative
# --------------------------------------------------
# Test Example 1739:
# Prediction   : main aspect: location extracted aspects: i, apartment, view, accommodation, area, neighborhoods, bedrooms, location, hotel extracted opinions: beautiful, bad global polarity: negative
# Ground truth : main aspect: interaction extracted aspects: i, apartment, view, accommodation, area, neighborhoods, bedrooms, location, interaction, hotel extracted opinions: beautiful, bad global polarity: negative
# --------------------------------------------------
# Test Example 1740:
# Prediction   : main aspect: nan extracted aspects: mako, lech extracted opinions: neutral global polarity: neutral
# Ground truth : main aspect: service extracted aspects: ghali, lech, mako, service extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 1741:
# Prediction   : main aspect: meals extracted aspects: breakfast, views, level, meals, garbage, front, cash, atmosphere, shops, river, security, hotel extracted opinions: pleasant, unfortunately, security, wonderful, delicious, beautiful, secure global polarity: positive
# Ground truth : main aspect: meals extracted aspects: breakfast, views, level, cash, garbage, front, meals, security, river, atmosphere, shops, hotel extracted opinions: pleasant, unfortunately, security, delicious, wonderful, beautiful global polarity: positive
# --------------------------------------------------
# Test Example 1742:
# Prediction   : main aspect: service extracted aspects: money, beauty, service, staff, area, storehouse, gas, sound, morning, behavior, trees, wayanad, hotel extracted opinions: beauty, bad, worth global polarity: negative
# ...
# --------------------------------------------------
# Test Example 2851:
# Prediction   : main aspect: service extracted aspects: hours, reception, problems, i, staff, service, season, visitor, rooms, apology, suite, feasibility, reason, times extracted opinions: clean, problems, poor, complaining, apology, solving global polarity: negative
# Ground truth : main aspect: rooms extracted aspects: hours, visitor, reception, problems, staff, service, i, room, season, rooms, suite, apology, reason, feasibility, times extracted opinions: clean, problems, poor, ignoring, complained, apology, solving global polarity: negative
# --------------------------------------------------
# Test Example 2852:
# Prediction   : main aspect: restaurant extracted aspects: club, restaurant, bathroom, tower extracted opinions: special global polarity: positive
# Ground truth : main aspect: facilities extracted aspects: club, restaurant, facilities, bathroom, tower extracted opinions: special global polarity: positive
# --------------------------------------------------
# Test Example 2853:
# Prediction   : main aspect: service extracted aspects: days, parties, room, service, beauty, view, sides, masterpiece, rooms, star, food, vacation, atmosphere, evening, habeeto, hotel extracted opinions: excellent, clean, parties, masterpiece, beauty, enjoyed, wonderful, beautiful, calm global polarity: positive
# Ground truth : main aspect: views extracted aspects: days, room, parties, service, view, beauty, sides, masterpiece, rooms, views, star, food, vacation, atmosphere, evening, habeeto, hotel extracted opinions: excellent, clean, parties, masterpiece, beauty, wonderful, enjoyed, beautiful, calm global polarity: positive
# --------------------------------------------------
# Test Example 2854:
# Prediction   : main aspect: transportation extracted aspects: taxi, place extracted opinions: special global polarity: positive
# Ground truth : main aspect: receptionists extracted aspects: receptionists, taxi, place extracted opinions: special global polarity: neutral
# --------------------------------------------------
# Test Example 2855:
# Prediction   : main aspect: meals extracted aspects: door, breakfast, airport, drivers, accommodation, lot, meals, terrace, bazaar, places, resident, limousine, mosque, minutes, location, mo, hotel extracted opinions: grand, clear, recommend, beautiful, sweet global polarity: positive
# Ground truth : main aspect: meals extracted aspects: door, breakfast, airport, drivers, accommodation, lot, bazaar, meals, terrace, places, resident, limousine, mosque, minutes, hagia, location, mo, hotel extracted opinions: grand, clear, recommend, beautiful, sweet global polarity: positive
# --------------------------------------------------
# Test Example 2856:
# Prediction   : main aspect: receptionists extracted aspects: money, grounds, receptionists, campus, rooms, hotel extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: receptionists extracted aspects: money, grounds, i, receptionists, campus, rooms, hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 2857:
# Prediction   : main aspect: bathroom extracted aspects: door, stairs, room, bathroom extracted opinions: shared global polarity: negative
# Ground truth : main aspect: room extracted aspects: door, stairs, bathroom, room extracted opinions: shared global polarity: negative
# --------------------------------------------------
# Test Example 2858:
# Prediction   : main aspect: hotel extracted aspects: moataz, hotel extracted opinions: neutral global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: moataz, i, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Test Example 2859:
# Prediction   : main aspect: facilities extracted aspects: island, room, place, resort, options, chalet, facilities, fursan extracted opinions: best global polarity: positive
# Ground truth : main aspect: place extracted aspects: island, i, place, fursan, resort, options, room, chalet extracted opinions: best global polarity: positive
# --------------------------------------------------
# Test Example 2860:
# Prediction   : main aspect: hotel extracted aspects: number, flight, person, need, company, trip, rhet, people, offer, boat, management, dolphin, price, hotel extracted opinions: number, worn, good, wonderful, beautiful, sweet global polarity: negative
# Ground truth : main aspect: hotel extracted aspects: number, flight, person, need, company, trip, offer, rhet, people, knowing, boat, management, dolphin, price, d, hotel extracted opinions: number, good, worn, wonderful, beautiful, sweet global polarity: positive
# --------------------------------------------------
# Test Example 2861:
# Prediction   : main aspect: hotel extracted aspects: year, name, i, stay, humility, god, mother, way, temperament, name, hotel extracted opinions: thank, miss, god, regret, humility, want, miss global polarity: positive
# Ground truth : main aspect: residence extracted aspects: mother, humility, year, names, i, stay, god, temperament, way, residence, hotel extracted opinions: thank, miss, god, regret, want global polarity: positive
# --------------------------------------------------
# Test Example 2862:
# Prediction   : main aspect: meals extracted aspects: breakfast, care, acts, meals, notes, customers, taste, hotel extracted opinions: care, good global polarity: neutral
# Ground truth : main aspect: room extracted aspects: breakfast, care, room, acts, hotel, notes, customers, taste extracted opinions: care, good global polarity: neutral
# --------------------------------------------------
# Test Example 2863:
# Prediction   : main aspect: transportation extracted aspects: place, bus, transportation, street, i, station, walk, hassle, prince extracted opinions: hesitate, want, great global polarity: positive
# Ground truth : main aspect: place extracted aspects: place, i, street, bus, walk, prince, station, hassle extracted opinions: hesitate, want, great global polarity: positive
# --------------------------------------------------
# Test Example 2864:
# Prediction   : main aspect: rooms extracted aspects:, days, room, place, administration, servicers, family, things, rooms, attention, people, vacation, camera, glass, police extracted opinions: clear, failed, good, worst, lost, dirty, pay global polarity: negative
# Ground truth : main aspect: internet extracted aspects: , internet, days, room, place, administration, servicers, family, things, rooms, attention, people, vacation, camera, didn, glass, police extracted opinions: clear, failed, good, worst, lost, dirty, pay global polarity: neutral
# --------------------------------------------------
# Test Example 2865:
# Prediction   : main aspect: meals extracted aspects: breakfast, floor, bit, club, weather, meals, nuisance, station, minutes, stir, metro, dance, hotel extracted opinions: creating, comfortable, good global polarity: neutral
# Ground truth : main aspect: meals extracted aspects: breakfast, floor, bit, club, walking, weather, nuisance, meals, station, minutes, stir, metro, dance, hotel extracted opinions: creating, comfortable, good global polarity: neutral
# --------------------------------------------------
# Test Example 2866:
# Prediction   : main aspect: prices extracted aspects: prices, something, massage, barros, collar, experience, privacy extracted opinions: beautiful, thanks, sweet, fun, worth global polarity: positive
# Ground truth : main aspect: prices extracted aspects: prices, something, massage, privacy, thanks, barros, collar, experience extracted opinions: thanks, beautiful, fun, sweet, worth global polarity: negative
# --------------------------------------------------
# Test Example 2867:
# Prediction   : main aspect: hotel extracted aspects: entry, room, sign, crew, seasons, defect, cleaning, hotel extracted opinions: clean, defect, certain, well global polarity: negative
# Ground truth : main aspect: hotel extracted aspects: crew, defect, entry, room, sign, seasons, cleaning, hotel extracted opinions: clean, defect, certain, well, disturb global polarity: negative
# --------------------------------------------------
# Test Example 2868:
# Prediction   : main aspect: hotel extracted aspects: tourist, lot, price, hotel extracted opinions: hope global polarity: positive
# Ground truth : main aspect: prices extracted aspects: prices, lot, tourists, price, hotel extracted opinions: hope, attracts global polarity: positive
# --------------------------------------------------
# Test Example 2869:
# Prediction   : main aspect: hotel extracted aspects: distance,, taj, entry, crown, walk, fog, roof, surprise, t, hotel extracted opinions: pleasant, good, surprise global polarity: neutral
# Ground truth : main aspect: cleanliness extracted aspects: distance, , taj, tuk, cleanliness, entry, crown, look, walk, fog, roof, surprise, t, hotel extracted opinions: pleasant, good, surprise global polarity: neutral
# --------------------------------------------------
# Test Example 2870:
# Prediction   : main aspect: restaurant extracted aspects: order, tongue, comment, bottle, i, drink, person, mouth, hand, drink, reply, mandhmsh, drink, mouth, hand, mouth, hand, people, cup, drink, limit, hand, dishes, minute, ask, bar, gift extracted opinions: gift, no, weak, sure, empty global polarity: negative
# Ground truth : main aspect: restaurant extracted aspects: blood, tongue, restaurant, gentleman, child, taste, cup, order, comment, gift, front, people, tasteless, ask, limit, bar, enter, cappuccino, i, minute, dishes, pass, reply extracted opinions: gift, no, weak, sure, empty global polarity: negative
# --------------------------------------------------
# Test Example 2871:
# Prediction   : main aspect: rooms extracted aspects: drinks, door, room, family, rooms, trouble extracted opinions: trouble, want global polarity: negative
# Ground truth : main aspect: stay extracted aspects: drinks, door, room, stay, family, rooms, trouble extracted opinions: trouble, want global polarity: negative
# --------------------------------------------------
# Test Example 2872:
# Prediction   : main aspect: hotel extracted aspects: respect, staff, family, market, guest, class, hotel extracted opinions: nice, clean, respect global polarity: positive
# Ground truth : main aspect: hotel extracted aspects: respect, staff, family, market, guest, class, hotel extracted opinions: nice, clean, respect global polarity: positive
# --------------------------------------------------
# Test Example 2873:
# Prediction   : main aspect: hotel extracted aspects: breakfast, airport, place, centre, stars, extent, city, apartments, metro, shopping, deira, hotel extracted opinions: neutral global polarity: neutral
# Ground truth : main aspect: parking extracted aspects: breakfast, airport, place, centre, stars, center, deira, parking, extent, city, apartments, metro, shopping, hotel extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Test Example 2874:
# Prediction   : main aspect: staff extracted aspects: life, receptionists, stay, staff, cooks, guards, housekeepers, waiters extracted opinions: pretty, welcoming, friendly global polarity: positive
# Ground truth : main aspect: amenities extracted aspects: housekeepers, life, stay, staff, cooks, receptionists, guards, welcoming, waiters, amenities extracted opinions: pretty, welcoming, friendly global polarity: positive
# --------------------------------------------------
# Test Example 2875:
# Prediction   : main aspect: beach extracted aspects: excellent, terms, beach, team, sea, location, hotel extracted opinions: excellent, beautiful, great global polarity: positive
# Ground truth : main aspect: sea extracted aspects: excellent, terms, beach, team, sea, location, hotel extracted opinions: excellent, beautiful, great global polarity: positive
# --------------------------------------------------
# Test Example 2876:
# Prediction   : main aspect: rooms extracted aspects: design, pool, floor, rooms, hotel extracted opinions: comfortable, good, great global polarity: neutral
# Ground truth : main aspect: cleanliness extracted aspects: design, pool, floor, rooms, cleanliness, hotel extracted opinions: comfortable, good, great global polarity: neutral
# --------------------------------------------------
# Test Example 2877:
# Prediction   : main aspect: hotel extracted aspects: level, i, cleanliness, hotel extracted opinions: horrible global polarity: negative
# Ground truth : main aspect: hotel extracted aspects: level, cleanliness, i, hotel extracted opinions: horrible global polarity: negative
# --------------------------------------------------
# Test Example 2878:
# Prediction   : main aspect: bathroom extracted aspects: faucet, rooms, bathroom, cleanliness extracted opinions: no global polarity: negative
# Ground truth : main aspect: rooms extracted aspects: bathroom, faucet, cleanliness, rooms extracted opinions: no global polarity: negative
# --------------------------------------------------
# Test Example 2879:
# Prediction   : main aspect: service extracted aspects: reception, service, resort, lot, attention extracted opinions: clean, excellent global polarity: positive
# Ground truth : main aspect: resort extracted aspects: excellent, reception, service, resort, lot, attention extracted opinions: clean, excellent global polarity: positive
# --------------------------------------------------
# Test Example 2880:
# Prediction   : main aspect: hotel extracted aspects: days, services, i, cafs, staff, area, barber, kitchen, needs, everything, guest, location, hotel extracted opinions: clean, good, wonderful, beautiful, great global polarity: positive
# Ground truth : main aspect: room extracted aspects: days, services, i, cafs, staff, room, area, barber, kitchen, needs, everything, guest, location, hotel extracted opinions: clean, good, wonderful, beautiful, great global polarity: neutral
# --------------------------------------------------
# Test Example 2881:
# Prediction   : main aspect: food extracted aspects: food extracted opinions: awful global polarity: negative
# Ground truth : main aspect: food extracted aspects: food extracted opinions: awful global polarity: negative
# --------------------------------------------------
# Test Example 2882:
# Prediction   : main aspect: bathroom extracted aspects: shower, days, room, vent, tile, towel, time, euros, fungus, bathroom, slurry, cloudy, mold extracted opinions: like global polarity: negative
# Ground truth : main aspect: room extracted aspects: fungus, tile, days, shower, room, vent, towel, time, bathroom, euros, slurry, cloudy, mold extracted opinions: like global polarity: negative
# --------------------------------------------------
# Test Example 2883:
# Prediction   : main aspect: amenities extracted aspects: amenities, shower, filter extracted opinions: neutral global polarity: negative
# Ground truth : main aspect: bathroom extracted aspects: shower, bathroom, filter extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Test Example 2884:
# Prediction   : main aspect: prices extracted aspects: prices, services, i, resorts extracted opinions: satisfied, well global polarity: positive
# Ground truth : main aspect: prices extracted aspects: resorts, prices, services, i extracted opinions: well, satisfied global polarity: positive
# --------------------------------------------------
# Test Example 2885:
# Prediction   : main aspect: meals extracted aspects: breakfast, people, meals, bathrooms, palmyra, dinner extracted opinions: nice, helpful, fine, respectable global polarity: neutral
# Ground truth : main aspect: wifi extracted aspects: wifi, breakfast, people, bathrooms, palmyra, dinner extracted opinions: nice, helpful, fine, respectable global polarity: neutral
# --------------------------------------------------

# %%
print(len(predictions))
print(len(truths))
# Out:
# 2885
# 2885

# %% [markdown]
# #Calcul des metrics

# %%
def extract_component_indices(text):
    words = text.split()
    try:
        main_aspect_index = words.index('aspect:') + 1 if 'aspect:' in words else -1
        global_polarity_index = words.index('polarity:') + 1 if 'polarity:' in words else -1
        aspects_start_index = words.index('aspects:') + 1 if 'aspects:' in words else -1
        aspects_end_index = words.index('opinions:') - 2 if 'opinions:' in words else -1
        opinions_start_index = words.index('opinions:') + 1 if 'opinions:' in words else -1
        opinions_end_index = global_polarity_index - 2 if global_polarity_index != -1 else -1
    except ValueError:
        return -1, -1, -1, -1, -1, -1

    return main_aspect_index, global_polarity_index, aspects_start_index, aspects_end_index, opinions_start_index, opinions_end_index

MAIN_ASPECT_IDX = 0
GLOBAL_POLARITY_IDX = 1
ASPECTS_START_IDX = 2
ASPECTS_END_IDX = 3
OPINIONS_START_IDX = 4
OPINIONS_END_IDX = 5

# %%
def calculate_metrics(preds, truths):
    tp, fp, fn = 0, 0, 0
    jaccard_scores = []
    for pred_elements, truth_elements in zip(preds, truths):
        pred_set = set(pred_elements)
        truth_set = set(truth_elements)
        tp += len(pred_set.intersection(truth_set))
        fp += len(pred_set.difference(truth_set))
        fn += len(truth_set.difference(pred_set))
        jaccard_score = len(pred_set.intersection(truth_set)) / len(pred_set.union(truth_set)) if len(pred_set.union(truth_set)) != 0 else 0
        jaccard_scores.append(jaccard_score)
    precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    accuracy = tp / (tp + fp + fn) if (tp + fp + fn) != 0 else 0
    recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0
    mean_jaccard = sum(jaccard_scores) / len(jaccard_scores) if jaccard_scores else 0
    return precision, accuracy, recall, f1_score, mean_jaccard

def calculate_metrics_for_single_element(preds, truths):
    tp, fp, fn, tn = 0, 0, 0, 0

    for pred, truth in zip(preds, truths):
        #print(pred," -- " ,truth)
        if pred == truth:
            if pred:
                tp += 1
            else:
                tn += 1
        else:
            if pred:
                fp += 1
            else:
                fn += 1

    precision = tp / (tp + fp) if (tp + fp) != 0 else 0
    recall = tp / (tp + fn) if (tp + fn) != 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

    return precision, accuracy, recall, f1_score


def separate_components(preds, truths):
    preds_aspects, preds_opinions, preds_main_aspects, preds_global_polarities = [], [], [], []
    truths_aspects, truths_opinions, truths_main_aspects, truths_global_polarities = [], [], [], []
    for pred, truth in zip(preds, truths):
        pred_idx = extract_component_indices(pred)
        truth_idx = extract_component_indices(truth)
        preds_aspects.append(pred.split()[pred_idx[ASPECTS_START_IDX]:pred_idx[ASPECTS_END_IDX]])
        preds_opinions.append(pred.split()[pred_idx[OPINIONS_START_IDX]:pred_idx[OPINIONS_END_IDX]])
        preds_main_aspects.append(pred.split()[pred_idx[MAIN_ASPECT_IDX]])
        preds_global_polarities.append(pred.split()[pred_idx[GLOBAL_POLARITY_IDX]])
        truths_aspects.append(truth.split()[truth_idx[ASPECTS_START_IDX]:truth_idx[ASPECTS_END_IDX]])
        truths_opinions.append(truth.split()[truth_idx[OPINIONS_START_IDX]:truth_idx[OPINIONS_END_IDX]])
        truths_main_aspects.append(truth.split()[truth_idx[MAIN_ASPECT_IDX]])
        truths_global_polarities.append(truth.split()[truth_idx[GLOBAL_POLARITY_IDX]])
    return preds_aspects, preds_opinions, preds_main_aspects, preds_global_polarities, truths_aspects, truths_opinions, truths_main_aspects, truths_global_polarities


preds_aspects, preds_opinions, preds_main_aspects, preds_global_polarities, truths_aspects, truths_opinions, truths_main_aspects, truths_global_polarities = separate_components(predictions, truths)

precision_aspects, accuracy_aspects, recall_aspects,f1_aspects,jaccard_aspects = calculate_metrics(preds_aspects, truths_aspects)
precision_opinions, accuracy_opinions, recall_opinions,f1_opinions,jaccard_opinions = calculate_metrics (preds_opinions, truths_opinions)

precision_main_aspect, accuracy_main_aspect, recall_main_aspect,f1_main_aspect = calculate_metrics_for_single_element(preds_main_aspects, truths_main_aspects)
precision_global_polarity, accuracy_global_polarity, recall_global_polarity,f1_global_polarity = calculate_metrics_for_single_element(preds_global_polarities, truths_global_polarities)

print("-"*50)
print("Precision Aspects:", precision_aspects)
print("Accuracy Aspects:", accuracy_aspects)
print("Recall Aspects:", recall_aspects)
print("F1 Aspects:", f1_aspects)
print("jaccard Aspects:", jaccard_aspects)
print("-"*50)
print("Precision Opinions:", precision_opinions)
print("Accuracy Opinions:", accuracy_opinions)
print("Recall Opinions:", recall_opinions)
print("F1 Opinions:", f1_opinions)
print("jaccard Opinions:", jaccard_opinions)
print("-"*50)
print("Precision Main Aspect:", precision_main_aspect)
print("Accuracy Main Aspect:", accuracy_main_aspect)
print("Recall Main Aspect:", recall_main_aspect)
print("F1 Main Aspect:", f1_main_aspect)
print("-"*50)
print("Precision Global Polarity:", precision_global_polarity)
print("Accuracy Global Polarity:", accuracy_global_polarity)
print("Recall Global Polarity:", recall_global_polarity)
print("F1 Global Polarity:", f1_global_polarity)
print("-"*50)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# facilities  --  facilities
# service  --  service
# hotel  --  treatment
# service  --  facilities
# room  --  room
# hotel  --  location
# accommodation  --  room
# hotel  --  bathroom
# hotel  --  meals
# service  --  service
# room  --  service
# hotel  --  staff
# food  --  meals
# service  --  hotel
# rooms  --  rooms
# location  --  cleanliness
# hotel  --  wifi
# food  --  service
# location  --  location
# location  --  parking
# food  --  prices
# location  --  location
# hotel  --  views
# facilities  --  bathroom
# rooms  --  rooms
# rooms  --  facilities
# food  --  facilities
# hotel  --  hotel
# location  --  residence
# bedding  --  meals
# hotel  --  pool
# staff  --  rooms
# hotel  --  management
# hotel  --  meals
# hotel  --  employees
# prices  --  prices
# room  --  room
# staff  --  reception
# hotel  --  hotel
# hotel  --  position
# prices  --  prices
# hotel  --  hotel
# location  --  location
# prices  --  hotel
# internet  --  internet
# hotel  --  hotel
# amenities  --  amenities
# bedding  --  reception
# hotelservices  --  hotelservices
# hotel  --  hotel
# hotel  --  position
# hotel  --  service
# hotel  --  service
# rooms  --  facilities
# hotel  --  hotel
# rooms  --  prices
# hotel  --  rooms
# rooms  --  rooms
# prices  --  prices
# rooms  --  views
# facilities  --  facilities
# room  --  rooms
# crew  --  crew
# hotel  --  hotel
# hotel  --  facilities
# management  --  team
# staff  --  location
# pool  --  pool
# receptionists  --  receptionists
# staff  --  place
# employees  --  amenities
# hotel  --  hotel
# hotel  --  furniture
# hotel  --  facilities
# restaurant  --  reception
# facilities  --  cleanliness
# hotel  --  hotel
# rooms  --  rooms
# reception  --  location
# location  --  restaurant
# rooms  --  amenities
# elevator  --  hotel
# transportation  --  transportation
# hotel  --  hotel
# prices  --  prices
# hotel  --  hotel
# hotel  --  room
# prices  --  prices
# hotel  --  hotel
# service  --  service
# rooms  --  food
# rooms  --  cleanliness
# hotel  --  service
# reception  --  facilities
# crew  --  location
# hotel  --  hotel
# service  --  internet
# fitness  --  room
# beach  --  teamwork
# amenities  --  amenities
# meals  --  facilities
# bathroom  --  restaurant
# room  --  room
# meals  --  facilities
# food  --  bathroom
# hotel  --  hotel
# service  --  service
# hotel  --  bathroom
# hotel  --  hotel
# hotel  --  hotel
# staff  --  staff
# food  --  eating
# hotel  --  hotel
# hotel  --  hotel
# rooms  --  amenities
# service  --  facilities
# hotel  --  pool
# facilities  --  facilities
# hotel  --  resort
# hotel  --  hotel
# food  --  food
# location  --  eating
# television  --  restaurant
# hotel  --  hotel
# service  --  bathroom
# hotel  --  hotel
# staff  --  staff
# location  --  wifi
# room  --  room
# service  --  service
# prices  --  bathroom
# meals  --  internet
# hotel  --  accommodation
# meals  --  pool
# rooms  --  cleanliness
# location  --  position
# hotel  --  prices
# room  --  facilities
# hotel  --  service
# rooms  --  location
# bathroom  --  bathroom
# service  --  service
# facilities  --  amenities
# meat  --  food
# food  --  residence
# bathroom  --  room
# amenities  --  employees
# hotel  --  pool
# rooms  --  rooms
# room  --  facilities
# facilities  --  cleanliness
# meals  --  meals
# conditioning  --  bathroom
# hotel  --  hotelservices
# service  --  service
# hotel  --  hotel
# food  --  food
# furniture  --  internet
# meals  --  facilities
# hotel  --  television
# meals  --  meals
# elevator  --  elevator
# treatment  --  employees
# hotel  --  hotel
# rooms  --  food
# location  --  sea
# hotel  --  prices
# parking  --  position
# staff  --  staff
# hotel  --  cleanliness
# meals  --  prices
# hotel  --  service
# rooms  --  staff
# prices  --  restaurant
# restaurant  --  hotelservices
# hotel  --  cleanliness
# staff  --  restaurant
# rooms  --  cleanliness
# room  --  facilities
# reception  --  food
# hotel  --  bedding
# rooms  --  bathroom
# hotel  --  hotel
# prices  --  hotel
# hotel  --  location
# hotel  --  hotel
# service  --  service
# room  --  cleanliness
# hotel  --  furniture
# amenities  --  rooms
# hotel  --  management
# hotel  --  hotelservices
# conditioning  --  accommodation
# meals  --  location
# hotel  --  hotel
# hotel  --  place
# prices  --  hotel
# accommodation  --  hotel
# hotelservices  --  employees
# rooms  --  rooms
# beach  --  meals
# hotel  --  management
# hotel  --  employees
# hotel  --  hotel
# rooms  --  staff
# service  --  service
# rooms  --  rooms
# hotel  --  location
# hotel  --  views
# amenities  --  location
# rooms  --  rooms
# hotel  --  tourism
# hotel  --  service
# location  --  location
# food  --  beach
# rooms  --  rooms
# meals  --  meals
# facilities  --  staff
# conditioning  --  amenities
# prices  --  meals
# hotel  --  fitness
# service  --  location
# prices  --  prices
# room  --  bedding
# meals  --  meals
# reception  --  reception
# facilities  --  prices
# facilities  --  facilities
# meals  --  meals
# rooms  --  facilities
# reception  --  food
# hotel  --  facilities
# service  --  staff
# facilities  --  facilities
# bedding  --  bedding
# hotel  --  amenities
# reception  --  reception
# prices  --  parking
# pool  --  pool
# meals  --  meals
# location  --  location
# rooms  --  facilities
# internet  --  parking
# hotel  --  staff
# resort  --  resort
# television  --  accommodation
# bathroom  --  amenities
# amenities  --  amenities
# hotel  --  meals
# meals  --  meals
# meals  --  pool
# facilities  --  facilities
# hotel  --  hotel
# hotel  --  fitness
# hotel  --  rooms
# hotel  --  hotel
# hotel  --  staff
# room  --  room
# staff  --  staff
# internet  --  amenities
# staff  --  rooms
# rooms  --  amenities
# hotelservices  --  hotelservices
# location  --  amenities
# bathroom  --  hotel
# nan  --  treatment
# hotel  --  views
# hotel  --  hotel
# hotel  --  service
# prices  --  prices
# food  --  food
# pool  --  room
# facilities  --  parking
# conditioning  --  facilities
# staff  --  facilities
# location  --  location
# room  --  room
# room  --  room
# fitness  --  views
# hotel  --  meals
# location  --  residence
# meals  --  meals
# hotel  --  staff
# hotel  --  room
# prices  --  rooms
# hotel  --  hotel
# pool  --  accommodation
# food  --  transportation
# hotel  --  beach
# hotel  --  prices
# hotel  --  amenities
# hotel  --  receptionists
# hotel  --  staff
# service  --  employees
# rooms  --  rooms
# reception  --  reception
# hotel  --  food
# rooms  --  conditioning
# beach  --  fitness
# place  --  place
# rooms  --  meals
# hotel  --  hotel
# staff  --  employees
# rooms  --  staff
# hotel  --  service
# parking  --  parking
# service  --  tourism
# conditioning  --  hotel
# hotel  --  hotel
# hotel  --  bathroom
# service  --  furniture
# eating  --  food
# location  --  room
# wifi  --  hotel
# location  --  location
# internet  --  service
# hotel  --  food
# rooms  --  rooms
# hotel  --  hotel
# location  --  location
# rooms  --  bathroom
# room  --  amenities
# amenities  --  amenities
# hotel  --  room
# hotel  --  food
# hotelservices  --  hotelservices
# staff  --  rooms
# hotel  --  bathroom
# hotel  --  bathroom
# television  --  location
# rooms  --  room
# rooms  --  rooms
# hotel  --  staff
# room  --  location
# service  --  bathroom
# hotel  --  hotelservices
# hotel  --  hotel
# conditioning  --  conditioning
# food  --  food
# hotel  --  staff
# bathroom  --  bathroom
# facilities  --  parking
# staff  --  staff
# hotel  --  hotel
# food  --  restaurant
# hotel  --  meals
# hotel  --  hotel
# prices  --  facilities
# hotel  --  hotel
# location  --  reception
# amenities  --  bedding
# hotel  --  hotel
# room  --  room
# rooms  --  television
# service  --  employees
# hotel  --  location
# bathroom  --  amenities
# meals  --  meals
# hotel  --  meals
# room  --  room
# room  --  room
# rooms  --  rooms
# food  --  food
# hotel  --  transportation
# location  --  views
# hotel  --  accommodation
# conditioning  --  hotel
# staff  --  pool
# hotel  --  hotel
# hotel  --  hotel
# food  --  room
# hotel  --  receptionists
# rooms  --  beach
# hotel  --  hotel
# facilities  --  restaurant
# food  --  food
# staff  --  room
# buffet  --  meals
# staff  --  staff
# room  --  room
# room  --  room
# hotel  --  fitness
# hotel  --  internet
# hotel  --  hotel
# service  --  service
# prices  --  prices
# staff  --  parking
# food  --  transportation
# buffet  --  hotel
# hotel  --  hotel
# room  --  restaurant
# hotel  --  staff
# bathroom  --  bathroom
# room  --  facilities
# hotel  --  restaurant
# facilities  --  reception
# crew  --  pool
# service  --  tourism
# hotel  --  accommodation
# facilities  --  facilities
# staff  --  facilities
# menus  --  food
# hotel  --  hotel
# service  --  receptionists
# hotel  --  hotel
# facilities  --  pool
# location  --  place
# place  --  place
# hotel  --  parking
# receptionists  --  beach
# service  --  hotelservices
# staff  --  prices
# facilities  --  tourism
# hotel  --  hotel
# hotel  --  restaurant
# prices  --  prices
# bedding  --  meals
# meals  --  receptionists
# restaurant  --  cleanliness
# meals  --  amenities
# rooms  --  rooms
# hotel  --  hotel
# hotel  --  hotel
# rooms  --  rooms
# meals  --  meals
# location  --  facilities
# hotel  --  views
# food  --  food
# facilities  --  facilities
# hotel  --  place
# hotel  --  fitness
# hotel  --  position
# cleanliness  --  conditioning
# food  --  food
# room  --  room
# rooms  --  views
# staff  --  staff
# room  --  room
# facilities  --  facilities
# hotel  --  pool
# prices  --  prices
# facilities  --  meals
# food  --  amenities
# meals  --  bathroom
# prices  --  prices
# hotel  --  hotel
# service  --  transportation
# hotel  --  crew
# meals  --  meals
# meals  --  transportation
# hotel  --  treatment
# prices  --  location
# service  --  service
# hotel  --  prices
# resort  --  facilities
# facilities  --  cleanliness
# hotel  --  reception
# location  --  location
# stay  --  residence
# food  --  food
# staff  --  reception
# hotel  --  hotel
# restaurant  --  resort
# prices  --  room
# hotel  --  residence
# food  --  facilities
# room  --  receptionists
# meals  --  meals
# reception  --  reception
# food  --  amenities
# views  --  views
# pool  --  beach
# facilities  --  prices
# room  --  beach
# manager  --  position
# meals  --  food
# staff  --  hotelservices
# location  --  pool
# bedding  --  rooms
# food  --  facilities
# television  --  television
# service  --  beach
# meals  --  room
# hotel  --  accommodation
# location  --  amenities
# hotel  --  conditioning
# rooms  --  hotel
# accommodation  --  accommodation
# room  --  staff
# hotel  --  hotel
# facilities  --  fitness
# rooms  --  bedding
# hotelservices  --  hotel
# hotel  --  amenities
# prices  --  pool
# hotel  --  staff
# bathroom  --  bathroom
# rooms  --  restaurant
# employees  --  facilities
# location  --  location
# rooms  --  location
# hotel  --  wifi
# hotel  --  food
# hotel  --  hotelservices
# hotel  --  interaction
# hotel  --  hotel
# hotel  --  transportation
# location  --  staff
# rooms  --  facilities
# rooms  --  staff
# hotel  --  transportation
# hotel  --  interaction
# hotel  --  hotel
# food  --  food
# food  --  food
# restaurant  --  restaurant
# location  --  prices
# location  --  reception
# hotel  --  service
# cleanliness  --  cleanliness
# bathroom  --  bathroom
# hotel  --  hotel
# restaurant  --  food
# facilities  --  facilities
# prices  --  reception
# hotel  --  service
# hotel  --  hotel
# room  --  room
# hotel  --  hotel
# hotel  --  hotel
# rooms  --  location
# hotel  --  pool
# bedding  --  accommodation
# rooms  --  bathroom
# hotel  --  resort
# restaurant  --  eating
# food  --  food
# bathroom  --  amenities
# meals  --  food
# meals  --  internet
# hotel  --  management
# meals  --  rooms
# hotel  --  hotel
# rooms  --  pool
# room  --  room
# room  --  room
# room  --  room
# furniture  --  service
# service  --  facilities
# rooms  --  buffet
# hotel  --  residence
# hotel  --  location
# staff  --  rooms
# location  --  location
# hotel  --  hotel
# hotel  --  parking
# amenities  --  amenities
# hotel  --  hotelservices
# rooms  --  facilities
# hotel  --  hotel
# location  --  pool
# food  --  location
# food  --  food
# pool  --  hotel
# facilities  --  facilities
# staff  --  staff
# staff  --  staff
# facilities  --  location
# rooms  --  rooms
# hotel  --  hotel
# amenities  --  amenities
# hotel  --  food
# hotel  --  hotel
# room  --  room
# rooms  --  meals
# room  --  beach
# hotel  --  staff
# meals  --  prices
# hotel  --  hotel
# hotel  --  location
# food  --  rooms
# service  --  service
# service  --  service
# hotel  --  hotel
# location  --  bathroom
# treatment  --  treatment
# hotel  --  hotel
# facilities  --  facilities
# parking  --  eating
# hotel  --  tourism
# hotel  --  service
# hotel  --  wifi
# meals  --  staff
# place  --  location
# facilities  --  furniture
# conditioning  --  amenities
# crew  --  staff
# hotel  --  hotel
# meals  --  bathroom
# pool  --  pool
# pool  --  hotel
# amenities  --  conditioning
# hotel  --  service
# amenities  --  facilities
# rooms  --  rooms
# location  --  receptionists
# facilities  --  hotelservices
# hotel  --  rooms
# receptionists  --  rooms
# hotel  --  hotel
# place  --  place
# employees  --  staff
# hotel  --  meals
# staff  --  crew
# staff  --  position
# hotel  --  beach
# service  --  facilities
# rooms  --  fitness
# rooms  --  beach
# furniture  --  furniture
# hotel  --  rooms
# room  --  wifi
# service  --  reception
# hotel  --  beach
# rooms  --  amenities
# staff  --  interaction
# rooms  --  hotel
# staff  --  employees
# location  --  food
# reception  --  reception
# teamwork  --  furniture
# meals  --  meals
# rooms  --  transportation
# prices  --  service
# receptionists  --  receptionists
# rooms  --  location
# hotel  --  management
# reception  --  amenities
# fitness  --  room
# hotel  --  hotel
# meals  --  furniture
# room  --  hotelservices
# hotel  --  staff
# rooms  --  bathroom
# hotel  --  eating
# amenities  --  facilities
# hotel  --  pool
# rooms  --  prices
# accommodation  --  meals
# internet  --  internet
# room  --  location
# rooms  --  bedding
# hotel  --  hotel
# rooms  --  rooms
# conditioning  --  amenities
# meals  --  amenities
# rooms  --  food
# receptionists  --  parking
# amenities  --  amenities
# employees  --  staff
# hotel  --  wifi
# prices  --  accommodation
# service  --  food
# hotel  --  hotel
# food  --  food
# meals  --  meals
# meals  --  meals
# hotel  --  interaction
# hotel  --  reception
# prices  --  prices
# bathroom  --  amenities
# rooms  --  views
# hotel  --  furniture
# management  --  management
# service  --  location
# reception  --  service
# rooms  --  cleanliness
# service  --  staff
# rooms  --  rooms
# room  --  conditioning
# hotel  --  accommodation
# teamwork  --  wifi
# service  --  prices
# meals  --  transportation
# hotelservices  --  hotelservices
# rooms  --  fitness
# hotelservices  --  employees
# hotel  --  restaurant
# room  --  room
# rooms  --  location
# service  --  interaction
# rooms  --  hotel
# rooms  --  cleanliness
# location  --  location
# reception  --  room
# service  --  beach
# rooms  --  cleanliness
# rooms  --  reception
# rooms  --  prices
# food  --  pool
# beach  --  beach
# restaurant  --  restaurant
# service  --  reception
# rooms  --  bathroom
# parking  --  parking
# hotel  --  service
# restaurant  --  restaurant
# staff  --  staff
# reception  --  reception
# hotel  --  rooms
# service  --  parking
# location  --  location
# food  --  food
# transportation  --  service
# meals  --  teamwork
# location  --  facilities
# bathroom  --  bathroom
# food  --  residence
# rooms  --  hotel
# hotel  --  hotel
# prices  --  room
# service  --  transportation
# meals  --  food
# rooms  --  meals
# hotel  --  amenities
# food  --  food
# room  --  room
# hotel  --  room
# restaurant  --  hotel
# elevator  --  elevator
# food  --  amenities
# bathroom  --  amenities
# cleanliness  --  rooms
# rooms  --  bathroom
# rooms  --  rooms
# room  --  facilities
# amenities  --  bathroom
# hotel  --  amenities
# service  --  fitness
# meals  --  tourism
# meals  --  meals
# rooms  --  facilities
# rooms  --  interaction
# food  --  facilities
# location  --  place
# hotel  --  hotel
# bathroom  --  facilities
# hotel  --  television
# hotel  --  meals
# hotel  --  hotel
# rooms  --  television
# hotel  --  teamwork
# hotel  --  place
# service  --  hotelservices
# hotel  --  hotel
# meals  --  rooms
# room  --  room
# room  --  amenities
# service  --  rooms
# management  --  hotel
# hotel  --  internet
# beach  --  food
# pool  --  pool
# hotel  --  service
# amenities  --  amenities
# hotel  --  hotel
# restaurant  --  food
# prices  --  prices
# service  --  views
# bathroom  --  bathroom
# prices  --  prices
# hotel  --  eating
# location  --  location
# reception  --  hotelservices
# parking  --  amenities
# bathroom  --  internet
# rooms  --  amenities
# rooms  --  rooms
# hotel  --  location
# conditioning  --  reception
# service  --  receptionists
# facilities  --  facilities
# restaurant  --  location
# hotel  --  hotel
# hotel  --  amenities
# rooms  --  rooms
# food  --  facilities
# restaurant  --  views
# hotel  --  food
# hotel  --  hotel
# room  --  food
# hotel  --  place
# facilities  --  transportation
# foreign  --  facilities
# rooms  --  reception
# hotel  --  hotel
# bathroom  --  television
# hotel  --  beach
# amenities  --  tourism
# hotel  --  hotel
# location  --  pool
# rooms  --  service
# pool  --  pool
# pool  --  food
# rooms  --  meals
# location  --  amenities
# food  --  eating
# service  --  service
# meals  --  fitness
# hotel  --  treatment
# amenities  --  amenities
# room  --  hotel
# hotel  --  hotelservices
# hotel  --  meals
# restaurant  --  restaurant
# room  --  buffet
# transportation  --  internet
# rooms  --  parking
# location  --  location
# facilities  --  service
# location  --  location
# rooms  --  reception
# conditioning  --  parking
# teamwork  --  teamwork
# service  --  internet
# service  --  service
# rooms  --  receptionists
# rooms  --  rooms
# hotel  --  facilities
# rooms  --  internet
# meals  --  amenities
# rooms  --  furniture
# location  --  location
# hotel  --  conditioning
# location  --  facilities
# rooms  --  facilities
# hotel  --  amenities
# employees  --  bathroom
# staff  --  bathroom
# amenities  --  furniture
# restaurant  --  pool
# rooms  --  facilities
# hotel  --  transportation
# rooms  --  rooms
# hotel  --  hotelservices
# facilities  --  hotelservices
# hotel  --  restaurant
# hotel  --  hotel
# hotel  --  staff
# room  --  reception
# hotel  --  parking
# room  --  staff
# television  --  location
# receptionists  --  accommodation
# room  --  bathroom
# bathroom  --  bathroom
# pool  --  food
# hotel  --  internet
# hotel  --  food
# hotel  --  cleanliness
# rooms  --  rooms
# food  --  sea
# hotel  --  internet
# rooms  --  room
# meals  --  receptionists
# facilities  --  bathroom
# location  --  service
# hotel  --  pool
# hotel  --  hotel
# service  --  wifi
# reception  --  receptionists
# service  --  service
# hotel  --  tourism
# hotel  --  hotel
# hotel  --  place
# facilities  --  meals
# hotel  --  bathroom
# treatment  --  hotelservices
# hotel  --  hotel
# service  --  rooms
# pool  --  employees
# pool  --  tourism
# television  --  amenities
# furniture  --  tourism
# rooms  --  room
# hotel  --  hotel
# staff  --  staff
# food  --  staff
# location  --  location
# buffet  --  buffet
# prices  --  views
# hotel  --  hotel
# hotel  --  hotel
# location  --  location
# hotel  --  conditioning
# rooms  --  cleanliness
# restaurant  --  restaurant
# bar  --  food
# hotel  --  hotel
# hotel  --  meals
# hotel  --  bathroom
# hotel  --  hotel
# internet  --  room
# hotel  --  food
# rooms  --  bedding
# hotel  --  prices
# bedding  --  internet
# reception  --  restaurant
# food  --  restaurant
# food  --  food
# service  --  facilities
# reception  --  hotel
# amenities  --  room
# food  --  television
# meals  --  fitness
# hotel  --  television
# service  --  service
# service  --  service
# rooms  --  amenities
# conditioning  --  conditioning
# food  --  food
# amenities  --  rooms
# hotel  --  service
# service  --  staff
# staff  --  accommodation
# hotel  --  meals
# rooms  --  service
# bathroom  --  bedding
# furniture  --  furniture
# hotel  --  food
# hotel  --  staff
# hotelservices  --  hotelservices
# room  --  reception
# hotel  --  food
# rooms  --  pool
# meals  --  fitness
# rooms  --  facilities
# staff  --  employees
# hotel  --  bathroom
# rooms  --  internet
# location  --  views
# cleanliness  --  cleanliness
# rooms  --  rooms
# fitness  --  fitness
# management  --  staff
# location  --  interaction
# nan  --  service
# meals  --  meals
# service  --  receptionists
# bedding  --  bedding
# bathroom  --  bathroom
# hotel  --  television
# service  --  rooms
# food  --  hotel
# food  --  food
# room  --  restaurant
# bathroom  --  bathroom
# hotel  --  amenities
# food  --  food
# views  --  views
# hotel  --  tourism
# staff  --  staff
# rooms  --  rooms
# hotel  --  position
# location  --  facilities
# bathroom  --  bathroom
# facilities  --  service
# hotel  --  hotel
# hotelservices  --  hotelservices
# room  --  room
# meals  --  amenities
# hotel  --  hotel
# hotel  --  management
# hotelservices  --  employees
# pool  --  pool
# hotel  --  amenities
# hotel  --  staff
# facilities  --  amenities
# lobbyist  --  internet
# hotel  --  prices
# pool  --  accommodation
# reception  --  reception
# employees  --  facilities
# hotel  --  hotel
# hotel  --  parking
# rooms  --  reception
# room  --  fitness
# meals  --  hotel
# food  --  food
# rooms  --  rooms
# facilities  --  rooms
# hotel  --  reception
# parking  --  parking
# dishes  --  restaurant
# location  --  location
# service  --  service
# room  --  room
# meals  --  television
# rooms  --  cleanliness
# pool  --  accommodation
# location  --  meals
# hotel  --  hotel
# hotel  --  hotel
# furniture  --  furniture
# bathroom  --  fitness
# hotel  --  restaurant
# hotel  --  restaurant
# hotel  --  facilities
# facilities  --  facilities
# rooms  --  parking
# reception  --  facilities
# transportation  --  facilities
# reception  --  receptionists
# hotel  --  hotel
# facilities  --  amenities
# restaurant  --  tourism
# rooms  --  reception
# hotel  --  position
# hotel  --  facilities
# facilities  --  staff
# facilities  --  location
# television  --  beach
# room  --  facilities
# restaurant  --  internet
# transportation  --  transportation
# place  --  place
# meals  --  cleanliness
# rooms  --  facilities
# facilities  --  hotel
# hotel  --  room
# parking  --  facilities
# parking  --  parking
# staff  --  cleanliness
# restaurant  --  restaurant
# reception  --  reception
# transportation  --  transportation
# room  --  room
# hotel  --  rooms
# meals  --  food
# rooms  --  rooms
# rooms  --  hotel
# staff  --  rooms
# service  --  facilities
# service  --  service
# transportation  --  beach
# restaurant  --  restaurant
# meals  --  room
# hotel  --  hotel
# service  --  pool
# rooms  --  rooms
# reception  --  internet
# rooms  --  rooms
# facilities  --  facilities
# hotel  --  internet
# facilities  --  parking
# room  --  amenities
# furniture  --  facilities
# facilities  --  facilities
# hotel  --  service
# parking  --  facilities
# food  --  pool
# accommodation  --  room
# pool  --  pool
# pool  --  pool
# restaurant  --  restaurant
# meals  --  hotel
# hotel  --  hotel
# rooms  --  receptionists
# room  --  cleanliness
# room  --  room
# meals  --  buffet
# rooms  --  rooms
# amenities  --  pool
# staff  --  staff
# rooms  --  furniture
# amenities  --  facilities
# rooms  --  accommodation
# meals  --  meals
# conditioning  --  television
# receptionists  --  receptionists
# hotel  --  prices
# amenities  --  facilities
# food  --  receptionists
# food  --  hotel
# hotel  --  food
# hotel  --  restaurant
# location  --  tourism
# location  --  parking
# prices  --  prices
# hotel  --  staff
# service  --  hotel
# television  --  television
# prices  --  views
# hotel  --  receptionists
# prices  --  pool
# room  --  transportation
# rooms  --  bathroom
# fitness  --  location
# room  --  amenities
# teamwork  --  meals
# bathroom  --  rooms
# service  --  transportation
# location  --  elevator
# hotel  --  reception
# pool  --  accommodation
# parking  --  parking
# pool  --  pool
# location  --  cleanliness
# facilities  --  facilities
# staff  --  service
# facilities  --  furniture
# internet  --  internet
# rooms  --  rooms
# hotel  --  beach
# food  --  hotel
# buffet  --  buffet
# crew  --  crew
# hotel  --  internet
# room  --  amenities
# place  --  place
# service  --  service
# hotel  --  parking
# service  --  tourism
# meals  --  meals
# meals  --  meals
# prices  --  restaurant
# facilities  --  facilities
# receptionists  --  reception
# hotel  --  prices
# service  --  service
# hotel  --  hotel
# location  --  internet
# rooms  --  room
# rooms  --  hotel
# hotel  --  amenities
# location  --  food
# hotel  --  hotel
# conditioning  --  television
# bathroom  --  fitness
# room  --  food
# rooms  --  rooms
# hotelservices  --  hotel
# rooms  --  hotel
# facilities  --  staff
# room  --  room
# room  --  facilities
# rooms  --  prices
# hotel  --  hotel
# employees  --  employees
# facilities  --  facilities
# restaurant  --  restaurant
# hotel  --  room
# meals  --  facilities
# staff  --  meals
# hotel  --  hotel
# food  --  hotel
# room  --  meals
# facilities  --  staff
# hotel  --  hotel
# service  --  service
# hotel  --  staff
# meals  --  amenities
# rooms  --  rooms
# hotel  --  beach
# crew  --  facilities
# service  --  receptionists
# hotel  --  amenities
# rooms  --  rooms
# facilities  --  amenities
# tourism  --  tourism
# elevator  --  elevator
# rooms  --  amenities
# meals  --  meals
# location  --  amenities
# service  --  facilities
# hotel  --  hotel
# hotel  --  facilities
# furniture  --  amenities
# rooms  --  parking
# location  --  location
# hotel  --  parking
# facilities  --  fitness
# room  --  room
# rooms  --  parking
# meals  --  meals
# team  --  team
# hotel  --  hotel
# service  --  amenities
# hotel  --  hotel
# hotel  --  service
# prices  --  receptionists
# location  --  food
# elevator  --  elevator
# rooms  --  location
# hotel  --  pool
# prices  --  prices
# hotel  --  residence
# hotel  --  service
# reception  --  cleanliness
# location  --  television
# hotel  --  facilities
# meals  --  receptionists
# meals  --  pool
# rooms  --  parking
# service  --  facilities
# hotel  --  treatment
# restaurant  --  eating
# amenities  --  bathroom
# reception  --  bathroom
# hotel  --  hotel
# hotel  --  restaurant
# place  --  place
# room  --  room
# restaurant  --  restaurant
# rooms  --  reception
# food  --  transportation
# hotel  --  location
# facilities  --  bathroom
# hotel  --  service
# location  --  room
# hotel  --  restaurant
# facilities  --  residence
# location  --  facilities
# hotel  --  location
# service  --  service
# team  --  hotel
# food  --  rooms
# reception  --  reception
# hotel  --  hotel
# bathroom  --  bathroom
# hotel  --  views
# location  --  pool
# room  --  restaurant
# hotel  --  furniture
# room  --  teamwork
# prices  --  residence
# rooms  --  transportation
# pool  --  meals
# buffet  --  buffet
# rooms  --  facilities
# location  --  location
# hotel  --  hotelservices
# staff  --  staff
# hotelservices  --  employees
# rooms  --  rooms
# staff  --  facilities
# hotel  --  hotel
# hotel  --  food
# amenities  --  facilities
# room  --  views
# location  --  place
# food  --  views
# hotelservices  --  facilities
# food  --  food
# hotel  --  hotel
# hotel  --  hotel
# room  --  meals
# hotel  --  hotel
# rooms  --  facilities
# hotel  --  location
# hotel  --  bathroom
# beach  --  beach
# receptionists  --  eating
# food  --  facilities
# facilities  --  room
# pool  --  pool
# hotel  --  hotel
# service  --  service
# hotel  --  accommodation
# staff  --  facilities
# furniture  --  facilities
# rooms  --  hotel
# service  --  service
# prices  --  service
# service  --  receptionists
# television  --  stay
# rooms  --  bathroom
# restaurant  --  fitness
# amenities  --  pool
# hotel  --  wifi
# hotel  --  hotel
# hotel  --  facilities
# room  --  rooms
# elevator  --  elevator
# hotel  --  pool
# prices  --  transportation
# facilities  --  employees
# hotel  --  service
# service  --  service
# meals  --  food
# facilities  --  facilities
# staff  --  meals
# hotel  --  hotelservices
# restaurant  --  tourism
# hotel  --  hotel
# food  --  staff
# facilities  --  staff
# food  --  facilities
# service  --  reception
# food  --  food
# location  --  location
# hotelservices  --  hotelservices
# pool  --  amenities
# bedding  --  bathroom
# food  --  prices
# service  --  service
# prices  --  prices
# pool  --  beach
# internet  --  internet
# service  --  meals
# location  --  interaction
# service  --  bathroom
# bathroom  --  room
# hotel  --  management
# service  --  beach
# service  --  service
# management  --  management
# staff  --  employees
# staff  --  meals
# service  --  bathroom
# facilities  --  rooms
# hotel  --  hotel
# hotel  --  service
# hotel  --  hotel
# rooms  --  pool
# meals  --  facilities
# rooms  --  rooms
# room  --  room
# transportation  --  transportation
# food  --  hotel
# hotel  --  management
# room  --  staff
# room  --  staff
# hotel  --  rooms
# drinks  --  facilities
# amenities  --  amenities
# meals  --  room
# service  --  views
# bar  --  amenities
# prices  --  prices
# bedding  --  meals
# amenities  --  meals
# service  --  service
# food  --  hotel
# hotel  --  hotelservices
# facilities  --  pool
# hotel  --  food
# bathroom  --  bathroom
# hotel  --  hotel
# receptionists  --  receptionists
# hotel  --  interaction
# hotel  --  hotel
# reception  --  views
# meals  --  hotel
# hotel  --  views
# wifi  --  wifi
# service  --  service
# hotel  --  views
# hotel  --  pool
# hotel  --  views
# place  --  transportation
# restaurant  --  restaurant
# hotel  --  facilities
# hotel  --  hotel
# meals  --  restaurant
# hotel  --  food
# internet  --  service
# place  --  place
# prices  --  views
# television  --  television
# internet  --  prices
# room  --  bathroom
# receptionists  --  staff
# location  --  staff
# food  --  reception
# hotel  --  amenities
# hotel  --  cleanliness
# management  --  facilities
# hotel  --  internet
# staff  --  restaurant
# bathroom  --  bathroom
# hotel  --  staff
# prices  --  prices
# staff  --  teamwork
# hotel  --  views
# room  --  room
# hotel  --  hotel
# amenities  --  facilities
# location  --  location
# wifi  --  wifi
# rooms  --  rooms
# hotel  --  accommodation
# hotel  --  hotel
# rooms  --  hotel
# food  --  food
# hotel  --  amenities
# hotel  --  hotel
# bathroom  --  bathroom
# room  --  room
# hotel  --  hotel
# treatment  --  service
# location  --  fitness
# food  --  rooms
# service  --  internet
# rooms  --  fitness
# rooms  --  pool
# food  --  food
# hotel  --  hotel
# food  --  food
# service  --  reception
# hotel  --  parking
# location  --  rooms
# room  --  room
# television  --  pool
# service  --  service
# hotel  --  food
# rooms  --  fitness
# food  --  location
# hotel  --  wifi
# rooms  --  rooms
# resort  --  beach
# hotel  --  bathroom
# conditioning  --  rooms
# reception  --  restaurant
# location  --  cleanliness
# hotel  --  views
# location  --  pool
# location  --  bathroom
# rooms  --  views
# hotel  --  accommodation
# hotel  --  staff
# restaurant  --  transportation
# reception  --  reception
# rooms  --  internet
# rooms  --  bathroom
# hotel  --  location
# amenities  --  amenities
# meals  --  rooms
# hotel  --  amenities
# employees  --  employees
# location  --  rooms
# hotel  --  location
# meals  --  teamwork
# hotel  --  eating
# hotel  --  restaurant
# hotel  --  staff
# hotel  --  facilities
# hotel  --  hotel
# staff  --  location
# hotel  --  beach
# staff  --  staff
# parking  --  position
# food  --  food
# rooms  --  amenities
# hotel  --  restaurant
# menu  --  food
# prices  --  prices
# hotel  --  parking
# receptionists  --  fitness
# rooms  --  hotel
# hotel  --  transportation
# hotel  --  rooms
# hotel  --  staff
# hotel  --  restaurant
# service  --  service
# location  --  accommodation
# location  --  location
# rooms  --  rooms
# transportation  --  transportation
# buffet  --  rooms
# food  --  hotel
# facilities  --  amenities
# room  --  parking
# hotel  --  hotel
# food  --  food
# facilities  --  wifi
# location  --  hotel
# prices  --  staff
# rooms  --  room
# hotel  --  hotel
# restaurant  --  hotel
# hotel  --  accommodation
# rooms  --  location
# location  --  location
# meals  --  cleanliness
# rooms  --  facilities
# hotel  --  hotel
# hotel  --  hotelservices
# meals  --  place
# amenities  --  facilities
# bedding  --  cleanliness
# hotel  --  pool
# hotel  --  amenities
# hotel  --  meals
# room  --  bathroom
# restaurant  --  restaurant
# restaurant  --  restaurant
# prices  --  internet
# location  --  transportation
# service  --  service
# location  --  accommodation
# transportation  --  transportation
# hotel  --  wifi
# service  --  hotel
# facilities  --  fitness
# staff  --  restaurant
# employees  --  hotel
# internet  --  television
# facilities  --  views
# prices  --  food
# internet  --  facilities
# eating  --  eating
# food  --  food
# room  --  restaurant
# rooms  --  cleanliness
# hotel  --  crew
# service  --  service
# hotel  --  restaurant
# hotel  --  hotel
# hotel  --  hotel
# service  --  location
# hotel  --  hotel
# location  --  reception
# bathroom  --  transportation
# staff  --  facilities
# hotel  --  hotel
# hotel  --  hotel
# hotel  --  internet
# hotel  --  hotel
# hotel  --  restaurant
# food  --  accommodation
# prices  --  television
# receptionists  --  employees
# hotel  --  prices
# internet  --  internet
# food  --  food
# meals  --  hotel
# pool  --  cleanliness
# service  --  hotel
# hotel  --  hotel
# hotel  --  hotel
# reception  --  bathroom
# hotel  --  hotel
# meals  --  pool
# hotel  --  hotel
# location  --  hotel
# hotel  --  room
# hotel  --  meals
# hotelservices  --  interaction
# administration  --  management
# hotel  --  reception
# hotel  --  location
# food  --  receptionists
# facilities  --  employees
# hotel  --  hotel
# hotel  --  hotel
# location  --  service
# staff  --  hotel
# reception  --  facilities
# rooms  --  rooms
# service  --  service
# food  --  beach
# hotel  --  hotel
# hotel  --  room
# staff  --  staff
# staff  --  teamwork
# hotel  --  hotel
# resort  --  facilities
# room  --  rooms
# hotel  --  location
# hotel  --  residence
# meals  --  meals
# hotel  --  hotel
# hotel  --  prices
# hotel  --  staff
# elevator  --  food
# service  --  hotelservices
# hotel  --  hotel
# room  --  amenities
# prices  --  food
# employees  --  staff
# hotel  --  facilities
# meals  --  staff
# rooms  --  rooms
# room  --  room
# food  --  amenities
# amenities  --  amenities
# hotel  --  cleanliness
# prices  --  prices
# service  --  service
# room  --  pool
# hotel  --  room
# hotelservices  --  food
# hotel  --  views
# hotel  --  hotel
# service  --  transportation
# meals  --  parking
# prices  --  views
# location  --  rooms
# parking  --  facilities
# hotel  --  place
# food  --  beach
# rooms  --  food
# room  --  hotelservices
# meals  --  hotel
# meals  --  amenities
# reception  --  hotelservices
# hotel  --  amenities
# food  --  internet
# nan  --  residence
# hotel  --  place
# meals  --  views
# rooms  --  cleanliness
# hotel  --  rooms
# facilities  --  furniture
# room  --  room
# receptionists  --  food
# hotel  --  teamwork
# room  --  service
# staff  --  food
# amenities  --  amenities
# service  --  bathroom
# facilities  --  amenities
# staff  --  meals
# food  --  amenities
# rooms  --  hotel
# service  --  food
# location  --  wifi
# hotel  --  location
# prices  --  prices
# meals  --  residence
# room  --  room
# pool  --  hotel
# rooms  --  hotel
# hotel  --  bedding
# hotel  --  food
# service  --  amenities
# hotel  --  reception
# food  --  room
# buffet  --  pool
# refrigerator  --  conditioning
# hotel  --  views
# hotel  --  reception
# hotel  --  hotel
# meals  --  meals
# rooms  --  prices
# bathroom  --  bathroom
# amenities  --  amenities
# room  --  conditioning
# hotel  --  bathroom
# hotel  --  wifi
# parking  --  parking
# staff  --  food
# food  --  food
# room  --  staff
# accommodation  --  accommodation
# food  --  facilities
# staff  --  staff
# location  --  hotel
# hotel  --  reception
# reception  --  reception
# rooms  --  amenities
# hotel  --  hotel
# meals  --  cleanliness
# hotel  --  wifi
# restaurant  --  restaurant
# resort  --  resort
# staff  --  wifi
# service  --  team
# hotel  --  food
# meals  --  furniture
# hotel  --  restaurant
# hotel  --  hotel
# rooms  --  television
# hotel  --  hotel
# room  --  prices
# room  --  service
# meals  --  facilities
# food  --  eating
# hotel  --  staff
# bedding  --  location
# service  --  service
# receptionists  --  receptionists
# hotel  --  restaurant
# hotel  --  service
# prices  --  management
# room  --  rooms
# hotelservices  --  hotelservices
# service  --  hotelservices
# hotel  --  location
# room  --  receptionists
# teamwork  --  place
# hotel  --  hotelservices
# location  --  hotel
# facilities  --  facilities
# hotel  --  food
# hotel  --  management
# hotel  --  hotel
# hotel  --  hotel
# meals  --  meals
# room  --  location
# hotel  --  staff
# rooms  --  views
# rooms  --  prices
# food  --  food
# staff  --  hotel
# hotel  --  parking
# hotel  --  hotel
# buffet  --  pool
# service  --  service
# hotel  --  television
# rooms  --  crew
# staff  --  furniture
# room  --  room
# receptionists  --  receptionists
# amenities  --  facilities
# hotel  --  hotel
# hotel  --  rooms
# location  --  location
# rooms  --  views
# accommodation  --  accommodation
# treatment  --  prices
# hotel  --  fitness
# meals  --  facilities
# service  --  hotel
# rooms  --  rooms
# hotel  --  wifi
# bathroom  --  room
# staff  --  staff
# meals  --  meals
# hotel  --  hotel
# prices  --  prices
# television  --  employees
# staff  --  location
# facilities  --  facilities
# hotel  --  buffet
# service  --  parking
# service  --  hotel
# facilities  --  parking
# conditioning  --  food
# conditioning  --  parking
# service  --  service
# hotel  --  hotel
# prices  --  hotel
# service  --  pool
# rooms  --  receptionists
# hotel  --  parking
# amenities  --  prices
# room  --  parking
# service  --  service
# staff  --  staff
# room  --  room
# hotel  --  hotel
# rooms  --  employees
# hotel  --  hotel
# staff  --  staff
# hotel  --  hotel
# hotel  --  hotelservices
# location  --  meals
# service  --  room
# hotel  --  meals
# rooms  --  receptionists
# facilities  --  fitness
# hotel  --  hotel
# service  --  hotel
# staff  --  location
# rooms  --  rooms
# rooms  --  service
# reception  --  reception
# hotel  --  wifi
# hotel  --  reception
# hotel  --  meals
# hotel  --  hotel
# bathroom  --  wifi
# hotel  --  hotel
# conditioning  --  conditioning
# prices  --  prices
# hotel  --  hotel
# hotel  --  hotel
# location  --  room
# hotel  --  location
# facilities  --  management
# food  --  eating
# pool  --  facilities
# bedding  --  bedding
# hotel  --  location
# facilities  --  internet
# hotelservices  --  staff
# location  --  bathroom
# prices  --  cleanliness
# service  --  food
# room  --  views
# hotel  --  hotel
# staff  --  views
# amenities  --  facilities
# service  --  service
# room  --  prices
# location  --  location
# hotel  --  staff
# hotel  --  room
# staff  --  staff
# rooms  --  rooms
# rooms  --  location
# rooms  --  beach
# rooms  --  rooms
# teamwork  --  teamwork
# rooms  --  accommodation
# wifi  --  wifi
# bathroom  --  bathroom
# location  --  bathroom
# hotel  --  hotel
# facilities  --  facilities
# hotel  --  stay
# hotel  --  hotel
# hotel  --  hotel
# hotel  --  location
# hotel  --  accommodation
# location  --  location
# prices  --  pool
# hotel  --  staff
# hotel  --  television
# hotel  --  hotel
# rooms  --  rooms
# service  --  staff
# meals  --  hotel
# pool  --  cleanliness
# rooms  --  rooms
# meals  --  internet
# meals  --  cleanliness
# hotel  --  staff
# rooms  --  room
# hotel  --  hotel
# food  --  wifi
# rooms  --  hotel
# wifi  --  staff
# service  --  bathroom
# service  --  bathroom
# amenities  --  amenities
# procedures  --  facilities
# room  --  accommodation
# hotel  --  location
# rooms  --  cleanliness
# fitness  --  fitness
# rooms  --  wifi
# place  --  amenities
# meals  --  service
# location  --  location
# hotel  --  receptionists
# rooms  --  rooms
# management  --  management
# conditioning  --  hotel
# hotel  --  bathroom
# service  --  furniture
# hotel  --  amenities
# location  --  crew
# hotel  --  transportation
# rooms  --  tourism
# room  --  room
# service  --  staff
# facilities  --  facilities
# hotel  --  tourism
# television  --  bathroom
# hotel  --  hotel
# rooms  --  beach
# hotelservices  --  rooms
# staff  --  staff
# hotel  --  hotel
# food  --  beach
# facilities  --  wifi
# room  --  cleanliness
# hotel  --  facilities
# rooms  --  rooms
# furniture  --  cleanliness
# rooms  --  facilities
# rooms  --  television
# facilities  --  transportation
# conditioning  --  facilities
# service  --  place
# rooms  --  facilities
# staff  --  views
# hotel  --  staff
# staff  --  staff
# amenities  --  facilities
# internet  --  rooms
# meals  --  receptionists
# prices  --  cleanliness
# facilities  --  facilities
# bedding  --  bedding
# place  --  place
# internet  --  location
# beach  --  beach
# rooms  --  rooms
# pool  --  pool
# hotel  --  restaurant
# service  --  facilities
# rooms  --  restaurant
# hotel  --  facilities
# prices  --  restaurant
# hotel  --  hotel
# meals  --  place
# hotel  --  food
# hotel  --  hotel
# hotel  --  restaurant
# staff  --  team
# rooms  --  internet
# pool  --  wifi
# service  --  parking
# hotel  --  hotel
# service  --  service
# service  --  hotelservices
# room  --  restaurant
# rooms  --  stay
# bedding  --  views
# rooms  --  service
# hotel  --  transportation
# facilities  --  amenities
# place  --  place
# customer  --  service
# management  --  facilities
# prices  --  service
# hotel  --  restaurant
# hotel  --  hotel
# furnishings  --  furniture
# meals  --  meals
# service  --  wifi
# beach  --  reception
# hotel  --  service
# hotel  --  receptionists
# hotel  --  staff
# service  --  service
# reception  --  facilities
# facilities  --  furniture
# reception  --  rooms
# location  --  facilities
# location  --  accommodation
# rooms  --  rooms
# hotel  --  views
# location  --  restaurant
# hotel  --  hotel
# location  --  location
# furniture  --  tourism
# staff  --  facilities
# prices  --  bedding
# rooms  --  beach
# service  --  service
# staff  --  food
# hotel  --  management
# television  --  room
# location  --  sea
# facilities  --  television
# meals  --  restaurant
# hotel  --  restaurant
# conditioning  --  beach
# pool  --  pool
# prices  --  hotel
# location  --  beach
# hotel  --  room
# conditioning  --  amenities
# service  --  fitness
# location  --  service
# service  --  service
# employees  --  staff
# rooms  --  fitness
# meals  --  employees
# location  --  hotel
# hotel  --  hotel
# hotel  --  service
# food  --  accommodation
# hotel  --  parking
# meals  --  hotel
# employees  --  reception
# internet  --  location
# hotel  --  hotel
# restaurant  --  restaurant
# rooms  --  views
# hotel  --  hotel
# crew  --  hotel
# bathroom  --  transportation
# facilities  --  tourism
# hotel  --  beach
# service  --  room
# hotel  --  views
# rooms  --  reception
# hotel  --  amenities
# hotel  --  service
# food  --  bathroom
# rooms  --  cleanliness
# employees  --  staff
# location  --  parking
# hotel  --  hotel
# furniture  --  amenities
# hotel  --  beach
# bathroom  --  bathroom
# location  --  hotel
# reception  --  hotelservices
# rooms  --  receptionists
# rooms  --  reception
# room  --  room
# room  --  hotel
# hotel  --  bathroom
# room  --  rooms
# meals  --  pool
# amenities  --  cleanliness
# service  --  service
# hotel  --  hotel
# residence  --  restaurant
# wifi  --  wifi
# hotel  --  hotel
# staff  --  teamwork
# room  --  hotel
# rooms  --  rooms
# hotel  --  service
# location  --  hotel
# hotel  --  meals
# pool  --  facilities
# housing  --  facilities
# meals  --  beach
# facilities  --  pool
# conditioning  --  conditioning
# food  --  service
# rooms  --  amenities
# food  --  food
# food  --  food
# hotel  --  restaurant
# meals  --  beach
# prices  --  fitness
# hotel  --  cleanliness
# hotel  --  meals
# service  --  room
# hotel  --  rooms
# location  --  cleanliness
# facilities  --  bedding
# meals  --  food
# hotel  --  hotel
# room  --  room
# hotel  --  location
# rooms  --  rooms
# amenities  --  fitness
# food  --  tourism
# hotel  --  hotel
# hotel  --  fitness
# place  --  place
# prices  --  prices
# meals  --  meals
# pool  --  food
# pool  --  pool
# food  --  transportation
# hotelservices  --  position
# room  --  amenities
# hotel  --  facilities
# meals  --  meals
# hotel  --  receptionists
# meals  --  pool
# service  --  wifi
# hotel  --  facilities
# food  --  food
# internet  --  internet
# service  --  rooms
# restaurant  --  facilities
# service  --  views
# transportation  --  receptionists
# meals  --  meals
# receptionists  --  receptionists
# bathroom  --  room
# hotel  --  hotel
# facilities  --  place
# hotel  --  hotel
# hotel  --  residence
# meals  --  room
# transportation  --  place
# rooms  --  internet
# meals  --  meals
# prices  --  prices
# hotel  --  hotel
# hotel  --  prices
# hotel  --  cleanliness
# restaurant  --  restaurant
# rooms  --  stay
# hotel  --  hotel
# hotel  --  parking
# staff  --  amenities
# beach  --  sea
# rooms  --  cleanliness
# hotel  --  hotel
# bathroom  --  rooms
# service  --  resort
# hotel  --  room
# food  --  food
# bathroom  --  room
# amenities  --  bathroom
# prices  --  prices
# meals  --  wifi
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# neutral  --  positive
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# negative  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  neutral
# neutral  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  positive
# negative  --  negative
# positive  --  neutral
# positive  --  neutral
# negative  --  negative
# positive  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# positive  --  negative
# positive  --  positive
# neutral  --  positive
# negative  --  negative
# negative  --  negative
# neutral  --  neutral
# negative  --  negative
# positive  --  positive
# neutral  --  negative
# positive  --  positive
# positive  --  negative
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# neutral  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# negative  --  neutral
# positive  --  neutral
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  negative
# negative  --  negative
# negative  --  negative
# neutral  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  negative
# neutral  --  neutral
# neutral  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# negative  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# neutral  --  neutral
# positive  --  neutral
# negative  --  neutral
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  neutral
# positive  --  neutral
# neutral  --  neutral
# negative  --  negative
# negative  --  neutral
# positive  --  neutral
# positive  --  positive
# neutral  --  positive
# ...
# positive  --  positive
# positive  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  neutral
# negative  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# negative  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# negative  --  neutral
# negative  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  neutral
# neutral  --  negative
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# negative  --  neutral
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# neutral  --  neutral
# positive  --  positive
# negative  --  positive
# negative  --  negative
# negative  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# positive  --  negative
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# negative  --  neutral
# negative  --  negative
# neutral  --  neutral
# neutral  --  neutral
# negative  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# neutral  --  negative
# neutral  --  neutral
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# negative  --  negative
# negative  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# neutral  --  positive
# negative  --  neutral
# positive  --  negative
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# neutral  --  positive
# positive  --  positive
# neutral  --  neutral
# negative  --  neutral
# negative  --  negative
# negative  --  neutral
# neutral  --  neutral
# neutral  --  negative
# negative  --  negative
# neutral  --  neutral
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# negative  --  neutral
# negative  --  positive
# negative  --  neutral
# negative  --  neutral
# negative  --  negative
# neutral  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# neutral  --  negative
# negative  --  neutral
# negative  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# neutral  --  neutral
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  negative
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# negative  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  neutral
# neutral  --  positive
# neutral  --  negative
# positive  --  negative
# negative  --  neutral
# neutral  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# neutral  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# neutral  --  neutral
# neutral  --  neutral
# positive  --  neutral
# negative  --  negative
# negative  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# negative  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  neutral
# neutral  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# neutral  --  neutral
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# positive  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# negative  --  neutral
# negative  --  neutral
# neutral  --  negative
# negative  --  neutral
# neutral  --  neutral
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# positive  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# neutral  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# neutral  --  neutral
# negative  --  negative
# positive  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  neutral
# negative  --  neutral
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# neutral  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  neutral
# positive  --  positive
# negative  --  neutral
# negative  --  positive
# positive  --  neutral
# neutral  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# negative  --  negative
# neutral  --  positive
# negative  --  neutral
# positive  --  neutral
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# negative  --  negative
# neutral  --  positive
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  negative
# negative  --  negative
# neutral  --  neutral
# positive  --  negative
# negative  --  neutral
# positive  --  positive
# negative  --  neutral
# neutral  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  neutral
# positive  --  neutral
# neutral  --  neutral
# positive  --  positive
# negative  --  neutral
# negative  --  negative
# positive  --  neutral
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  neutral
# positive  --  positive
# neutral  --  neutral
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# negative  --  negative
# negative  --  neutral
# positive  --  neutral
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# neutral  --  neutral
# positive  --  neutral
# positive  --  negative
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# neutral  --  neutral
# negative  --  neutral
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# neutral  --  neutral
# neutral  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# positive  --  positive
# negative  --  negative
# neutral  --  neutral
# negative  --  neutral
# negative  --  negative
# positive  --  positive
# negative  --  negative
# positive  --  neutral
# negative  --  negative
# neutral  --  positive
# positive  --  negative
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  neutral
# positive  --  neutral
# positive  --  positive
# positive  --  neutral
# neutral  --  neutral
# positive  --  neutral
# positive  --  negative
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  positive
# positive  --  neutral
# positive  --  positive
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  positive
# negative  --  positive
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# negative  --  neutral
# neutral  --  neutral
# positive  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# positive  --  positive
# positive  --  positive
# neutral  --  neutral
# negative  --  negative
# negative  --  negative
# positive  --  positive
# positive  --  neutral
# negative  --  negative
# negative  --  negative
# negative  --  negative
# positive  --  positive
# neutral  --  neutral
# --------------------------------------------------
# Precision Aspects: 0.9447363959993219
# Accuracy Aspects: 0.7372343240144633
# Recall Aspects: 0.7704608294930876
# F1 Aspects: 0.8487448282864177
# jaccard Aspects: 0.7217696371029163
# --------------------------------------------------
# Precision Opinions: 0.9557079748895606
# Accuracy Opinions: 0.8996498139636682
# Recall Opinions: 0.93879182368391
# F1 Opinions: 0.9471743764041708
# jaccard Opinions: 0.9375471110826396
# --------------------------------------------------
# Precision Main Aspect: 0.31750433275563256
# Accuracy Main Aspect: 0.31750433275563256
# Recall Main Aspect: 1.0
# F1 Main Aspect: 0.4819784267298079
# --------------------------------------------------
# Precision Global Polarity: 0.687001733102253
# Accuracy Global Polarity: 0.687001733102253
# Recall Global Polarity: 1.0
# F1 Global Polarity: 0.814464762687487
# --------------------------------------------------

# %% [markdown]
# # Mise en forme de l'output du model

# %%
def parse_model_output(output):
    main_aspect_match = re.search(r"main aspect: ([^,]+?)(?= extracted aspects:)", output)
    aspects_match = re.search(r"extracted aspects: ([^,]+?(?:, [^,]+)*)(?= extracted opinions:)", output)
    opinions_match = re.search(r"extracted opinions: ([^,]+?(?:, [^,]+)*)(?= global polarity:)", output)
    polarity_match = re.search(r"global polarity: (\w+)", output)
    main_aspect = main_aspect_match.group(1) if main_aspect_match else None
    aspects = [aspect.strip() for aspect in aspects_match.group(1).split(",")] if aspects_match else []
    opinions = [opinion.strip() for opinion in opinions_match.group(1).split(",")] if opinions_match else []
    global_polarity = polarity_match.group(1) if polarity_match else None
    aspects = list(dict.fromkeys(aspects))
    return {
        "main_aspect": main_aspect,
        "extracted_aspects": aspects,
        "extracted_opinions": opinions,
        "global_polarity": global_polarity
    }

# %%
def generate_single_prediction(model, tokenizer, text, max_length=150):
    model.eval()
    formatted_text = f"review: {text}"
    input_encoding = tokenizer(
        formatted_text,
        padding="max_length",
        truncation=True,
        max_length=max_length,
        return_tensors="pt"
    ).to(device)

    output = model.generate(
        input_ids=input_encoding.input_ids,
        attention_mask=input_encoding.attention_mask,
        max_length=max_length
    )
    prediction = tokenizer.decode(output[0], skip_special_tokens=True)
    return prediction
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-5): 5 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-5): 5 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=32128, bias=False)
# )

# %% [markdown]
# # Phrases simple de test

# %%
sentences = [
    "The service was exceptionally friendly and efficient.",
    "Their new dessert menu is both inventive and tasty.",
    "The ambiance of the restaurant was cozy and inviting.",
    "I found the pasta to be wonderfully flavorful and perfectly cooked.",
    "The coffee was rich in aroma and perfectly brewed.",
    "The steak was tender, juicy, and cooked to perfection.",
    "The vegetarian options were both varied and delightful.",
    "The sushi rolls were fresh and expertly prepared.",
    "The wine selection complemented our meal beautifully.",
    "The presentation of the dishes was elegant and appealing.",
    "The pizza had a perfectly crispy crust and fresh toppings.",
    "The waiter provided excellent recommendations and attentive service.",
    "The spicy dishes had just the right amount of heat.",
    "The homemade bread was warm and delicious.",
    "The view from the dining room was breathtaking.",
    "The restaurant's atmosphere was modern and chic.",
    "The salad was crisp, fresh, and well-dressed.",
    "The seafood was extremely fresh and succulent.",
    "The chocolate cake was decadently rich and moist.",
    "The portion sizes were generous and satisfying.",
    "The soups were aromatic and bursting with flavor.",
    "The buffet had a great variety of choices.",
    "The outdoor seating area was pleasant and comfortable.",
    "The chicken was tender and seasoned perfectly.",
    "The homemade pasta was a standout dish.",
    "The cocktails were creative and well-crafted.",
    "The burgers were juicy and packed with flavor.",
    "The brunch menu had excellent choices for everyone.",
    "The tea selection was impressive and well-curated.",
    "The crepes were thin, light, and delicious.",
    "The ribs were fall-off-the-bone tender.",
    "The vegan dishes were innovative and tasty.",
    "The lamb was cooked to tender perfection.",
    "The ice cream was creamy and full of flavor.",
    "The dining experience was relaxing and enjoyable.",
    "The pastries were flaky, buttery, and delightful.",
    "The staff made us feel very welcome.",
    "The smoothies were fresh and perfectly blended.",
    "The appetizers were a great start to the meal.",
    "The decor added a unique charm to the restaurant.",
    "The pancakes were fluffy and delicious.",
    "The local ingredients made a noticeable difference.",
    "The curry had a perfect balance of spices.",
    "The atmosphere was lively and engaging.",
    "The kids' menu had great options.",
    "The sandwiches were fresh and very filling.",
    "The salads were an explosion of flavors.",
    "The duck was cooked to a crispy finish.",
    "The themed decor created a fun dining experience.",
    "The restaurant's cleanliness was top-notch.",
    "The nachos were loaded and flavorful.",
    "The tapas were the perfect size for sharing.",
    "The grilled vegetables were seasoned beautifully.",
    "The risotto was creamy and perfectly cooked.",
    "The fresh juices were a refreshing treat.",
    "The vegan burger was surprisingly delicious.",
    "The omelets were fluffy and packed with ingredients.",
    "The traditional dishes were authentic and tasty.",
    "The gluten-free options were plentiful and varied.",
    "The restaurant had a great energy and vibe.",
    "The cheesecake was smooth and creamy.",
    "The hot chocolate was rich and decadent.",
    "The artisanal cheeses were a delightful treat.",
    "The fish tacos were light and flavorful.",
    "The staff's attention to detail was impressive.",
    "The French fries were crispy and well-seasoned.",
    "The cocktail list was innovative and exciting.",
    "The breakfast burrito was hearty and satisfying.",
    "The location of the restaurant was convenient and accessible.",
    "The dim sum was authentic and delicious.",
    "The craft beer selection was excellent.",
    "The fresh fruit platter was beautifully arranged.",
    "The restaurant's ambiance was romantic and serene.",
    "The quiche was light and packed with flavor.",
    "The gourmet pizza options were unique and tasty.",
    "The seafood pasta was rich and flavorful.",
    "The Korean BBQ was an interactive and fun experience.",
    "The organic salad was fresh and nutritious.",
    "The bistro setting was quaint and charming.",
    "The homemade soups were comforting and hearty.",
    "The stir-fry was vibrant and packed with veggies.",
    "The outdoor patio had a great view and atmosphere.",
    "The tap water was refreshing and had a clean taste.",
    "The fine dining experience was unforgettable.",
    "The farm-to-table concept was evident in the freshness of the food.",
    "The seasonal menu always has something new and exciting.",
    "The Greek salad was authentic and refreshing.",
    "The sushi bar offered a wide variety of fresh options.",
    "The staff went above and beyond to ensure a great experience.",
    "The paella was packed with seafood and flavor.",
    "The gelato flavors were unique and delicious.",
    "The craft cocktails were a highlight of the evening.",
    "The vegetable curry was hearty and satisfying.",
    "The French toast was sweet and perfectly cooked.",
    "The farm-fresh eggs made a difference in taste.",
    "The BBQ chicken pizza was a perfect blend of flavors.",
    "The artisan breads were a great accompaniment to the meal.",
    "The ambiance made for a perfect date night.",
    "The Thai noodles were spicy and full of flavor.",
    "The gourmet sandwiches were a delightful lunch option."
]
outputs = []
for sentence in sentences:
      prediction = generate_single_prediction(model, tokenizer, sentence, max_length=150)
      print("-"*50)
      print("text : ",sentence)
      print(prediction)
      outputs.append(parse_model_output(prediction))
      print("-"*50)
# Out:
# --------------------------------------------------
# text :  The service was exceptionally friendly and efficient.
# main aspect: service extracted aspects: service extracted opinions: friendly, efficient global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  Their new dessert menu is both inventive and tasty.
# main aspect: dessert menu extracted aspects: dessert menu, menu, inventive extracted opinions: inventive global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The ambiance of the restaurant was cozy and inviting.
# main aspect: restaurant extracted aspects: ambiance, restaurant extracted opinions: inviting global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  I found the pasta to be wonderfully flavorful and perfectly cooked.
# main aspect: pasta extracted aspects: pasta extracted opinions: perfectly, wonderfully global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The coffee was rich in aroma and perfectly brewed.
# main aspect: coffee extracted aspects: aroma, coffee extracted opinions: rich, perfectly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The steak was tender, juicy, and cooked to perfection.
# main aspect: steak extracted aspects: steak, perfection extracted opinions: perfection global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The vegetarian options were both varied and delightful.
# main aspect: vegetarian options extracted aspects: vegetarian options, options extracted opinions: delightful global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The sushi rolls were fresh and expertly prepared.
# main aspect: sushi rolls extracted aspects: sushi rolls, rolls extracted opinions: fresh global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The wine selection complemented our meal beautifully.
# main aspect: wine selection extracted aspects: meal, wine selection, selection extracted opinions: beautifully global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The presentation of the dishes was elegant and appealing.
# main aspect: presentation extracted aspects: presentation, dishes extracted opinions: elegant, appealing global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The pizza had a perfectly crispy crust and fresh toppings.
# main aspect: pizza extracted aspects: crust, toppings, pizza extracted opinions: fresh, perfectly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The waiter provided excellent recommendations and attentive service.
# main aspect: waiter extracted aspects: service, recommendations, waiter extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The spicy dishes had just the right amount of heat.
# main aspect: spicy dishes extracted aspects: spicy dishes, amount, heat, dishes extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The homemade bread was warm and delicious.
# main aspect: homemade bread extracted aspects: homemade bread, bread extracted opinions: delicious, warm global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The view from the dining room was breathtaking.
# main aspect: view extracted aspects: view, dining, room extracted opinions: breathtaking global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The restaurant's atmosphere was modern and chic.
# main aspect: restaurant extracted aspects: atmosphere, restaurant extracted opinions: chic global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The salad was crisp, fresh, and well-dressed.
# main aspect: salad extracted aspects: salad extracted opinions: fresh global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The seafood was extremely fresh and succulent.
# main aspect: seafood extracted aspects: seafood extracted opinions: fresh global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The chocolate cake was decadently rich and moist.
# main aspect: chocolate cake extracted aspects: cake, chocolate cake extracted opinions: rich global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The portion sizes were generous and satisfying.
# main aspect: portion sizes extracted aspects: portions, sizes extracted opinions: generous, satisfying global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The soups were aromatic and bursting with flavor.
# main aspect: soups extracted aspects: soups, flavor extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The buffet had a great variety of choices.
# main aspect: buffet extracted aspects: choices, buffet extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The outdoor seating area was pleasant and comfortable.
# main aspect: outdoor seating area extracted aspects: area, outdoor seating area, outdoor seating extracted opinions: comfortable, pleasant global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The chicken was tender and seasoned perfectly.
# main aspect: chicken extracted aspects: chicken extracted opinions: perfectly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The homemade pasta was a standout dish.
# main aspect: homemade pasta extracted aspects: dish, homemade pasta, homemade pasta extracted opinions: standout global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The cocktails were creative and well-crafted.
# main aspect: cocktails extracted aspects: cocktails extracted opinions: creative global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The burgers were juicy and packed with flavor.
# main aspect: burgers extracted aspects: flavor, burgers extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The brunch menu had excellent choices for everyone.
# main aspect: brunch menu extracted aspects: brunch menu, menu, choices, everyone extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The tea selection was impressive and well-curated.
# main aspect: tea selection extracted aspects: selection, tea, tea extracted opinions: impressive global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The crepes were thin, light, and delicious.
# main aspect: crepes extracted aspects: crepes extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The ribs were fall-off-the-bone tender.
# main aspect: ribs extracted aspects: tender, ribs extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The vegan dishes were innovative and tasty.
# main aspect: vegan dishes extracted aspects: vegan dishes, dishes extracted opinions: innovative global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The lamb was cooked to tender perfection.
# main aspect: lamb extracted aspects: perfection, lamb extracted opinions: perfection global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The ice cream was creamy and full of flavor.
# main aspect: ice cream extracted aspects: cream, ice cream, flavor, ice extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The dining experience was relaxing and enjoyable.
# main aspect: dining experience extracted aspects: experience, dining experience extracted opinions: relaxing, enjoyable global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The pastries were flaky, buttery, and delightful.
# main aspect: pastries extracted aspects: pastries extracted opinions: delightful global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The staff made us feel very welcome.
# main aspect: staff extracted aspects: staff extracted opinions: welcome global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The smoothies were fresh and perfectly blended.
# main aspect: smoothies extracted aspects: smoothies extracted opinions: fresh, perfectly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The appetizers were a great start to the meal.
# main aspect: appetizers extracted aspects: appetizers, meal extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The decor added a unique charm to the restaurant.
# main aspect: decor extracted aspects: charm, restaurant, decor extracted opinions: charm global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The pancakes were fluffy and delicious.
# main aspect: pancakes extracted aspects: pancakes extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The local ingredients made a noticeable difference.
# main aspect: local ingredients extracted aspects: local ingredients, difference extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The curry had a perfect balance of spices.
# main aspect: curry extracted aspects: spices, balance extracted opinions: perfect global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The atmosphere was lively and engaging.
# main aspect: atmosphere extracted aspects: atmosphere extracted opinions: engaging global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The kids' menu had great options.
# main aspect: menu extracted aspects: menu, kids, options extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The sandwiches were fresh and very filling.
# main aspect: sandwiches extracted aspects: sandwiches extracted opinions: fresh global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The salads were an explosion of flavors.
# main aspect: salads extracted aspects: explosion, salads, flavors extracted opinions: explosion global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The duck was cooked to a crispy finish.
# main aspect: duck extracted aspects: duck, finish extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The themed decor created a fun dining experience.
# main aspect: decor extracted aspects: experience, decor, dining, fun extracted opinions: fun global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The restaurant's cleanliness was top-notch.
# main aspect: restaurant extracted aspects: restaurant, cleanliness extracted opinions: topnotch global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The nachos were loaded and flavorful.
# main aspect: nachos extracted aspects: nachos extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The tapas were the perfect size for sharing.
# main aspect: tapas extracted aspects: tapas, size, sharing extracted opinions: perfect global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The grilled vegetables were seasoned beautifully.
# main aspect: grilled vegetables extracted aspects: vegetables, grilled vegetables extracted opinions: beautifully global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The risotto was creamy and perfectly cooked.
# main aspect: risotto extracted aspects: risotto extracted opinions: perfectly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The fresh juices were a refreshing treat.
# main aspect: juices extracted aspects: treat, juices extracted opinions: fresh, treat global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The vegan burger was surprisingly delicious.
# main aspect: vegan burger extracted aspects: vegan burger, vegan burger extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The omelets were fluffy and packed with ingredients.
# main aspect: omelets extracted aspects: ingredients, omelets extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The traditional dishes were authentic and tasty.
# main aspect: dishes extracted aspects: dishes extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The gluten-free options were plentiful and varied.
# main aspect: options extracted aspects: options extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The restaurant had a great energy and vibe.
# main aspect: restaurant extracted aspects: vibe, energy, restaurant extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The cheesecake was smooth and creamy.
# main aspect: cheesecake extracted aspects: cheesecake extracted opinions: smooth global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The hot chocolate was rich and decadent.
# main aspect: hot chocolate extracted aspects: hot chocolate, chocolate extracted opinions: rich global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The artisanal cheeses were a delightful treat.
# main aspect: cheeses extracted aspects: treat, cheeses, artisanal extracted opinions: delightful global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The fish tacos were light and flavorful.
# main aspect: fish tacos extracted aspects: fish tacos, fish tacos, flavorful extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The staff's attention to detail was impressive.
# main aspect: staff extracted aspects: attention, detail, staff extracted opinions: impressive global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The French fries were crispy and well-seasoned.
# main aspect: French fries extracted aspects: French fries, fries extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The cocktail list was innovative and exciting.
# main aspect: cocktail list extracted aspects: cocktail list, list, cocktail extracted opinions: exciting, innovative global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The breakfast burrito was hearty and satisfying.
# main aspect: breakfast burrito extracted aspects: burrito, breakfast burrito extracted opinions: satisfying global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The location of the restaurant was convenient and accessible.
# main aspect: location extracted aspects: restaurant, location extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The dim sum was authentic and delicious.
# main aspect: dim sum extracted aspects: dim sum, dim sum, dim extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The craft beer selection was excellent.
# main aspect: craft beer selection extracted aspects: craft beer selection, craft beer selection, beer, selection extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The fresh fruit platter was beautifully arranged.
# main aspect: fruit platter extracted aspects: fruit platter, platter extracted opinions: beautifully global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The restaurant's ambiance was romantic and serene.
# main aspect: restaurant extracted aspects: ambiance, restaurant extracted opinions: romantic global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The quiche was light and packed with flavor.
# main aspect: quiche extracted aspects: quiche, flavor extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The gourmet pizza options were unique and tasty.
# main aspect: gourmet pizza options extracted aspects: gourmet pizza options, pizza, options extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The seafood pasta was rich and flavorful.
# main aspect: seafood pasta extracted aspects: seafood pasta, pasta, seafood extracted opinions: rich global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The Korean BBQ was an interactive and fun experience.
# main aspect: Korean BBQ extracted aspects: Korean BBQ, experience, BBQ, fun extracted opinions: fun global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The organic salad was fresh and nutritious.
# main aspect: organic salad extracted aspects: organic salad, salad, organic extracted opinions: fresh global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The bistro setting was quaint and charming.
# main aspect: bistro setting extracted aspects: bistro setting, setting extracted opinions: charming global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The homemade soups were comforting and hearty.
# main aspect: homemade soups extracted aspects: homemade soups, soups, comforting extracted opinions: comforting, hearty global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The stir-fry was vibrant and packed with veggies.
# main aspect: stir-fry extracted aspects: veggies, stirfry extracted opinions: vibrant global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The outdoor patio had a great view and atmosphere.
# main aspect: outdoor patio extracted aspects: outdoor patio, view, atmosphere extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The tap water was refreshing and had a clean taste.
# main aspect: tap water extracted aspects: tap water, water, taste extracted opinions: clean global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The fine dining experience was unforgettable.
# main aspect: dining extracted aspects: experience, dining extracted opinions: unforgettable, fine global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The farm-to-table concept was evident in the freshness of the food.
# main aspect: food extracted aspects: freshness, food, farmtotable, concept extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The seasonal menu always has something new and exciting.
# main aspect: seasonal menu extracted aspects: seasonal menu, something, seasonal menu extracted opinions: exciting global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The Greek salad was authentic and refreshing.
# main aspect: Greek salad extracted aspects: Greek salad, salad extracted opinions: refreshing global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The sushi bar offered a wide variety of fresh options.
# main aspect: sushi bar extracted aspects: options, bar, sushi bar, variety extracted opinions: fresh global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The staff went above and beyond to ensure a great experience.
# main aspect: staff extracted aspects: experience, staff extracted opinions: great, ensure global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The paella was packed with seafood and flavor.
# main aspect: seafood extracted aspects: seafood, paella, flavor extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The gelato flavors were unique and delicious.
# main aspect: gelato flavors extracted aspects: gelato flavors, flavors extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The craft cocktails were a highlight of the evening.
# main aspect: craft cocktails extracted aspects: craft cocktails, highlight, evening, cocktails, craft cocktails extracted opinions: highlight global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The vegetable curry was hearty and satisfying.
# main aspect: vegetable curry extracted aspects: vegetable curry, curry extracted opinions: satisfying global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The French toast was sweet and perfectly cooked.
# main aspect: French toast extracted aspects: French toast, toast extracted opinions: sweet, perfectly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The farm-fresh eggs made a difference in taste.
# main aspect: eggs extracted aspects: difference, eggs, taste extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The BBQ chicken pizza was a perfect blend of flavors.
# main aspect: BBQ chicken pizza extracted aspects: BBQ chicken pizza, blend, flavors, BBQ chicken pizza, pizza extracted opinions: perfect global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The artisan breads were a great accompaniment to the meal.
# main aspect: artisan breads extracted aspects: accompaniment, breads, meal, artisan breads extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The ambiance made for a perfect date night.
# main aspect: ambiance extracted aspects: night, ambiance, date extracted opinions: perfect global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The Thai noodles were spicy and full of flavor.
# main aspect: Thai noodles extracted aspects: Thai noodles, Thai noodles, Thai noodles, flavor extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# text :  The gourmet sandwiches were a delightful lunch option.
# main aspect: sandwiches extracted aspects: sandwiches, lunch, option extracted opinions: delightful global polarity: positive
# --------------------------------------------------

# %%
outputs = []
sentences =[]
for index, row in test_df.iterrows():
    prediction = generate_single_prediction(model, tokenizer, row["text"], max_length=150)

    print("-"*50)
    print("Text:", row["text"])
    print("Prediction:", prediction)

    parsed_output = parse_model_output(prediction)
    outputs.append(parsed_output)
    sentences.append(row["text"])
    print("-"*50)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# --------------------------------------------------
# Text: the hotel is average, the business hall is fantastic - you need to update
# Prediction: main aspect: hotel extracted aspects: business, hall, hotel extracted opinions: fantastic global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the rooms weren't at the desired level, and we found a lot of bugs in the rooms, and the food level wasn't good either.
# Prediction: main aspect: rooms extracted aspects: level, lot, rooms, food, bugs extracted opinions: desired, good global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the only bad thing to try is to get to the hotel entrance by taxi, not by a navigator.
# Prediction: main aspect: hotel extracted aspects: entrance, navigator, thing, taxi, hotel extracted opinions: bad global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: check-in and check-out were good.
# Prediction: main aspect: facilities extracted aspects: facilities, checkin extracted opinions: good global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: more than beautiful hotel we went to the lilly land beach club hotel the restaurant is clean and the aqua park is pleasant and we enjoy relaxing in this hotel and this hotel qualifies five stars instead of four stars
# Prediction: main aspect: hotel extracted aspects: club, park, beach, restaurant, stars, aqua, hotel extracted opinions: clean, pleasant, enjoy, beautiful global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: a great hotel and worth a visit is a great hotel for recreation and spending a wonderful time with the family amid beautiful and lush golf courses with excellent service that befits hilton hotels.
# Prediction: main aspect: hotel extracted aspects: hilton, recreation, visit, service, family, golf, time, hotels, courses, hotel extracted opinions: wonderful, excellent, beautiful, worth, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: good hotel i stayed for 3 nights in this hotel at the end of november 2011. the staff was friendly and helpful.
# Prediction: main aspect: hotel extracted aspects: i, staff, nights, hotel, end extracted opinions: helpful, friendly, good global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the room is fine if you're going to spend the holidays at very simple parties.
# Prediction: main aspect: room extracted aspects: parties, holidays, room extracted opinions: parties, holidays, fine global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: drinks are available and well distributed. the overall atmosphere of the hotel is excellent. the swimming pool of the hotel is distinctive. i recommend to try the submarine.. and choose rooms with direct views to the sea
# Prediction: main aspect: hotel extracted aspects: drinks, pool, views, rooms, submarine, atmosphere, sea, hotel extracted opinions: recommend, excellent, well global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the room was a great level of cleanliness and the room was suitable for two people and breakfast was rather good, and the room was quiet and there was no inconvenience.
# Prediction: main aspect: room extracted aspects: breakfast, room, level, people, inconvenience, cleanliness extracted opinions: inconvenience, no, good, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: rooms are nice and clean the tv screen is large but there are no arabic channels the reception service is normal and the breakfast service is quite a selection
# Prediction: main aspect: television extracted aspects: tv, breakfast, reception, service, screen, rooms, television, selection extracted opinions: nice, clean, no global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the reception staff is very respectable and modest and this is not strange to the saudi people, we were pleased to stay with you and of course we will repeat it to you very much thanks for what you gave
# Prediction: main aspect: receptionists extracted aspects: saudi, reception, staff, course, receptionists, people, thanks extracted opinions: pleased, strange, thanks, respectable global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: reasonable enough for a non-peak season. first it was expensive because of the peak season, i think. room space is limited with an unfinished roof, the bathtub has a leak,
# Prediction: main aspect: room extracted aspects: room, season, leak, bathtub, roof, space, peak extracted opinions: leak, limited global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: to use a shower, if you desperately need to use a poor shower, beware of the electrical wires torn down the bathroom door.
# Prediction: main aspect: bathroom extracted aspects: door, shower, wires, bathroom, beware extracted opinions: poor, desperately global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: and the super-premium dementia service, the food and drink places, the nightclubs, the pool, the way the meals are served, frankly, everything there is super-premium, and it's a relief to try to stay at the hotel when you get the chance.
# Prediction: main aspect: pool extracted aspects: pool, superpremium, service, relief, dementia, drink, way, meals, everything, chance, places, food, nightclubs, hotel extracted opinions: chance, relief global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel is fine, but don’t trust the staff, they are not honest and are trying to prey on the traveler.
# Prediction: main aspect: hotel extracted aspects:, traveler, staff, t, hotel extracted opinions: honest, fine, trust global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: this is my favorite hotel in bangkok when i travel for work, not only because of the excellent accommodation, that the hotel suites have been recently renovated (with a washing machine), and good food but because every one of the staff is very cooperative and kind.
# Prediction: main aspect: hotel extracted aspects: work, i, staff, kind, accommodation, machine, food, suites, bangkok, hotel extracted opinions: favorite, excellent, kind, good global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel's clean room level is bad, the rooms smell bad, the air conditioning happened, and it's very bad.
# Prediction: main aspect: hotel extracted aspects: room, level, air, conditioning, rooms, hotel extracted opinions: clean, bad global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: i recommend going online, good in the lobby, but slow in the rooms, no bother in the rooms.
# Prediction: main aspect: rooms extracted aspects: online, rooms, bother, lobby extracted opinions: recommend, no, good, bother global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: and the food is varied, but the taste is medium and sweet, hale, the hotel is very beautiful and comfortable and wide and the sea was adding and la vista bar in the middle of the sea is very sweet, the honesty was a very pleasant trip
# Prediction: main aspect: food extracted aspects: trip, vista, food, middle, bar, sea, honesty, taste, hotel extracted opinions: honesty, comfortable, pleasant, beautiful, sweet global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: resort hotel club 6 hurghada i booked online but when i arrived in hurghada no one knew the hotel because the name was different from what was on the internet
# Prediction: main aspect: hotel extracted aspects: internet, hurghada, i, club, resort, name, one, hotel extracted opinions: no global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the room this time is very, very far away.. personal obligations have become less, and after cleaning the rooms do not provide them again, not even water bottles!!
# Prediction: main aspect: rooms extracted aspects: room, water, rooms, time, obligations, bottles extracted opinions: obligations global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: however, breakfast is very modest and there are not many options for the arab inmate.
# Prediction: main aspect: meals extracted aspects: options, breakfast, meals, inmate extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the room is clean but has very modest facilities.
# Prediction: main aspect: facilities extracted aspects: facilities, room extracted opinions: clean global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: i didn’t like the service and the location for the price.
# Prediction: main aspect: location extracted aspects:, i, service, location, price extracted opinions: like global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: business trip to riyadh hello.. the hotel is well located in the heart of the city. opposite the landmark kingdom tower. the staff are friendly. i spent 3 nights there and had a business meeting at the hotel itself.
# Prediction: main aspect: hotel extracted aspects: hello, staff, trip, nights, heart, meeting, city, tower, kingdom, business, hotel extracted opinions: friendly, landmark, well global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: i wonder who says that the hotel is not five stars or that the food is not good or varied. the hotel is great rooms are very close and the service is excellent. the sea is charming and very safe for children swimming pools for all ages.
# Prediction: main aspect: hotel extracted aspects: service, pools, rooms, ages, stars, food, children, sea, wonder, hotel extracted opinions: excellent, charming, safe, good, great global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the service was good, the food wasn't bad, the beverage service was really good, except for the plastic cups.
# Prediction: main aspect: service extracted aspects: cups, service, food, beverage extracted opinions: bad, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: all reception, restaurant and room service staff are excellent without exception.
# Prediction: main aspect: reception extracted aspects: room, reception, service, staff, restaurant, exception extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the disadvantage of the management of this hotel is that its management is unprofessional and wants to gain without giving any effort to the quality of service refined food and service is not good either buildings and swimming pools are good rocky beach and continental shelf i.e. very deep after the coral reefs rooms are very good in terms of space and furniture the main restaurant is large in size and overlooking the sea.
# Prediction: main aspect: service extracted aspects: restaurant, swimming, quality, hotel, food, reefs, disadvantage, effort, buildings, terms, pools, size, rooms, beach, space, furniture, sea, shelf, management extracted opinions: good, giving, unprofessional, disadvantage, gain global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: from the nearest hotels to the prophet's mosque i stayed in this hotel twice and the hotel was wonderful and beautiful near the prophet's mosque and easy access
# Prediction: main aspect: hotel extracted aspects: access, i, prophet, hotels, mosque, hotel extracted opinions: wonderful, beautiful, easy global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: i do not recommend anyone to go to this hotel (and in the end ask an experimenter and do not ask an expert).
# Prediction: main aspect: hotel extracted aspects: anyone, experimenter, expert, hotel extracted opinions: recommend global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: a beautiful place of value the jewel hotel is not located directly on the beach but a few meters to the side of the sea.
# Prediction: main aspect: hotel extracted aspects: meters, place, side, beach, jewel, sea, value, hotel extracted opinions: value, beautiful global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: we tried, but we failed. we were booked here, but we were told we had to go to the paphos gardens, which was as good but not as comfortable as the basilica. does anyone know what happened?
# Prediction: main aspect: facilities extracted aspects: anyone, paphos, facilities, basilica, gardens extracted opinions: failed, comfortable, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: we stayed here on january 13 after some bad experiences with other hotels. the hotel is clean and has good beds, good bathrooms, excellent restaurant and one of the best places in dahab, at almost the same price as other hotels in the region.
# Prediction: main aspect: hotel extracted aspects: region, dahab, restaurant, beds, bathrooms, places, experiences, hotel extracted opinions: clean, excellent, bad, good, best global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: as well as good treatment and reception, so i recommend all my colleagues to use and stay in these hotels where it is equivalent to the level of service five-star hotels
# Prediction: main aspect: treatment extracted aspects: reception, service, level, colleagues, treatment, hotels extracted opinions: recommend, good, well global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: villa rosa is a nice little hotel in the trastevere area. there are good cable connections to the city center. the hotel rooms were nice and tidy, but when taking a bath the bathroom became completely flooded. the room also did not have a refrigerator. overall the hotel was worth the stay. good staff, and everything. i recommend it.
# Prediction: main aspect: hotel extracted aspects: cable, connections, room, stay, staff, bath, refrigerator, area, rooms, villa, center, tidy, city, bathroom, everything, rosa, hotel extracted opinions: nice, recommend, worth, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: but the rooms are cramped and the staff is unfriendly and unsmiling and the service is very poor.
# Prediction: main aspect: service extracted aspects: service, rooms, staff extracted opinions: poor, unfriendly global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the beach is great and the swimming pool is great and all the staff have been telling you that you are the most important guest in al fang. especially the front office managers mr. ahmed abaza and mr. mahmoud salem and all the front office staff who were solving any problem in the shortest time.
# Prediction: main aspect: pool extracted aspects: al, manager, pool, problem, staff, fang, beach, salem, time, swimming, abaza, guest extracted opinions: problem, important, solving, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the swimming pool is in dire need of daily cleaning and if you were travelling with children i would complain if it was too hot and we couldn’t swim in such a dirty pool. air conditioning and mini fridge work well. we will come back again but call in advance and make sure the pool is cleaned.....
# Prediction: main aspect: pool extracted aspects:, need, pool, work, air, conditioning, mini, fridge, children, swimming, advance, cleaning, t extracted opinions: complain, sure, dire, well, dirty global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the room was large and included a sitting room with two sofas and an extra plasma tv. there are few uk channels.
# Prediction: main aspect: television extracted aspects: tv, room, channels, sofas, television, plasma extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: what a surprise! very frustrating from the moment of the entry procedure - we were on the executive floor which they said was renovated - new furniture and carpets but everything except that is bad, and we've been on the executive floor for a long time.
# Prediction: main aspect: furniture extracted aspects: carpets, floor, entry, procedure, moment, furniture, time, everything, surprise, executive extracted opinions: frustrating, bad, surprise global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: hotel near the markets there is no insulation in the rooms you hear everything without exception cleanliness reasonable inside the rooms furniture is normal best location and price, they provide several forms of children's beds tv is normal with all the channels air conditioning good rooms are spacious but i hope they care about cleanliness more
# Prediction: main aspect: rooms extracted aspects: tv, markets, air, forms, conditioning, rooms, channels, insulation, exception, furniture, beds, everything, children, cleanliness, location, price, hotel extracted opinions: care, no, good, best, hope global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: god wants me to return to this spot and i will not live except in this wonderful hotel your brother daham narrator
# Prediction: main aspect: hotel extracted aspects: spot, i, brother, god, daham, narrator, hotel extracted opinions: wonderful, god global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the staff is very nice and friendly and breakfast is great. they can help you and give you tips for snorkeling, dining, and sightseeing. ask for what you want, and they will help you.
# Prediction: main aspect: staff extracted aspects: breakfast, dining, staff, tips, sightseeing extracted opinions: nice, friendly, want, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: we will definitely stay here when we visit playa del carmen...the place is worth a visit! you can go to the nearby karns restaurant if you are looking for great food, good drinks and great music. a perfect place to watch people relax.
# Prediction: main aspect: food extracted aspects: drinks, music, place, visit, del, people, carmen, food, karns extracted opinions: good, perfect, definitely, relax, worth, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: good location and high price. this hotel is excellent, but it's more expensive than i expected and i didn't eat at this hotel.
# Prediction: main aspect: location extracted aspects: location, i, price, hotel extracted opinions: excellent, good global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the breakfast buffet is frequent and of little quality - there is no shower in the bathtub, only a faucet, and you have to go to the shower afterwards.
# Prediction: main aspect: buffet extracted aspects: breakfast, bathtub, buffet, faucet, afterwards, quality extracted opinions: no global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the price is normal and the food tastes good. the road to the beach took about 10 minutes.
# Prediction: main aspect: prices extracted aspects: prices, road, tastes, beach, food, minutes, price extracted opinions: good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel is not recommended at all unless the hotel is used only for overnight stays.
# Prediction: main aspect: hotel extracted aspects: stays, hotel extracted opinions: recommended global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: one of the best family hotels in dubai i believe that al ghurair rayhaan rotana hotel is one of the best options available to families going to dubai, where it is linked to al ghurair mall, which has all the services of restaurants, pharmacies, cafes and high-end shops, and the presence of recreational facilities such as swimming pool and spa makes housing an unforgettable experience.
# Prediction: main aspect: hotel extracted aspects: families, services, spa, presence, mall, rotana, hotel, families, restaurants, facilities, cafes, housing, pharmacies, options, experience, ghurair, rotana, hotel extracted opinions: best global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the location is good, about 15-20 minutes walk up to the city center - fairly clean but the overall weather is bad
# Prediction: main aspect: location extracted aspects: weather, center, city, minutes, location extracted opinions: clean, bad, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: a very good hotel i had a conference and stayed for 3 nights at this hotel! the food was great and the service was good! but the heating system was hot while the weather required cold air conditioning! we had to open the windows all night but couldn’t sleep because of the noise from outside! we asked the reception to do something but they couldn’t do anything!
# Prediction: main aspect: hotel extracted aspects: windows, anything,, anything, t, hotel, i, service, air, conditioning, weather, food, nights, reception, noise, system, conference extracted opinions: good, great global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the rooms weren't cleaned the entire time we stayed, but upon request, the cleaner and receptionists were available to assist.
# Prediction: main aspect: rooms extracted aspects: cleaner, receptionists, rooms, time, request extracted opinions: cleaner global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: and the barbecue restaurant is closed.
# Prediction: main aspect: restaurant extracted aspects: restaurant, barbecue extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: - the bar's a professional cocktail worker.
# Prediction: main aspect: bar extracted aspects: bar, cocktail, worker extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the quality of the hotel has fallen as the plane lands at the landing of jain in ramadan, two blocks in diameter and suhoor, and the hotel is overflowing until we leave the restaurant because of the pressure on it.
# Prediction: main aspect: hotel extracted aspects: diameter, pressure, plane, jain, suhoor, restaurant, blocks, landing, quality, ramadan, hotel extracted opinions: leave, pressure global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: my friend has a stomach ache after dinner at the hotel.
# Prediction: main aspect: hotel extracted aspects: friend, ache, dinner, stomach, hotel extracted opinions: friend global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: it's probably the worst hotel i've ever stayed in. stay away from it. it's not great, but it's a new low-key hotel. the rooms are dirty, the shower and the tub are the worst ever. the air conditioning works and the manager has given us a mosquito repellent. there are no bedspreads!!
# Prediction: main aspect: hotel extracted aspects: manager, shower, repellent, i, air, works, rooms, bedspreads, tub, hotel extracted opinions: dirty, no, great, worst global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: i have no comment except to thank every little one in this hotel as i found comfort and good reception and i felt like i was someone else inside your hotel from all sides.
# Prediction: main aspect: hotel extracted aspects: comfort, comment, reception, i, sides, someone, one, hotel extracted opinions: comfort, thank, like, no, good global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: there's no phone, there's no tv, there's no soap, there's no soap, there's no soap, there's no soap, there's no toilet, there's no toilet, there's no internet, there's no room.
# Prediction: main aspect: internet extracted aspects: tv, internet, phone, soap, room, toilet extracted opinions: no global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: a good hotel, but a good resort in terms of space and services, but it lacks a lot of joy, it becomes a very boring resort that does not have any kind of entertainment or entertainment at night becomes a semi-empty city of life, meals are not bad and not good with all this luxury lacks many things so my car is not allowed to enter the resort and leave it outside the resort and this is what excites the car
# Prediction: main aspect: hotel extracted aspects: entertainment, life, terms, services, kind, resort, night, lot, luxury, things, meals, joy, city, space, car, hotel extracted opinions: entertainment, kind, leave, boring, bad, good, joy, excites global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: nice rooms, although there are a bit old places - a comfortable bed, homemade shortbread cookies, a selection of tea....all good.
# Prediction: main aspect: rooms extracted aspects:, tea, bit, beds, rooms, shortbread, cookies, places, selection extracted opinions: nice, comfortable, good global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: we have stayed in many hotels in delhi, agra, jaipur and ahmedabad, and we love staying at this hotel where we stayed four times in the past year.
# Prediction: main aspect: hotel extracted aspects: year, agra, jaipur, delhi, hotels, times, hotel extracted opinions: love global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: notes on the cleanliness of the room the cleanliness of the room was not good. the bed was not properly set as it was used before we entered the room. there are stains on the chairs and the sofa. the smell of the cover on the bed is very bad and finally the cleanliness of the floors under the bed was not good. the rest of the hotel was very good.
# Prediction: main aspect: bedding extracted aspects: bed, room, cover, notes, sofa, rest, chairs, floors, stains, cleanliness, smell, hotel extracted opinions: bad, good global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: all reception, restaurant and room service staff are excellent without exception.
# Prediction: main aspect: reception extracted aspects: room, reception, service, staff, restaurant, exception extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: innumerable amounts of food and drink, great value to share with a family! i do not recommend going to the restaurant downstairs in the hotel because it is of poor value, small amounts and the food is not great. the breakfast menu in the restaurant seemed very expensive
# Prediction: main aspect: food extracted aspects: breakfast, i, menu, family, drink, restaurant, hotel, share, food, poor, amounts, value, downstairs extracted opinions: recommend, poor, share, value, great global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: food options are very limited. there's no food variety.
# Prediction: main aspect: food extracted aspects: options, food, variety extracted opinions: no, limited global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: nothing is more wonderful than the bliss of heights, everything is so wonderful and so organized, and every worker or official is smiling and so cooperative, service and food is such a wonderful thing.
# Prediction: main aspect: service extracted aspects: heights, service, food, thing, everything, worker, official, bliss, nothing extracted opinions: wonderful, smiling, bliss global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: especially mr. ahmed al-hassawi, the reception manager, where he did the self-rehabilitation and then i was called to check on the hotel.
# Prediction: main aspect: reception extracted aspects: manager, reception, selfrehabilitation, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: too bad i do not recommend anyone to spend a pleasant vacation in it... mini hot water bar and the number of 2 soft drinks only per room all the time.. cleanliness is not perfect at all where there are insects in the room and furniture is very old and worn out. it is worth only 3 stars :)
# Prediction: main aspect: amenities extracted aspects: number, drinks,, anyone, room, water, stars, furniture, amenities, vacation, bar, time, insects, cleanliness extracted opinions: number, recommend, pleasant, bad, worn, perfect, worth global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: but the biggest problem is the very average food in any of the restaurants. a typical block, the hotel meals have no panache.
# Prediction: main aspect: food extracted aspects: problem, restaurants, food, block, meals, panache, hotel extracted opinions: problem, block, no global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: all rooms need to be completed and re-decorated and new beds. but breakfast at the next bar was excellent and first-class service.
# Prediction: main aspect: meals extracted aspects: breakfast, service, rooms, meals, beds, bar extracted opinions: excellent global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: a very good hotel i had a conference and stayed for 3 nights at this hotel! the food was great and the service was good! but the heating system was hot while the weather required cold air conditioning! we had to open the windows all night but couldn’t sleep because of the noise from outside! we asked the reception to do something but they couldn’t do anything!
# Prediction: main aspect: hotel extracted aspects: windows, anything,, anything, t, hotel, i, service, air, conditioning, weather, food, nights, reception, noise, system, conference extracted opinions: good, great global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: good service excellent cleanliness very good food level nice quiet hotel to enjoy and recuperate actually it's definitely next and after and every time i bring down the sokhna hkon in cancn i'm sure
# Prediction: main aspect: service extracted aspects: hkon, i, service, level, food, time, cancn, sokhna, cleanliness, hotel extracted opinions: excellent, enjoy, good, sure, nice, definitely global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: crowne plaza hotel dubai is suitable for a short business trip. it is a bit old but its services are good for the money and the choice of food in the hotel is great.
# Prediction: main aspect: service extracted aspects: bit, services, money, service, trip, food, business, choice, dubai, hotel extracted opinions: good, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: even the dishes and the rooms are too bad, and everything doesn't work, so the cabinet is too weak.
# Prediction: main aspect: rooms extracted aspects: everything, rooms, dishes, cabinet extracted opinions: weak, bad global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: air conditioning hasn't worked for a month (maybe they turned off the air conditioning and now they tell us that it doesn't work -37 degrees in paris now) since the air conditioner isn't working we had to open the window!
# Prediction: main aspect: conditioning extracted aspects: window, month, air, conditioning, degrees, conditioner extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the food was great, with plenty of room service options.
# Prediction: main aspect: food extracted aspects: room, service, options, food, plenty extracted opinions: great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: cost minimization is best for good rooms, beautiful finishing. room service is good. it does not have its own tandoor oven. cost minimization is at its peak. there is no soap in the toilets. there is no shampoo. the shampoo dispenser has some annoying foam while the liquid is out. electrical socket problems - a problem in the bathroom and a problem in the room, that's all. and the gates of some rooms did not fit properly.
# Prediction: main aspect: amenities extracted aspects: socket, socket, gates, problem, room, minimization, service, toilets, foam, dispenser, toilets, amenities, foam, finishing, rooms, tandoor, cost, dispenser, problems, soap, peak extracted opinions: annoying, problems, problem, no, good, fit, best, beautiful global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel accommodation is comfortable level of service and cleanliness and dealing with the responsible gentlemen is more than wonderful but for further development and continuous improvement please take into account the problem you mentioned in the evaluation items,
# Prediction: main aspect: hotel extracted aspects: account, service, level, gentlemen, accommodation, problem, development, improvement, items, cleanliness, hotel extracted opinions: wonderful, comfortable, responsible, problem, improvement, please global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the service is good, but i stayed here during a business trip in the area. all i can do is repeat the previous remarks, the hotel building is old and the rooms are old, as well as the decoration and facilities.
# Prediction: main aspect: service extracted aspects: decoration, i, service, trip, area, rooms, building, facilities, remarks, business, hotel extracted opinions: good, well global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the positive attitude and friendliness of the staff always makes the stay great. not all staff members speak english well, but they try their best to be helpful. this attitude of trying as hard as possible makes up for a lot of english speaking deficits.
# Prediction: main aspect: staff extracted aspects: deficits, members, staff, lot, speaking, attitude, friendliness extracted opinions: hard, helpful, friendliness, positive, well, best, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: a good hotel for business trips, with modern facilities. it can also be a great tourist base, as it is close to tourist attractions and tower hill subway station.
# Prediction: main aspect: hotel extracted aspects: subway, attractions, station, trips, facilities, business, base, tourist extracted opinions: attractions, good, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: i do not recommend this hotel to any traveler, the rooms are very bad, the service is terrible, the cleanliness is very bad,
# Prediction: main aspect: rooms extracted aspects: traveler, i, service, rooms, cleanliness, hotel extracted opinions: recommend, bad, terrible global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the last time was a mistake in fact i visited the hotel in the period from 19-7 until 23-7-2013 i was shocked by eating generally taste very bad and almost no types of salads and sweets dry or acid either the service is bad and the mattress of the bed is bad my back very sperm and shower is broken and the bathroom has a smell of sweet i was in room 203 frankly was supposed to be 3 stars haram in which the only need of sweet sea and god
# Prediction: main aspect: bathroom extracted aspects: shower, period, stars, fact, frankly, room, i, service, back, mistake, god, salads, mattress, bathroom, smell, sweets, sea, time, types, smell, hotel extracted opinions: mistake, broken, god, no, bad, sweets, sweet, shocked global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: old and unclean. the building is old, and so is the furniture.
# Prediction: main aspect: furniture extracted aspects: furniture, building extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: for short business trips, which do not require special procedures, this hotel is fine, but no more!
# Prediction: main aspect: hotel extracted aspects: procedures, trips, business, hotel extracted opinions: special, no, fine global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: i had high hopes for this hotel. its location is convenient, the rooms are good, the restaurant is also acceptable. generally, it gives you the impression that it is not a hotel with anything wrong but at the same time you do not remember anything after a while. the staff were helpful, and they arranged for the sound and light display at the pyramids and it was smooth. and although there was nothing wrong, i would not choose this hotel again.
# Prediction: main aspect: hotel extracted aspects: while, anything, hopes, i, staff, impression, rooms, restaurant, display, sound, time, pyramids, location, hotel extracted opinions: hopes, impression, helpful, good, wrong, acceptable global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: also, my cell phone was stolen from room service workers, and unfortunately, even the manager couldn't do anything.
# Prediction: main aspect: hotelservices extracted aspects: manager, anything, phone, room, service, cell, workers, hotelservices extracted opinions: stolen, unfortunately global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: bad service, bad smell. i went with my son to fenway. the room smelled like sewers, people in reception seemed to get upset about answering questions, accidentally left some clothes in the room, called and was put on hold forever twice and emailed them, unresponsive, not cheap to a low-level motel, avoiding it.
# Prediction: main aspect: room extracted aspects: questions, forever, room, son, reception, service, sewers, people, clothes, hold, motel, smell extracted opinions: like, avoiding, bad, upset, accidentally global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: an ordinary hotel with a location close to the city.
# Prediction: main aspect: hotel extracted aspects: city, location, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: very good hotel suitable for non-smoking, and the size of the rooms is small grill, but its price for the rest of the hotels is suitable, and has no facade on the public street,
# Prediction: main aspect: rooms extracted aspects: size, rooms, street, facade, rest, hotels, grill, price extracted opinions: no, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: breakfast's fine, and if they can be any better,
# Prediction: main aspect: meals extracted aspects: breakfast, fine, meals extracted opinions: better, fine global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: there are clubs, drinks and entertainment rooms on the second and ninth floors.
# Prediction: main aspect: rooms extracted aspects: drinks, entertainment, rooms, clubs, floors extracted opinions: entertainment global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the best holiday you can have with your money. we spent our honeymoon in this wonderful resort. it was not the first time we visited taba and we felt as if we were at home. all the staff were very welcoming, friendly and cooperative from reception until evening. we stayed in room 1208 where we enjoyed the magnificent view of the mountains with the sea. we spent 12 days as minutes. we recommend this hotel to anyone looking for a holiday like no other.
# Prediction: main aspect: staff extracted aspects: holiday, days, room, reception, money, anyone, honeymoon, resort, view, mountains, minutes, hotel, time, taba, sea, home extracted opinions: holiday, recommend, like, no, friendly, magnificent, welcoming, best, enjoyed, wonderful global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: this hotel has to be closed. this hotel has to be a disaster. the rooms are dirty and the place is full of cockroaches. in my room, the bathroom ejection box is not working and the toilet is so dirty. i can't have breakfast in this place where the kitchen is so dirty.
# Prediction: main aspect: hotel extracted aspects: breakfast, disaster, room, i, place, box, toilet, rooms, kitchen, cockroaches, bathroom, ejection, hotel extracted opinions: disaster, dirty global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel is a little small, but the design is great, the rooms are good and comfortable, and the upper pool on the sixth floor is also small.
# Prediction: main aspect: rooms extracted aspects: design, pool, floor, rooms, hotel extracted opinions: comfortable, good, great global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the location is wonderful and the views are very beautiful, but unfortunately the service is very bad.
# Prediction: main aspect: location extracted aspects: views, service, location extracted opinions: wonderful, beautiful, bad, unfortunately global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: cleanliness is the worst.
# Prediction: main aspect: cleanliness extracted aspects: cleanliness extracted opinions: worst global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: and the rooms were clean and magnificent and overlooking the prophet's mosque and we had no problems with this hotel during the stay and the service is very reasonable.
# Prediction: main aspect: rooms extracted aspects: problems, stay, prophet, service, rooms, mosque, hotel extracted opinions: magnificent, clean, problems, no global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: there are no facilities to talk about, no swimming pool, a gym with one bike, and one treadmill. i do not recommend this hotel, if you want to have a comfortable stay in dammam.
# Prediction: main aspect: fitness extracted aspects: pool, stay, gym, fitness, bike, facilities, dammam, treadmill, hotel extracted opinions: recommend, comfortable, no, want global polarity: negative
# ...
# --------------------------------------------------
# Text: hotel 7 star :)))) habeeto ktiyeyer hotel is more than wonderful :))) and the room service is excellent and the rooms are very very luxurious and the view is very beautiful from all sides and the atmosphere is beautiful and really enjoyed very calm and beauty and clean and service and really they were the most beautiful 3 days vacation and we enjoyed the parties in the evening and the overall view in the evening was a masterpiece and more than wonderful food:)
# Prediction: main aspect: service extracted aspects: days, parties, room, service, beauty, view, sides, masterpiece, rooms, star, food, vacation, atmosphere, evening, habeeto, hotel extracted opinions: excellent, clean, parties, masterpiece, beauty, enjoyed, wonderful, beautiful, calm global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: there is also a designated place for regular and special taxi...
# Prediction: main aspect: transportation extracted aspects: taxi, place extracted opinions: special global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel's accommodation is beautiful and breakfast is over a rooftop terrace and their breakfast is sweet and varied and close to tourist places sultanahmet mosque and hagia sophia 3 minutes walk a lot and grand bazaar 5 minutes walk the hotel is sweet and affordable, but i recommend that the libyan resident to take a limousine from the airport to the hotel door because the location of mo is clear to tikasi drivers.
# Prediction: main aspect: meals extracted aspects: door, breakfast, airport, drivers, accommodation, lot, meals, terrace, bazaar, places, resident, limousine, mosque, minutes, location, mo, hotel extracted opinions: grand, clear, recommend, beautiful, sweet global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: and the receptionists get extra money on the grounds that it's for the hotel to get rooms overlooking the campus, even though i paid for it.
# Prediction: main aspect: receptionists extracted aspects: money, grounds, receptionists, campus, rooms, hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: small room, shared bathroom on the stairs (the door wasn't locked).
# Prediction: main aspect: bathroom extracted aspects: door, stairs, room, bathroom extracted opinions: shared global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: moataz stayed at the hotel from 1636 until 1633 until 1632, and i'm still here.
# Prediction: main aspect: hotel extracted aspects: moataz, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: coral fursan resort - the best place to stay when you're on fursan island i assume it's the best place to stay with both options available, whether a room or a chalet.
# Prediction: main aspect: facilities extracted aspects: island, room, place, resort, options, chalet, facilities, fursan extracted opinions: best global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: beautiful hotel but the hotel is wonderful and all the need is sweet in the hotel company called golden d company is not good, rhett people are dealing with her because if you booked with her a number 2 flight 1 boat trip was worn out and the price was very expensive 2 dolphin offer was 100 per person and the price per person in the same offer 35 knowing that it is close to the hotel management talked to the company and said that they will be liquidated dealing with rhet
# Prediction: main aspect: hotel extracted aspects: number, flight, person, need, company, trip, rhet, people, offer, boat, management, dolphin, price, hotel extracted opinions: number, worn, good, wonderful, beautiful, sweet global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: frankly i mean i do not regret my stay in the hotel and god willing next year and answer the mother with me and by the way i want to thank miss names for her temperament and humility and thank you all
# Prediction: main aspect: hotel extracted aspects: year, name, i, stay, humility, god, mother, way, temperament, name, hotel extracted opinions: thank, miss, god, regret, humility, want, miss global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: breakfast is good and well-positioned, we had some high-heating notes, and some customers don't take care of public taste, and the hotel doesn't deter such acts.
# Prediction: main aspect: meals extracted aspects: breakfast, care, acts, meals, notes, customers, taste, hotel extracted opinions: care, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: great place, just a 10-minute walk from prince street. the bus station is very close if you don't want the hassle of walking. i won't hesitate to come back.
# Prediction: main aspect: transportation extracted aspects: place, bus, transportation, street, i, station, walk, hassle, prince extracted opinions: hesitate, want, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: an unsafe place i spent seven days on a family vacation here and although the rooms were good, the rooms were dirty, the glass could barely see through it, and the worst of it was that we lost an expensive camera and some other things, and the administration didn’t pay much attention and the police failed to find out who did it even though it was clear that the only people able to get in were the room servicers.
# Prediction: main aspect: rooms extracted aspects:, days, room, place, administration, servicers, family, things, rooms, attention, people, vacation, camera, glass, police extracted opinions: clear, failed, good, worst, lost, dirty, pay global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: they made a good breakfast, but there was a dance club, which was creating a stir and a nuisance even though i stayed on the fourth floor and also the hotel a little bit away from the metro station, 10-15 minutes of walking, it's not very comfortable to walk in hot weather.
# Prediction: main aspect: meals extracted aspects: breakfast, floor, bit, club, weather, meals, nuisance, station, minutes, stir, metro, dance, hotel extracted opinions: creating, comfortable, good global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: the prices are high but the privacy we got worth that massage experience sweet privacy is what distinguishes them and the collar is very beautiful, but snorkeling is something very fun thanks barros
# Prediction: main aspect: prices extracted aspects: prices, something, massage, barros, collar, experience, privacy extracted opinions: beautiful, thanks, sweet, fun, worth global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: defect of the hotel during certain seasons, as well as the entry of the cleaning crew to clean the room despite the sign not to disturb
# Prediction: main aspect: hotel extracted aspects: entry, room, sign, crew, seasons, defect, cleaning, hotel extracted opinions: clean, defect, certain, well global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: and i hope to keep a price that attracts a lot of tourists to the hotel.
# Prediction: main aspect: hotel extracted aspects: tourist, lot, price, hotel extracted opinions: hope global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the distance between the hotel and the taj is a short walk to the tuk tuk. i couldn’t actually see a crown from the roof because of the fog, but you should! it doesn’t look very good from the outside – just a regular modern hotel, but it was a pleasant surprise on entry.
# Prediction: main aspect: hotel extracted aspects: distance,, taj, entry, crown, walk, fog, roof, surprise, t, hotel extracted opinions: pleasant, good, surprise global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: enter the restaurant and show a mandhmsh limit that touches the empty dishes etni limit as far as i pass and i'm a child ask for a comment no, before leaving at 12:30, order a cup of cappuccino reply to the gentleman in the bar in front of the restaurant no, you're not sure i'd say that taste of you and say that even a minute is not a gift people very taste in his tongue a human almost tasteless was made of weak blood
# Prediction: main aspect: restaurant extracted aspects: order, tongue, comment, bottle, i, drink, person, mouth, hand, drink, reply, mandhmsh, drink, mouth, hand, mouth, hand, people, cup, drink, limit, hand, dishes, minute, ask, bar, gift extracted opinions: gift, no, weak, sure, empty global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: drinks arrive at the door of the room if you want to trouble the rooms that the family is small
# Prediction: main aspect: rooms extracted aspects: drinks, door, room, family, rooms, trouble extracted opinions: trouble, want global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel is nice and clean and family first class and the hotel is close to the market, but the hotel staff are all treated very high respect for the guest
# Prediction: main aspect: hotel extracted aspects: respect, staff, family, market, guest, class, hotel extracted opinions: nice, clean, respect global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: a very reasonable hotel for hotel apartments is a very reasonable place close to the metro, airport and shopping center city centre deira, but it is possible to classify 1635; four stars mesh breakfast to some extent is not luxurious but
# Prediction: main aspect: hotel extracted aspects: breakfast, airport, place, centre, stars, extent, city, apartments, metro, shopping, deira, hotel extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: all the staff we've dealt with during our stay have been pretty friendly and welcoming, receptionists, waiters, cooks, housekeepers plus life guards.
# Prediction: main aspect: staff extracted aspects: life, receptionists, stay, staff, cooks, guards, housekeepers, waiters extracted opinions: pretty, welcoming, friendly global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel is great in terms of location, the beach is excellent, the sea is very beautiful, the beach is above excellent and the team is very cooperative.
# Prediction: main aspect: beach extracted aspects: excellent, terms, beach, team, sea, location, hotel extracted opinions: excellent, beautiful, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: the hotel is a little small, but the design is great, the rooms are good and comfortable, and the upper pool on the sixth floor is also small.
# Prediction: main aspect: rooms extracted aspects: design, pool, floor, rooms, hotel extracted opinions: comfortable, good, great global polarity: neutral
# --------------------------------------------------
# --------------------------------------------------
# Text: i can't imagine a five-star hotel with such a horrible level of cleanliness.
# Prediction: main aspect: hotel extracted aspects: level, i, cleanliness, hotel extracted opinions: horrible global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: there's no cleanliness in the rooms, and the faucet in the bathroom doesn't work.
# Prediction: main aspect: bathroom extracted aspects: faucet, rooms, bathroom, cleanliness extracted opinions: no global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the resort is very clean and the service is above excellent and the reception has been a lot of attention.
# Prediction: main aspect: service extracted aspects: reception, service, resort, lot, attention extracted opinions: clean, excellent global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: beautiful hotel and great location i stayed in this hotel for five days was beautiful and wonderful and everything you need is within the hotel area of services, barber and cafs. the hotel is very clean and the staff is good and the kitchen is equipped with most of the needs of the guest.
# Prediction: main aspect: hotel extracted aspects: days, services, i, cafs, staff, area, barber, kitchen, needs, everything, guest, location, hotel extracted opinions: clean, good, wonderful, beautiful, great global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: and the food is awful sometimes.
# Prediction: main aspect: food extracted aspects: food extracted opinions: awful global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: the fungus comes out of the vent. the slurry in the bathroom is also covered with mold, it looked like a white tile with a cloudy black-and-brown slurry. we stayed 3 days and a wet towel remained on the shower rack the whole time will not spend 200 euros on a room like this again
# Prediction: main aspect: bathroom extracted aspects: shower, days, room, vent, tile, towel, time, euros, fungus, bathroom, slurry, cloudy, mold extracted opinions: like global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: and the shower filter couldn't have closed properly.
# Prediction: main aspect: amenities extracted aspects: amenities, shower, filter extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# --------------------------------------------------
# Text: other than that i was already satisfied with the services in general as well as the prices compared to other old resorts nearby.
# Prediction: main aspect: prices extracted aspects: prices, services, i, resorts extracted opinions: satisfied, well global polarity: positive
# --------------------------------------------------
# --------------------------------------------------
# Text: and the bathrooms are fine for breakfast, nice, nice dinner, and the people at palmyra are very respectable and very helpful.
# Prediction: main aspect: meals extracted aspects: breakfast, people, meals, bathrooms, palmyra, dinner extracted opinions: nice, helpful, fine, respectable global polarity: neutral
# --------------------------------------------------

# %%
print(len(outputs))
print(len(sentences))
# Out:
# 2885
# 2885

# %% [markdown]
# # Mise en forme de l'output final

# %%
# a partir des generations de t5 affiner les resultats avec NLTK
def find_closest_opinion(segment, aspect, opinions):
    words = nltk.word_tokenize(segment)
    aspect_index = words.index(aspect) if aspect in words else -1
    closest_opinion = None
    min_distance = float('inf')
    for opinion in opinions:
        if opinion in words:
            opinion_index = words.index(opinion)
            distance = abs(opinion_index - aspect_index)
            if distance < min_distance:
                min_distance = distance
                closest_opinion = opinion
    return closest_opinion

def analyze_sentiment(segment):
    if not segment:
        return "neutral"
    sentiment = TextBlob(segment).sentiment
    return "positive" if sentiment.polarity > 0 else "negative" if sentiment.polarity < 0 else "neutral"
data =[]
for text, output in zip(sentences, outputs):
    text_sans_virgules = text.replace(',', '.')
    phrases = sent_tokenize(text_sans_virgules)
    aspect_opinion_sentiments = []
    for phrase in phrases:
        for aspect in output["extracted_aspects"]:
            if aspect in phrase:
                closest_opinion = find_closest_opinion(phrase, aspect, output["extracted_opinions"])
                if closest_opinion:
                    sentiment = analyze_sentiment(phrase)
                    if aspect!=closest_opinion :
                      aspect_opinion_sentiments.append((aspect, closest_opinion, sentiment))

    print(text_sans_virgules)
    print("-"*50)
    print("Main Aspect:", output["main_aspect"])
    print("Extracted Aspects:", output["extracted_aspects"])
    print("Extracted Opinions:", output["extracted_opinions"])
    print("Global Polarity:", output["global_polarity"])
    print("-"*50)
    print("Aspect-Opinion Sentiments:")
    sorted_aspect_opinion_sentiments = sorted(aspect_opinion_sentiments, key=lambda x: x[0])
    for tup in sorted_aspect_opinion_sentiments :
      print(tup)
    print("*"*50)
    data_dict = {
    "text": text_sans_virgules,
    "main_aspect": output["main_aspect"],
    "extracted_aspects": output["extracted_aspects"],
    "extracted_opinions":output["extracted_opinions"],
    "global_polarity": output["global_polarity"],
    "aspect_opinion_sentiments": sorted_aspect_opinion_sentiments
      }
    data.append(data_dict)
    # break
with open('/content/drive/MyDrive/Master 2/output.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)

# %%
outputs = []
sentences =[]
for index, row in test_df.iterrows():
    prediction = generate_single_prediction(model, tokenizer, row["text"], max_length=150)

    print("-"*50)
    print("Text:", row["text"])
    print("Prediction:", prediction)

    parsed_output = parse_model_output(prediction)
    outputs.append(parsed_output)
    sentences.append(row["text"])
    print("-"*50)

# %%
outputs = []
sentences = []

for index, row in test_df.iterrows():

    text_sans_virgules = row["text"].replace(',', '.')
    phrases = sent_tokenize(text_sans_virgules)
    predictions_par_phrase = []
    text_sans_virgules
    print("*"*50)
    print("text :", text_sans_virgules)
    for phrase in phrases:
        prediction = generate_single_prediction(model, tokenizer, phrase, max_length=150)
        parsed_output = parse_model_output(prediction)
        predictions_par_phrase.append(parsed_output)

        print("Phrase:", phrase)
        print("Prediction:", prediction)
        print("-"*50)

    outputs.append(predictions_par_phrase)
    sentences.append(row["text"])
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Prediction: main aspect: views extracted aspects: views, view, kaaba extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: the hotel's entrance is good from the back and not directly on the haram.
# Prediction: main aspect: hotel extracted aspects: back, entrance, haram, hotel extracted opinions: good global polarity: positive
# --------------------------------------------------
# **************************************************
# text : i stayed at this hotel for three nights in september.
# Phrase: i stayed at this hotel for three nights in september.
# Prediction: main aspect: hotel extracted aspects: september, nights, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : i checked out of the hotel half an hour after my arrival and got my money back. i don't recommend this hotel to anyone. please stay away from it.
# Phrase: i checked out of the hotel half an hour after my arrival and got my money back.
# Prediction: main aspect: hotel extracted aspects: money, i, arrival, hour, hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: i don't recommend this hotel to anyone.
# Prediction: main aspect: hotel extracted aspects: anyone, i, hotel extracted opinions: recommend global polarity: negative
# --------------------------------------------------
# Phrase: please stay away from it.
# Prediction: main aspect: facilities extracted aspects: facilities, please extracted opinions: please global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the breakfast wasn't very good. the shower didn't work very well. the staff was moody.
# Phrase: the breakfast wasn't very good.
# Prediction: main aspect: meals extracted aspects: breakfast, meals extracted opinions: good global polarity: negative
# --------------------------------------------------
# Phrase: the shower didn't work very well.
# Prediction: main aspect: bathroom extracted aspects: shower, bathroom extracted opinions: well global polarity: negative
# --------------------------------------------------
# Phrase: the staff was moody.
# Prediction: main aspect: staff extracted aspects: staff extracted opinions: moody global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the rooms are beautiful. the bathroom is elegant and the price is tempting.
# Phrase: the rooms are beautiful.
# Prediction: main aspect: rooms extracted aspects: rooms extracted opinions: beautiful global polarity: positive
# --------------------------------------------------
# Phrase: the bathroom is elegant and the price is tempting.
# Prediction: main aspect: bathroom extracted aspects: bathroom, price extracted opinions: elegant, tempting global polarity: positive
# --------------------------------------------------
# **************************************************
# text : and simple bathroom facilities. too. the toilet wasn't dropping water (to clean) and the bathroom was very rotten.
# Phrase: and simple bathroom facilities.
# Prediction: main aspect: bathroom extracted aspects: facilities, bathroom extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: too.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: the toilet wasn't dropping water (to clean) and the bathroom was very rotten.
# Prediction: main aspect: bathroom extracted aspects: toilet, water, bathroom extracted opinions: clean, rotten global polarity: negative
# --------------------------------------------------
# **************************************************
# text : and its accessories are never good. you find the lights are not all working. the towels and towels are very old and some are cut and the smell is not good...
# Phrase: and its accessories are never good.
# Prediction: main aspect: accessories extracted aspects: accessories extracted opinions: good global polarity: negative
# --------------------------------------------------
# Phrase: you find the lights are not all working.
# Prediction: main aspect: lights extracted aspects: lights extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: the towels and towels are very old and some are cut and the smell is not good...
# Prediction: main aspect: amenities extracted aspects: amenities, towels, smell extracted opinions: cut, good global polarity: negative
# --------------------------------------------------
# **************************************************
# text : it's okay. you can stay in it. the air conditioning wasn't working all over the hotel. when we stayed on july 2-5. 2007. the room was a small triplet and we were busy in it. but we managed. we got a front-facing room on the third floor. there's some construction work. but it doesn't start early. convenient location close to landmarks. food and metro. great prices! i'll be staying there again on the 22nd!
# Phrase: it's okay.
# Prediction: main aspect: nan extracted aspects: extracted opinions: okay global polarity: neutral
# --------------------------------------------------
# Phrase: you can stay in it.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: the air conditioning wasn't working all over the hotel.
# Prediction: main aspect: conditioning extracted aspects: air, conditioning, hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: when we stayed on july 2-5.
# Prediction: main aspect: facilities extracted aspects: facilities, july extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: 2007. the room was a small triplet and we were busy in it.
# Prediction: main aspect: room extracted aspects: triplet, room extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: but we managed.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: we got a front-facing room on the third floor.
# Prediction: main aspect: room extracted aspects: floor, room extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: there's some construction work.
# Prediction: main aspect: construction work extracted aspects: construction work, work extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: but it doesn't start early.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: convenient location close to landmarks.
# Prediction: main aspect: location extracted aspects: landmarks, location extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: food and metro.
# Prediction: main aspect: food extracted aspects: food, metro extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: great prices!
# Prediction: main aspect: prices extracted aspects: prices extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: i'll be staying there again on the 22nd!
# Prediction: main aspect: facilities extracted aspects: facilities, i extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : if the blash family. the place. if the guys keep the right place. the place is too high. if you and your friends see a place where you sleep nights and nights and spend the trip. they'll keep the hotel.
# Phrase: if the blash family.
# Prediction: main aspect: nan extracted aspects: family, blash extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: the place.
# Prediction: main aspect: place extracted aspects: place extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: if the guys keep the right place.
# Prediction: main aspect: place extracted aspects: place, guys extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: the place is too high.
# Prediction: main aspect: place extracted aspects: place extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: if you and your friends see a place where you sleep nights and nights and spend the trip.
# Prediction: main aspect: place extracted aspects: trip, nights, place, friends extracted opinions: friends global polarity: positive
# --------------------------------------------------
# Phrase: they'll keep the hotel.
# Prediction: main aspect: hotel extracted aspects: hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the hotel is very bad i was shocked at the hotel when i visited kuwait with my family and the stay was for two nights the level of cleanliness is almost non-existent mattresses with stains of dirt blood everywhere. the most important thing they have is to reduce expenses and increase income as the location is somewhat good. but the rest is very bad and cleanliness is the most important thing in hotels i will definitely never return to this hotel and increase you after the electricity right avaish ruined with oven and bathroom heaters.
# Phrase: the hotel is very bad i was shocked at the hotel when i visited kuwait with my family and the stay was for two nights the level of cleanliness is almost non-existent mattresses with stains of dirt blood everywhere.
# Prediction: main aspect: hotel extracted aspects: stains, blood, kuwait, stay, family, level, nights, mattresses, dirt, cleanliness, hotel extracted opinions: shocked, dirt, bad global polarity: negative
# --------------------------------------------------
# Phrase: the most important thing they have is to reduce expenses and increase income as the location is somewhat good.
# Prediction: main aspect: location extracted aspects: location, income, thing extracted opinions: increase, important, good global polarity: positive
# --------------------------------------------------
# Phrase: but the rest is very bad and cleanliness is the most important thing in hotels i will definitely never return to this hotel and increase you after the electricity right avaish ruined with oven and bathroom heaters.
# Prediction: main aspect: cleanliness extracted aspects: heaters, i, rest, electricity, bathroom, hotels, thing, cleanliness, oven, hotel extracted opinions: ruined, increase, bad, definitely global polarity: negative
# --------------------------------------------------
# **************************************************
# text : free parking is available as well as the internet.
# Phrase: free parking is available as well as the internet.
# Prediction: main aspect: parking extracted aspects: internet, parking extracted opinions: free, well global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the staff wasn't sure and cared.
# Phrase: the staff wasn't sure and cared.
# Prediction: main aspect: staff extracted aspects: staff extracted opinions: sure, cared global polarity: negative
# --------------------------------------------------
# **************************************************
# text : and the food is bad. the rooms are dirty. and the internet is bad. and i paid 20 dinars for the internet. and i'm not going to use it in the first place.
# Phrase: and the food is bad.
# Prediction: main aspect: food extracted aspects: food extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: the rooms are dirty.
# Prediction: main aspect: rooms extracted aspects: rooms extracted opinions: dirty global polarity: negative
# --------------------------------------------------
# Phrase: and the internet is bad.
# Prediction: main aspect: internet extracted aspects: internet extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: and i paid 20 dinars for the internet.
# Prediction: main aspect: internet extracted aspects: internet, dinars extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and i'm not going to use it in the first place.
# Prediction: main aspect: facilities extracted aspects: facilities, place extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : they greeted us with a delicious hibiscus drink and the staff was very friendly. our room was good size and the air conditioning was working great (and this was important as we were in august). we were just steps away from the egyptian museum. i recommend this hostel to anyone looking for an inexpensive and simple place to stay.
# Phrase: they greeted us with a delicious hibiscus drink and the staff was very friendly.
# Prediction: main aspect: staff extracted aspects: drink, staff extracted opinions: delicious, friendly global polarity: positive
# --------------------------------------------------
# Phrase: our room was good size and the air conditioning was working great (and this was important as we were in august).
# Prediction: main aspect: conditioning extracted aspects: room, size, air, conditioning, august extracted opinions: important, good, great global polarity: positive
# --------------------------------------------------
# Phrase: we were just steps away from the egyptian museum.
# Prediction: main aspect: facilities extracted aspects: facilities, museum extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: i recommend this hostel to anyone looking for an inexpensive and simple place to stay.
# Prediction: main aspect: place extracted aspects: anyone, place, hostel extracted opinions: recommend global polarity: positive
# --------------------------------------------------
# **************************************************
# text : despite the high cost of accommodation...
# Phrase: despite the high cost of accommodation...
# Prediction: main aspect: accommodation extracted aspects: accommodation, cost extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : and a lot of visitors mean to me that all the food is clean and good. and that's what i found in the bathroom tower restaurant and the rum service.
# Phrase: and a lot of visitors mean to me that all the food is clean and good.
# Prediction: main aspect: food extracted aspects: visitors, lot, food extracted opinions: clean, good global polarity: positive
# --------------------------------------------------
# Phrase: and that's what i found in the bathroom tower restaurant and the rum service.
# Prediction: main aspect: service extracted aspects: i, service, tower, bathroom, restaurant, rum extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : i trust him and recommend him to all my friends who are crossing the city or coming to work. he has a very great view of the mediterranean coast. i enjoyed the palm trees the most. the staff are friendly. as well as sleep and food.
# Phrase: i trust him and recommend him to all my friends who are crossing the city or coming to work.
# Prediction: main aspect: facilities extracted aspects: facilities, city, friends extracted opinions: recommend, trust global polarity: positive
# --------------------------------------------------
# Phrase: he has a very great view of the mediterranean coast.
# Prediction: main aspect: views extracted aspects: views, view, coast extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: i enjoyed the palm trees the most.
# Prediction: main aspect: palm trees extracted aspects: palm trees, i extracted opinions: enjoyed global polarity: positive
# --------------------------------------------------
# Phrase: the staff are friendly.
# Prediction: main aspect: staff extracted aspects: staff extracted opinions: friendly global polarity: positive
# --------------------------------------------------
# Phrase: as well as sleep and food.
# Prediction: main aspect: food extracted aspects: food, sleep extracted opinions: well global polarity: positive
# --------------------------------------------------
# **************************************************
# text : good location. don't take bags i stayed for two nights and enjoyed barcelona. the hotel was clean despite some noise.
# Phrase: good location.
# Prediction: main aspect: location extracted aspects: location extracted opinions: good global polarity: positive
# --------------------------------------------------
# Phrase: don't take bags i stayed for two nights and enjoyed barcelona.
# Prediction: main aspect: barcelona extracted aspects: nights, barcelona, bags extracted opinions: enjoyed global polarity: positive
# --------------------------------------------------
# Phrase: the hotel was clean despite some noise.
# Prediction: main aspect: hotel extracted aspects: noise, hotel extracted opinions: clean global polarity: positive
# --------------------------------------------------
# **************************************************
# text : my first experience in abu dhabi. was a premium experience in this hotel... the reception and excellent handling of the hotel's cleanliness wonderful comfort of bed was above the perception of my only criticism that high wi-fi prices are not everything was good hotel location sweet nearby 820382038203and the hotel is adjacent to the six continents park and the hotel provides free degrees and i liked the movement
# Phrase: my first experience in abu dhabi.
# Prediction: main aspect: facilities extracted aspects: facilities, dhabi, experience extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: was a premium experience in this hotel... the reception and excellent handling of the hotel's cleanliness wonderful comfort of bed was above the perception of my only criticism that high wi-fi prices are not everything was good hotel location sweet nearby 820382038203and the hotel is adjacent to the six continents park and the hotel provides free degrees and i liked the movement
# Prediction: main aspect: hotel extracted aspects: comfort, criticism, prices, reception, bed, perception, wifi, park, everything, continents, handling, cleanliness, movement, location, hotel extracted opinions: excellent, comfort, criticism, good, liked, wonderful, free, sweet global polarity: positive
# --------------------------------------------------
# **************************************************
# text : i couldn't get into the room until 5:15. even though i was in front of the reception from 2:00 p.m.
# Phrase: i couldn't get into the room until 5:15. even though i was in front of the reception from 2:00 p.m.
# Prediction: main aspect: reception extracted aspects: reception, room, i, front, pm extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : we found that the rooms were medium and fairly small in size. and the food had nothing special about it.
# Phrase: we found that the rooms were medium and fairly small in size.
# Prediction: main aspect: rooms extracted aspects: size, rooms extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: and the food had nothing special about it.
# Prediction: main aspect: food extracted aspects: food, nothing extracted opinions: special global polarity: negative
# --------------------------------------------------
# **************************************************
# text : great hotel at a great price! this was the best hotel we had seen in three weeks in italy. not only was it great and centrally located with a very helpful staff but the room had the amenities travelers needed – a large. very spacious storage space. hanger. light switches. a well-functioning air conditioner. etc. check out the bulletin board in the lobby with guest compliments.
# Phrase: great hotel at a great price!
# Prediction: main aspect: hotel extracted aspects: price, hotel extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: this was the best hotel we had seen in three weeks in italy.
# Prediction: main aspect: hotel extracted aspects: weeks, italy, hotel extracted opinions: best global polarity: positive
# --------------------------------------------------
# Phrase: not only was it great and centrally located with a very helpful staff but the room had the amenities travelers needed – a large.
# Prediction: main aspect: staff extracted aspects: travelers, room, staff, amenities, amenities extracted opinions: helpful, great global polarity: positive
# --------------------------------------------------
# Phrase: very spacious storage space.
# Prediction: main aspect: storage space extracted aspects: storage space, space extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: hanger.
# Prediction: main aspect: hanger extracted aspects: hanger extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: light switches.
# Prediction: main aspect: amenities extracted aspects: amenities, switches extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: a well-functioning air conditioner.
# Prediction: main aspect: conditioning extracted aspects: air, conditioning, conditioner extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: etc.
# Prediction: main aspect: nan extracted aspects: etc extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: check out the bulletin board in the lobby with guest compliments.
# Prediction: main aspect: amenities extracted aspects: bulletin, board, amenities, compliments, lobby extracted opinions: lobby global polarity: positive
# --------------------------------------------------
# **************************************************
# text : breakfast was normal. although there were plenty of options.
# Phrase: breakfast was normal.
# Prediction: main aspect: meals extracted aspects: breakfast, meals extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: although there were plenty of options.
# Prediction: main aspect: options extracted aspects: options, plenty extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : my breakfast rating is average in terms of location. breakfast location next to the hotel. and in terms of type.
# Phrase: my breakfast rating is average in terms of location.
# Prediction: main aspect: meals extracted aspects: breakfast, terms, meals, location, rating extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: breakfast location next to the hotel.
# Prediction: main aspect: hotel extracted aspects: location, breakfast, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and in terms of type.
# Prediction: main aspect: nan extracted aspects: terms, type extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# **************************************************
# text : you listen when you eat at the restaurant. and all the cooks in front of you cook.
# Phrase: you listen when you eat at the restaurant.
# Prediction: main aspect: restaurant extracted aspects: restaurant extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and all the cooks in front of you cook.
# Prediction: main aspect: meals extracted aspects: cooks, front extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the resort is a separate chalets interspersed with artificial trees and rivers and this is considered a healthy thing. of course not suitable for conservative families. the nightlife system in the resort is bad. there are no privileges for the resort guests.
# Phrase: the resort is a separate chalets interspersed with artificial trees and rivers and this is considered a healthy thing.
# Prediction: main aspect: resort extracted aspects: resort, chalets, thing, rivers, trees extracted opinions: healthy global polarity: positive
# --------------------------------------------------
# Phrase: of course not suitable for conservative families.
# Prediction: main aspect: facilities extracted aspects: families, course, facilities extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: the nightlife system in the resort is bad.
# Prediction: main aspect: hotelservices extracted aspects: resort, hotelservices, system, nightlife extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: there are no privileges for the resort guests.
# Prediction: main aspect: resort extracted aspects: resort, privileges, guests extracted opinions: no, privileges global polarity: negative
# --------------------------------------------------
# **************************************************
# text : how great was it? trust me. if you love family. then you’ll have the best vacation there is. i’ve visited this place three times so far. and it’s become my vacation destination. it’s where you’ll find value for the money you pay. the staff is very friendly. and the food is good.
# Phrase: how great was it?
# Prediction: main aspect: nan extracted aspects: extracted opinions: great global polarity: neutral
# --------------------------------------------------
# Phrase: trust me.
# Prediction: main aspect: nan extracted aspects: extracted opinions: trust global polarity: neutral
# --------------------------------------------------
# Phrase: if you love family.
# Prediction: main aspect: facilities extracted aspects: facilities, family extracted opinions: love global polarity: positive
# --------------------------------------------------
# Phrase: then you’ll have the best vacation there is.
# Prediction: main aspect: amenities extracted aspects: amenities, vacation extracted opinions: best global polarity: positive
# --------------------------------------------------
# Phrase: i’ve visited this place three times so far.
# Prediction: main aspect: place extracted aspects: i, place extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and it’s become my vacation destination.
# Prediction: main aspect: transportation extracted aspects: transportation, destination, vacation extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: it’s where you’ll find value for the money you pay.
# Prediction: main aspect: value extracted aspects: money, value extracted opinions: value, pay global polarity: positive
# --------------------------------------------------
# Phrase: the staff is very friendly.
# Prediction: main aspect: staff extracted aspects: staff extracted opinions: friendly global polarity: positive
# --------------------------------------------------
# Phrase: and the food is good.
# Prediction: main aspect: food extracted aspects: food extracted opinions: good global polarity: positive
# --------------------------------------------------
# **************************************************
# text : excellent service easy and comfortable accommodation from the first moment an excellent team of staff who help you to have a happy time all day smile and welcome are very special we were able to enjoy many activities on the beach and the hotel the atmosphere of the golf courses add luxury to the beach place is very special and large and varied activities and services
# Phrase: excellent service easy and comfortable accommodation from the first moment an excellent team of staff who help you to have a happy time all day smile and welcome are very special we were able to enjoy many activities on the beach and the hotel the atmosphere of the golf courses add luxury to the beach place is very special and large and varied activities and services
# Prediction: main aspect: service extracted aspects: golf, services, place, service, staff, accommodation, moment, luxury, smile, time, atmosphere, day, team, beach, activities, welcome, hotel extracted opinions: excellent, comfortable, smile, enjoy, easy, happy, welcome, help global polarity: positive
# --------------------------------------------------
# **************************************************
# text : hilton. but we went to the hilton taba and the family and it was a bad visit. and the family and i couldn't have a good meal at any restaurant. and i don't know for sure that this hotel is not a five-star hotel. the food is so bad. the kitchen is so bad. i'm not thinking of going back to hilton again.
# Phrase: hilton.
# Prediction: main aspect: nan extracted aspects: hilton extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: but we went to the hilton taba and the family and it was a bad visit.
# Prediction: main aspect: facilities extracted aspects: hilton, visit, family, facilities, taba extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: and the family and i couldn't have a good meal at any restaurant.
# Prediction: main aspect: meals extracted aspects: i, family, restaurant, meal extracted opinions: good global polarity: negative
# --------------------------------------------------
# Phrase: and i don't know for sure that this hotel is not a five-star hotel.
# Prediction: main aspect: hotel extracted aspects: hotel extracted opinions: sure global polarity: negative
# --------------------------------------------------
# Phrase: the food is so bad.
# Prediction: main aspect: food extracted aspects: food extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: the kitchen is so bad.
# Prediction: main aspect: kitchen extracted aspects: kitchen extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: i'm not thinking of going back to hilton again.
# Prediction: main aspect: nan extracted aspects: hilton extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# **************************************************
# text : but his furniture is very bad and the family is dirty and worn with stains and dirt. and the breakfast room is very small and the quality of breakfast is bad. it is a collection of cheese. bread. juice and pieces of meat
# Phrase: but his furniture is very bad and the family is dirty and worn with stains and dirt.
# Prediction: main aspect: furniture extracted aspects: dirt, furniture, family extracted opinions: dirty, worn, dirt global polarity: negative
# --------------------------------------------------
# Phrase: and the breakfast room is very small and the quality of breakfast is bad.
# Prediction: main aspect: meals extracted aspects: breakfast, room, meals, quality extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: it is a collection of cheese.
# Prediction: main aspect: cheese extracted aspects: collection, cheese extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: bread.
# Prediction: main aspect: bread extracted aspects: bread extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: juice and pieces of meat
# Prediction: main aspect: juice extracted aspects: pieces, meat, juice extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : i had high hopes for this hotel. its location is convenient. the rooms are good. the restaurant is also acceptable. generally. it gives you the impression that it is not a hotel with anything wrong but at the same time you do not remember anything after a while. the staff were helpful. and they arranged for the sound and light display at the pyramids and it was smooth. and although there was nothing wrong. i would not choose this hotel again.
# Phrase: i had high hopes for this hotel.
# Prediction: main aspect: hotel extracted aspects: hopes, i, hotel extracted opinions: hopes global polarity: positive
# --------------------------------------------------
# Phrase: its location is convenient.
# Prediction: main aspect: location extracted aspects: location extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: the rooms are good.
# Prediction: main aspect: rooms extracted aspects: rooms extracted opinions: good global polarity: positive
# --------------------------------------------------
# Phrase: the restaurant is also acceptable.
# Prediction: main aspect: restaurant extracted aspects: restaurant extracted opinions: acceptable global polarity: positive
# --------------------------------------------------
# Phrase: generally.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: it gives you the impression that it is not a hotel with anything wrong but at the same time you do not remember anything after a while.
# Prediction: main aspect: hotel extracted aspects: impression, while, anything, time, hotel extracted opinions: impression, wrong global polarity: negative
# --------------------------------------------------
# Phrase: the staff were helpful.
# Prediction: main aspect: staff extracted aspects: staff extracted opinions: helpful global polarity: positive
# --------------------------------------------------
# Phrase: and they arranged for the sound and light display at the pyramids and it was smooth.
# Prediction: main aspect: display extracted aspects: display, pyramids, sound extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and although there was nothing wrong.
# Prediction: main aspect: nan extracted aspects: nothing extracted opinions: wrong global polarity: neutral
# --------------------------------------------------
# Phrase: i would not choose this hotel again.
# Prediction: main aspect: hotel extracted aspects: hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the hotel is very beautiful and luxurious and they gave us a room in a high floor and free access to the spa and health club from the disadvantages of high prices and inconvenience trains around it
# Phrase: the hotel is very beautiful and luxurious and they gave us a room in a high floor and free access to the spa and health club from the disadvantages of high prices and inconvenience trains around it
# Prediction: main aspect: hotel extracted aspects: prices, floor, room, access, health, club, spa, inconvenience, disadvantages, trains, hotel extracted opinions: inconvenience, disadvantages, beautiful, free global polarity: positive
# --------------------------------------------------
# **************************************************
# text : great hotel to stay close to the street partition and independence! but for couples be ready to wake up to room service 08:00! we stayed at this hotel had a good breakfast there is no great choice for vegetarians but the rooms were very nice and comfortable
# Phrase: great hotel to stay close to the street partition and independence!
# Prediction: main aspect: hotel extracted aspects: street, partition, independence, hotel extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: but for couples be ready to wake up to room service 08:00!
# Prediction: main aspect: room extracted aspects: room, service, couples, couples extracted opinions: ready global polarity: positive
# --------------------------------------------------
# Phrase: we stayed at this hotel had a good breakfast there is no great choice for vegetarians but the rooms were very nice and comfortable
# Prediction: main aspect: rooms extracted aspects: breakfast, vegetarians, rooms, choice, hotel extracted opinions: nice, comfortable, no, good, great global polarity: positive
# --------------------------------------------------
# **************************************************
# text : a beautiful hotel on the red sea is a nice hotel. the location is perfect on the red sea which has some of the best coral reefs in the world.
# Phrase: a beautiful hotel on the red sea is a nice hotel.
# Prediction: main aspect: hotel extracted aspects: sea, hotel extracted opinions: nice, beautiful global polarity: positive
# --------------------------------------------------
# Phrase: the location is perfect on the red sea which has some of the best coral reefs in the world.
# Prediction: main aspect: location extracted aspects: reefs, world, location, sea extracted opinions: best, perfect global polarity: positive
# --------------------------------------------------
# **************************************************
# text : reasonable enough for a non-peak season. first it was expensive because of the peak season. i think. room space is limited with an unfinished roof. the bathtub has a leak.
# Phrase: reasonable enough for a non-peak season.
# Prediction: main aspect: facilities extracted aspects: facilities, season extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: first it was expensive because of the peak season.
# Prediction: main aspect: facilities extracted aspects: season, facilities, peak extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: i think.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: room space is limited with an unfinished roof.
# Prediction: main aspect: room extracted aspects: room, space, roof extracted opinions: limited global polarity: negative
# --------------------------------------------------
# Phrase: the bathtub has a leak.
# Prediction: main aspect: bathroom extracted aspects: bathroom, leak, bathtub extracted opinions: leak global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the room is very dirty. and the room is very bad. as my previous stay was better in terms of service and cleanliness. and i was delayed in entering.
# Phrase: the room is very dirty.
# Prediction: main aspect: room extracted aspects: room extracted opinions: dirty global polarity: negative
# --------------------------------------------------
# Phrase: and the room is very bad.
# Prediction: main aspect: room extracted aspects: room extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: as my previous stay was better in terms of service and cleanliness.
# Prediction: main aspect: cleanliness extracted aspects: terms, stay, service, cleanliness extracted opinions: better global polarity: positive
# --------------------------------------------------
# Phrase: and i was delayed in entering.
# Prediction: main aspect: nan extracted aspects: i extracted opinions: delayed global polarity: neutral
# --------------------------------------------------
# **************************************************
# text : and breakfast sucks because it's so varied. the food and the mosquitos on the catering area. the security guys are so friendly. the smoke comes out of the air conditioner.
# Phrase: and breakfast sucks because it's so varied.
# Prediction: main aspect: meals extracted aspects: breakfast, meals, sucks extracted opinions: sucks global polarity: negative
# --------------------------------------------------
# Phrase: the food and the mosquitos on the catering area.
# Prediction: main aspect: food extracted aspects: food, area, mosquitos extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: the security guys are so friendly.
# Prediction: main aspect: security guys extracted aspects: security guys, guys extracted opinions: friendly global polarity: positive
# --------------------------------------------------
# Phrase: the smoke comes out of the air conditioner.
# Prediction: main aspect: amenities extracted aspects: amenities, air, conditioner, smoke extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : i'd say the smell of the dishes and the spoons. the belly turns and the eating is brutal. but the regiment that i was in was mostly food poisoning.
# Phrase: i'd say the smell of the dishes and the spoons.
# Prediction: main aspect: food extracted aspects: spoons, food, dishes, smell extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: the belly turns and the eating is brutal.
# Prediction: main aspect: eating extracted aspects: eating, belly extracted opinions: brutal global polarity: negative
# --------------------------------------------------
# Phrase: but the regiment that i was in was mostly food poisoning.
# Prediction: main aspect: food extracted aspects: i, food, regiment, poisoning extracted opinions: poisoning global polarity: negative
# --------------------------------------------------
# **************************************************
# text : a new hotel is not fully ready (no credit card payments. only cash). and there is limited parking available.
# Phrase: a new hotel is not fully ready (no credit card payments.
# Prediction: main aspect: hotel extracted aspects: credit, card, payments, hotel extracted opinions: credit, no, ready global polarity: negative
# --------------------------------------------------
# Phrase: only cash).
# Prediction: main aspect: facilities extracted aspects: facilities, cash extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: and there is limited parking available.
# Prediction: main aspect: parking extracted aspects: parking extracted opinions: limited global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the large bed is more than comfortable and the space inside makes you feel comfortable inside.
# Phrase: the large bed is more than comfortable and the space inside makes you feel comfortable inside.
# Prediction: main aspect: bedding extracted aspects: bed, space, inside, bedding extracted opinions: comfortable global polarity: positive
# --------------------------------------------------
# **************************************************
# text : bad experience. bad hotel. bad service. bad food. really bad employees. and they stick their noses in everything.
# Phrase: bad experience.
# Prediction: main aspect: facilities extracted aspects: facilities, experience extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: bad hotel.
# Prediction: main aspect: hotel extracted aspects: hotel extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: bad service.
# Prediction: main aspect: service extracted aspects: service extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: bad food.
# Prediction: main aspect: food extracted aspects: food extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: really bad employees.
# Prediction: main aspect: employees extracted aspects: employees extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: and they stick their noses in everything.
# Prediction: main aspect: nan extracted aspects: noses, everything extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# **************************************************
# text : the receptionists are some of them in need of rehabilitation and the manner of tact is far from them and every employee tells you something and you find them contradictory to each other.
# Phrase: the receptionists are some of them in need of rehabilitation and the manner of tact is far from them and every employee tells you something and you find them contradictory to each other.
# Prediction: main aspect: receptionists extracted aspects: need, receptionists, something, manner, employee, tact, rehabilitation extracted opinions: contradictory global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the hotel is average. the business hall is fantastic - you need to update
# Phrase: the hotel is average.
# Prediction: main aspect: hotel extracted aspects: hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: the business hall is fantastic - you need to update
# Prediction: main aspect: facilities extracted aspects: facilities, hall, business extracted opinions: fantastic global polarity: positive
# --------------------------------------------------
# **************************************************
# text : special conditions i traveled to alexandria to attend an event and i booked a hotel in jeddah by the sea with my family and after the completion of the event we went to stay at the hotel is suitable for one night only the door of the room was not fully closed and breakfast realize that you live in a camp for young people many prices at the level of service and after the end of the night in the morning we left to cairo but the hotel needs to improve services a lot
# Phrase: special conditions i traveled to alexandria to attend an event and i booked a hotel in jeddah by the sea with my family and after the completion of the event we went to stay at the hotel is suitable for one night only the door of the room was not fully closed and breakfast realize that you live in a camp for young people many prices at the level of service and after the end of the night in the morning we left to cairo but the hotel needs to improve services a lot
# ...
# --------------------------------------------------
# Phrase: as well as the entry of the cleaning crew to clean the room despite the sign not to disturb
# Prediction: main aspect: room extracted aspects: entry, room, crew, sign, cleaning extracted opinions: clean, disturb, well global polarity: positive
# --------------------------------------------------
# **************************************************
# text : and i hope to keep a price that attracts a lot of tourists to the hotel.
# Phrase: and i hope to keep a price that attracts a lot of tourists to the hotel.
# Prediction: main aspect: hotel extracted aspects: tourist, lot, price, hotel extracted opinions: hope global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the distance between the hotel and the taj is a short walk to the tuk tuk. i couldn’t actually see a crown from the roof because of the fog. but you should! it doesn’t look very good from the outside – just a regular modern hotel. but it was a pleasant surprise on entry.
# Phrase: the distance between the hotel and the taj is a short walk to the tuk tuk.
# Prediction: main aspect: hotel extracted aspects: distance, taj, walk, hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: i couldn’t actually see a crown from the roof because of the fog.
# Prediction: main aspect: amenities extracted aspects:, crown, i, fog, amenities, roof extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: but you should!
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: it doesn’t look very good from the outside – just a regular modern hotel.
# Prediction: main aspect: hotel extracted aspects:, hotel extracted opinions: good global polarity: negative
# --------------------------------------------------
# Phrase: but it was a pleasant surprise on entry.
# Prediction: main aspect: entry extracted aspects: entry, surprise extracted opinions: pleasant global polarity: positive
# --------------------------------------------------
# **************************************************
# text : enter the restaurant and show a mandhmsh limit that touches the empty dishes etni limit as far as i pass and i'm a child ask for a comment no. before leaving at 12:30. order a cup of cappuccino reply to the gentleman in the bar in front of the restaurant no. you're not sure i'd say that taste of you and say that even a minute is not a gift people very taste in his tongue a human almost tasteless was made of weak blood
# Phrase: enter the restaurant and show a mandhmsh limit that touches the empty dishes etni limit as far as i pass and i'm a child ask for a comment no.
# Prediction: main aspect: restaurant extracted aspects: comment, pass, restaurant, etni, dishes, limit, child extracted opinions: empty, no global polarity: negative
# --------------------------------------------------
# Phrase: before leaving at 12:30. order a cup of cappuccino reply to the gentleman in the bar in front of the restaurant no.
# Prediction: main aspect: restaurant extracted aspects: order, reply, gentleman, bar, restaurant, bar, cappuccino, no extracted opinions: no global polarity: negative
# --------------------------------------------------
# Phrase: you're not sure i'd say that taste of you and say that even a minute is not a gift people very taste in his tongue a human almost tasteless was made of weak blood
# Prediction: main aspect: taste extracted aspects: tongue, tongue, minute, people, blood, gift, taste extracted opinions: gift, weak, sure global polarity: negative
# --------------------------------------------------
# **************************************************
# text : drinks arrive at the door of the room if you want to trouble the rooms that the family is small
# Phrase: drinks arrive at the door of the room if you want to trouble the rooms that the family is small
# Prediction: main aspect: rooms extracted aspects: drinks, door, room, family, rooms, trouble extracted opinions: trouble, want global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the hotel is nice and clean and family first class and the hotel is close to the market. but the hotel staff are all treated very high respect for the guest
# Phrase: the hotel is nice and clean and family first class and the hotel is close to the market.
# Prediction: main aspect: hotel extracted aspects: market, family, class, hotel extracted opinions: nice, clean global polarity: positive
# --------------------------------------------------
# Phrase: but the hotel staff are all treated very high respect for the guest
# Prediction: main aspect: hotelservices extracted aspects: respect, staff, guest, hotelservices, hotel extracted opinions: respect global polarity: positive
# --------------------------------------------------
# **************************************************
# text : a very reasonable hotel for hotel apartments is a very reasonable place close to the metro. airport and shopping center city centre deira. but it is possible to classify 1635; four stars mesh breakfast to some extent is not luxurious but
# Phrase: a very reasonable hotel for hotel apartments is a very reasonable place close to the metro.
# Prediction: main aspect: hotel extracted aspects: place, apartments, metro, hotel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: airport and shopping center city centre deira.
# Prediction: main aspect: transportation extracted aspects: airport, transportation, centre, city, shopping extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: but it is possible to classify 1635; four stars mesh breakfast to some extent is not luxurious but
# Prediction: main aspect: meals extracted aspects: breakfast, extent, stars, meals extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : all the staff we've dealt with during our stay have been pretty friendly and welcoming. receptionists. waiters. cooks. housekeepers plus life guards.
# Phrase: all the staff we've dealt with during our stay have been pretty friendly and welcoming.
# Prediction: main aspect: staff extracted aspects: staff, stay extracted opinions: pretty, welcoming, friendly global polarity: positive
# --------------------------------------------------
# Phrase: receptionists.
# Prediction: main aspect: receptionists extracted aspects: receptionists extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: waiters.
# Prediction: main aspect: waiters extracted aspects: waiters extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: cooks.
# Prediction: main aspect: facilities extracted aspects: cooks extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: housekeepers plus life guards.
# Prediction: main aspect: residence extracted aspects: life, housekeepers, residence, guards extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the hotel is great in terms of location. the beach is excellent. the sea is very beautiful. the beach is above excellent and the team is very cooperative.
# Phrase: the hotel is great in terms of location.
# Prediction: main aspect: hotel extracted aspects: terms, location, hotel extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: the beach is excellent.
# Prediction: main aspect: beach extracted aspects: beach extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# Phrase: the sea is very beautiful.
# Prediction: main aspect: sea extracted aspects: sea extracted opinions: beautiful global polarity: positive
# --------------------------------------------------
# Phrase: the beach is above excellent and the team is very cooperative.
# Prediction: main aspect: beach extracted aspects: team, beach extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# **************************************************
# text : the hotel is a little small. but the design is great. the rooms are good and comfortable. and the upper pool on the sixth floor is also small.
# Phrase: the hotel is a little small.
# Prediction: main aspect: hotel extracted aspects: hotel extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: but the design is great.
# Prediction: main aspect: design extracted aspects: design extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: the rooms are good and comfortable.
# Prediction: main aspect: rooms extracted aspects: rooms extracted opinions: comfortable, good global polarity: positive
# --------------------------------------------------
# Phrase: and the upper pool on the sixth floor is also small.
# Prediction: main aspect: pool extracted aspects: floor, pool extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : i can't imagine a five-star hotel with such a horrible level of cleanliness.
# Phrase: i can't imagine a five-star hotel with such a horrible level of cleanliness.
# Prediction: main aspect: hotel extracted aspects: level, i, cleanliness, hotel extracted opinions: horrible global polarity: negative
# --------------------------------------------------
# **************************************************
# text : there's no cleanliness in the rooms. and the faucet in the bathroom doesn't work.
# Phrase: there's no cleanliness in the rooms.
# Prediction: main aspect: rooms extracted aspects: cleanliness, rooms extracted opinions: no global polarity: negative
# --------------------------------------------------
# Phrase: and the faucet in the bathroom doesn't work.
# Prediction: main aspect: bathroom extracted aspects: faucet, bathroom extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the resort is very clean and the service is above excellent and the reception has been a lot of attention.
# Phrase: the resort is very clean and the service is above excellent and the reception has been a lot of attention.
# Prediction: main aspect: service extracted aspects: reception, service, resort, lot, attention extracted opinions: clean, excellent global polarity: positive
# --------------------------------------------------
# **************************************************
# text : beautiful hotel and great location i stayed in this hotel for five days was beautiful and wonderful and everything you need is within the hotel area of services. barber and cafs. the hotel is very clean and the staff is good and the kitchen is equipped with most of the needs of the guest.
# Phrase: beautiful hotel and great location i stayed in this hotel for five days was beautiful and wonderful and everything you need is within the hotel area of services.
# Prediction: main aspect: hotel extracted aspects: days, services, i, area, everything, location, hotel extracted opinions: wonderful, beautiful, great global polarity: positive
# --------------------------------------------------
# Phrase: barber and cafs.
# Prediction: main aspect: amenities extracted aspects: amenities, barber, cafs extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: the hotel is very clean and the staff is good and the kitchen is equipped with most of the needs of the guest.
# Prediction: main aspect: hotel extracted aspects: needs, staff, kitchen, guest, hotel extracted opinions: clean, good global polarity: positive
# --------------------------------------------------
# **************************************************
# text : and the food is awful sometimes.
# Phrase: and the food is awful sometimes.
# Prediction: main aspect: food extracted aspects: food extracted opinions: awful global polarity: negative
# --------------------------------------------------
# **************************************************
# text : the fungus comes out of the vent. the slurry in the bathroom is also covered with mold. it looked like a white tile with a cloudy black-and-brown slurry. we stayed 3 days and a wet towel remained on the shower rack the whole time will not spend 200 euros on a room like this again
# Phrase: the fungus comes out of the vent.
# Prediction: main aspect: fungus extracted aspects: vent, fungus extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: the slurry in the bathroom is also covered with mold.
# Prediction: main aspect: bathroom extracted aspects: slurry, bathroom, mold extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: it looked like a white tile with a cloudy black-and-brown slurry.
# Prediction: main aspect: tile extracted aspects: tile, slurry extracted opinions: like global polarity: negative
# --------------------------------------------------
# Phrase: we stayed 3 days and a wet towel remained on the shower rack the whole time will not spend 200 euros on a room like this again
# Prediction: main aspect: room extracted aspects: days, room, towel, time, euros, shower, rack extracted opinions: like global polarity: negative
# --------------------------------------------------
# **************************************************
# text : and the shower filter couldn't have closed properly.
# Phrase: and the shower filter couldn't have closed properly.
# Prediction: main aspect: amenities extracted aspects: amenities, shower, filter extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# **************************************************
# text : other than that i was already satisfied with the services in general as well as the prices compared to other old resorts nearby.
# Phrase: other than that i was already satisfied with the services in general as well as the prices compared to other old resorts nearby.
# Prediction: main aspect: prices extracted aspects: prices, services, i, resorts extracted opinions: satisfied, well global polarity: positive
# --------------------------------------------------
# **************************************************
# text : and the bathrooms are fine for breakfast. nice. nice dinner. and the people at palmyra are very respectable and very helpful.
# Phrase: and the bathrooms are fine for breakfast.
# Prediction: main aspect: bathroom extracted aspects: breakfast, bathrooms, bathroom extracted opinions: fine global polarity: neutral
# --------------------------------------------------
# Phrase: nice.
# Prediction: main aspect: nan extracted aspects: extracted opinions: nice global polarity: neutral
# --------------------------------------------------
# Phrase: nice dinner.
# Prediction: main aspect: dinner extracted aspects: dinner extracted opinions: nice global polarity: positive
# --------------------------------------------------
# Phrase: and the people at palmyra are very respectable and very helpful.
# Prediction: main aspect: people extracted aspects: palmyra, people extracted opinions: helpful, respectable global polarity: positive
# --------------------------------------------------

# %%
#
data = []
for text, predictions_par_phrase in zip(sentences, outputs):
    text_sans_virgules = text.replace(',', '.')
    phrases = sent_tokenize(text_sans_virgules)
    aspect_opinion_sentiments = []

    for prediction in predictions_par_phrase:
        for phrase in phrases:
            aspects_to_use = [prediction["main_aspect"]] if prediction["main_aspect"] and prediction["main_aspect"] != "nan" else prediction["extracted_aspects"]

            for aspect in aspects_to_use:
                if aspect in phrase:
                    closest_opinion = find_closest_opinion(phrase, aspect, prediction["extracted_opinions"])
                    if closest_opinion and aspect != closest_opinion:
                        sentiment = analyze_sentiment(phrase)# NLTK sentiment analysis pour affiner le sentiment lié a une opnion precise la generation etant trop brut
                        aspect_opinion_sentiments.append((aspect, closest_opinion, sentiment))

    # Éliminer les doublons en convertissant la liste en un ensemble, puis en la reconvertissant en liste
    aspect_opinion_sentiments = list(set(aspect_opinion_sentiments))
    sorted_aspect_opinion_sentiments = sorted(aspect_opinion_sentiments, key=lambda x: x[0])

    print(text_sans_virgules)
    print("-"*50)
    print("Aspect-Opinion Sentiments:")
    for tup in sorted_aspect_opinion_sentiments:
        print(tup)
    print("*"*50)

    data_dict = {
        "text": text_sans_virgules,
        "main_aspect": prediction["main_aspect"],
        "extracted_aspects": prediction["extracted_aspects"],
        "extracted_opinions": prediction["extracted_opinions"],
        "global_polarity": prediction["global_polarity"],
        "aspect_opinion_sentiments": sorted_aspect_opinion_sentiments
    }
    data.append(data_dict)

with open('/content/drive/MyDrive/Master 2/output.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'hopes', 'positive')
# ('hotel', 'wrong', 'negative')
# ('nothing', 'wrong', 'negative')
# ('restaurant', 'acceptable', 'neutral')
# ('rooms', 'good', 'positive')
# ('staff', 'helpful', 'neutral')
# **************************************************
# there are many chairs in the sun. it was a really nice holiday!! we will definitely get back to this hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'definitely', 'neutral')
# **************************************************
# and the design of the rooms is wonderful and spacious and modern in terms of furniture and design. in addition to equipping them with all the requirements needed by the tourist
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('furniture', 'wonderful', 'positive')
# **************************************************
# the hotel is well located.. the reception is friendly.. the rooms are spacious.. the family is large and comfortable.. and the service is excellent
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'friendly', 'positive')
# **************************************************
# great location but the hotel is very old-fashioned.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'great', 'positive')
# **************************************************
# a new hotel is not fully ready (no credit card payments. only cash). and there is limited parking available.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'ready', 'positive')
# ('parking', 'limited', 'positive')
# **************************************************
# there are a lot of activities. the most important for me is the water ball and the flying ball on the beach. and there is a large football field and a gym. so i advise every family to go to this resort for a fun vacation.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('beach', 'important', 'positive')
# ('resort', 'fun', 'positive')
# **************************************************
# samaya was great recently i stayed for a week in this wonderful hotel. the food was great and the room was excellent and the sky on the bay was clear... i will come back to visit the hotel again and again of course....
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'great', 'positive')
# ('hotel', 'wonderful', 'positive')
# ('room', 'excellent', 'positive')
# **************************************************
# not very five stars. i had to stay here for two full days as a hotel workshop. the rooms weren’t bad. but i’m not sure about the five-star rating. the food level was average. and there was nothing noticeable. but you could swallow your bites. i think it’s overpriced compared to similar hotels.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rating', 'sure', 'negative')
# ('rooms', 'bad', 'negative')
# **************************************************
# yes. very luxurious. but there is no internet in it. it just works slowly in the hallway. breakfast is fine. the furniture is old. fair to the limit of 4/5. i think this glory was from the past.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('internet', 'no', 'neutral')
# ('limit', 'fair', 'positive')
# ('past', 'glory', 'negative')
# **************************************************
# too expensive a little playground a disgusting entertainment team
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('team', 'entertainment', 'negative')
# **************************************************
# a wonderful hotel is a permanent customer. the hotel as if you are in your home of security and safety enjoys complete cleanliness and good accommodation as well as eating very clean and also the variety of dishes permanently for the best..
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('accommodation', 'good', 'positive')
# ('hotel', 'wonderful', 'positive')
# **************************************************
# great value for money and full service
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'value', 'positive')
# **************************************************
# beautiful hotel and good location excellent hotel for families and close to the shopping center easy access from the hotel and recommend to visit and beautiful for honeymoon
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'beautiful', 'positive')
# **************************************************
# hotel cardenia it is a good hotel and its services are good and its staff are loyal to their work and high morals and the hotel's monastery is a gentleman... the hotel is quiet and delicious and has a comfortable gymnasium has been very comfortable with a room on my own and this hotel will be the hotel where i always stay
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'good', 'positive')
# **************************************************
# you will not get bored.i spent a whole week with the family there and enjoyed a lot. the price is good and the cleanliness is good...
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# niali is a great location. there are a lot of things to do in the area on all this hotel is medium to poor level...
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'poor', 'negative')
# ('location', 'great', 'positive')
# **************************************************
# it is not recommended that there should be a guide for you in order to find the elevator. we were dragging bags up and down the drawers and around them.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('elevator', 'recommended', 'neutral')
# **************************************************
# * great view. service. clean and average rooms
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'clean', 'positive')
# ('view', 'great', 'positive')
# **************************************************
# a very reasonable hotel for hotel apartments is a very reasonable place close to the metro. airport and shopping center city centre deira. but it is possible to classify 1635; four stars mesh breakfast to some extent is not luxurious but
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# i expected the suite i booked to be bigger than it actually was compared to its price. but when i told them to accompany the kids. a lot of things were added to the kids that they liked and it was a fun touch.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# for every person who dreams of a great stay i advise him to choose the hotel for one day only. the hotel place is great lake view fantasy
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'great', 'positive')
# **************************************************
# there is also no direct access from the courtyard to the hotel. i wanted a pick-up service to the airport. and the concierge told me not to book through the hotel booking desk. and to book through him. which immediately frustrated me. so i decided to take a taxi.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'no', 'negative')
# **************************************************
# great hotel i was visiting the hotel late last year.....great memories.....reception is good.....the rooms are very clean.....
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('reception', 'good', 'positive')
# **************************************************
# good location. don't take bags i stayed for two nights and enjoyed barcelona. the hotel was clean despite some noise.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('barcelona', 'enjoyed', 'positive')
# ('hotel', 'clean', 'positive')
# ('location', 'good', 'positive')
# **************************************************
# very good hotel his service hotel is excellent floors of all rooms ceramics and this thing is a big disadvantage there is no distinction room features the presence of a club and spa more than wonderful and close to restaurants from it
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'good', 'positive')
# **************************************************
# the breakfast buffet was well chosen; the evening meals were very good and were on demand. the buffet was not very exciting.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('buffet', 'exciting', 'negative')
# ('meals', 'good', 'positive')
# **************************************************
# the hotel is very clean and the spa is very wonderful and the breakfast is the most beautiful meal and all the staff have taste and enjoy the civility can spend the whole day inside it without the need to go out and the system of eating meals is excellent. but more attention must be paid to the swimming pool
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('meals', 'excellent', 'positive')
# **************************************************
# the rooms are well furnished. the kitchen space is very good.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('kitchen space', 'good', 'positive')
# ('rooms', 'well', 'neutral')
# **************************************************
# great days in laguna vista very excellent service - rooms at the top in the clean - high ceiling with high experience - excellent comfort - landscape management very understanding - swimming pools very clean and spacious -
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'excellent', 'positive')
# **************************************************
# i liked the cleanliness of the hotel and the good treatment of the workers there and i enjoyed the beach and bisin in terms of the wonderful atmosphere and cleanliness and enjoyed the parties there
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'good', 'positive')
# **************************************************
# and the restaurant is clean. but eating is required. it's varied and has a distinct flavor.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('restaurant', 'clean', 'positive')
# **************************************************
# with a mini-fridge. a wardrobe. and a mini-toilet.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# reception is great. rooms are perfect. size is clean. service is fast.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('reception', 'great', 'positive')
# ('rooms', 'perfect', 'positive')
# ('size', 'clean', 'positive')
# **************************************************
# a yemeni tourist is a beautiful hotel whose services are suitable for its price excellent room comfortable bathroom excellent breakfast also very good wholesale the hotel is very suitable and has no obvious defect
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'beautiful', 'positive')
# **************************************************
# he explained the hotel facilities and advised the restaurants and the health club.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the most beautiful place in egypt is one of the most beautiful places where you and your family can enjoy a beautiful place to do
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'beautiful', 'positive')
# **************************************************
# if you can’t sleep at night or nap during the day. your room is right on the bar area so there’s no escape and after a day or so you’ll want to escape.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('room', 'no', 'positive')
# **************************************************
# the restaurant is characterized by a beautiful view of the sea and a concern for cleanliness and the taste of beautiful food. many thanks to professor shirin al-bukhari and the entire staff of the hotel
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'thanks', 'positive')
# ('restaurant', 'beautiful', 'positive')
# **************************************************
# apart from it. it is an excellent hotel and very elegant. well received. and its service is excellent. the rooms are beautiful and well equipped and has a good breakfast.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'excellent', 'positive')
# ('rooms', 'beautiful', 'positive')
# ('service', 'excellent', 'positive')
# **************************************************
# which made a good impact. the cleanliness of the rooms was at the top. the food was preserved but of good quality. a special tribute to mohammed amer at the main restaurant who did his best in helping us. we definitely recommend this hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('cleanliness', 'top', 'positive')
# ('food', 'good', 'positive')
# ('hotel', 'recommend', 'neutral')
# ('impact', 'good', 'positive')
# ('restaurant', 'best', 'positive')
# **************************************************
# good arrangement for a passing stop i used this hotel as a casual stay in dubai while travelling on emirates. the arrangements are generally good. the transfer goes smoothly. the arrangements at the hotel are good. your meal allowance is offered according to your flight schedule. the hotel is clean. the food is good and the assortment is extensive. a good place to relax when traveling on a long trip.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'good', 'positive')
# ('hotel', 'good', 'positive')
# ('hotel', 'casual', 'positive')
# ('hotel', 'clean', 'positive')
# ('place', 'good', 'positive')
# **************************************************
# bathtubs. no rinsing.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# good hotel by my work i visited this hotel several times during the months of march and april 2013... is more than a good hotel... the service is distinctive and all the workers are very cooperative.... modern design. and feel familiar in your home.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'good', 'positive')
# **************************************************
# excellent location and good value we stayed here for two nights after arriving late in the evening.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'excellent', 'positive')
# **************************************************
# hotel management and staff are more than excellent - excellent security guards - restaurant. bar and club are really great - i have never seen better than that hotel in addis ababa
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'better', 'positive')
# **************************************************
# fun stay for children and parents near disneyland paris. a good economic space for children. already clean.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('stay', 'fun', 'positive')
# **************************************************
# very excellent apartments very very excellent apartments with modern and clean furniture. excellent location beautiful reception a quiet area away from the hustle and bustle of the city excellent and integrated kitchen and full furnishing.. i will stay there again. god willing.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('furniture', 'clean', 'positive')
# ('location', 'excellent', 'positive')
# **************************************************
# the hotel is located in a privileged location. close to the train station. approximately 5 minutes on foot and very close to the main river.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'privileged', 'neutral')
# **************************************************
# high-level service with the finest details in mind. which helped me to relax. recuperate and save the most beautiful memories in this resort
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('resort', 'beautiful', 'positive')
# ('service', 'finest', 'neutral')
# **************************************************
# a wonderful team headed by mr. hassan attia denmo hotel and an excellent entertainment team and a wonderful reception from the reception team and the beautiful stranger that you can meet mr. hassan everywhere to the extent that you are afraid to ride my arabic goa
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('team', 'wonderful', 'positive')
# **************************************************
# and the rooms are beautiful and the view of the rooms was wonderful and the food was delicious and varied and beautiful and i will invite friends and colleagues to visit this wonderful place and enjoy the gardens and mountains and the view of the sunrise and sunset like no other.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'delicious', 'positive')
# **************************************************
# the reception's slow. i've been waiting almost four hours.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# don’t even think about staying at the crystal hotel. this hotel is not worth any star as well as 3 stars.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'worth', 'negative')
# **************************************************
# the bathroom tiles are broken. the surroundings of the bathroom sink are old. the roads are dark. on saturday night this place looked terrifying...save your money.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'broken', 'negative')
# ('place', 'terrifying', 'neutral')
# **************************************************
# great hotel at a great price! this was the best hotel we had seen in three weeks in italy. not only was it great and centrally located with a very helpful staff but the room had the amenities travelers needed – a large. very spacious storage space. hanger. light switches. a well-functioning air conditioner. etc. check out the bulletin board in the lobby with guest compliments.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'great', 'positive')
# ('hotel', 'best', 'positive')
# ('staff', 'helpful', 'positive')
# **************************************************
# a very dirty and noisy hotel. the location is good. as it is a 15-minute walk to the old city. however. the place is very noisy. as it is located right next to the construction site. the noise starts from 07.00 am to 20.00 pm.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'noisy', 'negative')
# ('location', 'good', 'positive')
# ('place', 'noisy', 'positive')
# **************************************************
# i stayed three nights in december three years ago. and the hotel had only one breakfast restaurant. and the price was very high for the double room and breakfast buffet as well.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# comfort and luxury pleasure honestly from the finest doha hotels at all in terms of comfort and cleanliness and guest service and good furniture and strategic place and at a great price. i recommend it and thank ms. raneem for her manners and great dealings. which did not fall short with us in extending our stay to the time of the afternoon and also thank all the staff for the spaciousness of their chest
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('manners', 'great', 'positive')
# ('service', 'good', 'positive')
# ('staff', 'thank', 'neutral')
# **************************************************
# good enough but not great team work - nice. the room - is fine but not up to three stars.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('room', 'fine', 'positive')
# **************************************************
# and its only advantage is the size of the unit is large and the prices are good but it never made me happy i heard that there is a new administration that will take over and until then make comprehensive improvements in everything that is not recommended at all
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('prices', 'good', 'positive')
# **************************************************
# but the view is normal. the rooms are well taken care of.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'well', 'neutral')
# **************************************************
# beautiful location and beautiful grounds. great swimming pool. you even get a free breakfast.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'beautiful', 'positive')
# ('pool', 'great', 'positive')
# **************************************************
# breakfast is very poor: the buffet cannot be found.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('buffet', 'poor', 'negative')
# **************************************************
# rooms are suites and not standard rooms like the rest of the hotels. (two rooms separated by a door)
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'like', 'neutral')
# **************************************************
# the staff is very helpful and nice. the apartments are modern and well equipped. as well as the wonderful location in the heart of taksim at an attractive price. i will not lose any effort on my next visit because i found the right place
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'wonderful', 'positive')
# ('place', 'lose', 'positive')
# ('staff', 'helpful', 'positive')
# **************************************************
# the owner of the hotel is a good man. he's very nervous and incomprehensive.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'good', 'positive')
# **************************************************
# it's a real mess. the staff is completely unprofessional. i've been there five days in the hotel with a new problem every day.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'problem', 'positive')
# **************************************************
# the hotel staff all speak egyptian. feel yourself in your country. and always laugh at their forgiving faces.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('faces', 'laugh', 'positive')
# **************************************************
# disgusting. i only spent two nights in this hotel. the rooms were so filthy.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the staff of the bar are excellent especially mohammed and ahmed who unfortunately left. entertainment zero... the amusement team is excellent when they were allowed to mingle with the guests!!
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('staff', 'excellent', 'positive')
# ('team', 'amusement', 'positive')
# **************************************************
# excellent hotel. excellent hotel in all respects.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'excellent', 'positive')
# **************************************************
# a hotel that lacks the lowest degrees of tourism. it is a dirt address in its rooms and services and food even utensils where they serve food is not washed and leftovers of food and previous drinking.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'dirt', 'negative')
# ('hotel', 'lowest', 'neutral')
# **************************************************
# i'm starting to smell smoke all over the floor. and my mom's really upset about it.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('mom', 'upset', 'positive')
# **************************************************
# and the room's view of a swamp of green water.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# very beautiful place. excellent service and a great location the place is beautiful and requests on lake jeddah directly close to all places in jeddah all services are available
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'great', 'positive')
# ('place', 'beautiful', 'positive')
# **************************************************
# the food selection is good. clean and excellent. the views are great. and the markets and restaurants are plentiful.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food selection', 'good', 'positive')
# ('views', 'great', 'positive')
# **************************************************
# the most luxurious thing in the lobby was the black and white photos of the opening day in 1977.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the hotel staff were friendly. the rooms were great and the food was special. our stay was upgraded to a better room.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'special', 'positive')
# ('room', 'better', 'positive')
# **************************************************
# nice hotel. but the adaptation problem. the hotel's location is excellent. it has a private beach and a nice swimming pool.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('adaptation', 'problem', 'neutral')
# ('hotel', 'nice', 'positive')
# ('hotel', 'excellent', 'positive')
# ('pool', 'nice', 'positive')
# **************************************************
# the hotel staff is not helpful at all. except that the person at the reception was called ashraf. he was the best person in them. i'm egyptian. but honestly this hotel is a bad picture of egypt. don't go there.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'honestly', 'negative')
# ('person', 'best', 'positive')
# **************************************************
# the room is very clean but the breakfast is very bad.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('room', 'clean', 'negative')
# **************************************************
# my advice to you if you are booking this hotel is to cancel your booking or cancel the entire trip if you can't. experienced advice
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'cancel', 'neutral')
# **************************************************
# the hotel is a little small. but the design is great. the rooms are good and comfortable. and the upper pool on the sixth floor is also small.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('design', 'great', 'positive')
# ('rooms', 'good', 'positive')
# **************************************************
# inexpensive hotel. poor but nice hotel staff
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# it's the worst hotel i've ever lived in. ruined bathrooms. contaminated water. a broken crib. a broken phone. no internet.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'ruined', 'neutral')
# ('hotel', 'worst', 'negative')
# ('internet', 'no', 'neutral')
# **************************************************
# the beach is excellent. but it's not clean.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('beach', 'excellent', 'positive')
# **************************************************
# receptionists and restaurant staff are not friendly. but without going beyond (most guests can be egyptian) eating poorly.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('eating', 'poorly', 'positive')
# ('receptionists', 'friendly', 'negative')
# **************************************************
# filters are not working and of course food is useful only for non-humans.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'useful', 'positive')
# **************************************************
# the room is clean but has very modest facilities.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('facilities', 'clean', 'positive')
# **************************************************
# the pool was large and rudderless. the service around the pool was excellent.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pool', 'excellent', 'positive')
# **************************************************
# nice hotel. the hotel is really nice. and people have very good taste. the place is close to everything. and the swimming pools are sweet. and the price for the place is really nice.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'nice', 'positive')
# ('pool', 'sweet', 'positive')
# **************************************************
# i visited many hotels in the kingdom and abroad and did not leave a beautiful stamp of this experience i have never seen such treatment and service before in terms of speed of response and quality and service paper
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'beautiful', 'positive')
# **************************************************
# this is the best hotel i’ve ever stayed at in terms of management. i enjoyed it and i was treated well. and the staff was attentive and happy.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'best', 'positive')
# ('staff', 'happy', 'positive')
# **************************************************
# the staff is friendly and seeks the need of the inmate and feels that he has priority in everything i thank both mr. issa daoud and mr. awad al-zahrani for professionalism in the way of dealing
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('staff', 'friendly', 'positive')
# **************************************************
# we waited in the morning to change the hotel. the ruins are not beautiful. the furniture is very old. and the equipment in the room is also old.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# a good modern hotel is worth every clean. bright and beautiful penny. a really great hotel to stay in. the rooms are very clean. and breakfast on the top floor (or roof) was a real delight. i recommend it 100%.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'great', 'positive')
# ('hotel', 'good', 'positive')
# ('rooms', 'clean', 'positive')
# **************************************************
# please avoid this hotel. it is expensive. and the service does not meet the standards of a three-star hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'avoid', 'neutral')
# **************************************************
# the rooms are spacious. tidy and clean and the service is great but the lobby is very small and the price is very good and not high
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'great', 'positive')
# **************************************************
# restaurants are very good. if you are in alexandria. this is the place to stay. no nasty surprises here at four seasons hotel. the service is good.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'nasty', 'positive')
# ('restaurant', 'good', 'positive')
# ('service', 'good', 'positive')
# **************************************************
# i honestly thought my stay was fun. but i was surprised that even though i was a guest. i wasn't allowed to watch tv in the bar or restaurant without asking for food or drink. i found this strange.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('stay', 'fun', 'positive')
# **************************************************
# the hotel is a little small. but the design is great. the rooms are good and comfortable. and the upper pool on the sixth floor is also small.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('design', 'great', 'positive')
# ('rooms', 'good', 'positive')
# **************************************************
# the beach view is an added advantage. the facilities are clean without complaints. and the restaurants are very nice. especially the olio restaurant. which makes italian pizza in an oven with wood fuel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('beach view', 'advantage', 'neutral')
# ('facilities', 'clean', 'positive')
# ('restaurant', 'nice', 'positive')
# **************************************************
# and the air conditioner doesn't work (thankfully we were in the fall. so the window could have opened). it's worth staying in it for the off-peak season. breakfast and parking are fine.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('parking', 'fine', 'positive')
# ('stay', 'worth', 'positive')
# **************************************************
# overall. the hotel is good for its price in dubai. but compared to istanbul's four-star hotels. this hotel is a star.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'good', 'positive')
# **************************************************
# i stayed there for three days. and this was my worst experience! i'm sure i'll never choose this hotel again! it was horrible!
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('experience', 'worst', 'negative')
# ('hotel', 'sure', 'positive')
# **************************************************
# we chose anacato to rest for a while on our way to abu simbel. the hotel is in a great location on the nile.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'great', 'positive')
# **************************************************
# but the room was fine. clean and the bed wasn't so bad and the food was too.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'bad', 'negative')
# ('room', 'fine', 'positive')
# **************************************************
# there is no elevator and the stairs are too narrow (one needs a small foot to be able to climb up or stand on one's side.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('elevator', 'no', 'positive')
# **************************************************
# the hotel is simple and its design is wonderful and suitable for young people. breakfast did not include in the price of the room. but it was wonderful and cheap to type 40 saudi riyals per person.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'wonderful', 'positive')
# ('saudi riyals', 'wonderful', 'positive')
# **************************************************
# quality for the price for the city of alexandria from the best hotels at this price and the price paid is appropriate
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the front desk and the phone workers are uncooperative.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# a bad hotel. a hotel that works without running cleaning equipment just for the first day. and then everything was pulled. and the tv broke my stay. no internet repair. bad door key. always broken room service. receiving a call. but without the help of a lot of missing services in this hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('door key', 'bad', 'negative')
# ('hotel', 'bad', 'negative')
# ('internet repair', 'no', 'neutral')
# ('room', 'broken', 'negative')
# ('service', 'help', 'negative')
# **************************************************
# they gave me a bad service. check-out at other hotels is at 3:00 p.m. but here it should be at 12:00 p.m.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'bad', 'negative')
# **************************************************
# but his furniture is very bad and the family is dirty and worn with stains and dirt. and the breakfast room is very small and the quality of breakfast is bad. it is a collection of cheese. bread. juice and pieces of meat
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('furniture', 'dirty', 'negative')
# **************************************************
# the sea view. the shower area. the secluded horticulture all add value to this facility. and i’m sure there’s no other place like this on the island!!!
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'like', 'positive')
# **************************************************
# good value. but the hotel is clean. and the staff is happy. near the metro station sisli and jawaher mall and close to a large range of shops and close to the american hospital. semi-new furniture opportunities to walk to taksim square.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('furniture', 'opportunities', 'neutral')
# ('hotel', 'clean', 'positive')
# ('staff', 'happy', 'positive')
# **************************************************
# i wish more progress for the staff of this wonderful hotel and more progress. god willing. and i will definitely return.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'wonderful', 'positive')
# **************************************************
# transportation is very expensive from the airport. $50 and $35 for breakfast. there are good restaurants near the hotel. there is a japanese restaurant on the front and another chinese restaurant near a back street. but the casino attracts empty and shallow people. loud-mouthed whores beat the dirty streets right next to the hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('casino', 'empty', 'negative')
# ('hotel', 'dirty', 'negative')
# ('restaurant', 'good', 'positive')
# **************************************************
# a self-respecting person will not repeat the visit because the hotel has prostitutes sitting in the halls and in the garden and everywhere. so they follow you to the rooms after they have finished their task in one of the rooms with customers and this is happening in front of the management and security of the hotel. the painful thing is that any guest of the hotel becomes like a seeker for this
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'like', 'negative')
# ('rooms', 'security', 'neutral')
# **************************************************
# the hotel was very nice. the hotel is well-received and clean. the staff is very cooperative and keen to serve you. the food is varied and tastes great. and there are foods to suit all tastes.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'great', 'positive')
# ('hotel', 'nice', 'positive')
# ('hotel', 'clean', 'positive')
# ('staff', 'keen', 'positive')
# **************************************************
# i will repeat the experience again. god willing.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# as well as when you enter the hotel you move to another world of luxury and comfort starts the morning with the smile of all employees and the calmness of the place and the splendor of breakfast and the variety of food options and the professionalism of chefs and super fast to meet your needs and all your needs
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'splendor', 'positive')
# **************************************************
# medium service hotel i liked very much the site. the quality of service and cleanliness is medium. commensurate with the price. frankly a suitable choice for those with a medium budget to spend a long time without high cost rooms and furniture in need of some renovation some noise due to the night cans and the lack of fence surrounding the hotel and yet spent a beautiful week in the hotel
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'lack', 'positive')
# ('service', 'liked', 'positive')
# **************************************************
# the food sucks.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'sucks', 'negative')
# **************************************************
# the staff is great. and the location is excellent. what else can i say? the train station is at the end of the street and there are fast food places where children will eat their food in peace.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'excellent', 'positive')
# ('staff', 'great', 'positive')
# **************************************************
# beautiful hotel ratings top reception workers in taste excellent room service
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the swimming pool is in dire need of daily cleaning and if you were travelling with children i would complain if it was too hot and we couldn’t swim in such a dirty pool. air conditioning and mini fridge work well. we will come back again but call in advance and make sure the pool is cleaned.....
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('conditioning', 'well', 'neutral')
# ('pool', 'dire', 'negative')
# ('pool', 'sure', 'positive')
# **************************************************
# the restaurant is special. delivery of food to the rooms is very special. the bed is comfortable. the bathroom is at the highest level.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'special', 'positive')
# ('restaurant', 'special', 'positive')
# **************************************************
# food is clean but limited and average quality the hotel is attached to the mall and has all the shops. restaurants and pharmacy the hotel is attached to a market with excellent prices and cheaper than cairo the swimming pool is clean
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'clean', 'positive')
# ('prices', 'excellent', 'positive')
# **************************************************
# and the service sucks.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'sucks', 'negative')
# **************************************************
# and its only advantage is the size of the unit is large and the prices are good but it never made me happy i heard that there is a new administration that will take over and until then make comprehensive improvements in everything that is not recommended at all
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('prices', 'good', 'positive')
# **************************************************
# perfect weekend getaway!. outstanding location for city attractions. spacious rooms. small but very good pool with jacuzzi and sauna. as well as spa la prairie. egg dish benedict with champagne at breakfast and live piano playing bar at night is the beating heart of city life! we got the perfect vacation! highly recommended!!
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'attractions', 'positive')
# ('pool', 'good', 'positive')
# ('spa la prairie', 'well', 'neutral')
# **************************************************
# the security level is very high where you can only access with the apartment key or a secret number. the internet is very fast and wonderful as the free card provides zelamsi and cabron there is no cleaning service. but there are two manual vacuum cleaners
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('internet', 'wonderful', 'positive')
# **************************************************
# the worst service i got in a decade! the site is awesome! the weekend price is good.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'worst', 'negative')
# ('site', 'awesome', 'positive')
# **************************************************
# great view and nice location.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'nice', 'positive')
# **************************************************
# the worst service i got in a decade! the site is awesome! the weekend price is good.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'worst', 'negative')
# ('site', 'awesome', 'positive')
# **************************************************
# the room and the bathroom are so old and dirty i'm not booking this hotel again.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'dirty', 'negative')
# **************************************************
# to the esteemed hotel management... there is a distinctive qualitative shift in the level of service and the extent of improvement observed from the previous year in terms of the high style of employees and supervisors all such as jamal manaseer
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'esteemed', 'negative')
# **************************************************
# and soon the maintenance staff was named alaa. i think. he ended the problem. as for the food and his service. it was one of the most distinctive services provided by the resort.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# but the service is very weak. and any request needs to be repeated more than once to implement it.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'weak', 'negative')
# **************************************************
# message of thanks to the management of the fairmont hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('management', 'thanks', 'positive')
# **************************************************
# ...
# also. my cell phone was stolen from room service workers. and unfortunately. even the manager couldn't do anything.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'stolen', 'neutral')
# **************************************************
# our room was well furnished and the design was fine. except the floors were dirty. all the floors in the kitchens and bathrooms are dirty.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathrooms', 'dirty', 'negative')
# ('floors', 'dirty', 'negative')
# ('room', 'well', 'positive')
# **************************************************
# breakfast at lotus hotel has been updated recently. hot water is available in the morning and evening in moderation. my advice to you is always to ask for a renovated room on the back of the hotel that is quiet during the night.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# and a good breakfast buffet.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# i swear by almighty god that i do not miss it. but in order not to be located in this hotel what i signed in and to be honest that the good of this hotel is breakfast and that it is near the sanctuary. date of my stay in this hotel 9 june 2013
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('almighty', 'god', 'neutral')
# ('hotel', 'honest', 'positive')
# **************************************************
# and breakfast was good. and i stayed in a studio apartment. and it was a big. family-friendly space.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# good service and excellent breakfast good service and excellent breakfast the hotel is located close to all means of transport and markets in the center of istanbul and the rooms overlooking the bosphorus have a distinctive view but a little narrow and do not forget to experience the turkish bath in the health club
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'good', 'positive')
# **************************************************
# my stay in the hotel is more than a wonderful hotel beautiful with it is close to the prophet's mosque easy communication and service rooms are very beautiful i like the most wall paintings that have the names of god beautiful psychological comfort in the hotel but the moket is bad in proportion to the restaurant service in the restaurant was very wonderful dinner period
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'wonderful', 'positive')
# **************************************************
# the food was mostly out there. it was a nice trip. and i hope to visit again.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the downsides are that there is no free internet in the rooms. no signs of discomfort on the doors.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('internet', 'free', 'negative')
# **************************************************
# poor service and clean rooms. poor reception staff. ignoring the visitor and not solving problems. i waited for room service 8 hours to come to the suite after calling for more than 10 times. i was complained without any feasibility or apology. the season may have a reason to do so.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'clean', 'negative')
# ('visitor', 'solving', 'neutral')
# **************************************************
# the club is just the special... and the bathroom tower restaurant is special.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('restaurant', 'special', 'positive')
# **************************************************
# hotel 7 star :)))) habeeto ktiyeyer hotel is more than wonderful :))) and the room service is excellent and the rooms are very very luxurious and the view is very beautiful from all sides and the atmosphere is beautiful and really enjoyed very calm and beauty and clean and service and really they were the most beautiful 3 days vacation and we enjoyed the parties in the evening and the overall view in the evening was a masterpiece and more than wonderful food:)
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'excellent', 'positive')
# **************************************************
# there is also a designated place for regular and special taxi...
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# the hotel's accommodation is beautiful and breakfast is over a rooftop terrace and their breakfast is sweet and varied and close to tourist places sultanahmet mosque and hagia sophia 3 minutes walk a lot and grand bazaar 5 minutes walk the hotel is sweet and affordable. but i recommend that the libyan resident to take a limousine from the airport to the hotel door because the location of mo is clear to tikasi drivers.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('location', 'clear', 'positive')
# **************************************************
# and the receptionists get extra money on the grounds that it's for the hotel to get rooms overlooking the campus. even though i paid for it.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# small room. shared bathroom on the stairs (the door wasn't locked).
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'shared', 'neutral')
# **************************************************
# moataz stayed at the hotel from 1636 until 1633 until 1632. and i'm still here.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# coral fursan resort - the best place to stay when you're on fursan island i assume it's the best place to stay with both options available. whether a room or a chalet.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# beautiful hotel but the hotel is wonderful and all the need is sweet in the hotel company called golden d company is not good. rhett people are dealing with her because if you booked with her a number 2 flight 1 boat trip was worn out and the price was very expensive 2 dolphin offer was 100 per person and the price per person in the same offer 35 knowing that it is close to the hotel management talked to the company and said that they will be liquidated dealing with rhet
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'beautiful', 'positive')
# **************************************************
# frankly i mean i do not regret my stay in the hotel and god willing next year and answer the mother with me and by the way i want to thank miss names for her temperament and humility and thank you all
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'god', 'negative')
# **************************************************
# breakfast is good and well-positioned. we had some high-heating notes. and some customers don't take care of public taste. and the hotel doesn't deter such acts.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# great place. just a 10-minute walk from prince street. the bus station is very close if you don't want the hassle of walking. i won't hesitate to come back.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('i', 'hesitate', 'neutral')
# ('place', 'great', 'positive')
# **************************************************
# an unsafe place i spent seven days on a family vacation here and although the rooms were good. the rooms were dirty. the glass could barely see through it. and the worst of it was that we lost an expensive camera and some other things. and the administration didn’t pay much attention and the police failed to find out who did it even though it was clear that the only people able to get in were the room servicers.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('camera', 'lost', 'negative')
# ('rooms', 'dirty', 'negative')
# ('rooms', 'good', 'positive')
# ('servicers', 'clear', 'positive')
# **************************************************
# they made a good breakfast. but there was a dance club. which was creating a stir and a nuisance even though i stayed on the fourth floor and also the hotel a little bit away from the metro station. 10-15 minutes of walking. it's not very comfortable to walk in hot weather.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'nuisance', 'negative')
# ('weather', 'comfortable', 'positive')
# **************************************************
# the prices are high but the privacy we got worth that massage experience sweet privacy is what distinguishes them and the collar is very beautiful. but snorkeling is something very fun thanks barros
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('prices', 'worth', 'positive')
# ('snorkeling', 'fun', 'positive')
# **************************************************
# defect of the hotel during certain seasons. as well as the entry of the cleaning crew to clean the room despite the sign not to disturb
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'certain', 'positive')
# ('room', 'clean', 'positive')
# **************************************************
# and i hope to keep a price that attracts a lot of tourists to the hotel.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'hope', 'neutral')
# **************************************************
# the distance between the hotel and the taj is a short walk to the tuk tuk. i couldn’t actually see a crown from the roof because of the fog. but you should! it doesn’t look very good from the outside – just a regular modern hotel. but it was a pleasant surprise on entry.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('entry', 'pleasant', 'positive')
# ('hotel', 'good', 'positive')
# **************************************************
# enter the restaurant and show a mandhmsh limit that touches the empty dishes etni limit as far as i pass and i'm a child ask for a comment no. before leaving at 12:30. order a cup of cappuccino reply to the gentleman in the bar in front of the restaurant no. you're not sure i'd say that taste of you and say that even a minute is not a gift people very taste in his tongue a human almost tasteless was made of weak blood
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('restaurant', 'empty', 'neutral')
# ('restaurant', 'no', 'neutral')
# ('taste', 'sure', 'negative')
# **************************************************
# drinks arrive at the door of the room if you want to trouble the rooms that the family is small
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'trouble', 'negative')
# **************************************************
# the hotel is nice and clean and family first class and the hotel is close to the market. but the hotel staff are all treated very high respect for the guest
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'nice', 'positive')
# **************************************************
# a very reasonable hotel for hotel apartments is a very reasonable place close to the metro. airport and shopping center city centre deira. but it is possible to classify 1635; four stars mesh breakfast to some extent is not luxurious but
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# all the staff we've dealt with during our stay have been pretty friendly and welcoming. receptionists. waiters. cooks. housekeepers plus life guards.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('staff', 'pretty', 'positive')
# **************************************************
# the hotel is great in terms of location. the beach is excellent. the sea is very beautiful. the beach is above excellent and the team is very cooperative.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('beach', 'excellent', 'positive')
# ('hotel', 'great', 'positive')
# ('sea', 'beautiful', 'positive')
# **************************************************
# the hotel is a little small. but the design is great. the rooms are good and comfortable. and the upper pool on the sixth floor is also small.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('design', 'great', 'positive')
# ('rooms', 'good', 'positive')
# **************************************************
# i can't imagine a five-star hotel with such a horrible level of cleanliness.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'horrible', 'negative')
# **************************************************
# there's no cleanliness in the rooms. and the faucet in the bathroom doesn't work.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rooms', 'no', 'neutral')
# **************************************************
# the resort is very clean and the service is above excellent and the reception has been a lot of attention.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'clean', 'positive')
# **************************************************
# beautiful hotel and great location i stayed in this hotel for five days was beautiful and wonderful and everything you need is within the hotel area of services. barber and cafs. the hotel is very clean and the staff is good and the kitchen is equipped with most of the needs of the guest.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('hotel', 'clean', 'positive')
# ('hotel', 'beautiful', 'positive')
# **************************************************
# and the food is awful sometimes.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'awful', 'negative')
# **************************************************
# the fungus comes out of the vent. the slurry in the bathroom is also covered with mold. it looked like a white tile with a cloudy black-and-brown slurry. we stayed 3 days and a wet towel remained on the shower rack the whole time will not spend 200 euros on a room like this again
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('room', 'like', 'positive')
# ('tile', 'like', 'neutral')
# **************************************************
# and the shower filter couldn't have closed properly.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# **************************************************
# other than that i was already satisfied with the services in general as well as the prices compared to other old resorts nearby.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('prices', 'well', 'positive')
# **************************************************
# and the bathrooms are fine for breakfast. nice. nice dinner. and the people at palmyra are very respectable and very helpful.
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'fine', 'positive')
# ('dinner', 'nice', 'positive')
# ('people', 'respectable', 'positive')
# **************************************************

# %% [markdown]
# # Test de generalisation sur un dataset de triplet

# %%
dataset  = load_dataset('NEUDM/aste-data-v2', 'default')
# Out:
# Downloading data:   0%|          | 0.00/2.86M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/694k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.15M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
dataset_df = pd.DataFrame(dataset['test'])

# %%
dataset_df
# Out:
#        task_type       dataset  \
# 0     generation  aste-data-v2
# 1     generation  aste-data-v2
# 2     generation  aste-data-v2
# 3     generation  aste-data-v2
# 4     generation  aste-data-v2
# ...          ...           ...
# 1463  generation  aste-data-v2
# 1464  generation  aste-data-v2
# 1465  generation  aste-data-v2
# 1466  generation  aste-data-v2
# 1467  generation  aste-data-v2
#
#                                                   input  \
# 0     [Boot time is super fast , around anywhere fro...
# 1     [tech support would not fix the problem unless...
# 2                                   [Set up was easy .]
# 3     [Did not enjoy the new Windows 8 and touchscre...
# 4     [Other than not being a fan of click pads ( in...
# ...                                                 ...
# 1463  [My friend enjoyed the grilled Alaskan King Sa...
# 1464  [I had a taste of all three items on her plate...
# 1465  [Our server continued to be attentive througho...
# 1466  [While I could have done without the youth who...
# 1467            [Oh yeah ... the view was good , too .]
#
#                                                  output situation label extra  \
# 0                   [['Boot time', 'fast', 'positive']]      none
# 1             [['tech support', 'not fix', 'negative']]      none
# 2                      [['Set up', 'easy', 'positive']]      none
# 3     [['Windows 8', 'not enjoy', 'negative'], ['tou...      none
# 4          [['internal speakers', 'lousy', 'negative']]      none
# ...                                                 ...       ...   ...   ...
# 1463  [['grilled Alaskan King Salmon', 'enjoyed', 'p...      none
# 1464                  [['plate', 'superb', 'positive']]      none
# 1465  [['server', 'attentive', 'positive'], ["Ray 's...      none
# 1466  [['server', 'wonderful', 'positive'], ['food',...      none
# 1467                     [['view', 'good', 'positive']]      none
#
#                                             instruction
# 0     Task: Extracting aspect terms ,their opinion w...
# 1     Task: Extracting aspect terms ,their opinion w...
# 2     Task: Extracting aspect terms ,their opinion w...
# 3     Task: Extracting aspect terms ,their opinion w...
# 4     Task: Extracting aspect terms ,their opinion w...
# ...                                                 ...
# 1463  Task: Extracting aspect terms ,their opinion w...
# 1464  Task: Extracting aspect terms ,their opinion w...
# 1465  Task: Extracting aspect terms ,their opinion w...
# 1466  Task: Extracting aspect terms ,their opinion w...
# 1467  Task: Extracting aspect terms ,their opinion w...
#
# [1468 rows x 8 columns]

# %%
input_texts=["oh speaking of bathroom. the mens bathroom was disgusting.","The dessert ( we had a pear torte ) was good  but. once again. the staff was unable to provide appropriate drink suggestions.","The dining experience was relaxing and enjoyable.","The pastries were flaky, buttery, and delightful.","The staff made us feel very welcome.","The smoothies were fresh and perfectly blended."]
for input_text in input_texts:
    text_sans_virgules = input_text.replace(',', '.')
    phrases = sent_tokenize(text_sans_virgules)
    predictions_par_phrase = []
    # prediction = generate_single_prediction(model, tokenizer, input_text, max_length=150)
    print("*"*50)
    print("text :", text_sans_virgules)
    print("-"*50)
    for phrase in phrases:
        prediction = generate_single_prediction(model, tokenizer, phrase, max_length=150)
        parsed_output = parse_model_output(prediction)
        predictions_par_phrase.append(parsed_output)

        print("Phrase:", phrase)
        print("Prediction:", prediction)
        # print("-"*50)

    aspect_opinion_sentiments = []

    for prediction in predictions_par_phrase:
        for phrase in phrases:
            aspects_to_use = [prediction["main_aspect"]] if prediction["main_aspect"] and prediction["main_aspect"] != "nan" else prediction["extracted_aspects"]
            for aspect in aspects_to_use:
                if aspect in phrase:
                    closest_opinion = find_closest_opinion(phrase, aspect, prediction["extracted_opinions"])
                    if closest_opinion and aspect != closest_opinion:
                        sentiment = analyze_sentiment(phrase)
                        aspect_opinion_sentiments.append((aspect, closest_opinion, sentiment))


    aspect_opinion_sentiments = list(set(aspect_opinion_sentiments))
    sorted_aspect_opinion_sentiments = sorted(aspect_opinion_sentiments, key=lambda x: x[0])


    print("-"*50)
    print("Aspect-Opinion Sentiments:")
    for tup in sorted_aspect_opinion_sentiments:
        print(tup)
    print("-"*50)

    print("*"*50)
# Out:
# **************************************************
# text : oh speaking of bathroom. the mens bathroom was disgusting.
# --------------------------------------------------
# Phrase: oh speaking of bathroom.
# Prediction: main aspect: bathroom extracted aspects: bathroom extracted opinions: neutral global polarity: negative
# Phrase: the mens bathroom was disgusting.
# Prediction: main aspect: bathroom extracted aspects: bathroom, mens extracted opinions: disgusting global polarity: negative
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'disgusting', 'negative')
# --------------------------------------------------
# **************************************************
# **************************************************
# text : The dessert ( we had a pear torte ) was good  but. once again. the staff was unable to provide appropriate drink suggestions.
# --------------------------------------------------
# Phrase: The dessert ( we had a pear torte ) was good  but.
# Prediction: main aspect: dessert extracted aspects: dessert, torte extracted opinions: good global polarity: positive
# Phrase: once again.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# Phrase: the staff was unable to provide appropriate drink suggestions.
# Prediction: main aspect: staff extracted aspects: suggestions, drink, staff extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dessert', 'good', 'positive')
# --------------------------------------------------
# **************************************************
# **************************************************
# text : The dining experience was relaxing and enjoyable.
# --------------------------------------------------
# Phrase: The dining experience was relaxing and enjoyable.
# Prediction: main aspect: dining experience extracted aspects: dining experience, dining, experience extracted opinions: relaxing, enjoyable global polarity: positive
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dining experience', 'relaxing', 'positive')
# --------------------------------------------------
# **************************************************
# **************************************************
# text : The pastries were flaky. buttery. and delightful.
# --------------------------------------------------
# Phrase: The pastries were flaky.
# Prediction: main aspect: pastries extracted aspects: pastries extracted opinions: neutral global polarity: negative
# Phrase: buttery.
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# Phrase: and delightful.
# Prediction: main aspect: nan extracted aspects: extracted opinions: delightful global polarity: neutral
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# **************************************************
# **************************************************
# text : The staff made us feel very welcome.
# --------------------------------------------------
# Phrase: The staff made us feel very welcome.
# Prediction: main aspect: staff extracted aspects: staff extracted opinions: welcome global polarity: positive
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('staff', 'welcome', 'positive')
# --------------------------------------------------
# **************************************************
# **************************************************
# text : The smoothies were fresh and perfectly blended.
# --------------------------------------------------
# Phrase: The smoothies were fresh and perfectly blended.
# Prediction: main aspect: smoothies extracted aspects: smoothies extracted opinions: perfectly global polarity: positive
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('smoothies', 'perfectly', 'positive')
# --------------------------------------------------
# **************************************************

# %%
outputs = []
sentences =[]
triplets =[]
for index, row in dataset_df.iterrows():
    # Générer la prédiction pour le texte courant
    # print(row["input"][0])
    text_sans_virgules = row["input"][0].replace(',', '.')
    phrases = sent_tokenize(text_sans_virgules)
    predictions_par_phrase = []
    # prediction = generate_single_prediction(model, tokenizer, row["input"][0], max_length=150)
    print("*"*50)
    print("text :", text_sans_virgules)
    for phrase in phrases:
        prediction = generate_single_prediction(model, tokenizer, phrase, max_length=150)
        parsed_output = parse_model_output(prediction)
        predictions_par_phrase.append(parsed_output)

        print("Phrase:", phrase)
        print("Prediction:", prediction)
        print("-"*50)
    # print("-"*50)
    # print("Text:", row["input"][0])
    # print("Prediction:", prediction)
    triplet_list = ast.literal_eval( row["output"])
    print("Triplet:", triplet_list)


    outputs.append(predictions_par_phrase)
    sentences.append(row["input"][0])
    triplets.append(triplet_list)
    print("-"*50)
    # break
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Phrase: filthy bathroom .
# Prediction: main aspect: bathroom extracted aspects: bathroom extracted opinions: filthy global polarity: negative
# --------------------------------------------------
# Triplet: [['Service', 'ok', 'negative'], ['Service', 'unfriendly', 'negative'], ['bathroom', 'filthy', 'negative']]
# --------------------------------------------------
# **************************************************
# text : The bar drinks were Eh . ok to say the least .
# Phrase: The bar drinks were Eh .
# Prediction: main aspect: bar drinks extracted aspects: drinks, bar drinks, Eh extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: ok to say the least .
# Prediction: main aspect: nan extracted aspects: extracted opinions: ok global polarity: neutral
# --------------------------------------------------
# Triplet: [['bar drinks', 'ok', 'negative']]
# --------------------------------------------------
# **************************************************
# text : The stuff tilapia was horrid ... tasted like cardboard .
# Phrase: The stuff tilapia was horrid ... tasted like cardboard .
# Prediction: main aspect: stuff tilapia extracted aspects: cardboard, stuff tilapia extracted opinions: like, horrid global polarity: negative
# --------------------------------------------------
# Triplet: [['stuff tilapia', 'horrid', 'negative']]
# --------------------------------------------------
# **************************************************
# text : oh speaking of bathroom . the mens bathroom was disgusting .
# Phrase: oh speaking of bathroom .
# Prediction: main aspect: bathroom extracted aspects: bathroom extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: the mens bathroom was disgusting .
# Prediction: main aspect: bathroom extracted aspects: bathroom, mens extracted opinions: disgusting global polarity: negative
# --------------------------------------------------
# Triplet: [['mens bathroom', 'disgusting', 'negative']]
# --------------------------------------------------
# **************************************************
# text : The wine list was extensive - though the staff did not seem knowledgeable about wine pairings .
# Phrase: The wine list was extensive - though the staff did not seem knowledgeable about wine pairings .
# Prediction: main aspect: wine list extracted aspects: pairings, list, staff, wine list extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['wine list', 'extensive', 'positive'], ['staff', 'not seem knowledgeable', 'negative']]
# --------------------------------------------------
# **************************************************
# text : The bread we received was horrible - rock hard and cold - and the `` free '' appetizer of olives was disappointing .
# Phrase: The bread we received was horrible - rock hard and cold - and the `` free '' appetizer of olives was disappointing .
# Prediction: main aspect: bread extracted aspects:, rock, appetizer, olives, bread extracted opinions: hard, disappointing, free, horrible global polarity: negative
# --------------------------------------------------
# Triplet: [['bread', 'horrible', 'negative'], ['bread', 'rock hard', 'negative'], ['bread', 'cold', 'negative'], ['appetizer of olives', 'disappointing', 'neutral']]
# --------------------------------------------------
# **************************************************
# text : However . our main course was wonderful .
# Phrase: However .
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: our main course was wonderful .
# Prediction: main aspect: course extracted aspects: course extracted opinions: wonderful global polarity: positive
# --------------------------------------------------
# Triplet: [['main course', 'wonderful', 'positive']]
# --------------------------------------------------
# **************************************************
# text : I had fish and my husband had the filet - both of which exceeded our expectations .
# Phrase: I had fish and my husband had the filet - both of which exceeded our expectations .
# Prediction: main aspect: fish extracted aspects: expectations, husband, fish extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['fish', 'exceeded our expectations', 'positive'], ['filet', 'exceeded our expectations', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The dessert ( we had a pear torte ) was good - but . once again . the staff was unable to provide appropriate drink suggestions .
# Phrase: The dessert ( we had a pear torte ) was good - but .
# Prediction: main aspect: dessert extracted aspects: dessert, torte extracted opinions: good global polarity: positive
# --------------------------------------------------
# Phrase: once again .
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: the staff was unable to provide appropriate drink suggestions .
# Prediction: main aspect: staff extracted aspects: suggestions, drink, staff extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['pear torte', 'good', 'positive'], ['staff', 'unable to provide', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Not what I would expect for the price and prestige of this location .
# Phrase: Not what I would expect for the price and prestige of this location .
# Prediction: main aspect: location extracted aspects: prestige, location, price extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['location', 'expect', 'neutral']]
# --------------------------------------------------
# **************************************************
# text : All in all . I would return - as it was a beautiful restaurant - but I hope the staff pays more attention to the little details in the future .
# Phrase: All in all .
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: I would return - as it was a beautiful restaurant - but I hope the staff pays more attention to the little details in the future .
# Prediction: main aspect: staff extracted aspects: future, staff, restaurant, attention, details extracted opinions: beautiful, hope global polarity: positive
# --------------------------------------------------
# Triplet: [['restaurant', 'beautiful', 'positive']]
# --------------------------------------------------
# **************************************************
# text : short and sweet – seating is great : it 's romantic . cozy and private .
# Phrase: short and sweet – seating is great : it 's romantic .
# Prediction: main aspect: seating extracted aspects: seating,, romantic extracted opinions: romantic, sweet, great global polarity: positive
# --------------------------------------------------
# Phrase: cozy and private .
# Prediction: main aspect: facilities extracted aspects: facilities, cozy extracted opinions: cozy global polarity: positive
# --------------------------------------------------
# Triplet: [['seating', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The boths are not as small as some of the reviews make them out to look they 're perfect for 2 people .
# Phrase: The boths are not as small as some of the reviews make them out to look they 're perfect for 2 people .
# Prediction: main aspect: boths extracted aspects: reviews, people extracted opinions: perfect global polarity: negative
# --------------------------------------------------
# Triplet: [['boths', 'not as small', 'positive'], ['boths', 'perfect', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The service was extremely fast and attentive ( thanks to the service button on your table ) but I barely understood 1 word when the waiter took our order .
# Phrase: The service was extremely fast and attentive ( thanks to the service button on your table ) but I barely understood 1 word when the waiter took our order .
# Prediction: main aspect: waiter extracted aspects: order, button, word, service, table, waiter extracted opinions: thanks global polarity: negative
# --------------------------------------------------
# Triplet: [['service', 'fast', 'positive'], ['service', 'attentive', 'positive'], ['service button', 'thanks to', 'positive'], ['waiter', 'barely understood', 'negative']]
# --------------------------------------------------
# **************************************************
# text : The food was ok and fair nothing to go crazy .
# Phrase: The food was ok and fair nothing to go crazy .
# Prediction: main aspect: food extracted aspects: food, nothing extracted opinions: crazy, fair, ok global polarity: negative
# --------------------------------------------------
# Triplet: [['food', 'ok', 'neutral'], ['food', 'fair', 'neutral']]
# --------------------------------------------------
# **************************************************
# text : Over all the looks of the place exceeds the actual meals .
# Phrase: Over all the looks of the place exceeds the actual meals .
# Prediction: main aspect: meals extracted aspects: place, meals, looks extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['looks', 'exceeds', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Subtle food and service
# Phrase: Subtle food and service
# Prediction: main aspect: service extracted aspects: food, Subtle, service extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'Subtle', 'positive'], ['service', 'Subtle', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Noodle pudding is exactly the type of service and food I enjoy .
# Phrase: Noodle pudding is exactly the type of service and food I enjoy .
# Prediction: main aspect: Noodle pudding extracted aspects: Noodle, type, service, food, pudding extracted opinions: enjoy global polarity: positive
# --------------------------------------------------
# Triplet: [['service', 'enjoy', 'positive'], ['food', 'enjoy', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Servers are all different . Greg is my favorite .
# Phrase: Servers are all different .
# Prediction: main aspect: Servers extracted aspects: Servers extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: Greg is my favorite .
# Prediction: main aspect: nan extracted aspects: Greg extracted opinions: favorite global polarity: neutral
# --------------------------------------------------
# Triplet: [['Greg', 'favorite', 'positive']]
# --------------------------------------------------
# **************************************************
# text : I go out to eat and like my courses . servers are patient and never rush courses or force another drink .
# Phrase: I go out to eat and like my courses .
# Prediction: main aspect: courses extracted aspects: courses extracted opinions: like global polarity: positive
# --------------------------------------------------
# Phrase: servers are patient and never rush courses or force another drink .
# Prediction: main aspect: servers extracted aspects: drink, courses, servers extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['servers', 'patient', 'positive']]
# --------------------------------------------------
# **************************************************
# text : amazing fresh dogs but best of all endless toppings ! ! !
# Phrase: amazing fresh dogs but best of all endless toppings !
# Prediction: main aspect: dogs extracted aspects: toppings, dogs extracted opinions: amazing, best global polarity: positive
# --------------------------------------------------
# Phrase: !
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: !
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['dogs', 'amazing fresh', 'positive'], ['toppings', 'best', 'positive'], ['toppings', 'endless', 'positive']]
# --------------------------------------------------
# **************************************************
# text : amazing fun for hot dog lovers of all ages PLEASE do yourself a favor and check this place out ! ! ! !
# Phrase: amazing fun for hot dog lovers of all ages PLEASE do yourself a favor and check this place out !
# Prediction: main aspect: place extracted aspects: lovers, favor, place, dogs, PLEASE, fun extracted opinions: lovers, amazing, favor, fun global polarity: positive
# --------------------------------------------------
# Phrase: !
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: !
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: !
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['hot dog', 'amazing fun', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Stepping into Casa La Femme last night was a true experience unlike any other in New York !
# Phrase: Stepping into Casa La Femme last night was a true experience unlike any other in New York !
# Prediction: main aspect: Casa La Femme extracted aspects: La, New, Maison, Femme, New, experience, York, Stepping, night extracted opinions: true global polarity: positive
# --------------------------------------------------
# Triplet: [['Casa La Femme', 'true', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Highly impressed from the decor to the food to the hospitality to the great night I had !
# Phrase: Highly impressed from the decor to the food to the hospitality to the great night I had !
# Prediction: main aspect: food extracted aspects: hospitality, decor, food, night extracted opinions: impressed, great global polarity: positive
# --------------------------------------------------
# Triplet: [['decor', 'impressed', 'positive'], ['food', 'impressed', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The have a great cocktail with Citrus Vodka and lemon and lime juice and mint leaves that is to die for !
# Phrase: The have a great cocktail with Citrus Vodka and lemon and lime juice and mint leaves that is to die for !
# Prediction: main aspect: mint leaves extracted aspects: Citrus Vodka, mint, juice, lime, leaves, cocktail, Vodka extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['cocktail with Citrus Vodka and lemon and lime juice and mint leaves', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Food took some time to prepare . all worth waiting for .
# Phrase: Food took some time to prepare .
# Prediction: main aspect: Food extracted aspects: Food, time extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: all worth waiting for .
# Prediction: main aspect: facilities extracted aspects: facilities, worth extracted opinions: worth global polarity: positive
# --------------------------------------------------
# Triplet: [['Food', 'worth', 'positive']]
# --------------------------------------------------
# **************************************************
# text : We were drawn into the belly dancing show that captivated the crowd .
# Phrase: We were drawn into the belly dancing show that captivated the crowd .
# Prediction: main aspect: belly dancing show extracted aspects: show, belly dancing show, crowd extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['belly dancing show', 'captivated', 'positive']]
# --------------------------------------------------
# **************************************************
# text : I never write on these sites but this restaurant is def worth commending !
# Phrase: I never write on these sites but this restaurant is def worth commending !
# Prediction: main aspect: restaurant extracted aspects: sites, restaurant extracted opinions: commending, worth global polarity: positive
# --------------------------------------------------
# Triplet: [['restaurant', 'worth', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The menu looked great . and the waiter was very nice . but when the food came . it was average .
# Phrase: The menu looked great .
# Prediction: main aspect: menu extracted aspects: menu extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: and the waiter was very nice .
# Prediction: main aspect: waiter extracted aspects: waiter extracted opinions: nice global polarity: positive
# --------------------------------------------------
# Phrase: but when the food came .
# Prediction: main aspect: food extracted aspects: food extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: it was average .
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['waiter', 'nice', 'positive'], ['food', 'average', 'neutral']]
# --------------------------------------------------
# **************************************************
# text : I have worked in restaurants and cook a lot . and there is no way a maggot should be able to get into well prepared food .
# Phrase: I have worked in restaurants and cook a lot .
# Prediction: main aspect: cook extracted aspects: cook, restaurants, lot extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and there is no way a maggot should be able to get into well prepared food .
# Prediction: main aspect: food extracted aspects: food, maggot, way extracted opinions: prepared, no, well global polarity: negative
# --------------------------------------------------
# Triplet: [['food', 'well prepared', 'negative']]
# --------------------------------------------------
# **************************************************
# text : For a restaurant with such a good reputation and that is usually so packed . there was no reason for such a lack of intelligent customer service .
# Phrase: For a restaurant with such a good reputation and that is usually so packed .
# Prediction: main aspect: restaurant extracted aspects: reputation, restaurant extracted opinions: good global polarity: positive
# --------------------------------------------------
# Phrase: there was no reason for such a lack of intelligent customer service .
# Prediction: main aspect: service extracted aspects: reason, service, customer, lack extracted opinions: lack, intelligent, no global polarity: negative
# --------------------------------------------------
# Triplet: [['restaurant', 'good reputation', 'positive'], ['customer service', 'intelligent', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Great place . great value .
# Phrase: Great place .
# Prediction: main aspect: place extracted aspects: place extracted opinions: Great global polarity: positive
# --------------------------------------------------
# Phrase: great value .
# Prediction: main aspect: value extracted aspects: value extracted opinions: value, great global polarity: positive
# --------------------------------------------------
# Triplet: [['place', 'Great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The food is flavorful . plentiful and reasonably priced .
# Phrase: The food is flavorful .
# Prediction: main aspect: food extracted aspects: food extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: plentiful and reasonably priced .
# Prediction: main aspect: prices extracted aspects: prices extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'flavorful', 'positive'], ['food', 'plentiful', 'positive'], ['food', 'reasonably priced', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The atmosphere is relaxed and casual .
# Phrase: The atmosphere is relaxed and casual .
# Prediction: main aspect: atmosphere extracted aspects: atmosphere extracted opinions: relaxed, casual global polarity: positive
# --------------------------------------------------
# Triplet: [['atmosphere', 'relaxed', 'positive'], ['atmosphere', 'casual', 'positive']]
# --------------------------------------------------
# **************************************************
# text : It 's a great place to order from or sit-in .
# Phrase: It 's a great place to order from or sit-in .
# Prediction: main aspect: place extracted aspects: order, place extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['place', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Sushi experience was unbelievable with my fiance .
# Phrase: Sushi experience was unbelievable with my fiance .
# Prediction: main aspect: Sushi experience extracted aspects: Sushi, fiance, experience extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['Sushi', 'unbelievable', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Good creative rolls !
# Phrase: Good creative rolls !
# Prediction: main aspect: creative rolls extracted aspects: creative rolls, rolls extracted opinions: Good global polarity: positive
# --------------------------------------------------
# Triplet: [['rolls', 'Good creative', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Yamato is an excellent place to go if youre not into sashimi . or if you have friends who doesnt like sushi much .
# Phrase: Yamato is an excellent place to go if youre not into sashimi .
# Prediction: main aspect: place extracted aspects: Yamato, place extracted opinions: excellent global polarity: positive
# --------------------------------------------------
# Phrase: or if you have friends who doesnt like sushi much .
# Prediction: main aspect: sushi extracted aspects: sushi, friends extracted opinions: like, friends global polarity: positive
# --------------------------------------------------
# Triplet: [['Yamato', 'excellent', 'positive']]
# --------------------------------------------------
# **************************************************
# text : They have great rolls . the triple color and norwegetan rolls . are awesome and filling .
# Phrase: They have great rolls .
# Prediction: main aspect: rolls extracted aspects: rolls extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: the triple color and norwegetan rolls .
# Prediction: main aspect: triple color extracted aspects: rolls, triple color, norwegetan, color extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: are awesome and filling .
# Prediction: main aspect: facilities extracted aspects: facilities, filling extracted opinions: awesome global polarity: positive
# --------------------------------------------------
# Triplet: [['rolls', 'great', 'positive'], ['triple color and norwegetan rolls', 'awesome', 'positive'], ['triple color and norwegetan rolls', 'filling', 'positive']]
# --------------------------------------------------
# **************************************************
# text : One special roll and one regular roll is enough to fill you up . but save room for dessert !
# Phrase: One special roll and one regular roll is enough to fill you up .
# Prediction: main aspect: roll extracted aspects: roll extracted opinions: special global polarity: positive
# --------------------------------------------------
# Phrase: but save room for dessert !
# Prediction: main aspect: dessert extracted aspects: dessert, room extracted opinions: save global polarity: positive
# --------------------------------------------------
# Triplet: [['dessert', 'save room', 'positive'], ['special roll', 'enough', 'positive'], ['regular roll', 'enough', 'positive']]
# --------------------------------------------------
# **************************************************
# text : They have a delicious banana chocolate dessert . as well as a great green tea tempura .
# Phrase: They have a delicious banana chocolate dessert .
# Prediction: main aspect: banana chocolate dessert extracted aspects: banana chocolate dessert, dessert, banana, chocolate extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# Phrase: as well as a great green tea tempura .
# Prediction: main aspect: facilities extracted aspects: tea, facilities, tempura, green extracted opinions: well, great global polarity: positive
# --------------------------------------------------
# Triplet: [['banana chocolate dessert', 'delicious', 'positive'], ['green tea tempura', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The appetizers are also delicious !
# Phrase: The appetizers are also delicious !
# Prediction: main aspect: appetizers extracted aspects: appetizers extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# Triplet: [['appetizers', 'delicious', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Amazing food .
# Phrase: Amazing food .
# Prediction: main aspect: food extracted aspects: food extracted opinions: Amazing global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'Amazing', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Mazing interior .
# Phrase: Mazing interior .
# Prediction: main aspect: Mazing interior extracted aspects: Mazing interior, interior extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['interior', 'Mazing', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Great food !
# Phrase: Great food !
# Prediction: main aspect: food extracted aspects: food, Great extracted opinions: Great global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'Great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : I 've had my fair share of modern Japanese and this spot delivers .
# Phrase: I 've had my fair share of modern Japanese and this spot delivers .
# Prediction: main aspect: Japanese extracted aspects: share, Japanese, spot extracted opinions: fair global polarity: positive
# --------------------------------------------------
# Triplet: [['modern Japanese', 'delivers', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The atmosphere was pretty nice but had a bit lacking . which it tries to make up for with a crazy scheme of mirrors .
# Phrase: The atmosphere was pretty nice but had a bit lacking .
# Prediction: main aspect: atmosphere extracted aspects: bit, atmosphere extracted opinions: nice, lacking global polarity: positive
# --------------------------------------------------
# Phrase: which it tries to make up for with a crazy scheme of mirrors .
# Prediction: main aspect: facilities extracted aspects: scheme, facilities, mirrors extracted opinions: crazy global polarity: negative
# --------------------------------------------------
# Triplet: [['atmosphere', 'nice', 'negative'], ['scheme of mirrors', 'crazy', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Despite the confusing mirrors this will likely be my go-to for modern Japanese food for the foreseeable future .
# Phrase: Despite the confusing mirrors this will likely be my go-to for modern Japanese food for the foreseeable future .
# Prediction: main aspect: Japanese food extracted aspects: mirrors, food, future, Japanese food, goto extracted opinions: confusing global polarity: negative
# --------------------------------------------------
# Triplet: [['modern Japanese food', 'go-to for', 'positive'], ['mirrors', 'confusing', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Indo Chinese food . pretty good ...
# Phrase: Indo Chinese food .
# Prediction: main aspect: Indo Chinese food extracted aspects: food, Indo Chinese food, Indo, Chinese extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: pretty good ...
# Prediction: main aspect: nan extracted aspects: extracted opinions: pretty, good global polarity: neutral
# --------------------------------------------------
# Triplet: [['Indo Chinese food', 'good', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Not a very fancy place but very good Chinese style Indian food .
# Phrase: Not a very fancy place but very good Chinese style Indian food .
# Prediction: main aspect: place extracted aspects: place, style, food, Indian extracted opinions: good global polarity: negative
# --------------------------------------------------
# Triplet: [['place', 'fancy', 'neutral'], ['Chinese style Indian food', 'good', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The chicken lollipop is my favorite . most of the dishes ( I have to agree with a previous reviewer ) are quite oily and very spicy . espeically the Chilli Chicken .
# Phrase: The chicken lollipop is my favorite .
# Prediction: main aspect: chicken lollipop extracted aspects: chicken lollipop, lollipop extracted opinions: favorite global polarity: positive
# --------------------------------------------------
# Phrase: most of the dishes ( I have to agree with a previous reviewer ) are quite oily and very spicy .
# Prediction: main aspect: dishes extracted aspects: dishes, reviewer extracted opinions: agree global polarity: positive
# --------------------------------------------------
# Phrase: espeically the Chilli Chicken .
# Prediction: main aspect: Chilli Chicken extracted aspects: Chilli, Chilli Chicken, Chicken extracted opinions: espeically global polarity: positive
# --------------------------------------------------
# Triplet: [['chicken lollipop', 'favorite', 'positive'], ['dishes', 'oily', 'negative'], ['dishes', 'spicy', 'negative'], ['Chilli Chicken', 'oily', 'negative'], ['Chilli Chicken', 'spicy', 'negative']]
# --------------------------------------------------
# **************************************************
# text : My mom originally introduced me to this place . but even she ( being Indian ) feels the food can be somewhat over the top spicy and far too oily .
# Phrase: My mom originally introduced me to this place .
# Prediction: main aspect: nan extracted aspects: mom, place extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: but even she ( being Indian ) feels the food can be somewhat over the top spicy and far too oily .
# Prediction: main aspect: food extracted aspects: spicy, food extracted opinions: top global polarity: negative
# --------------------------------------------------
# Triplet: [['food', 'spicy', 'negative'], ['food', 'oily', 'negative']]
# --------------------------------------------------
# **************************************************
# text : I was speechless by the horrible food .
# Phrase: I was speechless by the horrible food .
# Prediction: main aspect: food extracted aspects: food extracted opinions: horrible global polarity: negative
# --------------------------------------------------
# Triplet: [['food', 'speechless', 'negative'], ['food', 'horrible', 'negative']]
# --------------------------------------------------
# **************************************************
# text : I attended a holiday dinner at the restaurant . and the food was majorly disappointing .
# Phrase: I attended a holiday dinner at the restaurant .
# Prediction: main aspect: dinner extracted aspects: dinner, holiday, restaurant extracted opinions: holiday global polarity: positive
# --------------------------------------------------
# Phrase: and the food was majorly disappointing .
# Prediction: main aspect: food extracted aspects: food extracted opinions: disappointing global polarity: negative
# --------------------------------------------------
# Triplet: [['food', 'disappointing', 'negative']]
# --------------------------------------------------
# **************************************************
# text : This is the MOST wonderful restaurant in all of New York City . not just Brooklyn ...
# Phrase: This is the MOST wonderful restaurant in all of New York City .
# Prediction: main aspect: restaurant extracted aspects: MOST, New, City, restaurant, York extracted opinions: wonderful global polarity: positive
# --------------------------------------------------
# Phrase: not just Brooklyn ...
# Prediction: main aspect: nan extracted aspects: Brooklyn extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['restaurant', 'wonderful', 'positive']]
# --------------------------------------------------
# **************************************************
# text : for 7 years they have put out the most tasty . most delicious food and kept it that way ...
# Phrase: for 7 years they have put out the most tasty .
# Prediction: main aspect: nan extracted aspects: years extracted opinions: tasty global polarity: neutral
# --------------------------------------------------
# Phrase: most delicious food and kept it that way ...
# Prediction: main aspect: food extracted aspects: food, way extracted opinions: delicious global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'tasty', 'positive'], ['food', 'delicious', 'positive']]
# --------------------------------------------------
# **************************************************
# text : never swaying . never a bad meal . never bad service ...
# Phrase: never swaying .
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: never a bad meal .
# Prediction: main aspect: meal extracted aspects: meal extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Phrase: never bad service ...
# Prediction: main aspect: service extracted aspects: service extracted opinions: bad global polarity: negative
# --------------------------------------------------
# Triplet: [['meal', 'never a bad', 'positive'], ['service', 'never bad', 'positive']]
# --------------------------------------------------
# **************************************************
# text : great food . great wine list . great service in a great neighborhood ...
# Phrase: great food .
# Prediction: main aspect: food extracted aspects: food extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: great wine list .
# Prediction: main aspect: wine list extracted aspects: wine list, list extracted opinions: great global polarity: positive
# --------------------------------------------------
# Phrase: great service in a great neighborhood ...
# Prediction: main aspect: service extracted aspects: neighborhood, service extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'great', 'positive'], ['wine list', 'great', 'positive'], ['service', 'great', 'positive'], ['neighborhood', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Patsy 's Pizza - true love
# Phrase: Patsy 's Pizza - true love
# Prediction: main aspect: Pizza extracted aspects: love, Patsy, Pizza extracted opinions: love, true global polarity: positive
# --------------------------------------------------
# Triplet: [["Patsy 's Pizza", 'true love', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Hands down the best pizza on the planet .
# Phrase: Hands down the best pizza on the planet .
# Prediction: main aspect: pizza extracted aspects: planet, pizza extracted opinions: best global polarity: positive
# --------------------------------------------------
# Triplet: [['pizza', 'best', 'positive']]
# --------------------------------------------------
# **************************************************
# text : great hot dogs .
# Phrase: great hot dogs .
# Prediction: main aspect: facilities extracted aspects: facilities, dogs extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['hot dogs', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : the hot dogs were juicy and tender inside and had plenty of crunch and snap on the outside .
# Phrase: the hot dogs were juicy and tender inside and had plenty of crunch and snap on the outside .
# Prediction: main aspect: dogs extracted aspects: dogs, crunch, plenty, outside, snap extracted opinions: tender global polarity: positive
# --------------------------------------------------
# Triplet: [['hot dogs', 'juicy', 'positive']]
# --------------------------------------------------
# **************************************************
# text : great toppings definitely a place you need to check out for late night munchies or a mid day boost !
# Phrase: great toppings definitely a place you need to check out for late night munchies or a mid day boost !
# Prediction: main aspect: place extracted aspects: toppings, place, night, day, munchies, boost extracted opinions: definitely, great global polarity: positive
# --------------------------------------------------
# Triplet: [['toppings', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : For me dishes a little oily . but overall dining experience good .
# Phrase: For me dishes a little oily .
# Prediction: main aspect: dishes extracted aspects: dishes extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: but overall dining experience good .
# Prediction: main aspect: dining experience extracted aspects: dining experience, experience extracted opinions: good global polarity: positive
# --------------------------------------------------
# Triplet: [['dishes', 'oily', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Helpful service and average price per dish $ 10 .
# Phrase: Helpful service and average price per dish $ 10 .
# Prediction: main aspect: service extracted aspects: dish, price, service extracted opinions: Helpful global polarity: positive
# --------------------------------------------------
# Triplet: [['service', 'Helpful', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The only thing that strikes you is the decor ? ( not very pleasant ) .
# Phrase: The only thing that strikes you is the decor ?
# Prediction: main aspect: decor extracted aspects: decor, thing extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: ( not very pleasant ) .
# Prediction: main aspect: nan extracted aspects: extracted opinions: pleasant global polarity: neutral
# --------------------------------------------------
# Triplet: [['decor', 'not very pleasant', 'negative']]
# --------------------------------------------------
# **************************************************
# text : great food
# Phrase: great food
# Prediction: main aspect: food extracted aspects: food extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['food', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : This place has great indian chinese food .
# Phrase: This place has great indian chinese food .
# Prediction: main aspect: food extracted aspects: food, place extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['indian chinese food', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Be prepared to wait . because the place is pretty tiny .
# Phrase: Be prepared to wait .
# Prediction: main aspect: nan extracted aspects: Be extracted opinions: prepared global polarity: neutral
# --------------------------------------------------
# Phrase: because the place is pretty tiny .
# Prediction: main aspect: place extracted aspects: place extracted opinions: pretty global polarity: positive
# --------------------------------------------------
# Triplet: [['place', 'tiny', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Even though the place is not beautiful . the food speaks for itself .
# Phrase: Even though the place is not beautiful .
# Prediction: main aspect: place extracted aspects: place extracted opinions: beautiful global polarity: negative
# --------------------------------------------------
# Phrase: the food speaks for itself .
# Prediction: main aspect: food extracted aspects: food extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['place', 'not beautiful', 'negative'], ['food', 'speaks for itself', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Best Indian Chinese in the city . by far !
# Phrase: Best Indian Chinese in the city .
# Prediction: main aspect: Indian Chinese extracted aspects: Chinese, city, Indian Chinese extracted opinions: Best global polarity: positive
# --------------------------------------------------
# Phrase: by far !
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['Indian Chinese', 'Best', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The martinis are amazing and very fairly priced .
# Phrase: The martinis are amazing and very fairly priced .
# Prediction: main aspect: martinis extracted aspects: martinis extracted opinions: amazing global polarity: positive
# --------------------------------------------------
# Triplet: [['martinis', 'amazing', 'positive'], ['martinis', 'fairly priced', 'positive']]
# --------------------------------------------------
# **************************************************
# text : THE SERVICE IS AMAZING . i 've had different waiters and they were all nice . which is a rare thing in NYC .
# Phrase: THE SERVICE IS AMAZING .
# Prediction: main aspect: SERVICE extracted aspects: SERVICE extracted opinions: AMAZING global polarity: positive
# --------------------------------------------------
# Phrase: i 've had different waiters and they were all nice .
# Prediction: main aspect: waiters extracted aspects: waiters extracted opinions: nice global polarity: positive
# --------------------------------------------------
# Phrase: which is a rare thing in NYC .
# Prediction: main aspect: nan extracted aspects: NYC, thing extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['SERVICE', 'AMAZING', 'positive'], ['waiters', 'nice', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The DJ is awesome . I have been there for my birthday and a bunch of other times with friends and I keep going back .
# Phrase: The DJ is awesome .
# Prediction: main aspect: DJ extracted aspects: DJ extracted opinions: awesome global polarity: positive
# --------------------------------------------------
# Phrase: I have been there for my birthday and a bunch of other times with friends and I keep going back .
# Prediction: main aspect: nan extracted aspects: birthday, bunch, times, friends extracted opinions: friends global polarity: neutral
# --------------------------------------------------
# Triplet: [['DJ', 'awesome', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Everything on the menu is great .
# Phrase: Everything on the menu is great .
# Prediction: main aspect: menu extracted aspects: menu, Everything extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['menu', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : This establishment is the real deal .
# Phrase: This establishment is the real deal .
# Prediction: main aspect: nan extracted aspects: deal, establishment extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['establishment', 'real deal', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Wish NY had more of these kind of places : intimate . superb food . homey . top notch all the way around . certainly worth the wait .
# Phrase: Wish NY had more of these kind of places : intimate .
# Prediction: main aspect: places extracted aspects: kind, NY, places, Wish extracted opinions: Wish global polarity: positive
# --------------------------------------------------
# Phrase: superb food .
# Prediction: main aspect: food extracted aspects: food extracted opinions: superb global polarity: positive
# --------------------------------------------------
# Phrase: homey .
# Prediction: main aspect: nan extracted aspects: homey extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: top notch all the way around .
# ...
# **************************************************
# text : The presentation of Snooze is excellent and it is one of those places that you feel more sophisticated just for being there ; but peel back the layers and you have an overpriced IHOP with a high brow menu .
# Phrase: The presentation of Snooze is excellent and it is one of those places that you feel more sophisticated just for being there ; but peel back the layers and you have an overpriced IHOP with a high brow menu .
# Prediction: main aspect: nan extracted aspects: Snooze, presentation, menu, layers, places, IHOP, brow extracted opinions: excellent, sophisticated global polarity: neutral
# --------------------------------------------------
# Triplet: [['Snooze', 'excellent', 'negative'], ['menu', 'high brow', 'negative']]
# --------------------------------------------------
# **************************************************
# text : They serve it in a tall . skinny hour-glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket .
# Phrase: They serve it in a tall .
# Prediction: main aspect: serve extracted aspects: serve extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: skinny hour-glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket .
# Prediction: main aspect: glass extracted aspects: fact, half, gallon, hourglass, glass, supermarket, juice, price extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['juice', 'small', 'negative']]
# --------------------------------------------------
# **************************************************
# text : I should have just asked for the check when I saw that ; but their menu was so unique that I continued .
# Phrase: I should have just asked for the check when I saw that ; but their menu was so unique that I continued .
# Prediction: main aspect: menu extracted aspects: menu, check extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['menu', 'unique', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The pancakes were certainly inventive but $ 8.50 for 3 - 6 '' pancakes ( one of them was more like 5 '' ) in the pancake flight ( sample of 3 different pancakes ) is well over-priced .
# Phrase: The pancakes were certainly inventive but $ 8.50 for 3 - 6 '' pancakes ( one of them was more like 5 '' ) in the pancake flight ( sample of 3 different pancakes ) is well over-priced .
# Prediction: main aspect: pancakes extracted aspects:, sample, pancakes, flight, pancakes extracted opinions: like, certainly global polarity: positive
# --------------------------------------------------
# Triplet: [['pancakes', 'inventive', 'negative'], ['pancakes', 'over-priced', 'negative']]
# --------------------------------------------------
# **************************************************
# text : The pancakes should be larger ( at least 8 '' ) to justify the expense even with the unique offerings .
# Phrase: The pancakes should be larger ( at least 8 '' ) to justify the expense even with the unique offerings .
# Prediction: main aspect: pancakes extracted aspects: pancakes, offerings, expense extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Triplet: [['pancakes', 'should be larger', 'negative']]
# --------------------------------------------------
# **************************************************
# text : In the end our check came to $ 27 for 4 small pancakes . a breakfast burrito . an orange juice and an iced tea ( I had water ) .
# Phrase: In the end our check came to $ 27 for 4 small pancakes .
# Prediction: main aspect: check extracted aspects: pancakes, check, end extracted opinions: neutral global polarity: negative
# --------------------------------------------------
# Phrase: a breakfast burrito .
# Prediction: main aspect: facilities extracted aspects: breakfast, facilities, burrito extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: an orange juice and an iced tea ( I had water ) .
# Prediction: main aspect: orange juice extracted aspects: tea, juice, orange juice, water extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['pancakes', 'small', 'negative']]
# --------------------------------------------------
# **************************************************
# text : Much more than just a great view !
# Phrase: Much more than just a great view !
# Prediction: main aspect: view extracted aspects: view extracted opinions: great global polarity: positive
# --------------------------------------------------
# Triplet: [['view', 'great', 'positive']]
# --------------------------------------------------
# **************************************************
# text : – I am exceedingly pleased to report that my dinner at Ray 's Boathouse last Friday completely exceeded my expectations .
# Phrase: – I am exceedingly pleased to report that my dinner at Ray 's Boathouse last Friday completely exceeded my expectations .
# Prediction: main aspect: dinner extracted aspects: expectations, Friday, dinner, Ray, Boathouse extracted opinions: pleased global polarity: positive
# --------------------------------------------------
# Triplet: [["Ray 's Boathouse", 'exceeded my expectations', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Ray 's is something of a Seattle institution . but given its gorgeous Sound views . I had suspected that the accolades were more due to the scenery than to the food and service .
# Phrase: Ray 's is something of a Seattle institution .
# Prediction: main aspect: nan extracted aspects: something, Ray, institution, Seattle extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: but given its gorgeous Sound views .
# Prediction: main aspect: Sound views extracted aspects: Sound views, views extracted opinions: gorgeous global polarity: positive
# --------------------------------------------------
# Phrase: I had suspected that the accolades were more due to the scenery than to the food and service .
# Prediction: main aspect: food extracted aspects: accolades, service, scenery, food extracted opinions: accolades global polarity: positive
# --------------------------------------------------
# Triplet: [['Sound views', 'gorgeous', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Imagine my happy surprise upon finding that the views are only the third-best thing about Ray 's !
# Phrase: Imagine my happy surprise upon finding that the views are only the third-best thing about Ray 's !
# Prediction: main aspect: views extracted aspects: views, thing, Ray, surprise extracted opinions: happy, surprise global polarity: positive
# --------------------------------------------------
# Triplet: [["Ray 's", 'happy surprise', 'positive']]
# --------------------------------------------------
# **************************************************
# text : To start things off . our lovely server Brooke was quickly on hand to take my drink order .
# Phrase: To start things off .
# Prediction: main aspect: nan extracted aspects: things extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: our lovely server Brooke was quickly on hand to take my drink order .
# Prediction: main aspect: drink order extracted aspects: order, drink order, Brooke, server, hand extracted opinions: lovely global polarity: positive
# --------------------------------------------------
# Triplet: [['Brooke', 'lovely', 'positive'], ['Brooke', 'quickly', 'positive']]
# --------------------------------------------------
# **************************************************
# text : My party of two was feeling particularly ambitious . and we splurged on the Shilshole Sampler ... a beautiful assortment of enormous white gulf prawns . smoked albacore tuna . Ray 's fantastic manila clams seasoned with dill . scallops in a tasty soy dressing . and a tiny pile of Dungeness crab atop a sublime butter sauce .
# Phrase: My party of two was feeling particularly ambitious .
# Prediction: main aspect: nan extracted aspects: party extracted opinions: party global polarity: neutral
# --------------------------------------------------
# Phrase: and we splurged on the Shilshole Sampler ... a beautiful assortment of enormous white gulf prawns .
# Prediction: main aspect: Shilshole Sampler extracted aspects: Shilshole Sampler, assortment, prawns, Sampler extracted opinions: beautiful global polarity: positive
# --------------------------------------------------
# Phrase: smoked albacore tuna .
# Prediction: main aspect: albacore tuna extracted aspects: tuna, albacore tuna extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: Ray 's fantastic manila clams seasoned with dill .
# Prediction: main aspect: manila extracted aspects: dill, Ray, manila, clams extracted opinions: fantastic global polarity: positive
# --------------------------------------------------
# Phrase: scallops in a tasty soy dressing .
# Prediction: main aspect: scallops extracted aspects: scallops, dressing, soy extracted opinions: tasty global polarity: positive
# --------------------------------------------------
# Phrase: and a tiny pile of Dungeness crab atop a sublime butter sauce .
# Prediction: main aspect: butter sauce extracted aspects: sauce, Dungeness, crab, butter sauce, pile extracted opinions: sublime global polarity: positive
# --------------------------------------------------
# Triplet: [['white gulf prawns', 'enormous', 'positive'], ['manila clams', 'fantastic', 'positive'], ['soy dressing', 'tasty', 'positive'], ['butter sauce', 'sublime', 'positive']]
# --------------------------------------------------
# **************************************************
# text : For my entr & eacute ; e . I completely enjoyed the seared Alaskan sea scallops complemented by chard . artichoke hearts . fennel . and pecorino toscano .
# Phrase: For my entr & eacute ; e .
# Prediction: main aspect: nan extracted aspects: entr extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: I completely enjoyed the seared Alaskan sea scallops complemented by chard .
# Prediction: main aspect: seared Alaskan sea scallops extracted aspects: scallops, chard, seared Alaskan sea scallops extracted opinions: enjoyed global polarity: positive
# --------------------------------------------------
# Phrase: artichoke hearts .
# Prediction: main aspect: artichoke hearts extracted aspects: hearts, artichoke hearts extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: fennel .
# Prediction: main aspect: facilities extracted aspects: facilities, fennel extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: and pecorino toscano .
# Prediction: main aspect: pecorino toscano extracted aspects: pecorino toscano, toscano extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Triplet: [['seared Alaskan sea scallops', 'enjoyed', 'positive']]
# --------------------------------------------------
# **************************************************
# text : The scallops are apparently cooked in a black olive butter which really makes them unique ( not to mention tasty ) .
# Phrase: The scallops are apparently cooked in a black olive butter which really makes them unique ( not to mention tasty ) .
# Prediction: main aspect: scallops extracted aspects: butter, scallops, olive extracted opinions: unique global polarity: positive
# --------------------------------------------------
# Triplet: [['scallops', 'unique', 'positive'], ['scallops', 'tasty', 'positive']]
# --------------------------------------------------
# **************************************************
# text : My friend enjoyed the grilled Alaskan King Salmon with delectable creamed Washington russet potatoes and crisp green beans .
# Phrase: My friend enjoyed the grilled Alaskan King Salmon with delectable creamed Washington russet potatoes and crisp green beans .
# Prediction: main aspect: Alaskan King Salmon extracted aspects: Salmon, Washington, potatoes, King, beans, Alaskan King Salmon, friend, russet extracted opinions: friend, enjoyed global polarity: positive
# --------------------------------------------------
# Triplet: [['grilled Alaskan King Salmon', 'enjoyed', 'positive'], ['creamed Washington russet potatoes', 'delectable', 'positive'], ['green beans', 'crisp', 'positive']]
# --------------------------------------------------
# **************************************************
# text : I had a taste of all three items on her plate . and they were superb .
# Phrase: I had a taste of all three items on her plate .
# Prediction: main aspect: taste extracted aspects: plate, items, taste extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Phrase: and they were superb .
# Prediction: main aspect: nan extracted aspects: extracted opinions: superb global polarity: neutral
# --------------------------------------------------
# Triplet: [['plate', 'superb', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Our server continued to be attentive throughout the night . but I did remain puzzled by one issue : Who thinks that Ray 's is an appropriate place to take young children for dinner ?
# Phrase: Our server continued to be attentive throughout the night .
# Prediction: main aspect: server extracted aspects: server, night extracted opinions: neutral global polarity: positive
# --------------------------------------------------
# Phrase: but I did remain puzzled by one issue : Who thinks that Ray 's is an appropriate place to take young children for dinner ?
# Prediction: main aspect: dinner extracted aspects: place, children, issue, dinner, Ray extracted opinions: puzzled global polarity: neutral
# --------------------------------------------------
# Triplet: [['server', 'attentive', 'positive'], ["Ray 's", 'appropriate', 'neutral']]
# --------------------------------------------------
# **************************************************
# text : While I could have done without the youth who shared the evening with us . our wonderful server and food made the experience a very positive one .
# Phrase: While I could have done without the youth who shared the evening with us .
# Prediction: main aspect: nan extracted aspects: youth, evening extracted opinions: shared global polarity: neutral
# --------------------------------------------------
# Phrase: our wonderful server and food made the experience a very positive one .
# Prediction: main aspect: server extracted aspects: food, server, experience extracted opinions: wonderful, positive global polarity: positive
# --------------------------------------------------
# Triplet: [['server', 'wonderful', 'positive'], ['food', 'wonderful', 'positive']]
# --------------------------------------------------
# **************************************************
# text : Oh yeah ... the view was good . too .
# Phrase: Oh yeah ... the view was good .
# Prediction: main aspect: view extracted aspects: view extracted opinions: yeah, good global polarity: positive
# --------------------------------------------------
# Phrase: too .
# Prediction: main aspect: nan extracted aspects: extracted opinions: neutral global polarity: neutral
# --------------------------------------------------
# Triplet: [['view', 'good', 'positive']]
# --------------------------------------------------

# %%
print(triplets)
# Out:
# [[['Boot time', 'fast', 'positive']], [['tech support', 'not fix', 'negative']], [['Set up', 'easy', 'positive']], [['Windows 8', 'not enjoy', 'negative'], ['touchscreen functions', 'not enjoy', 'negative']], [['internal speakers', 'lousy', 'negative']], [['use', 'fast', 'positive'], ['use', 'light', 'positive'], ['use', 'simple', 'positive']], [['Works', 'well', 'positive'], ['apple OS', 'happy', 'positive']], [['features', 'not light and slim', 'positive']], [['log on', 'pleased', 'positive'], ['log on', 'fast', 'positive'], ['WiFi connection', 'pleased', 'positive'], ['WiFi connection', 'speedy', 'positive'], ['battery life', 'pleased', 'positive'], ['battery life', 'long', 'positive']], [['delete key', 'not yet discovered', 'negative']], [['interneting', 'difficult', 'negative']], [['priced', 'right', 'positive']], [['track pad', 'not very good', 'negative']], [['graphics', 'outstanding', 'positive']], [['mountain lion', 'slow', 'negative']], [['durability', 'Strong', 'positive'], ['build', 'Strong', 'positive']], [['battery life', 'excellent', 'positive']], [['works', 'perfectly', 'positive']], [['Windows 8', 'liking', 'positive']], [['baterry', 'longer', 'positive']], [['size', 'ideal', 'positive'], ['weight', 'acceptable', 'positive']], [['performance', 'satisfied', 'positive']], [['speed', 'much more', 'positive'], ['screen', 'sharp', 'positive']], [['price', 'great', 'positive']], [['Hardware performance', 'impressive', 'positive']], [['works', 'always', 'positive'], ['set up', 'easy', 'positive']], [['Keyboard', 'responds well', 'positive']], [['Windows 8', 'annoying', 'negative']], [['setup', 'easy', 'positive'], ['setup', 'intuitive', 'positive'], ['configure', 'easy', 'positive'], ['configure', 'intuitive', 'positive']], [['Windows 8', 'complaint', 'negative']], [['usb ports', 'limited', 'negative']], [['features', 'expected', 'positive'], ['screen', 'wide', 'positive'], ['keyboard', 'roomy', 'positive']], [['Performance', 'Amazing', 'positive']], [['quality', 'superlatives', 'positive'], ['performance', 'superlatives', 'positive']], [['OS', 'happy', 'positive']], [['portability', 'great', 'positive']], [['portable computing', 'recommend', 'positive'], ['portable computing', 'truly', 'positive']], [['MS Office 2011 for Mac', 'wonderful', 'positive'], ['MS Office 2011 for Mac', 'well worth', 'positive']], [['performance', 'disappointment', 'negative']], [['look', 'good', 'positive'], ['performance', 'excellent', 'positive']], [['lit up keys', 'love', 'positive'], ['lit up keys', 'Fast', 'positive'], ['lit up keys', 'clear', 'positive'], ['screen display', 'love', 'positive'], ['screen display', 'Fast', 'positive'], ['screen display', 'clear', 'positive']], [['Mountain Lion OS', 'not hard', 'positive'], ['Microsoft Windows', 'familiar', 'neutral']], [['OSX', 'FAST', 'negative']], [['Microsoft Office', 'Enjoy', 'positive']], [['graphics', 'Incredible', 'positive'], ['colors', 'brilliant', 'positive']], [['Built-in apps', 'amazing', 'positive']], [['operating system', 'beats', 'positive']], [['size', 'like', 'positive']], [['SquareTrade 3-Year Computer Accidental Protection Warranty', 'support', 'positive'], ['AppleCare', 'NOT covered', 'negative']], [['transport', 'light', 'positive'], ['transport', 'easy', 'positive']], [['Windows 8 Set-Up', 'poorly designed', 'negative'], ['Windows 8 Set-Up', 'frustrated', 'negative']], [['aluminum body', 'stand out', 'positive']], [['integrate bluetooth devices', 'easy', 'positive'], ['USB devices', 'instantly', 'positive']], [['Intel4000 graphic chip', 'underpowered', 'negative']], [['DVD drive Firewire port', 'removed', 'neutral'], ['SDXC slot', 'silly', 'negative']], [['durability', 'worth', 'positive']], [['designed', 'Well', 'positive']], [['use', 'easy', 'positive']], [['value', 'great', 'positive']], [['specs', 'good', 'positive']], [['product quality', 'unmatched', 'positive'], ['aesthetics', 'unmatched', 'positive'], ['craftmanship', 'unmatched', 'positive'], ['customer s ...

# %%
data = []
triplets_predicted=[]
triplets_ground_truth=[]
for text, predictions_par_phrase, triplet_list in zip(sentences, outputs ,triplets):
    text_sans_virgules = text.replace(',', '.')
    phrases = sent_tokenize(text_sans_virgules)
    aspect_opinion_sentiments = []

    for prediction in predictions_par_phrase:
        for phrase in phrases:
            aspects_to_use = [prediction["main_aspect"]] if prediction["main_aspect"] and prediction["main_aspect"] != "nan" else prediction["extracted_aspects"]

            for aspect in aspects_to_use:
                if aspect in phrase:
                    closest_opinion = find_closest_opinion(phrase, aspect, prediction["extracted_opinions"])
                    if closest_opinion and aspect != closest_opinion:
                        sentiment = analyze_sentiment(phrase)
                        aspect_opinion_sentiments.append((aspect, closest_opinion, sentiment))

    # Éliminer les doublons en convertissant la liste en un ensemble, puis en la reconvertissant en liste
    aspect_opinion_sentiments = list(set(aspect_opinion_sentiments))
    sorted_aspect_opinion_sentiments = sorted(aspect_opinion_sentiments, key=lambda x: x[0])

    # Affichage et sauvegarde des données
    print(text_sans_virgules)
    print("-"*50)
    print("Aspect-Opinion Sentiments:")
    tri=[]
    for tup in sorted_aspect_opinion_sentiments:
        print(tup)
        tri.append(tup)
    triplets_predicted.append(tri)
    triplets_ground_truth.append(triplet_list)
    print("-"*50)
    print("Ground truth triplet: ",triplet_list)
    print("*"*50)

    data_dict = {
        "text": text_sans_virgules,
        "main_aspect": prediction["main_aspect"],
        "extracted_aspects": prediction["extracted_aspects"],
        "extracted_opinions": prediction["extracted_opinions"],
        "global_polarity": prediction["global_polarity"],
        "aspect_opinion_sentiments": sorted_aspect_opinion_sentiments
    }
    data.append(data_dict)

# Sauvegarde des données dans un fichier JSON
with open('/content/drive/MyDrive/Master 2/output.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Aspect-Opinion Sentiments:
# ('room', 'sure', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['bill', 'big', 'negative']]
# **************************************************
# Not only was the sushi fresh . they also served other entrees allowed each guest something to choose from and we all left happy ( try the duck !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('entrees', 'happy', 'positive')
# ('sushi', 'fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['sushi', 'fresh', 'positive'], ['duck', 'try', 'positive']]
# **************************************************
# good variety but nothing surprising .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('variety', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['variety', 'good', 'positive']]
# **************************************************
# No green beans . no egg . no anchovy dressing . no nicoise olives . no red onion .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('green beans', 'No', 'positive')
# ('nicoise olives', 'no', 'neutral')
# ('red onion', 'no', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['green beans', 'No', 'neutral'], ['egg', 'no', 'neutral'], ['anchovy dressing', 'no', 'neutral'], ['nicoise olives', 'no', 'neutral'], ['red onion', 'no', 'neutral']]
# **************************************************
# Thick fries . meaty chili and stuffed baked potatoes round out a menu that includes a cool . ultra-thick chocolate Frosty .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('baked potatoes', 'cool', 'positive')
# ('chocolate', 'Frosty', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['fries', 'Thick', 'neutral'], ['chocolate Frosty', 'cool', 'positive'], ['chocolate Frosty', 'ultra-thick', 'positive']]
# **************************************************
# The homage to India is most evident in the delectable roti canai appetizer . a fried pancake served with pungent curry dipping sauce . while the mango chicken offers a surprisingly sophisticated . fresh take on sweet-and-sour .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('mango chicken', 'surprisingly', 'neutral')
# ('take', 'fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['roti canai appetizer', 'delectable', 'positive'], ['mango chicken', 'surprisingly sophisticated', 'positive'], ['mango chicken', 'fresh', 'positive']]
# **************************************************
# The ground chickpea soup we sampled as a starter tasted somewhat thin .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['ground chickpea soup', 'thin', 'negative'], ['starter', 'thin', 'neutral']]
# **************************************************
# The service . however . is a peg or two below the quality of food ( horrible bartenders ) . and the clientele . for the most part . are rowdy . loud-mouthed commuters ( this could explain the bad attitudes from the staff ) getting loaded for an AC/DC concert or a Knicks game .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'horrible', 'negative')
# ('staff', 'bad', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'below', 'negative'], ['bartenders', 'horrible', 'negative'], ['clientele', 'rowdy', 'negative'], ['clientele', 'loud-mouthed', 'negative'], ['staff', 'bad', 'negative']]
# **************************************************
# If you 're in the neighborhood . definitely stop by for a great meal .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('meal', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['meal', 'great', 'positive']]
# **************************************************
# Although small . it has beautiful ambience . excellent food ( the catfish is delicious - if ya do n't mind it a lil salty ) and attentive service .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('ambience', 'beautiful', 'positive')
# ('food', 'excellent', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['ambience', 'beautiful', 'positive'], ['food', 'excellent', 'positive'], ['catfish', 'delicious', 'positive'], ['catfish', 'salty', 'positive'], ['service', 'attentive', 'positive']]
# **************************************************
# Stick to the items the place does best . brisket . ribs . wings . cajun shrimp is good . not great .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('cajun shrimp', 'good', 'positive')
# ('place', 'best', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['brisket', 'good', 'positive'], ['ribs', 'good', 'positive'], ['wings', 'good', 'positive'], ['cajun shrimp', 'good', 'neutral']]
# **************************************************
# Hip boutiques and bars on Ludlow add to the artsy . laid-back atmosphere at this Israeli-style takeout and eat-in burger joint .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['atmosphere', 'artsy', 'positive'], ['atmosphere', 'laid-back', 'positive']]
# **************************************************
# My Chelsea 's impressive and creative menu includes modern . Westernized Japanese dishes such as Foie Gras Unagi Napolean . Jap style hamburger steak . spicy cod roe spaghetti . black cod with miso base . and rack of lamb in black truffle sauce . to name a few .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('menu', 'impressive', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['menu', 'impressive', 'positive'], ['menu', 'creative', 'positive'], ['Japanese dishes', 'modern', 'neutral'], ['Japanese dishes', 'Westernized', 'neutral'], ['Foie Gras Unagi Napolean', 'modern', 'neutral'], ['Foie Gras Unagi Napolean', 'Westernized', 'neutral'], ['Jap style hamburger steak', 'modern', 'neutral'], ['Jap style hamburger steak', 'Westernized', 'neutral'], ['spicy cod roe spaghetti', 'modern', 'neutral'], ['spicy cod roe spaghetti', 'Westernized', 'neutral'], ['black cod with miso base', 'modern', 'neutral'], ['black cod with miso base', 'Westernized', 'neutral'], ['rack of lamb in black truffle sauce', 'modern', 'neutral'], ['rack of lamb in black truffle sauce', 'Westernized', 'neutral']]
# **************************************************
# His food is excellent ( and not expensive by NYC standards- no entrees over $ 30 . most appetizers $ 12 to 14 ) .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('entrees', 'no', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'excellent', 'positive'], ['appetizers', 'not expensive', 'positive']]
# **************************************************
# The food is consistant and good but how it got name Best Diner In Manhattan is beyond me .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'consistant', 'positive'], ['food', 'good', 'positive']]
# **************************************************
# The pasta primavera was outstanding as well . lots of fresh veggies .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pasta primavera', 'outstanding', 'positive')
# ('veggies', 'fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['pasta primavera', 'outstanding', 'positive'], ['fresh veggies', 'lots', 'positive']]
# **************************************************
# do n't get me wrong - sushi was good . just not fantastic .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('sushi', 'wrong', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['sushi', 'good', 'positive'], ['sushi', 'not fantastic', 'positive']]
# **************************************************
# Been to the one in Brooklyn for over 25 years . now I dont have to go over the bridge for the best pizza ... .Hanx
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pizza', 'best', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['pizza', 'best', 'positive']]
# **************************************************
# Had dinner here on a Friday and the food was great .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'great', 'positive']]
# **************************************************
# We recently spent New Year 's Eve at the restaurant . and had a great experience . from the wine to the dessert menu .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['wine', 'great', 'positive'], ['dessert menu', 'great', 'positive']]
# **************************************************
# Highly recommended ... As stated . I have n't dined *in* the restaurant but stopped by there to pick up takeout and it seems a very relaxing place ; also . the bar looks nice .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bar', 'nice', 'positive')
# ('takeout', 'relaxing', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'relaxing', 'positive'], ['bar', 'nice', 'positive']]
# **************************************************
# The ambiance was fine . a little loud but still nice and romantic .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('ambiance', 'fine', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['ambiance', 'fine', 'positive'], ['ambiance', 'loud', 'positive'], ['ambiance', 'nice', 'positive'], ['ambiance', 'romantic', 'positive']]
# **************************************************
# but . the filet mignon was not very good at all cocktail hour includes free appetizers ( nice non-sushi selection ) .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('appetizers', 'free', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['filet mignon', 'not very good', 'negative'], ['non-sushi selection', 'nice', 'positive'], ['appetizers', 'free', 'positive']]
# **************************************************
# Can be a bit busy around peak times because of the size .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['size', 'busy', 'negative']]
# **************************************************
# I was on jury duty . rode my bike up Centre Street on my lunch break and came across this great little place with awesome chicken tacos and Hibiscus lemonade .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('chicken tacos', 'great', 'positive')
# ('jury duty', 'duty', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['chicken tacos', 'awesome', 'positive'], ['Hibiscus lemonade', 'awesome', 'positive'], ['place', 'great', 'positive']]
# **************************************************
# good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'good', 'positive'], ['soup', 'simple', 'neutral'], ['french dish', 'classic', 'neutral']]
# **************************************************
# Very nice touch that very much fits the place .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'nice', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'nice', 'positive']]
# **************************************************
# However . there is just something so great about being outdoors . in great landscaping . enjoying a casual drink that makes going to this place worthwhile .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('drink', 'casual', 'positive')
# ('landscaping', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['casual drink', 'enjoying', 'positive'], ['outdoors', 'great', 'positive']]
# **************************************************
# The comments about fried foods is correct ( below ) but the other dishes . including the lamb entree and many of the salads ( avocado shrimp ) were quite good .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('fried foods', 'correct', 'negative')
# ('salads', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['dishes', 'good', 'positive'], ['lamb entree', 'good', 'positive'], ['salads ( avocado shrimp )', 'good', 'positive']]
# **************************************************
# Slow service . but when you 're hanging around with groups of 10 or 20 . who really notices ?
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['service', 'Slow', 'negative']]
# **************************************************
# The sauce is excellent ( very fresh ) with dabs of real mozzarella .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('sauce', 'excellent', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['sauce', 'excellent', 'positive'], ['sauce', 'fresh', 'positive']]
# **************************************************
# Do n't ever bother - the drinks were awful . but it was the people who work there that really made this the worst experience at dining .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dining', 'worst', 'negative')
# ('drinks', 'awful', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['drinks', 'awful', 'negative'], ['people', 'worst', 'negative'], ['dining', 'worst', 'negative']]
# **************************************************
# The room is a little plain . but it 's difficult to make such a small place exciting and I would not suggest that as a reason not to go .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'exciting', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['room', 'plain', 'negative']]
# **************************************************
# Prices even outside of restaurant week were great .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Prices', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Prices', 'great', 'positive']]
# **************************************************
# A small . outdoor eating area makes for a private . comfortable space to study alone or meet up with friends .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('space', 'comfortable', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['space', 'private', 'positive'], ['space', 'comfortable', 'positive'], ['outdoor eating area', 'small', 'positive']]
# **************************************************
# The best dessert . a chocolate and peanut butter tart . is n't particularly Hawaiian . but it 's a small world when it comes to sweets .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dessert', 'best', 'positive')
# ('world', 'sweets', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['dessert', 'best', 'positive']]
# **************************************************
# for an appetizer . their calamari is a winner .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('calamari', 'winner', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['appetizer', 'winner', 'neutral'], ['calamari', 'winner', 'positive']]
# **************************************************
# The room is a gorgeous . bi-level space and the long bar perfect for a drink .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bar', 'perfect', 'positive')
# ('room', 'gorgeous', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['room', 'gorgeous', 'positive'], ['bi-level space', 'gorgeous', 'positive'], ['long bar', 'perfect', 'positive']]
# **************************************************
# Two complaints- their appetizer selection stinks . it would be nice to get some mozzarella sticks on the menu .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('mozzarella sticks', 'nice', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['appetizer selection', 'stinks', 'negative']]
# **************************************************
# I was especially impressed during the bday party when the waitstaff went above and beyond in helping me decorate and bring out a bday cake as well as offering prompt and friendly service to a 15 person party .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('waitstaff', 'helping', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'prompt', 'positive'], ['service', 'friendly', 'positive']]
# **************************************************
# The chicken and falafel platters were nondescript combinations with fresh leaf salad .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('chicken', 'fresh', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['chicken and falafel platters', 'nondescript', 'neutral'], ['fresh leaf salad', 'fresh', 'neutral']]
# **************************************************
# several times and put up with the waiters ' bad manners . knowing that their job is n't easy .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('job', 'easy', 'positive')
# ('waiters', 'bad', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['waiters', 'bad', 'negative']]
# **************************************************
# The service is great ( maybe even borderline nagging but at least you get attention ) . the desserts are excellent and the coffee is so very good ...
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['desserts', 'excellent', 'positive'], ['coffee', 'good', 'positive']]
# **************************************************
# They are served on Focacchia bread and are to die for .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Focacchia bread', 'die', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['Focacchia bread', 'die for', 'neutral']]
# **************************************************
# While the smoothies are a little big for me . the fresh juices are the best I have ever had !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('juices', 'best', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['smoothies', 'big', 'negative'], ['fresh juices', 'best', 'positive']]
# **************************************************
# The food is just OKAY . and it 's almost not worth going unless you 're getting the pialla . which is the only dish that 's really good .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dish', 'good', 'positive')
# ('food', 'OKAY', 'positive')
# ('pialla', 'worth', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['pialla', 'good', 'positive'], ['dish', 'good', 'positive']]
# **************************************************
# The guac is fresh . yet lacking flavor . we like to add our fresh salsa into it .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('flavor', 'lacking', 'neutral')
# ('guac', 'fresh', 'positive')
# ('salsa', 'like', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['flavor', 'lacking', 'negative']]
# **************************************************
# The new menu has a few creative items . they were smart enough to keep some of the old favorites ( but they raised the prices ) . the staff is friendly most of the time . but I must agree with the person that wrote about their favorite words : No . ca n't . sorry ... . boy . they wo n't bend the rules for anyone .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('menu', 'creative', 'positive')
# ('prices', 'smart', 'positive')
# ('rules', 'wo', 'neutral')
# ('staff', 'friendly', 'positive')
# ('words', 'favorite', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['prices', 'raised', 'negative'], ['new menu', 'creative', 'positive']]
# **************************************************
# It ' only open for lunch but the food is so good !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'good', 'positive']]
# **************************************************
# How can they survive serving mediocre food at exorbitant prices ? !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'survive', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'mediocre', 'neutral'], ['prices', 'exorbitant', 'negative']]
# **************************************************
# The food was mediocre and the service was severely slow .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'mediocre', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'severely slow', 'negative'], ['food', 'mediocre', 'neutral']]
# **************************************************
# i have eaten here on a different occasion - the food is mediocre for the prices .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['food', 'mediocre', 'neutral']]
# **************************************************
# I asked repeatedly what the status of the meal was and was pretty much grunted at by the unbelievably rude waiter .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('waiter', 'rude', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['waiter', 'rude', 'negative']]
# **************************************************
# Sweet Irish bartender is always happy and able to bring a smile to my friends a my face .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bartender', 'Sweet', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['bartender', 'Sweet', 'positive'], ['bartender', 'happy', 'positive']]
# **************************************************
# Its good to go there for drinks if you do n't want to get drunk because you 'll be lucky if you can get one drink an hour the service is so bad .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('drinks', 'good', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'bad', 'negative'], ['drinks', 'good', 'neutral']]
# **************************************************
# Anyway . the owner was fake .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('owner', 'fake', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['owner', 'fake', 'negative']]
# **************************************************
# Owner is pleasant and entertaining .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Owner', 'pleasant', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Owner', 'pleasant', 'positive'], ['Owner', 'entertaining', 'positive']]
# **************************************************
# Creamy appetizers -- taramasalata . eggplant salad . and Greek yogurt ( with cuccumber . dill . and garlic ) taste excellent when on warm pitas .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pitas', 'excellent', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Creamy appetizers', 'Creamy', 'positive'], ['Creamy appetizers', 'excellent', 'positive'], ['warm pitas', 'warm', 'neutral'], ['taramasalata', 'Creamy', 'positive'], ['eggplant salad', 'excellent', 'positive'], ['Greek yogurt ( with cuccumber , dill , and garlic )', 'excellent', 'positive']]
# **************************************************
# Love Al Di La
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Di', 'Love', 'positive')
# ('La', 'Love', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Al Di La', 'Love', 'positive']]
# **************************************************
# I recommend this place to everyone .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'recommend', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'recommend', 'positive']]
# **************************************************
# Great food .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'Great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'Great', 'positive']]
# **************************************************
# The pastas are incredible . the risottos ( particularly the sepia ) are fantastic and the braised rabbit is amazing .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pastas', 'incredible', 'positive')
# ('risottos', 'fantastic', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['pastas', 'incredible', 'positive'], ['risottos', 'fantastic', 'positive'], ['sepia', 'fantastic', 'positive'], ['braised rabbit', 'amazing', 'positive']]
# **************************************************
# The food here was mediocre at best .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'best', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'mediocre', 'negative']]
# **************************************************
# It was totally overpriced - fish and chips was about $ 15 ... .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['fish and chips', 'overpriced', 'negative']]
# **************************************************
# Tasty Dog !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['Dog', 'Tasty', 'positive']]
# **************************************************
# An awesome organic dog . and a conscious eco friendly establishment .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('organic dog', 'awesome', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['dog', 'organic', 'positive'], ['establishment', 'eco friendly', 'positive']]
# **************************************************
# But the best pork souvlaki I ever had is the main thing .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pork souvlaki', 'best', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['pork souvlaki', 'best', 'positive']]
# **************************************************
# Super YUMMY Pizza !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Super YUMMY Pizza', 'Super', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Pizza', 'YUMMY', 'positive']]
# **************************************************
# I was visiting New York City with a friend and we discovered this really warm and inviting restaurant .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('restaurant', 'inviting', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['restaurant', 'inviting', 'positive']]
# **************************************************
# I LOOOVE their eggplant pizza . as well as their pastas !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pastas', 'well', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['eggplant pizza', 'LOOOVE', 'positive'], ['pastas', 'LOOOVE', 'positive']]
# **************************************************
# We had half/half pizza . mine was eggplant and my friend had the buffalo and it was sooo huge for a small size pizza !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('buffalo', 'friend', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['half/half pizza', 'huge', 'positive']]
# **************************************************
# Excellent food . although the interior could use some help .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'Excellent', 'positive')
# ('interior', 'help', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'Excellent', 'positive'], ['interior', 'help', 'negative']]
# **************************************************
# I paid just about $ 60 for a good meal . though : )
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('meal', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['meal', 'good', 'positive']]
# **************************************************
# Great sake !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('sake', 'Great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['sake', 'Great', 'positive']]
# **************************************************
# Reliable . Fresh Sushi
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Sushi', 'Fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Sushi', 'Reliable', 'positive'], ['Sushi', 'Fresh', 'positive']]
# **************************************************
# The sashimi is always fresh and the rolls are innovative and delicious .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rolls', 'fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['sashimi', 'fresh', 'positive'], ['rolls', 'innovative', 'positive'], ['rolls', 'delicious', 'positive']]
# **************************************************
# Have never had a problem with service save a missing rice once .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('rice', 'missing', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'problem', 'positive']]
# **************************************************
# Delivery can be spot on or lacking depending on the weather and the day of the week .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Delivery', 'lacking', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['Delivery', 'lacking', 'negative']]
# **************************************************
# Delivery guy sometimes get upset if you do n't tip more than 10 % .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Delivery guy', 'upset', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Delivery guy', 'upset', 'negative']]
# **************************************************
# Best . Sushi . Ever .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['Sushi', 'Best', 'positive']]
# **************************************************
# This place has ruined me for neighborhood sushi .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('sushi', 'ruined', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['sushi', 'ruined', 'positive']]
# **************************************************
# Excellent sashimi . and the millennium roll is beyond delicious .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('millennium roll', 'delicious', 'positive')
# ('sashimi', 'Excellent', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['sashimi', 'Excellent', 'positive'], ['millennium roll', 'delicious', 'positive']]
# **************************************************
# The place is a bit hidden away . but once you get there . it 's all worth it .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['place', 'hidden away', 'positive'], ['place', 'worth', 'positive']]
# **************************************************
# The waiter was attentive . the food was delicious and the views of the city were great .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'delicious', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['waiter', 'attentive', 'positive'], ['food', 'delicious', 'positive'], ['views of the city', 'great', 'positive']]
# **************************************************
# Great place to relax and enjoy your dinner
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dinner', 'enjoy', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'Great', 'positive']]
# **************************************************
# Good food : my favorite is the seafood spaghetti .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('seafood spaghetti', 'Good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'Good', 'positive'], ['seafood spaghetti', 'favorite', 'positive']]
# **************************************************
# Excellent food for great prices
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('prices', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'Excellent', 'positive']]
# **************************************************
# The wait staff is very courteous and accomodating .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('wait staff', 'courteous', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['wait staff', 'courteous', 'positive'], ['wait staff', 'accomodating', 'positive']]
# **************************************************
# The space is limited so be prepared to wait up to 45 minutes - 1 hour . but be richly rewarded when you savor the delicious indo-chinese food .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'delicious', 'positive')
# ('space', 'limited', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['space', 'limited', 'negative'], ['indo-chinese food', 'delicious', 'positive']]
# **************************************************
# my favorite place lol
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'favorite', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'favorite', 'positive']]
# **************************************************
# i love their chicken pasta cant remember the name but is sooo good
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('chicken pasta', 'love', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['chicken pasta', 'love', 'positive']]
# **************************************************
# im not necessarily fanatical about this place . but it was a fun time for low pirces .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pirces', 'fun', 'positive')
# ('place', 'fanatical', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'fanatical', 'positive']]
# **************************************************
# lobster was good . nothing spectacular .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('lobster', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['lobster', 'good', 'neutral'], ['lobster', 'nothing spectacular', 'neutral']]
# **************************************************
# its just a fun place to go . not a five star restaraunt .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'fun', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['restaraunt', 'five star', 'neutral']]
# **************************************************
# I think the pizza is so overrated and was under cooked .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['pizza', 'overrated', 'negative'], ['pizza', 'under cooked', 'negative']]
# **************************************************
# Had no flavor and the staff is rude and not attentive .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('flavor', 'no', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['staff', 'rude', 'negative'], ['staff', 'not attentive', 'negative']]
# **************************************************
# I love this place
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'love', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'love', 'positive']]
# **************************************************
# The service was quick and friendly .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'friendly', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'quick', 'positive'], ['service', 'friendly', 'positive']]
# **************************************************
# I thought the restaurant was nice and clean .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('restaurant', 'nice', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['restaurant', 'nice', 'positive'], ['restaurant', 'clean', 'positive']]
# **************************************************
# I ordered the vitello alla marsala and I was pretty impressed .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('vitello alla marsala', 'pretty', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['vitello alla marsala', 'impressed', 'positive']]
# **************************************************
# The veal and the mushrooms were cooked perfectly .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('veal', 'perfectly', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['veal', 'perfectly', 'positive'], ['mushrooms', 'perfectly', 'positive']]
# **************************************************
# The potato balls were not dry at all ... in fact it was buttery .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('potato balls', 'dry', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['potato balls', 'not dry', 'positive'], ['potato balls', 'buttery', 'positive']]
# **************************************************
# WORST PLACE ON SMITH STREET IN BROOKLYN
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('PLACE ON SMITH STREET IN BROOKLYN', 'WORST', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['PLACE', 'WORST', 'negative']]
# **************************************************
# Very immature bartender . didnt know how to make specific drinks . service was so slowwwww . the food was not fresh or warm . waitresses were busy flirting with men at the bar and werent very attentive to all the customers .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['bartender', 'immature', 'negative'], ['service', 'slowwwww', 'negative'], ['food', 'not fresh or warm', 'negative'], ['waitresses', 'werent very attentive', 'negative']]
# **************************************************
# I would never recommend this place to anybody even for a casual dinner .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dinner', 'recommend', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'never recommend', 'negative']]
# **************************************************
# the food is always fresh ...
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'fresh', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'fresh', 'positive']]
# **************************************************
# overpriced japanese food with mediocre service
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['japanese food', 'overpriced', 'negative'], ['service', 'mediocre', 'neutral']]
# **************************************************
# food was luke warm .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'warm', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'luke warm', 'negative']]
# **************************************************
# The waitress was not attentive at all .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['waitress', 'not attentive', 'negative']]
# **************************************************
# The food was excellent as well as service . however . I left The Four Seasons very dissappointed .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Four Seasons', 'dissappointed', 'positive')
# ('food', 'excellent', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'excellent', 'positive'], ['service', 'excellent', 'positive'], ['The Four Seasons', 'dissappointed', 'negative']]
# **************************************************
# Red Dragon Roll - my favorite thing to eat . of any food group - hands down
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Red Dragon Roll', 'favorite', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Red Dragon Roll', 'favorite', 'positive']]
# **************************************************
# The Seafood Dynamite is also otherworldly .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['Seafood Dynamite', 'otherworldly', 'positive']]
# **************************************************
# Favorite Sushi in NYC
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Sushi', 'Favorite', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Sushi', 'Favorite', 'positive']]
# **************************************************
# An unpretentious spot in Park Slope . the sushi is consistently good . the service is pleasant . effective and unassuming .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'pleasant', 'positive')
# ('sushi', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['spot', 'unpretentious', 'positive'], ['sushi', 'good', 'positive'], ['service', 'pleasant', 'positive'], ['service', 'effective', 'positive'], ['service', 'unassuming', 'positive']]
# **************************************************
# In the summer months . the back garden area is really nice .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('back garden area', 'nice', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['back garden area', 'nice', 'positive']]
# **************************************************
# The rolls are creative and I have yet to find another sushi place that serves up more inventive yet delicious japanese food .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('sushi', 'creative', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['rolls', 'creative', 'positive'], ['japanese food', 'inventive', 'positive'], ['japanese food', 'delicious', 'positive']]
# **************************************************
# The Dancing . White River and Millenium rolls are musts .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['Dancing , White River and Millenium rolls', 'musts', 'positive']]
# **************************************************
# I CAN EAT HERE EVERY DAY OF THE WEEK REALLY LOL LOVE THIS PLACE ... )
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('CAN', 'LOVE', 'positive')
# ('DAY', 'LOVE', 'positive')
# ('EAT', 'LOVE', 'positive')
# ('EVERY', 'LOVE', 'positive')
# ('HERE', 'LOVE', 'positive')
# ('PLACE', 'LOVE', 'positive')
# ('THE', 'LOVE', 'positive')
# ('THIS', 'LOVE', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['PLACE', 'LOVE', 'positive']]
# **************************************************
# Gross food – Wow-
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('food', 'Gross', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'Gross', 'negative']]
# ...
# Ground truth triplet:  [["pepperoni 's", 'thick', 'positive'], ["pepperoni 's", 'Yum', 'positive']]
# **************************************************
# The pizza itself is not exactly the best I 've had EVER . but still pretty good .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pizza', 'best', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['pizza', 'not exactly the best', 'positive'], ['pizza', 'good', 'positive']]
# **************************************************
# Food was good and appetizing .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Food', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Food', 'good', 'positive'], ['Food', 'appetizing', 'positive']]
# **************************************************
# Portions was just enough for me . but may not be for a big eater .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['Portions', 'enough', 'neutral']]
# **************************************************
# Fair menu selection .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('menu selection', 'Fair', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['menu selection', 'Fair', 'neutral']]
# **************************************************
# The appetizer was interesting . but the Creme Brulee was very savory and delicious .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Creme Brulee', 'delicious', 'positive')
# ('appetizer', 'interesting', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['appetizer', 'interesting', 'positive'], ['Creme Brulee', 'savory', 'positive'], ['Creme Brulee', 'delicious', 'positive']]
# **************************************************
# Indoor ambience was modern .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['Indoor ambience', 'modern', 'positive']]
# **************************************************
# It 's a great place to people watch .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('place', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['place', 'great', 'positive']]
# **************************************************
# Late night dinning with exeptional food .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['food', 'exeptional', 'positive']]
# **************************************************
# We were seated right away . the table was private and nice .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('table', 'nice', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['table', 'private', 'positive'], ['table', 'nice', 'positive']]
# **************************************************
# The service was exceptional - sometime there was a feeling that we were served by the army of friendly waiters .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'feeling', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'exceptional', 'positive'], ['waiters', 'friendly', 'positive']]
# **************************************************
# The food was very good . filet mignon was probably the best I 've ever try .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('filet mignon', 'best', 'positive')
# ('food', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['food', 'good', 'positive'], ['filet mignon', 'best', 'positive']]
# **************************************************
# The portions are big though . so do not order too much .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['portions', 'big', 'neutral']]
# **************************************************
# Groovy music made the dinner casual .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dinner casual', 'casual', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['music', 'casual', 'positive']]
# **************************************************
# I have a but here - there was a bathroom attendant in the restroom which was odd .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('bathroom', 'odd', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['restroom', 'odd', 'negative']]
# **************************************************
# The bathroom itself is very small with two toilets and only one sink . the girl was staying totally on the way hanging out paper towels from the dispenser .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['bathroom', 'small', 'negative']]
# **************************************************
# – Mercedes restaurant is so tasty . the service is undeniably awesome !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('service', 'awesome', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['service', 'awesome', 'positive']]
# **************************************************
# The atmosphere is aspiring . and the decor is festive and amazing ...
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('decor', 'festive', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['atmosphere', 'aspiring', 'positive'], ['decor', 'festive', 'positive'], ['decor', 'amazing', 'positive']]
# **************************************************
# The catering is out of this world . and Raouls chicken vegetable soup rocks my world ! ! !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('chicken vegetable soup', 'rocks', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['Raouls chicken vegetable soup', 'rocks my world', 'positive'], ['catering', 'out of this world', 'positive']]
# **************************************************
# Drinks are suberb . and I feel like I am in a Third World country when I walk in the door .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('World', 'like', 'neutral')
# ('country', 'like', 'neutral')
# ('door', 'like', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['Drinks', 'suberb', 'positive']]
# **************************************************
# - Mediocre Service / Quality
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Mediocre Service', 'Quality', 'negative')
# --------------------------------------------------
# Ground truth triplet:  [['Service', 'Mediocre', 'neutral']]
# **************************************************
# The presentation of Snooze is excellent and it is one of those places that you feel more sophisticated just for being there ; but peel back the layers and you have an overpriced IHOP with a high brow menu .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('IHOP', 'sophisticated', 'positive')
# ('Snooze', 'excellent', 'positive')
# ('brow', 'sophisticated', 'positive')
# ('layers', 'sophisticated', 'positive')
# ('menu', 'sophisticated', 'positive')
# ('places', 'sophisticated', 'positive')
# ('presentation', 'excellent', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Snooze', 'excellent', 'negative'], ['menu', 'high brow', 'negative']]
# **************************************************
# They serve it in a tall . skinny hour-glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['juice', 'small', 'negative']]
# **************************************************
# I should have just asked for the check when I saw that ; but their menu was so unique that I continued .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['menu', 'unique', 'positive']]
# **************************************************
# The pancakes were certainly inventive but $ 8.50 for 3 - 6 '' pancakes ( one of them was more like 5 '' ) in the pancake flight ( sample of 3 different pancakes ) is well over-priced .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('pancakes', 'certainly', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['pancakes', 'inventive', 'negative'], ['pancakes', 'over-priced', 'negative']]
# **************************************************
# The pancakes should be larger ( at least 8 '' ) to justify the expense even with the unique offerings .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['pancakes', 'should be larger', 'negative']]
# **************************************************
# In the end our check came to $ 27 for 4 small pancakes . a breakfast burrito . an orange juice and an iced tea ( I had water ) .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['pancakes', 'small', 'negative']]
# **************************************************
# Much more than just a great view !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('view', 'great', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['view', 'great', 'positive']]
# **************************************************
# – I am exceedingly pleased to report that my dinner at Ray 's Boathouse last Friday completely exceeded my expectations .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dinner', 'pleased', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [["Ray 's Boathouse", 'exceeded my expectations', 'positive']]
# **************************************************
# Ray 's is something of a Seattle institution . but given its gorgeous Sound views . I had suspected that the accolades were more due to the scenery than to the food and service .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Sound views', 'gorgeous', 'positive')
# ('food', 'accolades', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Sound views', 'gorgeous', 'positive']]
# **************************************************
# Imagine my happy surprise upon finding that the views are only the third-best thing about Ray 's !
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('views', 'surprise', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [["Ray 's", 'happy surprise', 'positive']]
# **************************************************
# To start things off . our lovely server Brooke was quickly on hand to take my drink order .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('drink order', 'lovely', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['Brooke', 'lovely', 'positive'], ['Brooke', 'quickly', 'positive']]
# **************************************************
# My party of two was feeling particularly ambitious . and we splurged on the Shilshole Sampler ... a beautiful assortment of enormous white gulf prawns . smoked albacore tuna . Ray 's fantastic manila clams seasoned with dill . scallops in a tasty soy dressing . and a tiny pile of Dungeness crab atop a sublime butter sauce .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Shilshole Sampler', 'beautiful', 'positive')
# ('butter sauce', 'sublime', 'neutral')
# ('manila', 'fantastic', 'positive')
# ('scallops', 'tasty', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['white gulf prawns', 'enormous', 'positive'], ['manila clams', 'fantastic', 'positive'], ['soy dressing', 'tasty', 'positive'], ['butter sauce', 'sublime', 'positive']]
# **************************************************
# For my entr & eacute ; e . I completely enjoyed the seared Alaskan sea scallops complemented by chard . artichoke hearts . fennel . and pecorino toscano .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('seared Alaskan sea scallops', 'enjoyed', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['seared Alaskan sea scallops', 'enjoyed', 'positive']]
# **************************************************
# The scallops are apparently cooked in a black olive butter which really makes them unique ( not to mention tasty ) .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('scallops', 'unique', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['scallops', 'unique', 'positive'], ['scallops', 'tasty', 'positive']]
# **************************************************
# My friend enjoyed the grilled Alaskan King Salmon with delectable creamed Washington russet potatoes and crisp green beans .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('Alaskan King Salmon', 'friend', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['grilled Alaskan King Salmon', 'enjoyed', 'positive'], ['creamed Washington russet potatoes', 'delectable', 'positive'], ['green beans', 'crisp', 'positive']]
# **************************************************
# I had a taste of all three items on her plate . and they were superb .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# --------------------------------------------------
# Ground truth triplet:  [['plate', 'superb', 'positive']]
# **************************************************
# Our server continued to be attentive throughout the night . but I did remain puzzled by one issue : Who thinks that Ray 's is an appropriate place to take young children for dinner ?
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('dinner', 'puzzled', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['server', 'attentive', 'positive'], ["Ray 's", 'appropriate', 'neutral']]
# **************************************************
# While I could have done without the youth who shared the evening with us . our wonderful server and food made the experience a very positive one .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('evening', 'shared', 'neutral')
# ('server', 'wonderful', 'positive')
# ('youth', 'shared', 'neutral')
# --------------------------------------------------
# Ground truth triplet:  [['server', 'wonderful', 'positive'], ['food', 'wonderful', 'positive']]
# **************************************************
# Oh yeah ... the view was good . too .
# --------------------------------------------------
# Aspect-Opinion Sentiments:
# ('view', 'good', 'positive')
# --------------------------------------------------
# Ground truth triplet:  [['view', 'good', 'positive']]
# **************************************************

# %%
print(triplets_predicted)
print(triplets_ground_truth)

# %%
triplets_ground_truth = [[tuple(sublist) for sublist in list] for list in triplets_ground_truth]
print(triplets_ground_truth)
# Out:
# [[('Boot time', 'fast', 'positive')], [('tech support', 'not fix', 'negative')], [('Set up', 'easy', 'positive')], [('Windows 8', 'not enjoy', 'negative'), ('touchscreen functions', 'not enjoy', 'negative')], [('internal speakers', 'lousy', 'negative')], [('use', 'fast', 'positive'), ('use', 'light', 'positive'), ('use', 'simple', 'positive')], [('Works', 'well', 'positive'), ('apple OS', 'happy', 'positive')], [('features', 'not light and slim', 'positive')], [('log on', 'pleased', 'positive'), ('log on', 'fast', 'positive'), ('WiFi connection', 'pleased', 'positive'), ('WiFi connection', 'speedy', 'positive'), ('battery life', 'pleased', 'positive'), ('battery life', 'long', 'positive')], [('delete key', 'not yet discovered', 'negative')], [('interneting', 'difficult', 'negative')], [('priced', 'right', 'positive')], [('track pad', 'not very good', 'negative')], [('graphics', 'outstanding', 'positive')], [('mountain lion', 'slow', 'negative')], [('durability', 'Strong', 'positive'), ('build', 'Strong', 'positive')], [('battery life', 'excellent', 'positive')], [('works', 'perfectly', 'positive')], [('Windows 8', 'liking', 'positive')], [('baterry', 'longer', 'positive')], [('size', 'ideal', 'positive'), ('weight', 'acceptable', 'positive')], [('performance', 'satisfied', 'positive')], [('speed', 'much more', 'positive'), ('screen', 'sharp', 'positive')], [('price', 'great', 'positive')], [('Hardware performance', 'impressive', 'positive')], [('works', 'always', 'positive'), ('set up', 'easy', 'positive')], [('Keyboard', 'responds well', 'positive')], [('Windows 8', 'annoying', 'negative')], [('setup', 'easy', 'positive'), ('setup', 'intuitive', 'positive'), ('configure', 'easy', 'positive'), ('configure', 'intuitive', 'positive')], [('Windows 8', 'complaint', 'negative')], [('usb ports', 'limited', 'negative')], [('features', 'expected', 'positive'), ('screen', 'wide', 'positive'), ('keyboard', 'roomy', 'positive')], [('Performance', 'Amazing', 'positive')], [('quality', 'superlatives', 'positive'), ('performance', 'superlatives', 'positive')], [('OS', 'happy', 'positive')], [('portability', 'great', 'positive')], [('portable computing', 'recommend', 'positive'), ('portable computing', 'truly', 'positive')], [('MS Office 2011 for Mac', 'wonderful', 'positive'), ('MS Office 2011 for Mac', 'well worth', 'positive')], [('performance', 'disappointment', 'negative')], [('look', 'good', 'positive'), ('performance', 'excellent', 'positive')], [('lit up keys', 'love', 'positive'), ('lit up keys', 'Fast', 'positive'), ('lit up keys', 'clear', 'positive'), ('screen display', 'love', 'positive'), ('screen display', 'Fast', 'positive'), ('screen display', 'clear', 'positive')], [('Mountain Lion OS', 'not hard', 'positive'), ('Microsoft Windows', 'familiar', 'neutral')], [('OSX', 'FAST', 'negative')], [('Microsoft Office', 'Enjoy', 'positive')], [('graphics', 'Incredible', 'positive'), ('colors', 'brilliant', 'positive')], [('Built-in apps', 'amazing', 'positive')], [('operating system', 'beats', 'positive')], [('size', 'like', 'positive')], [('SquareTrade 3-Year Computer Accidental Protection Warranty', 'support', 'positive'), ('AppleCare', 'NOT covered', 'negative')], [('transport', 'light', 'positive'), ('transport', 'easy', 'positive')], [('Windows 8 Set-Up', 'poorly designed', 'negative'), ('Windows 8 Set-Up', 'frustrated', 'negative')], [('aluminum body', 'stand out', 'positive')], [('integrate bluetooth devices', 'easy', 'positive'), ('USB devices', 'instantly', 'positive')], [('Intel4000 graphic chip', 'underpowered', 'negative')], [('DVD drive Firewire port', 'removed', 'neutral'), ('SDXC slot', 'silly', 'negative')], [('durability', 'worth', 'positive')], [('designed', 'Well', 'positive')], [('use', 'easy', 'positive')], [('value', 'great', 'positive')], [('specs', 'good', 'positive')], [('product quality', 'unmatched', 'positive'), ('aesthetics', 'unmatched', 'positive'), ('craftmanship', 'unmatched', 'positive'), ('customer s ...

# %%
def calculate_tp_fp_fn(predicted, ground_truth):
    # print(predicted," -- ", ground_truth)
    # tp = len(set(predicted).intersection(set(ground_truth)))
    # fp = len(set(predicted) - set(ground_truth))
    # fn = len(set(ground_truth) - set(predicted))
    pred_set = set(predicted)
    truth_set = set(ground_truth)
    tp = len(pred_set.intersection(truth_set))
    fp = len(pred_set.difference(truth_set))
    fn = len(truth_set.difference(pred_set))
    print(" predicted :",predicted," -- ground_truth :", ground_truth," --- TP:",tp," - FP:", fp," - FN:", fn)
    print("*"*50)
    return tp, fp, fn

def calculate_jaccard(predicted, ground_truth):
    intersection = len(set(predicted).intersection(set(ground_truth)))
    union = len(set(predicted).union(set(ground_truth)))
    return intersection / union if union != 0 else 0

metrics = []
for predicted, ground_truth in zip(triplets_predicted, triplets_ground_truth):
    tp, fp, fn = calculate_tp_fp_fn(predicted, ground_truth)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    jaccard_score = calculate_jaccard(predicted, ground_truth)
    metrics.append((precision, recall, f1_score, jaccard_score))

average_precision = sum(m[0] for m in metrics) / len(metrics)
average_recall = sum(m[1] for m in metrics) / len(metrics)
average_f1_score = sum(m[2] for m in metrics) / len(metrics)
average_jaccard_score = sum(m[3] for m in metrics) / len(metrics)

print(f"Average Precision: {average_precision}")
print(f"Average Recall: {average_recall}")
print(f"Average F1 Score: {average_f1_score}")
print(f"Average Jaccard Score: {average_jaccard_score}")
# Out:
#  predicted : [('Boot time', 'super', 'positive')]  -- ground_truth : [('Boot time', 'fast', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('tech support', 'support', 'neutral')]  -- ground_truth : [('tech support', 'not fix', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('Set up', 'easy', 'positive')]  -- ground_truth : [('Set up', 'easy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Windows 8', 'enjoy', 'negative')]  -- ground_truth : [('Windows 8', 'not enjoy', 'negative'), ('touchscreen functions', 'not enjoy', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('notebook', 'like', 'negative'), ('speakers', 'lousy', 'negative'), ('things', 'hard', 'negative')]  -- ground_truth : [('internal speakers', 'lousy', 'negative')]  --- TP: 0  - FP: 3  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('use', 'fast', 'positive'), ('use', 'light', 'positive'), ('use', 'simple', 'positive')]  --- TP: 0  - FP: 0  - FN: 3
# **************************************************
#  predicted : [('OS', 'happy', 'positive'), ('Works', 'well', 'neutral'), ('apple', 'happy', 'positive')]  -- ground_truth : [('Works', 'well', 'positive'), ('apple OS', 'happy', 'positive')]  --- TP: 0  - FP: 3  - FN: 2
# **************************************************
#  predicted : [('features', 'Sure', 'positive')]  -- ground_truth : [('features', 'not light and slim', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('fast log', 'pleased', 'positive')]  -- ground_truth : [('log on', 'pleased', 'positive'), ('log on', 'fast', 'positive'), ('WiFi connection', 'pleased', 'positive'), ('WiFi connection', 'speedy', 'positive'), ('battery life', 'pleased', 'positive'), ('battery life', 'long', 'positive')]  --- TP: 0  - FP: 1  - FN: 6
# **************************************************
#  predicted : []  -- ground_truth : [('delete key', 'not yet discovered', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('business', 'difficult', 'negative'), ('interneting', 'difficult', 'negative'), ('part', 'difficult', 'negative')]  -- ground_truth : [('interneting', 'difficult', 'negative')]  --- TP: 1  - FP: 2  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('priced', 'right', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('bit', 'defective', 'neutral'), ('computer', 'defective', 'neutral'), ('track pad', 'problem', 'negative')]  -- ground_truth : [('track pad', 'not very good', 'negative')]  --- TP: 0  - FP: 3  - FN: 1
# **************************************************
#  predicted : [('graphics', 'outstanding', 'positive')]  -- ground_truth : [('graphics', 'outstanding', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('mountain lion', 'slow', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('build', 'Strong', 'positive')]  -- ground_truth : [('durability', 'Strong', 'positive'), ('build', 'Strong', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('battery life', 'excellent', 'positive')]  -- ground_truth : [('battery life', 'excellent', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('works', 'perfectly', 'positive')]  -- ground_truth : [('works', 'perfectly', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Windows 8', 'liking', 'positive')]  -- ground_truth : [('Windows 8', 'liking', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('baterry', 'longer', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('size', 'ideal', 'positive')]  -- ground_truth : [('size', 'ideal', 'positive'), ('weight', 'acceptable', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('performance', 'satisfied', 'positive')]  -- ground_truth : [('performance', 'satisfied', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('screen', 'sharp', 'positive')]  -- ground_truth : [('speed', 'much more', 'positive'), ('screen', 'sharp', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('price', 'great', 'positive')]  -- ground_truth : [('price', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Hardware performance', 'impressive', 'positive')]  -- ground_truth : [('Hardware performance', 'impressive', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('thing', 'awesome', 'positive')]  -- ground_truth : [('works', 'always', 'positive'), ('set up', 'easy', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Keyboard', 'well', 'neutral')]  -- ground_truth : [('Keyboard', 'responds well', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('Windows 8', 'annoying', 'negative')]  -- ground_truth : [('Windows 8', 'annoying', 'negative')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Everything', 'easy', 'positive')]  -- ground_truth : [('setup', 'easy', 'positive'), ('setup', 'intuitive', 'positive'), ('configure', 'easy', 'positive'), ('configure', 'intuitive', 'positive')]  --- TP: 0  - FP: 1  - FN: 4
# **************************************************
#  predicted : [('Windows 8', 'Biggest', 'negative')]  -- ground_truth : [('Windows 8', 'complaint', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('usb ports', 'kind', 'positive')]  -- ground_truth : [('usb ports', 'limited', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('features', 'expected', 'positive'), ('screen', 'wide', 'positive'), ('keyboard', 'roomy', 'positive')]  --- TP: 0  - FP: 0  - FN: 3
# **************************************************
#  predicted : [('Performance', 'Amazing', 'positive')]  -- ground_truth : [('Performance', 'Amazing', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('quality', 'superlatives', 'positive'), ('performance', 'superlatives', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('OS', 'happy', 'positive')]  -- ground_truth : [('OS', 'happy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('portability', 'great', 'positive')]  -- ground_truth : [('portability', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Air', 'recommend', 'positive')]  -- ground_truth : [('portable computing', 'recommend', 'positive'), ('portable computing', 'truly', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('MS Office 2011 for Mac', 'wonderful', 'positive'), ('MS Office 2011 for Mac', 'well worth', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('performance', 'huge', 'negative')]  -- ground_truth : [('performance', 'disappointment', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('performance', 'excellent', 'positive')]  -- ground_truth : [('look', 'good', 'positive'), ('performance', 'excellent', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('lit up keys', 'kind', 'positive')]  -- ground_truth : [('lit up keys', 'love', 'positive'), ('lit up keys', 'Fast', 'positive'), ('lit up keys', 'clear', 'positive'), ('screen display', 'love', 'positive'), ('screen display', 'Fast', 'positive'), ('screen display', 'clear', 'positive')]  --- TP: 0  - FP: 1  - FN: 6
# **************************************************
#  predicted : [('OS', 'hard', 'positive')]  -- ground_truth : [('Mountain Lion OS', 'not hard', 'positive'), ('Microsoft Windows', 'familiar', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('OSX', 'FAST', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Microsoft Office', 'Enjoy', 'positive')]  -- ground_truth : [('Microsoft Office', 'Enjoy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('graphics', 'Incredible', 'positive')]  -- ground_truth : [('graphics', 'Incredible', 'positive'), ('colors', 'brilliant', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Built-in apps', 'amazing', 'positive')]  -- ground_truth : [('Built-in apps', 'amazing', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('speed', 'easily', 'positive')]  -- ground_truth : [('operating system', 'beats', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('size', 'fan', 'positive')]  -- ground_truth : [('size', 'like', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('SquareTrade 3-Year Computer Accidental Protection Warranty', 'support', 'positive'), ('AppleCare', 'NOT covered', 'negative')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('transport', 'easy', 'positive')]  -- ground_truth : [('transport', 'light', 'positive'), ('transport', 'easy', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Windows 8 Set-Up', 'poorly designed', 'negative'), ('Windows 8 Set-Up', 'frustrated', 'negative')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('aluminum body', 'sure', 'positive')]  -- ground_truth : [('aluminum body', 'stand out', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('bluetooth devices', 'easy', 'positive')]  -- ground_truth : [('integrate bluetooth devices', 'easy', 'positive'), ('USB devices', 'instantly', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Apple', 'underpowered', 'neutral'), ('Intel4000', 'underpowered', 'neutral'), ('RMBP', 'underpowered', 'neutral'), ('chip', 'underpowered', 'neutral'), ('fact', 'underpowered', 'neutral'), ('graphic', 'underpowered', 'neutral')]  -- ground_truth : [('Intel4000 graphic chip', 'underpowered', 'negative')]  --- TP: 0  - FP: 6  - FN: 1
# **************************************************
#  predicted : [('DVD drive Firewire port', 'silly', 'negative')]  -- ground_truth : [('DVD drive Firewire port', 'removed', 'neutral'), ('SDXC slot', 'silly', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('durability', 'worth', 'positive')]  -- ground_truth : [('durability', 'worth', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('designed', 'Well', 'positive')]  -- ground_truth : [('designed', 'Well', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('use', 'easy', 'positive')]  -- ground_truth : [('use', 'easy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('value', 'great', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('specs', 'pretty', 'positive')]  -- ground_truth : [('specs', 'good', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('product quality', 'unmatched', 'positive'), ('aesthetics', 'unmatched', 'positive'), ('craftmanship', 'unmatched', 'positive'), ('customer service', 'unmatched', 'positive')]  --- TP: 0  - FP: 0  - FN: 4
# **************************************************
#  predicted : [('windows', 'amazing', 'positive')]  -- ground_truth : [('size', 'great', 'positive'), ('windows 8', 'amazing', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Windows 8', 'like', 'positive')]  -- ground_truth : [('Windows 8', 'not like', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Startup times', 'long', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('colors', 'stunning', 'positive')]  -- ground_truth : [('colors', 'stunning', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('shipping', 'free', 'positive')]  -- ground_truth : [('price', 'great', 'positive'), ('shipping', 'free', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('mouse', 'terrific', 'neutral')]  -- ground_truth : [('mouse', 'terrific', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('battery', 'thick', 'neutral')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('windows 7', 'like', 'neutral')]  -- ground_truth : [('windows 7', 'charm', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('delivery', 'great', 'positive'), ('price', 'great', 'positive'), ('product', 'Great', 'positive'), ('service', 'great', 'positive')]  -- ground_truth : [('price', 'great', 'positive'), ('delivery', 'great', 'positive'), ('service', 'great', 'positive')]  --- TP: 3  - FP: 1  - FN: 0
# **************************************************
#  predicted : [('customer service', 'great', 'positive')]  -- ground_truth : [('customer service', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('windows', 'hated', 'negative')]  -- ground_truth : [('windows 8', 'hated', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Set up', 'breeze', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Win8', 'like', 'neutral')]  -- ground_truth : [('Win8', 'NOT like', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('OSX', 'lack', 'neutral')]  -- ground_truth : [('OSX', 'overbearing', 'negative'), ('support for games', 'lack', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('boy', 'bad', 'negative')]  -- ground_truth : [('mobility', 'nice', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('mini', 'easy', 'positive')]  -- ground_truth : [('set up', 'easy', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('sound', 'nice', 'positive')]  -- ground_truth : [('sound', 'nice', 'positive'), ('sound', 'loud', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('track pad', 'impressed', 'positive')]  -- ground_truth : [('track pad', 'slim', 'positive'), ('track pad', 'impressed', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('settings', 'not user-friendly', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('OpenOffice', 'goodness', 'neutral')]  -- ground_truth : [('OpenOffice', 'goodness', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('UX', 'wonderful', 'positive'), ('battery life', 'great', 'positive'), ('form factor', 'Awesome', 'positive')]  -- ground_truth : [('form factor', 'Awesome', 'positive'), ('battery life', 'great', 'positive'), ('UX', 'wonderful', 'positive')]  --- TP: 3  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('keyboard', 'love', 'positive')]  -- ground_truth : [('keyboard', 'love', 'positive'), ('screen', 'love', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('touchpad', 'useless', 'negative')]  -- ground_truth : [('touchpad', 'issues', 'negative'), ('touchpad', 'useless', 'negative')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Mavericks', 'impressed', 'positive'), ('computer', 'impressed', 'positive'), ('everything', 'impressed', 'positive')]  -- ground_truth : [('Mavericks', 'impressed', 'positive')]  --- TP: 1  - FP: 2  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('i5', 'Not as fast', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('service', 'great', 'positive')]  -- ground_truth : [('service', 'great', 'positive'), ('shipping', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('built-in applications', 'like', 'positive'), ('performance', 'good', 'positive')]  -- ground_truth : [('performance', 'good', 'positive'), ('built-in applications', 'great', 'positive'), ('iPhoto', 'great', 'positive')]  --- TP: 1  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('hard drive', 'hard', 'negative')]  -- ground_truth : [('Samsung 830 SSD', 'recommend', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('aluminum', 'easily', 'positive'), ('thing', 'good', 'positive')]  -- ground_truth : [('aluminum', 'scratches easily', 'negative')]  --- TP: 0  - FP: 2  - FN: 1
# **************************************************
#  predicted : [('components of the Mac Book', 'dirty', 'negative')]  -- ground_truth : [('components', 'dirty', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('hardware', 'bad', 'negative')]  -- ground_truth : [('hardware', 'bad', 'negative')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('snow lion', 'nice', 'positive')]  -- ground_truth : [('battery', 'nice', 'positive'), ('battery', 'long', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('features', 'wanted', 'positive'), ('features', 'new', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('keyboard', 'sensitive', 'negative')]  -- ground_truth : [('keyboard', 'cheap', 'negative'), ('keyboard', 'not very sensitive', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('sound quality', 'superb', 'positive')]  -- ground_truth : [('sound quality', 'isnt superb', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('navigate', 'easy', 'positive')]  -- ground_truth : [('navigate', 'easy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('battery life', 'wonderful', 'positive')]  -- ground_truth : [('battery life', 'wonderful', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Performance', 'Great', 'positive')]  -- ground_truth : [('Performance', 'Great', 'positive'), ('Quality', 'Great', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('restore disks', 'sure', 'negative')]  -- ground_truth : [('material', 'cheap', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('macbook', 'great', 'positive'), ('os', 'great', 'positive')]  -- ground_truth : [('os', 'great', 'positive')]  --- TP: 1  - FP: 1  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('works', 'as anticipated', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('System', 'great', 'positive')]  -- ground_truth : [('System', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('setting', 'Easy', 'positive')]  -- ground_truth : [('customize setting', 'Easy', 'positive'), ('create your own bookmarks', 'Easy', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('working', 'well', 'positive')]  -- ground_truth : [('price', 'good', 'positive'), ('working', 'well', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('operating system', 'super', 'positive')]  -- ground_truth : [('operating system', 'new', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('set up', 'Easy', 'positive')]  -- ground_truth : [('set up', 'Easy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('hard drive', 'hard', 'positive')]  -- ground_truth : [('hard drive', 'quiet', 'positive'), ('boots up', 'quick', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('works', 'great', 'positive')]  -- ground_truth : [('works', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('working', 'responsive', 'positive')]  -- ground_truth : [('working', 'pleasurable', 'positive'), ('surfing', 'pleasurable', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('software', 'pretty', 'positive'), ('works', 'fine', 'positive')]  -- ground_truth : [('works', 'fine', 'positive'), ('software', 'well', 'positive')]  --- TP: 1  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('performance', 'great', 'positive')]  -- ground_truth : [('performance', 'great', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('Harddrive', 'poor', 'negative')]  -- ground_truth : [('Harddrive', 'poor', 'negative')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('on/off switch', 'obscure', 'neutral')]  -- ground_truth : [('on/off switch', 'obscure', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('instructions', 'lack', 'negative')]  -- ground_truth : [('instructions', 'lack', 'negative')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('gaming', 'good', 'positive'), ('integrated Intel 4000 graphics', 'well', 'negative')]  -- ground_truth : [('gaming', 'not be good', 'negative')]  --- TP: 0  - FP: 2  - FN: 1
# **************************************************
#  predicted : [('content creation', 'creation', 'positive'), ('photo editing', 'reliable', 'neutral')]  -- ground_truth : [('Audio', 'reliable', 'positive'), ('video', 'reliable', 'positive'), ('photo editing', 'reliable', 'positive')]  --- TP: 0  - FP: 2  - FN: 3
# **************************************************
#  predicted : [('Screen', 'bright', 'positive')]  -- ground_truth : [('Screen', 'bright', 'positive'), ('Screen', 'gorgeous', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('use', 'friendly', 'positive')]  -- ground_truth : [('use', 'friendly', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('use', 'easy', 'positive')]  -- ground_truth : [('use', 'easy', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('fact', 'definitely', 'neutral'), ('processor', 'definitely', 'neutral'), ('things', 'definitely', 'neutral')]  -- ground_truth : [('i5 processor', 'speeds things up', 'positive')]  --- TP: 0  - FP: 3  - FN: 1
# **************************************************
#  predicted : [('built in features', 'great', 'positive')]  -- ground_truth : [('built in features', 'great help', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('keyboard', 'great', 'positive'), ('screen', 'Nice', 'positive')]  -- ground_truth : [('screen', 'Nice', 'positive'), ('keyboard', 'great', 'positive')]  --- TP: 2  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('delivery', 'amazed', 'positive')]  -- ground_truth : [('delivery', 'amazed', 'positive'), ('delivery', 'fast', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('memory', 'gone', 'negative')]  -- ground_truth : [('memory', 'gone', 'negative'), ('memory', 'not able to be used', 'negative')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('works', 'great', 'positive')]  -- ground_truth : [('works', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('design', 'like', 'neutral')]  -- ground_truth : [('design', 'like', 'positive'), ('keyboard', 'like', 'positive'), ('keyboard', 'ease of use', 'positive'), ('ports', 'plenty', 'positive')]  --- TP: 0  - FP: 1  - FN: 4
# **************************************************
#  predicted : [('service', 'great', 'positive')]  -- ground_truth : [('service', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('Web browsing', 'quick', 'positive'), ('Safari browser', 'quick', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('lighted screen', 'like', 'neutral')]  -- ground_truth : [('lighted screen', 'like', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('use', 'easy', 'positive')]  -- ground_truth : [('use', 'easy', 'positive'), ('start up', 'quick', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('operation', 'slow', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('USB3 Peripherals', 'less expensive', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('media editing', 'perfect', 'positive')]  -- ground_truth : [('media editing', 'perfect', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('user experience', 'elegant', 'positive')]  -- ground_truth : [('user experience', 'elegant', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('shipment', 'great', 'positive')]  -- ground_truth : [('shipment', 'fast', 'positive'), ('price', 'great', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('performance', 'Excellent', 'positive')]  -- ground_truth : [('performance', 'Excellent', 'positive'), ('usability', 'Excellent', 'positive'), ('presentation', 'Excellent', 'positive'), ('time response', 'Excellent', 'positive')]  --- TP: 1  - FP: 0  - FN: 3
# **************************************************
#  predicted : [('size', 'bonus', 'neutral')]  -- ground_truth : [('size', 'smaller', 'positive'), ('size', 'bonus', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Mac OS', 'blame', 'neutral')]  -- ground_truth : [('Mac OS', 'blame', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('operating system', 'like', 'neutral')]  -- ground_truth : [('operating system', 'like', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('form factor', 'love', 'positive')]  -- ground_truth : [('form factor', 'love', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('loading the internet', 'fast', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('looking', 'faster', 'positive'), ('looking', 'sleeker', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('XP', 'Unfortunately', 'neutral'), ('support', 'Unfortunately', 'negative'), ('support', 'dropping', 'negative')]  --- TP: 0  - FP: 0  - FN: 3
# **************************************************
#  predicted : [('OS', 'pretty', 'positive'), ('keyboard', 'great', 'positive')]  -- ground_truth : [('OS', 'like', 'positive'), ('OS', 'easy', 'positive'), ('overall build', 'great', 'positive'), ('keyboard', 'best', 'positive')]  --- TP: 0  - FP: 2  - FN: 4
# **************************************************
#  predicted : [('construction', 'solid', 'neutral')]  -- ground_truth : [('construction', 'solid', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('construction', 'nice', 'positive')]  -- ground_truth : [('unibody construction', 'nice', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('runs', 'super', 'positive')]  -- ground_truth : [('runs', 'quiet', 'positive'), ('runs', 'cool', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('disk drive', 'ok', 'positive')]  -- ground_truth : [('disk drive', "does n't have", 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('HDMI receptacle', 'no', 'neutral')]  -- ground_truth : [('HDMI receptacle', 'no', 'neutral'), ('SD card slot', 'nor', 'neutral')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('works', 'perfectly', 'positive')]  -- ground_truth : [('works', 'perfectly', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('design app', "do n't have", 'neutral')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('TRACKPAD', 'NOT WORKING', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('finish', 'flawless', 'positive')]  -- ground_truth : [('finish', 'flawless', 'positive'), ('looks', 'solid', 'positive'), ('feels', 'solid', 'positive')]  --- TP: 1  - FP: 0  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('Price', 'higher', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('system', 'forced', 'positive')]  -- ground_truth : [('system', 'not power down', 'negative'), ('power down', 'not', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('configuration', 'perfect', 'positive')]  -- ground_truth : [('configuration', 'perfect', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('speakers', 'worst', 'negative')]  -- ground_truth : [('speakers', 'worst', 'negative')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('trackpad', 'love', 'positive')]  -- ground_truth : [('use', 'easy', 'positive'), ('trackpad', 'love', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Web surfuring', 'smooth', 'positive'), ('Web surfuring', 'seamless', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('interface', 'pleased', 'positive')]  -- ground_truth : [('interface', 'pleased', 'positive'), ('portability', 'pleased', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('carry', 'easy', 'positive'), ('piece', 'beautiful', 'positive'), ('works', 'well', 'neutral')]  -- ground_truth : [('works', 'well', 'positive'), ('carry', 'easy', 'positive'), ('handle', 'easy', 'positive')]  --- TP: 1  - FP: 2  - FN: 2
# **************************************************
#  predicted : [('hardware', 'suffering', 'neutral')]  -- ground_truth : [('performance', 'slow', 'negative'), ('battery lifetime', 'shortening', 'negative'), ('hardware ( keyboard )', 'suffering', 'negative'), ('hardware ( keyboard )', 'issues', 'negative')]  --- TP: 0  - FP: 1  - FN: 4
# **************************************************
#  predicted : [('Runs', 'good', 'positive'), ('ca', 'complain', 'neutral')]  -- ground_truth : [('Runs', 'good', 'positive')]  --- TP: 1  - FP: 1  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('footprint', 'small', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('exterior', 'gorgeous', 'positive')]  -- ground_truth : [('exterior', 'gorgeous', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('performance', 'high', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('graphics chipset', 'defective', 'positive')]  -- ground_truth : [('intel 4000 graphics chipset', 'defective', 'neutral'), ('design', 'defective', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('USB ports', 'mistake', 'neutral')]  -- ground_truth : [('USB ports', 'mistake', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('size', 'perfect', 'positive')]  -- ground_truth : [('size', 'perfect', 'positive'), ('speed', 'perfect', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('CUSTOMER SERVICE', 'TERRIFIC', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('ASUS', 'problems', 'negative'), ('something', 'wanting', 'negative')]  -- ground_truth : [('performed', 'admirably', 'positive')]  --- TP: 0  - FP: 2  - FN: 1
# **************************************************
#  predicted : [('battery cycle count', 'pretty', 'positive'), ('hardware', 'perfectly', 'positive')]  -- ground_truth : [('battery cycle count', 'ZERO', 'positive'), ('battery cycle count', 'surprised', 'positive'), ('hardware', 'perfectly', 'positive')]  --- TP: 1  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('finger swipes', 'fancy', 'neutral')]  -- ground_truth : [('finger swipes', 'fancy', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('screen', 'nice', 'positive')]  -- ground_truth : [('storage', 'big', 'neutral'), ('screen', 'nice', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('speaker quality', 'like', 'positive')]  -- ground_truth : [('Mac OS', 'like', 'positive'), ('speaker quality', 'lacking', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Shipped', 'safely', 'positive')]  -- ground_truth : [('Shipped', 'quickly', 'positive'), ('Shipped', 'safely', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('thunderbolt port', 'awesome', 'positive')]  -- ground_truth : [('thunderbolt port', 'awesome', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('performance', 'definitely', 'positive')]  -- ground_truth : [('performance', 'superior', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('streaming video', 'great', 'positive')]  -- ground_truth : [('streaming video', 'great', 'positive'), ('entertainment uses', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('design', 'like', 'neutral')]  -- ground_truth : [('design', 'like', 'positive'), ('features', 'needs to be improved', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Mac', 'problems', 'negative'), ('office', 'problems', 'negative')]  -- ground_truth : [('Mac office', 'problems', 'negative')]  --- TP: 0  - FP: 2  - FN: 1
# **************************************************
#  predicted : [('Imacs', 'disappointed', 'negative'), ('mac', 'disappointed', 'negative'), ('mini', 'disappointed', 'negative'), ('spec', 'disappointed', 'negative')]  -- ground_truth : [('spec', 'disappointed', 'negative')]  --- TP: 1  - FP: 3  - FN: 0
# **************************************************
#  predicted : [('use', 'easy', 'positive')]  -- ground_truth : [('use', 'easy', 'positive'), ('looks', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Performance', 'better', 'positive')]  -- ground_truth : [('Performance', 'better', 'positive'), ('SSD', 'better', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('MagSafe accessories', 'not work', 'neutral'), ('MagSafe 2 connection', 'not work', 'negative')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('mouse', 'recommend', 'neutral'), ('things', 'want', 'neutral'), ('times', 'want', 'neutral'), ('touchpad', 'dislike', 'neutral')]  -- ground_truth : [('touchpad', 'dislike', 'negative'), ('touchpad', 'unresponsive', 'negative'), ('mouse', 'recommend', 'neutral')]  --- TP: 1  - FP: 3  - FN: 2
# **************************************************
#  predicted : [('runs', 'huge', 'positive')]  -- ground_truth : [('runs', 'quiet', 'positive'), ('fans', "are n't audible", 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('transition', 'difficult', 'positive')]  -- ground_truth : [('Mac ecosystem', 'take some time', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('price', 'worth', 'positive')]  -- ground_truth : [('price', 'wonderful', 'positive'), ('price', 'worth', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('use', 'ease', 'positive')]  -- ground_truth : [('use', 'please', 'positive'), ('use', 'ease', 'positive'), ('appearance', 'please', 'positive'), ('functionality', 'please', 'positive')]  --- TP: 1  - FP: 0  - FN: 3
# **************************************************
#  predicted : [('graphic design classes', 'Perfect', 'positive')]  -- ground_truth : [('graphic design', 'Perfect', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('slot', 'not be using', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('OS', 'fast', 'positive'), ('OS', 'fluid', 'positive'), ('OS', 'organized', 'positive'), ('OS', 'beautiful', 'positive')]  --- TP: 0  - FP: 0  - FN: 4
# **************************************************
#  predicted : []  -- ground_truth : [('use', 'simpler', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('SSD', 'nice', 'positive')]  -- ground_truth : [('SSD', 'nice', 'positive'), ('SSD', 'stable', 'positive'), ('SSD', 'fast', 'positive')]  --- TP: 1  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('start up', 'love', 'positive')]  -- ground_truth : [('start up', 'love', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('functionality', 'beat', 'neutral')]  -- ground_truth : [('functionality', 'can not beat', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('function', 'properly', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Graphics', 'improved', 'positive')]  -- ground_truth : [('Graphics', 'improved', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('Build Quality', 'confident', 'positive')]  -- ground_truth : [('Build Quality', 'confident', 'positive'), ('unibody construction', "ca n't beat", 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('flexibility for connectivity', 'more', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Mac tutorials', 'help', 'neutral')]  -- ground_truth : [('Mac tutorials', 'help', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('technical support', 'helpful', 'neutral')]  -- ground_truth : [('technical support', 'not helpful', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('adapter', 'no', 'positive')]  -- ground_truth : [('adapter', 'new', 'neutral'), ('adapter', 'no change', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('Logic board', 'utterly fried', 'positive'), ('Logic board', 'cried', 'positive'), ('Logic board', 'laid down', 'positive'), ('Logic board', 'died', 'positive')]  --- TP: 0  - FP: 0  - FN: 4
# **************************************************
#  predicted : [('sound', 'crappy', 'positive')]  -- ground_truth : [('sound', 'crappy', 'negative'), ('volume', 'crappy', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('OSX Lion', 'great', 'positive')]  -- ground_truth : [('OSX Lion', 'great', 'positive'), ('OSX Lion', 'fast', 'positive'), ('OSX Lion', 'reliable', 'positive')]  --- TP: 1  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('Mac', 'friends', 'neutral'), ('application', 'crash', 'positive'), ('family', 'friends', 'neutral'), ('product', 'friends', 'neutral')]  -- ground_truth : [('application', 'crash', 'negative')]  --- TP: 0  - FP: 4  - FN: 1
# **************************************************
#  predicted : [('Macbook', 'wonderful', 'positive'), ('form', 'wonderful', 'positive')]  -- ground_truth : [('physical form', 'wonderful', 'positive')]  --- TP: 0  - FP: 2  - FN: 1
# **************************************************
#  predicted : [('Mini', 'good', 'positive')]  -- ground_truth : [('body', "has n't changed", 'positive'), ('body', 'good', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('unibody construction', 'solid', 'positive')]  -- ground_truth : [('unibody construction', 'solid', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('3D rendering', 'slows it down', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('apps', 'beautiful', 'positive'), ('screen', 'great', 'positive')]  -- ground_truth : [('screen', 'fast', 'positive'), ('screen', 'great', 'positive'), ('apps', 'beautiful', 'positive')]  --- TP: 2  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('ports', 'much needed', 'neutral')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('package', 'nice', 'positive')]  -- ground_truth : [('package', 'neat', 'positive'), ('package', 'nice', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('cover', 'better', 'positive')]  -- ground_truth : [('cover', 'a little better', 'neutral'), ('cover', 'complaint', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('gestures', 'unconsciously', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('extender cable', 'hoping', 'positive')]  -- ground_truth : [('cable', 'nice', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('2.9ghz dual-core i7 chip', 'really', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('seconds', 'good', 'positive')]  -- ground_truth : [('starts up', 'snappy', 'positive'), ('starts up', 'good', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Windows 8', 'sure', 'negative')]  -- ground_truth : [('Windows 8', 'Not sure', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('CD drive', 'complaint', 'negative')]  -- ground_truth : [('internal CD drive', 'complaint', 'negative'), ('internal CD drive', 'no', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('hard drive', 'no', 'positive')]  -- ground_truth : [('hard drive', 'no', 'neutral'), ('network lights', 'no', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('storage', 'enough', 'positive'), ('ports', 'enough', 'positive')]  --- TP: 0  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('audio volume', 'low', 'neutral')]  -- ground_truth : [('audio volume', 'low', 'negative'), ('audio volume', 'unusable', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
# ...
# **************************************************
#  predicted : [('menu', 'excited', 'positive')]  -- ground_truth : [('menu', 'creative', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('food', 'good', 'positive')]  -- ground_truth : [('food', 'good', 'negative'), ('food', 'overpriced', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('favortie pizza joint', 'favortie', 'neutral')]  -- ground_truth : [('pizza joint', 'favortie', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('pizza', 'delicious', 'positive')]  -- ground_truth : [('pizza', 'delicious', 'positive'), ('salads', 'fantastic', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('cooks', 'friendly', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('decor', 'simplicity', 'positive')]  -- ground_truth : [('decor', 'enjoy', 'positive'), ('decor', 'simplicity', 'positive'), ('feeling', 'intimate', 'positive')]  --- TP: 1  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('eating', 'love', 'positive')]  -- ground_truth : [('Mioposto Café', 'love', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('menu', 'disappointed', 'negative')]  -- ground_truth : [('menu', 'won ’ t be disappointed', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('pizza', 'creative', 'positive')]  -- ground_truth : [('menu', 'creative', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Pizza Ensalata', 'Try', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('pizza', 'huge', 'negative')]  -- ground_truth : [('crust', 'thin', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('food', 'sinful', 'neutral')]  -- ground_truth : [('food', 'sinful', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('staff', 'friendly', 'positive')]  -- ground_truth : [('staff', 'friendly', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('atmosphere', 'great', 'positive')]  -- ground_truth : [('atmosphere', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('pancakes', 'decadent', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('menu', 'amazing', 'positive')]  -- ground_truth : [('menu', 'amazing', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('eats', 'Good', 'positive')]  -- ground_truth : [('eats', 'Good', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('place', 'BAD', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('fish', 'good', 'positive')]  -- ground_truth : [('fish', 'decent', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('chef', 'special', 'positive')]  -- ground_truth : [('chef special dinner', 'dissappointment', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('atmosphere', 'great', 'positive')]  -- ground_truth : [('atmosphere', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('dish', 'best', 'positive')]  -- ground_truth : [('honwy walnut prawns', 'best', 'positive'), ('honwy walnut prawns', 'outstanding', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('service', 'charming', 'positive')]  -- ground_truth : [('service', 'attentive', 'positive'), ('service', 'charming', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('food', 'outstanding', 'positive'), ('service', 'excellent', 'positive')]  -- ground_truth : [('service', 'excellent', 'positive'), ('coffee', 'good', 'positive'), ('food', 'outstanding', 'positive')]  --- TP: 2  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('restaurant', 'delightful', 'positive')]  -- ground_truth : [('restaurant', 'delightful', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('food', 'fantastic', 'positive')]  -- ground_truth : [('food', 'fantastic', 'positive'), ('food', 'authentic', 'positive'), ('food', 'delicious', 'positive'), ('food', 'affordable', 'positive')]  --- TP: 1  - FP: 0  - FN: 3
# **************************************************
#  predicted : [('decor', 'beautiful', 'positive')]  -- ground_truth : [('decor', 'beautiful', 'positive'), ('decor', 'unique', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('atmosphere', 'happy', 'positive'), ('vibe', 'nice', 'positive')]  -- ground_truth : [('music', 'good', 'positive'), ('atmosphere', 'good', 'positive'), ('vibe', 'nice', 'positive'), ('people', 'happy', 'positive')]  --- TP: 1  - FP: 1  - FN: 3
# **************************************************
#  predicted : [('server', 'friendly', 'positive')]  -- ground_truth : [('server', 'professional', 'positive'), ('server', 'friendly', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('table', 'easier', 'neutral')]  -- ground_truth : [('place', 'tiny', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('menu', 'delectable', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('waiters', 'experienced', 'positive')]  -- ground_truth : [('waiters', 'experienced', 'positive'), ('waiters', 'helpful', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('sushi', 'fresh', 'positive')]  -- ground_truth : [('sushi', 'fresh', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('fish taste', 'interested', 'positive'), ('portions', 'creative', 'positive')]  -- ground_truth : [('portions', 'large', 'positive'), ('sushi dishes', 'creative', 'positive')]  --- TP: 0  - FP: 2  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('pepperoni', 'big thick', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('pepperoni', 'Yum', 'negative')]  -- ground_truth : [("pepperoni 's", 'thick', 'positive'), ("pepperoni 's", 'Yum', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('pizza', 'best', 'positive')]  -- ground_truth : [('pizza', 'not exactly the best', 'positive'), ('pizza', 'good', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Food', 'good', 'positive')]  -- ground_truth : [('Food', 'good', 'positive'), ('Food', 'appetizing', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Portions', 'enough', 'neutral')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('menu selection', 'Fair', 'positive')]  -- ground_truth : [('menu selection', 'Fair', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('Creme Brulee', 'delicious', 'positive'), ('appetizer', 'interesting', 'positive')]  -- ground_truth : [('appetizer', 'interesting', 'positive'), ('Creme Brulee', 'savory', 'positive'), ('Creme Brulee', 'delicious', 'positive')]  --- TP: 2  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('Indoor ambience', 'modern', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('place', 'great', 'positive')]  -- ground_truth : [('place', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('food', 'exeptional', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('table', 'nice', 'positive')]  -- ground_truth : [('table', 'private', 'positive'), ('table', 'nice', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('service', 'feeling', 'positive')]  -- ground_truth : [('service', 'exceptional', 'positive'), ('waiters', 'friendly', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('filet mignon', 'best', 'positive'), ('food', 'good', 'positive')]  -- ground_truth : [('food', 'good', 'positive'), ('filet mignon', 'best', 'positive')]  --- TP: 2  - FP: 0  - FN: 0
# **************************************************
#  predicted : []  -- ground_truth : [('portions', 'big', 'neutral')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('dinner casual', 'casual', 'negative')]  -- ground_truth : [('music', 'casual', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('bathroom', 'odd', 'positive')]  -- ground_truth : [('restroom', 'odd', 'negative')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('bathroom', 'small', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('service', 'awesome', 'positive')]  -- ground_truth : [('service', 'awesome', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('decor', 'festive', 'positive')]  -- ground_truth : [('atmosphere', 'aspiring', 'positive'), ('decor', 'festive', 'positive'), ('decor', 'amazing', 'positive')]  --- TP: 1  - FP: 0  - FN: 2
# **************************************************
#  predicted : [('chicken vegetable soup', 'rocks', 'negative')]  -- ground_truth : [('Raouls chicken vegetable soup', 'rocks my world', 'positive'), ('catering', 'out of this world', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('World', 'like', 'neutral'), ('country', 'like', 'neutral'), ('door', 'like', 'neutral')]  -- ground_truth : [('Drinks', 'suberb', 'positive')]  --- TP: 0  - FP: 3  - FN: 1
# **************************************************
#  predicted : [('Mediocre Service', 'Quality', 'negative')]  -- ground_truth : [('Service', 'Mediocre', 'neutral')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('IHOP', 'sophisticated', 'positive'), ('Snooze', 'excellent', 'positive'), ('brow', 'sophisticated', 'positive'), ('layers', 'sophisticated', 'positive'), ('menu', 'sophisticated', 'positive'), ('places', 'sophisticated', 'positive'), ('presentation', 'excellent', 'positive')]  -- ground_truth : [('Snooze', 'excellent', 'negative'), ('menu', 'high brow', 'negative')]  --- TP: 0  - FP: 7  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('juice', 'small', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('menu', 'unique', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('pancakes', 'certainly', 'positive')]  -- ground_truth : [('pancakes', 'inventive', 'negative'), ('pancakes', 'over-priced', 'negative')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : []  -- ground_truth : [('pancakes', 'should be larger', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : []  -- ground_truth : [('pancakes', 'small', 'negative')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('view', 'great', 'positive')]  -- ground_truth : [('view', 'great', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('dinner', 'pleased', 'positive')]  -- ground_truth : [("Ray 's Boathouse", 'exceeded my expectations', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('Sound views', 'gorgeous', 'positive'), ('food', 'accolades', 'positive')]  -- ground_truth : [('Sound views', 'gorgeous', 'positive')]  --- TP: 1  - FP: 1  - FN: 0
# **************************************************
#  predicted : [('views', 'surprise', 'positive')]  -- ground_truth : [("Ray 's", 'happy surprise', 'positive')]  --- TP: 0  - FP: 1  - FN: 1
# **************************************************
#  predicted : [('drink order', 'lovely', 'positive')]  -- ground_truth : [('Brooke', 'lovely', 'positive'), ('Brooke', 'quickly', 'positive')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('Shilshole Sampler', 'beautiful', 'positive'), ('butter sauce', 'sublime', 'neutral'), ('manila', 'fantastic', 'positive'), ('scallops', 'tasty', 'neutral')]  -- ground_truth : [('white gulf prawns', 'enormous', 'positive'), ('manila clams', 'fantastic', 'positive'), ('soy dressing', 'tasty', 'positive'), ('butter sauce', 'sublime', 'positive')]  --- TP: 0  - FP: 4  - FN: 4
# **************************************************
#  predicted : [('seared Alaskan sea scallops', 'enjoyed', 'positive')]  -- ground_truth : [('seared Alaskan sea scallops', 'enjoyed', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
#  predicted : [('scallops', 'unique', 'positive')]  -- ground_truth : [('scallops', 'unique', 'positive'), ('scallops', 'tasty', 'positive')]  --- TP: 1  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('Alaskan King Salmon', 'friend', 'positive')]  -- ground_truth : [('grilled Alaskan King Salmon', 'enjoyed', 'positive'), ('creamed Washington russet potatoes', 'delectable', 'positive'), ('green beans', 'crisp', 'positive')]  --- TP: 0  - FP: 1  - FN: 3
# **************************************************
#  predicted : []  -- ground_truth : [('plate', 'superb', 'positive')]  --- TP: 0  - FP: 0  - FN: 1
# **************************************************
#  predicted : [('dinner', 'puzzled', 'positive')]  -- ground_truth : [('server', 'attentive', 'positive'), ("Ray 's", 'appropriate', 'neutral')]  --- TP: 0  - FP: 1  - FN: 2
# **************************************************
#  predicted : [('evening', 'shared', 'neutral'), ('server', 'wonderful', 'positive'), ('youth', 'shared', 'neutral')]  -- ground_truth : [('server', 'wonderful', 'positive'), ('food', 'wonderful', 'positive')]  --- TP: 1  - FP: 2  - FN: 1
# **************************************************
#  predicted : [('view', 'good', 'positive')]  -- ground_truth : [('view', 'good', 'positive')]  --- TP: 1  - FP: 0  - FN: 0
# **************************************************
# Average Precision: 0.4018449137148048
# Average Recall: 0.3207327753989878
# Average F1 Score: 0.34089112711387964
# Average Jaccard Score: 0.30404015829765135

# %% [markdown]
# # Conclusion

# %% [markdown]
# Cette généralisation met en évidence les faiblesses de la méthode, notamment sa difficulté à identifier des aspects inédits. De plus, l'utilisation de NLTK pour le traitement du langage naturel présente des limitations, étant moins adaptée pour des tâches complexes ou spécifiques. Les imperfections dans la génération de triplets, particulièrement dans l'identification précise des aspects et des opinions, sont amplifiées par les contraintes des outils et méthodes utilisés. Ces défauts deviennent plus apparents lors des tentatives d'affinement ou d'optimisation du processus.
#
# Les problèmes liés aux données de base sont également critiques : la qualité et la diversité des données influencent grandement la performance des modèles ABSA. Les données limitées ou biaisées peuvent mener à des prédictions peu fiables, et les modèles pourraient peiner à généraliser à partir de ces données.
#
# L'approche adoptée pour généraliser à partir des listes d'aspects et d'opinions de chaque texte est certes audacieuse mais peut être ambiguë, compte tenu de la complexité et de la subtilité du langage naturel. Cela peut conduire à des interprétations erronées des sentiments exprimés.
#
# Pour améliorer cette approche, il serait judicieux d'envisager des techniques plus sophistiquées voir des modèles de langage pré-entraînés comme GPT. Ces technologies sont plus aptes à gérer la complexité du langage naturel et à identifier des aspects et opinions nouveaux.
# En outre, un ensemble de données plus riche et diversifié pourrait favoriser une meilleure généralisation des modèles. partir d'un dataset faible en relation en raisons de la necessité d'avoir une quantité suffisante reduit drastiquement la qualité de ce dernier.
